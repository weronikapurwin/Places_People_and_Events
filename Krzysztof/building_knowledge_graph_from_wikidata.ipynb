# %% [markdown]
# # Imports

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import sys
from neo4j import GraphDatabase
from neo4j.exceptions import CypherSyntaxError
from SPARQLWrapper import SPARQLWrapper, JSON  # pip install sparqlwrapper

# %% [markdown]
# # Defined functions

# %%
def get_sparql_results(endpoint_url, query):
    # Helper function
    user_agent = f"WDQS-example Python/{sys.version_info[0]}.{sys.version_info[1]}"  # https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %%
def scrape_qcodes(list, humans_only=False, first_only=False):
    """
    Gets Q codes and urls for wikidata pages from the first page of search results.
    
    list: list of search names, eg. ['Fryderyk Chopin', 'Ferenc Liszt', 'Wojciech Żywny']
    first_only: if True, gets data from the first link (result) only
    returns: list of dicts (search_name, page_name, description, Qcode, wiki_url)
             if page with given name doesn't exist, its qcode is ommited
    """
    retv = []
    input_length = len(list)-1
    for i, search_name in enumerate(list):
        print(f"Scraping... {i+1}/{input_length} ... " + search_name)
        url = f"https://www.wikidata.org/w/index.php?go=Go&search={search_name}"
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "html.parser")
        for item in soup.find_all('li', class_="mw-search-result mw-search-result-ns-0"):
            page_name = item.find('a', title=True)['title'].lstrip('\u200e').split('\u200e')[0]
            try:
                description = item.find('a', title=True)['title'].lstrip('\u200e').split('\u200e')[2]
            except IndexError:
                description = None
            href = item.find('a', href=True).get('href')
            Qcode = href.lstrip('/wiki/')
            wiki_url = f"https://www.wikidata.org{href}"
            if humans_only:
                human_test = get_all_human_objects([Qcode])
                if human_test:
                    retv.append({'search_name': search_name, 'page_name': page_name, 'description':description, 'Qcode': Qcode, 'wiki_url': wiki_url,})
                    if first_only:
                        break
            else:
                retv.append({'search_name': search_name, 'page_name': page_name, 'description':description, 'Qcode': Qcode, 'wiki_url': wiki_url,})
                if first_only:
                    break
    return retv

# %%
def get_all_triples_and_qcodes(Qcode, allow_literals=True):
    """
    Args:
        Qcode: wikidata subject Qcode, eg.: 'Q255'
        allow_literals: whether to allow returning literal objects (objects not represented as wikidata/wikimedia pages) associated with subject's Qcode

    Returns (First value returned): 
        list of tuples representig RDF triples (object-predicate-subject) and labels associated with each wikidata entity

        Example tuple representing RDF triple:
            ('http://www.wikidata.org/entity/Q255',
            'http://www.wikidata.org/entity/P19',
            'http://www.wikidata.org/entity/Q586',
            'Ludwig van Beethoven',
            'place of birth',
            'Bonn')
        Tuple contents:
            (object,
            predicate,
            subject,
            objectLabel,
            predicateLabel,
            subjectLabel)

    Returns (Second value returned): 
        list of all Qcodes of wikidata objects associated with provided subject (Qcode)

        Example:
            ['Q255', Q'1268']
    """
    #  UWAGA:  Z jakiegoś powodu query poniżej zwraca wielokrotnie zduplikowane wyniki, pewnie błąd leży po stronie twórców biblioteki SPARQLWrapper.
    #          To samo zapytanie wprwadzowne w https://query.wikidata.org/ zwraca normalne, nie powielane wyniki.
    #          Poprawiłem to dopiero przy dodawaniu krotek do listy trójek RDF.
    endpoint_url = "https://query.wikidata.org/sparql"
    query = """SELECT DISTINCT ?s ?sLabel ?wd ?wdLabel ?o ?oLabel   WHERE {
    SERVICE wikibase:label { bd:serviceParam wikibase:language "en,pl". }
    VALUES ?s { wd:%s }
    # ?s ?wdt ?o.
    # ?wd wikibase:directClaim ?wdt.
    # ?wd rdfs:label ?wdLabel.
    FILTER((LANG(?wdLabel)) = "en")
    }
    ORDER BY (xsd:integer(STRAFTER(STR(?wd), "http://www.wikidata.org/entity/P")))"""%(Qcode) 
    results = get_sparql_results(endpoint_url, query)

    list_of_triples = []
    for result in results["results"]["bindings"]:
        # print(result['wdLabel']['value'])
        try:
            if result['wdLabel']['value'].__contains__('date'):  # np. Personendatenbank Germania Sacra tu wchodzi, ale to nie data...
                t = (result['s']['value'], result['wd']['value'], result['o']['datatype'], result['sLabel']['value'], result['wdLabel']['value'], result['oLabel']['value'])
        except KeyError: # Personendatenbank Germania Sacra... 
            pass  # Personendatenbank Germania Sacra... 
        if not allow_literals:
            if result['o']['type'] != 'literal':
                t = (result['s']['value'], result['wd']['value'], result['o']['value'], result['sLabel']['value'], result['wdLabel']['value'], result['oLabel']['value'])
        else:
            t = (result['s']['value'], result['wd']['value'], result['o']['value'], result['sLabel']['value'], result['wdLabel']['value'], result['oLabel']['value'])
        if t not in list_of_triples:  # <-- o tutaj
            list_of_triples.append(t)

    object_qcodes = []
    for t in list_of_triples:
        object_url = t[2]
        if "http://www.wikidata.org/entity/Q" in object_url:
            Qcode = object_url[object_url.rfind('Q'):]
            object_qcodes.append(Qcode)

    return list_of_triples, object_qcodes

# %%
def get_all_human_objects(list_of_qcodes):
    """
    Filters wikidata objects based on provided Qcodes. Returns only objects which are instance_of human.

    Args:
        list_of_qcodes example: ['Q255', Q'1268']
    
    Returns:
        list of tuples representing humans (qcode, wikidata object url, name)
    """
    #  UWAGA:  Z jakiegoś powodu query poniżej zwraca wielokrotnie zduplikowane wyniki, pewnie błąd leży po stronie twórców biblioteki SPARQLWrapper.
    #          To samo zapytanie wprwadzowne w https://query.wikidata.org/ zwraca normalne, nie powielane wyniki.
    #          Poprawiłem to przy przygotowywaniu zwracanego wyniku
    list_of_wdqcodes = ["wd:" + qcode for qcode in list_of_qcodes]
    query_check_objects = """SELECT ?qcode ?qcodeLabel WHERE {{
    SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en,pl". }}
    VALUES ?qcode {{ {} }}
    # ?qcode wdt:P31 wd:Q5.
    }}""".format(' '.join(list_of_wdqcodes))
    endpoint_url="https://query.wikidata.org/sparql"
    humans = get_sparql_results(endpoint_url, query_check_objects)
    urls_qcodes_names = []
    for r in humans["results"]["bindings"]:
        url_qcode_and_name = (r['qcode']['value'][r['qcode']['value'].rfind('Q'):], r['qcode']['value'], r['qcodeLabel']['value'])
        if url_qcode_and_name not in urls_qcodes_names:
            urls_qcodes_names.append(url_qcode_and_name)
    return urls_qcodes_names

# %%
def recursive_get_rdf_info(input_qcodes, level=3):
    """For each provided qcode gets all rdf triples from wikidata. Also gets all rdf triples for humans associated with provided qcodes.
    If level=2, then also gets all rdf triples for humans associated with humans associated provided qcodes, etc...

    Args:
        input_qcodes (List): list of qcodes
        level (int, optional): "Depth of the recursive tree". Defaults to 3.

    Returns:
        Dict: Dictionary with qcodsccanocfdsgjwkdbfj:)lk]dsgdsa
    """
    rdf_dict = dict()
    current_humans = []
    for Q in input_qcodes:
        triples, all_qcodes = get_all_triples_and_qcodes(Q, allow_literals=True)
        rdf_dict[Q] = triples
        tuples = get_all_human_objects(all_qcodes)
        humans = [t[0] for t in tuples]  # human qcodes associated with Q qcode
        for new_qcode in humans:
            if new_qcode not in current_humans:
                current_humans.append(new_qcode)
            triples, all_qcodes = get_all_triples_and_qcodes(new_qcode, allow_literals=True)
            rdf_dict[new_qcode] = triples
    if level > 1:
        print("Done: ", input_qcodes)
        return recursive_get_rdf_info(current_humans, level=level-1)
    else:  # level == 1
        print("Done: ", input_qcodes)
        return rdf_dict

# %%
def recursive_get_rdf_info_v2_TO_CHECK(input_qcodes, level=3):
    """For each provided qcode gets all rdf triples from wikidata. Also gets all rdf triples for humans associated with provided qcodes.
    If level=2, then also gets all rdf triples for humans associated with humans associated provided qcodes, etc...

    Args:
        input_qcodes (List): list of qcodes
        level (int, optional): "Depth of the recursive tree". Defaults to 3.

    Returns:
        Dict: Dictionary with qcodsccanocfdsgjwkdbfj:)lk]dsgdsa
    """
    rdf_dict = dict()
    current_humans = []
    for Q in input_qcodes:
        if Q not in rdf_dict.keys():
            triples, all_qcodes = get_all_triples_and_qcodes(Q, allow_literals=True)
            rdf_dict[Q] = triples
            tuples = get_all_human_objects(all_qcodes)
            humans = [t[0] for t in tuples]  # human qcodes associated with Q qcode
        else:
            humans = []
        for new_qcode in humans:
            if new_qcode not in current_humans:
                current_humans.append(new_qcode)
            if new_qcode not in rdf_dict.keys():
                triples, all_qcodes = get_all_triples_and_qcodes(new_qcode, allow_literals=True)
                rdf_dict[new_qcode] = triples
    if level > 1:
        print("Done: ", input_qcodes)
        return recursive_get_rdf_info_v2_TO_CHECK(current_humans, level=level-1)
    else:  # level == 1
        print("Done: ", input_qcodes)
        return rdf_dict

# %% [markdown]
# # Input: List of persons ```(names from .txt file)```

# %%
with open("unique_persons.txt", 'r') as f:
    input = [name for name in f.read().splitlines() if len(name.split())!=1]
# input = ['Beethoven', 'Rachmaninoff', 'Mahler', 'Delta rzeki Okawango', 'Susanne Gibson-Milne', 'asfasfafasfs', 'sekwoja', 'Pierre']
# input = ['Rachmaninov']

# %%
print(len(input))
input
# Out:
# 399
# ['Antoni Kątski',
#  'Emilia Chopin',
#  'Louis Boulanger',
#  'Godefroi de Bouillon',
#  'Peter Paul Rubens',
#  'Susanne Gibson-Milner',
#  'Ernest Canut',
#  'Augustine Brault',
#  'Izabella Działyńska (hrabina)',
#  'Marie d’Agoult',
#  'Amélie Franchomme',
#  'Kazimierz Wernik',
#  'Josef Dessauer',
#  'Vera Rubio',
#  'Franciszek Skibicki',
#  'François-Victor Hugo',
#  'Sabine Heinefetter',
#  'Thomas Bohier',
#  'Aleksander Colonna-Walewski (książę)',
#  'Francesco de Vico',
#  'Urbain Jean-Joseph Le Verrier',
#  'Augustine Marie Bertholdi',
#  'Fontana Juanna Camila',
#  'Václav Hanka',
#  'Ludwika Magdalena Ciechomska',
#  'Gustaw Planche',
#  'Giulia Grisi',
#  'François-Joseph Gossec',
#  'Honorata Dziewanowska',
#  'Antoine de Orléans',
#  'Jan Křtitel Pišek',
#  'Władysław Żeleński',
#  'Adolphe d Ennery',
#  'Władysław Czartoryski',
#  'Henryk Jędrzejewicz',
#  'Mikołaj Chopin',
#  'Aleksandra Karasowska',
#  'Jules Janin',
#  'Sigismond von Neukomm',
#  'Thérèse Albrecht',
#  'Adam Towiański',
#  'Jean-Baptiste-Antoine Lassus',
#  'Adam Mickiewicz',
#  'Carl Helminger',
#  'Mary Rich',
#  'Antoni Orłowski',
#  'Fryderyk Skarbek (hrabia)',
#  'Pierre (służący Fryderyka Chopina)',
#  'Józef Kalasanty Jędrzejewicz',
#  'Gemmy Brandus',
#  'Józef Bem',
#  'Fanny Hensel',
#  'Wilhelm Würfel',
#  'Emil Jenike',
#  'Ann Houston',
#  'Aleksander Jełowicki',
#  'Fernand de Préaulx',
#  'Jacques de Vaucanson',
#  'Giuseppe Verdi',
#  'Abraham Louis Breguet',
#  'Karolina Elsner',
#  'Jan Barciński',
#  'Samuel Carter Hall',
#  'Adèle Hugo',
#  'Jean Nicolas Marjolin',
#  'Anna z Tańkowskich Paderewska',
#  'Charles-Valentin Alkan',
#  'Johannes Brahms',
#  'Marie-Amélie, Queen consort of Louis-Philippe',
#  'Joaquina Garcia',
#  'Friedrich Wilhelm Michael Kalkbrenner',
#  'Eugénie de Bonnechose',
#  'Casimir Stanislas d Arpentigny',
#  'María Luisa Fernanda de Borbón',
#  'Ludwik Adam Dmuszewski',
#  'de Perthuis (hrabia)',
#  'Jean-Baptiste Pierret',
#  'Gioacchino Rossini',
#  'Józef Damse',
#  'Heinrich Albert Probst',
#  'Marie Dorval',
#  'Eustachy Marylski',
#  'Adolphe Thiers',
#  'Jean-François Lesueur',
#  'Ludovic Houston',
#  'Hippolyte Chatiron',
#  'Jan Sebastian Bach',
#  'Anna Czartoryska',
#  'Tomasz Nidecki',
#  'Konstanty Pruszak',
#  'Charlotte Marliani',
#  'Feliks Wodziński',
#  'Albert, Prince of Schleswig-Holstein-Glücksburg',
#  'Pierre-Marcel Gaubert',
#  'Maurycy Karasowski',
#  'Tytus Woyciechowski',
#  'Louis James Alfred Lefébure-Wély',
#  'Ksawera Grocholska',
#  'Dominik Dziewanowski',
#  'Louis Spohr',
#  'Poliksena Paderewska',
#  'Norbert Alfons Kumelski',
#  'Piotr Sowiński',
#  'Paul Gavarni',
#  'Felix Mendelssohn-Bartholdy',
#  'Anton Schindler',
#  'Marcelina Czartoryska',
#  'C. P. Sotte',
#  'Adam Jerzy Czartoryski',
#  'Teresa Wodzińska',
#  'Johann Gottfried Galle',
#  'Józef Nowakowski',
#  'Thomas Couture',
#  'Justyna Chopin',
#  'Józef Kurowski',
#  'Joseph Faber',
#  'Józef Michał Poniatowski (książę)',
#  'René Vallet de Villeneuve',
#  'Élisa de Lamartine',
#  'Ludwika Jędrzejewiczowa',
#  'Jean-Baptiste Massillon',
#  'Wilhelm Kolberg',
#  'Léopoldine Hugo',
#  'Pierre Leroux',
#  'Laura Horsford',
#  'Agnès (Mlle)',
#  'Louis-Philippe-Joseph Girod de Vienney (baron de Trémont)',
#  'Angelika Catalani',
#  'August Franchomme',
#  'Clotilde Elisabeth Villetard',
#  'Jadwiga Klementyna Sapieha (księżna)',
#  'Hélène de Mecklembourg-Schwerin (księżna)',
#  'Edmund Chojecki',
#  'Édouard Herbault',
#  'Antonina  Wilkońska',
#  'Jakub Fromental Halévy',
#  'Edward Wolff',
#  'Auguste Mathieu Panseron',
#  'Karol Szulczewski',
#  'Jan Białobłocki',
#  'Marie de Rozières',
#  'Pelagia Skarbkowa',
#  'Christopher Columbus',
#  'Jean Jacques Rousseau',
#  'Juliusz Słowacki',
#  'Anna Liszt',
#  'Regina Hiller',
#  'François-Antoine Habeneck',
#  'Jan Nepomuk Štěpánek',
#  'Gabriel Bonnot de Mably',
#  'Henry Victor Malan',
#  'Marie Thérèse Ducroc de Brassac',
#  'Leopold Louis Sina',
#  'Jean de La Fontaine',
#  'Kazimierz Wodziński',
#  'Ary Scheffer',
#  'Maria Wodzińska',
#  'Ludwika Nakwaska',
#  'Rosine Stoltz',
#  'Adolf Gutmann',
#  'Thérèse Gavard',
#  'Alexandre Dumas',
#  'Katarzyna Potocka (hrabina)',
#  'Cécile Franchomme',
#  'Wincenty Władysław Grzymała',
#  'Ferdynand Hiller',
#  'Juliette Drouet',
#  'Francisco de Asís de Borbón (King, consort of Isabella II)',
#  'Fryderyk Bolesław Jędrzejewicz',
#  'King of France Francis I',
#  'Izabella Barcińska',
#  'Józefa Turowska',
#  'Harriet Leveson-Gower, Duchess of Sutherland',
#  'Isabella di Ricci (Księżna)',
#  'Élise Gavard',
#  'Ksawery Zboiński (hrabia)',
#  'Henri Vieuxtemps',
#  'Louis Brandus',
#  'King of Spain Charles III',
#  'Charles Schunke',
#  'Ludwika Chopin',
#  'Bohdan Zaleski',
#  'Napoleon Orda',
#  'Baron Carlo Marochetti',
#  'Anne Elizabeth Louise Delaroche',
#  'Helena Górska',
#  'Ludwika Dziewanowska',
#  'Giovanni Battista Pergolesi',
#  'Solange Dudevant',
#  'Paul Delaroche',
#  'Madame Etienne',
#  'Louise Franchomme',
#  'Louis Kleinwächter',
#  'Karol Lipiński',
#  'Antoine-Augustin Préault',
#  'Jane Wilhelmina Stirling',
#  'Adolf Cichowski',
#  'Gaspard Deguerry',
#  'Hippolyte Lucas',
#  'Laura Czosnowska (hrabina)',
#  'Catherine de Souzzo (księżna)',
#  'the Commitee of the Concert Society',
#  'Jean-Jacques Molin',
#  'Félix-Auguste Duvert',
#  'Marietta Alboni',
#  'King of France Louis XV',
#  'Wojciech Grzymała',
#  'Solange Clésinger',
#  'Władysław Górski',
#  'Anna Caroline Oury [de Belleville]',
#  'dr Fraenkel',
#  'Eugène Delacroix',
#  'Małgorzata Barcińska',
#  'Charles Aubertin',
#  'Isabella II, Queen of Spain',
#  'Karol Olizar',
#  'Maria Kalergis',
#  'Gustave Roger',
#  'Élisabeth Rachel Félix',
#  'François Guizot',
#  'Karol Franciszek Szulczewski',
#  'François-Joseph Fétis',
#  'Christian Friedrich Schönbein',
#  'Luigi Cherubini',
#  'Salis Schwabe',
#  'Kamila Billing de Courbonne',
#  'Gaetano Donizetti',
#  'Antonio Stradivari',
#  'Jenny Lind',
#  'Thomas Albrecht',
#  'Filippo Coletti',
#  'Jean-Baptiste Clésinger',
#  'Ludwik Piotr Norblin',
#  'Adam Crémieux',
#  'Antoni Żelisław Jędrzejewicz',
#  'Maurycy Dudevant',
#  'Vinzenz Prießnitz',
#  'Härtel from Breitkopf & Härtel company',
#  'Louis Hippolyte Lebas',
#  'Fanny Persiani',
#  'Konstanty Gaszyński',
#  'Stanisław Egbert Koźmian',
#  'Alexandre Artôt',
#  'Katarzyna Diller de Pereira',
#  'William Cavendish (4. diuk Devonshire)',
#  'Julian Fontana',
#  'George Sand',
#  'Françoise (pokojowa George Sand)',
#  'Schuberth & Co. company',
#  'Ignaz Moscheles',
#  'August Clésinger',
#  'Maurice Sand',
#  'Emmanuel Arago',
#  'Oskar Kolberg',
#  'Michael William Balfe',
#  'Stefan Witwicki',
#  'Ignacy Jan Paderewski',
#  'Maurice Schlesinger',
#  'Leopold von Baden',
#  'Ignacy Krasicki',
#  'Jadwiga Ramm',
#  'Ojciec macochy kompozytora, Anny z Tańkowskich Paderewskiej',
#  'Luigi Lablache',
#  'Jean-Antoine Letronne',
#  'Pierre Corneille',
#  'Karol Gavard',
#  'Katherine Erskine',
#  'Breitkopf & Härtel company',
#  'John Hind',
#  'Félicien David',
#  'Amélie Grille de Beuzelin',
#  'Wojciech Żywny',
#  'Giovanni Mario',
#  'Alojzy Janowicz (pułkownik)',
#  'Leopold Thun-Hohenstein',
#  'René Franchomme',
#  'Józefa Dziewanowska',
#  'Friederich Kalkbrenner',
#  'Mary Murray (Lady)',
#  'Frédéric Villot',
#  'Horace Vernet',
#  'William Herschel',
#  'Charles Hugo',
#  'Józef Haydn',
#  'Heinrich Heine',
#  'Robert Schumann',
#  'Elzéar de Sabran',
#  'Victor Hugo',
#  'Carl Reinecke',
#  'Narcisse-Achille de Salvandy (comte)',
#  'Ferenc Liszt',
#  'Józef Dwernicki',
#  'Astolphe de Custine',
#  'Juliusz Dziewanowski',
#  'Lucie (służąca George Sand)',
#  'Marcelina Czartoryska (księżna)',
#  'François Arago',
#  'Mary, Queen of Scots',
#  'Henry Fowler Broadwood',
#  'Józef Brzowski',
#  'Michał Skarbek',
#  'Cécile Mendelssohn-Bartholdy',
#  'Victor Borie',
#  'Auguste Maquet',
#  'Jane Welsh Carlyle',
#  'Antony Deschamps',
#  'Fryderyk Chopin',
#  'Victoria, Queen of Great Britain',
#  'Ferdinando Paër',
#  'Hector Berlioz',
#  'Ignacy Krzyżanowski',
#  'Ernest Legouvé',
#  'Louis Charles Philippe Raphaël Orléans (duc de Nemours)',
#  'Christian Rudolf Wessel',
#  'Zofia Rozengart',
#  'Natalia Obreskow (księżna)',
#  'Casimir Dudevant',
#  'Camille Pleyel',
#  'Auguste Léo',
#  'Anne Françoise Hyppolyte Boutet (Mademoiselle Mars)',
#  'Ludwik Plater',
#  'Józef Stefani',
#  'Jean-Delphin Alard',
#  'Émilie de Perthuis (hrabina)',
#  'Maria de Rozières',
#  'Frédéric Hénique',
#  'Jan Paderewski',
#  'Antoni Wodziński',
#  'Walenty Barciński',
#  'Léon Pillet',
#  'Charles Gavard',
#  'Leon Szmitkowski',
#  'Xavier Durrieu',
#  'Eugène-Théodore Troupenas',
#  'Delfina Potocka',
#  'Nicolas Poussin',
#  'Jeanne-Gabrielle Clésinger',
#  'Charlotte Rothschild (baronowa)',
#  'Anna Maria Walewska (księżna)',
#  'Aleksander Julian Hofman',
#  'Benjamin Lumley',
#  'Ludwik Filip I (król Francuzów)',
#  'Harriet Grote',
#  'Salomea Słowacka',
#  'Zofia Rosengardt-Zaleska',
#  'Józef Bełza',
#  'Michał Babiański',
#  'Suzanne (kucharka George Sand)',
#  'Anna Młokosiewicz',
#  'Ludwig van Beethoven',
#  'Charles Duvernet',
#  'Duke of Orleans Ferdinand Philippe',
#  'von Stockhausen (baronowa)',
#  'Baron de Montesquieu',
#  'Adam Łyszczyński',
#  'Catherine de Médicis, Queen consort of Henry II',
#  'Paulina Plater (hrabianka)',
#  'Paulina Viardot',
#  'Giacomo Meyerbeer',
#  'Michalina Rzyszczewska',
#  'Francisca de Joinville (Princess of Brazil)',
#  'Carlotta Marliani',
#  'Stanisław Grabowski',
#  'Antoni Barciński',
#  'Alphonse de Lamartine',
#  'Georgiana Somerset',
#  'Izabela Chopin',
#  'Henri Herz',
#  'Félicité de Lamennais',
#  'Lucie Maréchal',
#  'Krystyn Ostrowski',
#  'Louise de Lorraine (królowa)',
#  'Klementyna Hoffmanowa',
#  'Alexandre Dumas (syn)',
#  'William Pitt (1. hrabia Chatham)',
#  'Henryk Dorn',
#  'Jan Matuszyński',
#  'Pedro Calderón de la Barca',
#  'Józef Elsner',
#  'Theodor Döhler',
#  'Jan (służący Fryderyka Chopina)',
#  'Kamilla Zboińska',
#  'Friederike Müller-Streicher',
#  'Wolfgang Amadeusz Mozart',
#  'Felicjan Mallefille',
#  'Władysław Czartoryski (książę)',
#  'Louis Viardot',
#  'Hipolit Błotnicki',
#  'María Cristina, Queen consort of Ferdinand VII',
#  'Seweryn Goszczyński',
#  'Marie Constance Albertine de Montaran (baronowa)',
#  'Victoire de Saxe-Cobourg-Koháry (duchesse de Nemours)',
#  'Louis Dupin de Francueil',
#  'Antoni Radziwiłł',
#  'Józef Bohdan Zaleski',
#  'Eugène Lambert',
#  'Maria Wirtemberska',
#  'Juliette de Forget',
#  'Pietro Mechetti']

# %% [markdown]
# # Q-codes for names from input_list ```(Q-codes from wikidata search page)```

# %%
original_persons = scrape_qcodes(list=input, humans_only=True, first_only=True)  # 8m 30s dla 399 osób z listów z pliu .txt
# Out:
# Scraping... 0/399 ... Antoni Kątski
# Scraping... 1/399 ... Emilia Chopin
# Scraping... 2/399 ... Louis Boulanger
# Scraping... 3/399 ... Godefroi de Bouillon
# Scraping... 4/399 ... Peter Paul Rubens
# Scraping... 5/399 ... Susanne Gibson-Milner
# Scraping... 6/399 ... Ernest Canut
# Scraping... 7/399 ... Augustine Brault
# Scraping... 8/399 ... Izabella Działyńska (hrabina)
# Scraping... 9/399 ... Marie d’Agoult
# Scraping... 10/399 ... Amélie Franchomme
# Scraping... 11/399 ... Kazimierz Wernik
# Scraping... 12/399 ... Josef Dessauer
# Scraping... 13/399 ... Vera Rubio
# Scraping... 14/399 ... Franciszek Skibicki
# Scraping... 15/399 ... François-Victor Hugo
# Scraping... 16/399 ... Sabine Heinefetter
# Scraping... 17/399 ... Thomas Bohier
# Scraping... 18/399 ... Aleksander Colonna-Walewski (książę)
# Scraping... 19/399 ... Francesco de Vico
# Scraping... 20/399 ... Urbain Jean-Joseph Le Verrier
# Scraping... 21/399 ... Augustine Marie Bertholdi
# Scraping... 22/399 ... Fontana Juanna Camila
# Scraping... 23/399 ... Václav Hanka
# Scraping... 24/399 ... Ludwika Magdalena Ciechomska
# Scraping... 25/399 ... Gustaw Planche
# Scraping... 26/399 ... Giulia Grisi
# Scraping... 27/399 ... François-Joseph Gossec
# Scraping... 28/399 ... Honorata Dziewanowska
# Scraping... 29/399 ... Antoine de Orléans
# Scraping... 30/399 ... Jan Křtitel Pišek
# Scraping... 31/399 ... Władysław Żeleński
# Scraping... 32/399 ... Adolphe d Ennery
# Scraping... 33/399 ... Władysław Czartoryski
# Scraping... 34/399 ... Henryk Jędrzejewicz
# Scraping... 35/399 ... Mikołaj Chopin
# Scraping... 36/399 ... Aleksandra Karasowska
# Scraping... 37/399 ... Jules Janin
# Scraping... 38/399 ... Sigismond von Neukomm
# Scraping... 39/399 ... Thérèse Albrecht
# Scraping... 40/399 ... Adam Towiański
# Scraping... 41/399 ... Jean-Baptiste-Antoine Lassus
# Scraping... 42/399 ... Adam Mickiewicz
# Scraping... 43/399 ... Carl Helminger
# Scraping... 44/399 ... Mary Rich
# Scraping... 45/399 ... Antoni Orłowski
# Scraping... 46/399 ... Fryderyk Skarbek (hrabia)
# Scraping... 47/399 ... Pierre (służący Fryderyka Chopina)
# Scraping... 48/399 ... Józef Kalasanty Jędrzejewicz
# Scraping... 49/399 ... Gemmy Brandus
# Scraping... 50/399 ... Józef Bem
# Scraping... 51/399 ... Fanny Hensel
# Scraping... 52/399 ... Wilhelm Würfel
# Scraping... 53/399 ... Emil Jenike
# Scraping... 54/399 ... Ann Houston
# Scraping... 55/399 ... Aleksander Jełowicki
# Scraping... 56/399 ... Fernand de Préaulx
# Scraping... 57/399 ... Jacques de Vaucanson
# Scraping... 58/399 ... Giuseppe Verdi
# Scraping... 59/399 ... Abraham Louis Breguet
# Scraping... 60/399 ... Karolina Elsner
# Scraping... 61/399 ... Jan Barciński
# Scraping... 62/399 ... Samuel Carter Hall
# Scraping... 63/399 ... Adèle Hugo
# Scraping... 64/399 ... Jean Nicolas Marjolin
# Scraping... 65/399 ... Anna z Tańkowskich Paderewska
# Scraping... 66/399 ... Charles-Valentin Alkan
# Scraping... 67/399 ... Johannes Brahms
# Scraping... 68/399 ... Marie-Amélie, Queen consort of Louis-Philippe
# Scraping... 69/399 ... Joaquina Garcia
# Scraping... 70/399 ... Friedrich Wilhelm Michael Kalkbrenner
# Scraping... 71/399 ... Eugénie de Bonnechose
# Scraping... 72/399 ... Casimir Stanislas d Arpentigny
# Scraping... 73/399 ... María Luisa Fernanda de Borbón
# Scraping... 74/399 ... Ludwik Adam Dmuszewski
# Scraping... 75/399 ... de Perthuis (hrabia)
# Scraping... 76/399 ... Jean-Baptiste Pierret
# Scraping... 77/399 ... Gioacchino Rossini
# Scraping... 78/399 ... Józef Damse
# Scraping... 79/399 ... Heinrich Albert Probst
# Scraping... 80/399 ... Marie Dorval
# Scraping... 81/399 ... Eustachy Marylski
# Scraping... 82/399 ... Adolphe Thiers
# Scraping... 83/399 ... Jean-François Lesueur
# Scraping... 84/399 ... Ludovic Houston
# Scraping... 85/399 ... Hippolyte Chatiron
# Scraping... 86/399 ... Jan Sebastian Bach
# Scraping... 87/399 ... Anna Czartoryska
# Scraping... 88/399 ... Tomasz Nidecki
# Scraping... 89/399 ... Konstanty Pruszak
# Scraping... 90/399 ... Charlotte Marliani
# Scraping... 91/399 ... Feliks Wodziński
# Scraping... 92/399 ... Albert, Prince of Schleswig-Holstein-Glücksburg
# Scraping... 93/399 ... Pierre-Marcel Gaubert
# Scraping... 94/399 ... Maurycy Karasowski
# Scraping... 95/399 ... Tytus Woyciechowski
# Scraping... 96/399 ... Louis James Alfred Lefébure-Wély
# Scraping... 97/399 ... Ksawera Grocholska
# Scraping... 98/399 ... Dominik Dziewanowski
# Scraping... 99/399 ... Louis Spohr
# Scraping... 100/399 ... Poliksena Paderewska
# Scraping... 101/399 ... Norbert Alfons Kumelski
# Scraping... 102/399 ... Piotr Sowiński
# Scraping... 103/399 ... Paul Gavarni
# Scraping... 104/399 ... Felix Mendelssohn-Bartholdy
# Scraping... 105/399 ... Anton Schindler
# Scraping... 106/399 ... Marcelina Czartoryska
# Scraping... 107/399 ... C. P. Sotte
# Scraping... 108/399 ... Adam Jerzy Czartoryski
# Scraping... 109/399 ... Teresa Wodzińska
# Scraping... 110/399 ... Johann Gottfried Galle
# Scraping... 111/399 ... Józef Nowakowski
# Scraping... 112/399 ... Thomas Couture
# Scraping... 113/399 ... Justyna Chopin
# Scraping... 114/399 ... Józef Kurowski
# Scraping... 115/399 ... Joseph Faber
# Scraping... 116/399 ... Józef Michał Poniatowski (książę)
# Scraping... 117/399 ... René Vallet de Villeneuve
# Scraping... 118/399 ... Élisa de Lamartine
# Scraping... 119/399 ... Ludwika Jędrzejewiczowa
# Scraping... 120/399 ... Jean-Baptiste Massillon
# Scraping... 121/399 ... Wilhelm Kolberg
# Scraping... 122/399 ... Léopoldine Hugo
# Scraping... 123/399 ... Pierre Leroux
# Scraping... 124/399 ... Laura Horsford
# Scraping... 125/399 ... Agnès (Mlle)
# Scraping... 126/399 ... Louis-Philippe-Joseph Girod de Vienney (baron de Trémont)
# Scraping... 127/399 ... Angelika Catalani
# Scraping... 128/399 ... August Franchomme
# Scraping... 129/399 ... Clotilde Elisabeth Villetard
# Scraping... 130/399 ... Jadwiga Klementyna Sapieha (księżna)
# Scraping... 131/399 ... Hélène de Mecklembourg-Schwerin (księżna)
# Scraping... 132/399 ... Edmund Chojecki
# Scraping... 133/399 ... Édouard Herbault
# Scraping... 134/399 ... Antonina  Wilkońska
# Scraping... 135/399 ... Jakub Fromental Halévy
# Scraping... 136/399 ... Edward Wolff
# Scraping... 137/399 ... Auguste Mathieu Panseron
# Scraping... 138/399 ... Karol Szulczewski
# Scraping... 139/399 ... Jan Białobłocki
# Scraping... 140/399 ... Marie de Rozières
# Scraping... 141/399 ... Pelagia Skarbkowa
# Scraping... 142/399 ... Christopher Columbus
# Scraping... 143/399 ... Jean Jacques Rousseau
# Scraping... 144/399 ... Juliusz Słowacki
# Scraping... 145/399 ... Anna Liszt
# Scraping... 146/399 ... Regina Hiller
# Scraping... 147/399 ... François-Antoine Habeneck
# Scraping... 148/399 ... Jan Nepomuk Štěpánek
# Scraping... 149/399 ... Gabriel Bonnot de Mably
# Scraping... 150/399 ... Henry Victor Malan
# Scraping... 151/399 ... Marie Thérèse Ducroc de Brassac
# Scraping... 152/399 ... Leopold Louis Sina
# Scraping... 153/399 ... Jean de La Fontaine
# Scraping... 154/399 ... Kazimierz Wodziński
# Scraping... 155/399 ... Ary Scheffer
# Scraping... 156/399 ... Maria Wodzińska
# Scraping... 157/399 ... Ludwika Nakwaska
# Scraping... 158/399 ... Rosine Stoltz
# Scraping... 159/399 ... Adolf Gutmann
# Scraping... 160/399 ... Thérèse Gavard
# Scraping... 161/399 ... Alexandre Dumas
# Scraping... 162/399 ... Katarzyna Potocka (hrabina)
# Scraping... 163/399 ... Cécile Franchomme
# Scraping... 164/399 ... Wincenty Władysław Grzymała
# Scraping... 165/399 ... Ferdynand Hiller
# Scraping... 166/399 ... Juliette Drouet
# Scraping... 167/399 ... Francisco de Asís de Borbón (King, consort of Isabella II)
# Scraping... 168/399 ... Fryderyk Bolesław Jędrzejewicz
# Scraping... 169/399 ... King of France Francis I
# Scraping... 170/399 ... Izabella Barcińska
# Scraping... 171/399 ... Józefa Turowska
# Scraping... 172/399 ... Harriet Leveson-Gower, Duchess of Sutherland
# Scraping... 173/399 ... Isabella di Ricci (Księżna)
# Scraping... 174/399 ... Élise Gavard
# Scraping... 175/399 ... Ksawery Zboiński (hrabia)
# Scraping... 176/399 ... Henri Vieuxtemps
# Scraping... 177/399 ... Louis Brandus
# Scraping... 178/399 ... King of Spain Charles III
# Scraping... 179/399 ... Charles Schunke
# Scraping... 180/399 ... Ludwika Chopin
# Scraping... 181/399 ... Bohdan Zaleski
# Scraping... 182/399 ... Napoleon Orda
# Scraping... 183/399 ... Baron Carlo Marochetti
# Scraping... 184/399 ... Anne Elizabeth Louise Delaroche
# Scraping... 185/399 ... Helena Górska
# Scraping... 186/399 ... Ludwika Dziewanowska
# Scraping... 187/399 ... Giovanni Battista Pergolesi
# Scraping... 188/399 ... Solange Dudevant
# Scraping... 189/399 ... Paul Delaroche
# Scraping... 190/399 ... Madame Etienne
# Scraping... 191/399 ... Louise Franchomme
# Scraping... 192/399 ... Louis Kleinwächter
# Scraping... 193/399 ... Karol Lipiński
# Scraping... 194/399 ... Antoine-Augustin Préault
# Scraping... 195/399 ... Jane Wilhelmina Stirling
# Scraping... 196/399 ... Adolf Cichowski
# Scraping... 197/399 ... Gaspard Deguerry
# Scraping... 198/399 ... Hippolyte Lucas
# Scraping... 199/399 ... Laura Czosnowska (hrabina)
# Scraping... 200/399 ... Catherine de Souzzo (księżna)
# Scraping... 201/399 ... the Commitee of the Concert Society
# Scraping... 202/399 ... Jean-Jacques Molin
# Scraping... 203/399 ... Félix-Auguste Duvert
# Scraping... 204/399 ... Marietta Alboni
# Scraping... 205/399 ... King of France Louis XV
# Scraping... 206/399 ... Wojciech Grzymała
# Scraping... 207/399 ... Solange Clésinger
# Scraping... 208/399 ... Władysław Górski
# Scraping... 209/399 ... Anna Caroline Oury [de Belleville]
# Scraping... 210/399 ... dr Fraenkel
# Scraping... 211/399 ... Eugène Delacroix
# Scraping... 212/399 ... Małgorzata Barcińska
# Scraping... 213/399 ... Charles Aubertin
# Scraping... 214/399 ... Isabella II, Queen of Spain
# Scraping... 215/399 ... Karol Olizar
# Scraping... 216/399 ... Maria Kalergis
# Scraping... 217/399 ... Gustave Roger
# Scraping... 218/399 ... Élisabeth Rachel Félix
# Scraping... 219/399 ... François Guizot
# Scraping... 220/399 ... Karol Franciszek Szulczewski
# Scraping... 221/399 ... François-Joseph Fétis
# Scraping... 222/399 ... Christian Friedrich Schönbein
# Scraping... 223/399 ... Luigi Cherubini
# Scraping... 224/399 ... Salis Schwabe
# Scraping... 225/399 ... Kamila Billing de Courbonne
# Scraping... 226/399 ... Gaetano Donizetti
# Scraping... 227/399 ... Antonio Stradivari
# Scraping... 228/399 ... Jenny Lind
# Scraping... 229/399 ... Thomas Albrecht
# Scraping... 230/399 ... Filippo Coletti
# Scraping... 231/399 ... Jean-Baptiste Clésinger
# Scraping... 232/399 ... Ludwik Piotr Norblin
# Scraping... 233/399 ... Adam Crémieux
# Scraping... 234/399 ... Antoni Żelisław Jędrzejewicz
# Scraping... 235/399 ... Maurycy Dudevant
# Scraping... 236/399 ... Vinzenz Prießnitz
# Scraping... 237/399 ... Härtel from Breitkopf & Härtel company
# Scraping... 238/399 ... Louis Hippolyte Lebas
# Scraping... 239/399 ... Fanny Persiani
# Scraping... 240/399 ... Konstanty Gaszyński
# Scraping... 241/399 ... Stanisław Egbert Koźmian
# Scraping... 242/399 ... Alexandre Artôt
# Scraping... 243/399 ... Katarzyna Diller de Pereira
# Scraping... 244/399 ... William Cavendish (4. diuk Devonshire)
# Scraping... 245/399 ... Julian Fontana
# Scraping... 246/399 ... George Sand
# Scraping... 247/399 ... Françoise (pokojowa George Sand)
# Scraping... 248/399 ... Schuberth & Co. company
# Scraping... 249/399 ... Ignaz Moscheles
# Scraping... 250/399 ... August Clésinger
# Scraping... 251/399 ... Maurice Sand
# Scraping... 252/399 ... Emmanuel Arago
# Scraping... 253/399 ... Oskar Kolberg
# Scraping... 254/399 ... Michael William Balfe
# Scraping... 255/399 ... Stefan Witwicki
# Scraping... 256/399 ... Ignacy Jan Paderewski
# Scraping... 257/399 ... Maurice Schlesinger
# Scraping... 258/399 ... Leopold von Baden
# Scraping... 259/399 ... Ignacy Krasicki
# Scraping... 260/399 ... Jadwiga Ramm
# Scraping... 261/399 ... Ojciec macochy kompozytora, Anny z Tańkowskich Paderewskiej
# Scraping... 262/399 ... Luigi Lablache
# Scraping... 263/399 ... Jean-Antoine Letronne
# Scraping... 264/399 ... Pierre Corneille
# Scraping... 265/399 ... Karol Gavard
# Scraping... 266/399 ... Katherine Erskine
# Scraping... 267/399 ... Breitkopf & Härtel company
# Scraping... 268/399 ... John Hind
# Scraping... 269/399 ... Félicien David
# Scraping... 270/399 ... Amélie Grille de Beuzelin
# Scraping... 271/399 ... Wojciech Żywny
# Scraping... 272/399 ... Giovanni Mario
# Scraping... 273/399 ... Alojzy Janowicz (pułkownik)
# Scraping... 274/399 ... Leopold Thun-Hohenstein
# Scraping... 275/399 ... René Franchomme
# Scraping... 276/399 ... Józefa Dziewanowska
# Scraping... 277/399 ... Friederich Kalkbrenner
# Scraping... 278/399 ... Mary Murray (Lady)
# Scraping... 279/399 ... Frédéric Villot
# Scraping... 280/399 ... Horace Vernet
# Scraping... 281/399 ... William Herschel
# Scraping... 282/399 ... Charles Hugo
# Scraping... 283/399 ... Józef Haydn
# Scraping... 284/399 ... Heinrich Heine
# Scraping... 285/399 ... Robert Schumann
# Scraping... 286/399 ... Elzéar de Sabran
# Scraping... 287/399 ... Victor Hugo
# Scraping... 288/399 ... Carl Reinecke
# Scraping... 289/399 ... Narcisse-Achille de Salvandy (comte)
# Scraping... 290/399 ... Ferenc Liszt
# Scraping... 291/399 ... Józef Dwernicki
# Scraping... 292/399 ... Astolphe de Custine
# Scraping... 293/399 ... Juliusz Dziewanowski
# Scraping... 294/399 ... Lucie (służąca George Sand)
# Scraping... 295/399 ... Marcelina Czartoryska (księżna)
# Scraping... 296/399 ... François Arago
# Scraping... 297/399 ... Mary, Queen of Scots
# Scraping... 298/399 ... Henry Fowler Broadwood
# Scraping... 299/399 ... Józef Brzowski
# Scraping... 300/399 ... Michał Skarbek
# Scraping... 301/399 ... Cécile Mendelssohn-Bartholdy
# Scraping... 302/399 ... Victor Borie
# Scraping... 303/399 ... Auguste Maquet
# Scraping... 304/399 ... Jane Welsh Carlyle
# Scraping... 305/399 ... Antony Deschamps
# Scraping... 306/399 ... Fryderyk Chopin
# Scraping... 307/399 ... Victoria, Queen of Great Britain
# Scraping... 308/399 ... Ferdinando Paër
# Scraping... 309/399 ... Hector Berlioz
# Scraping... 310/399 ... Ignacy Krzyżanowski
# Scraping... 311/399 ... Ernest Legouvé
# Scraping... 312/399 ... Louis Charles Philippe Raphaël Orléans (duc de Nemours)
# Scraping... 313/399 ... Christian Rudolf Wessel
# Scraping... 314/399 ... Zofia Rozengart
# Scraping... 315/399 ... Natalia Obreskow (księżna)
# Scraping... 316/399 ... Casimir Dudevant
# Scraping... 317/399 ... Camille Pleyel
# Scraping... 318/399 ... Auguste Léo
# Scraping... 319/399 ... Anne Françoise Hyppolyte Boutet (Mademoiselle Mars)
# Scraping... 320/399 ... Ludwik Plater
# Scraping... 321/399 ... Józef Stefani
# Scraping... 322/399 ... Jean-Delphin Alard
# Scraping... 323/399 ... Émilie de Perthuis (hrabina)
# Scraping... 324/399 ... Maria de Rozières
# Scraping... 325/399 ... Frédéric Hénique
# Scraping... 326/399 ... Jan Paderewski
# Scraping... 327/399 ... Antoni Wodziński
# Scraping... 328/399 ... Walenty Barciński
# Scraping... 329/399 ... Léon Pillet
# Scraping... 330/399 ... Charles Gavard
# Scraping... 331/399 ... Leon Szmitkowski
# Scraping... 332/399 ... Xavier Durrieu
# Scraping... 333/399 ... Eugène-Théodore Troupenas
# Scraping... 334/399 ... Delfina Potocka
# Scraping... 335/399 ... Nicolas Poussin
# Scraping... 336/399 ... Jeanne-Gabrielle Clésinger
# Scraping... 337/399 ... Charlotte Rothschild (baronowa)
# Scraping... 338/399 ... Anna Maria Walewska (księżna)
# Scraping... 339/399 ... Aleksander Julian Hofman
# Scraping... 340/399 ... Benjamin Lumley
# Scraping... 341/399 ... Ludwik Filip I (król Francuzów)
# Scraping... 342/399 ... Harriet Grote
# Scraping... 343/399 ... Salomea Słowacka
# Scraping... 344/399 ... Zofia Rosengardt-Zaleska
# Scraping... 345/399 ... Józef Bełza
# Scraping... 346/399 ... Michał Babiański
# Scraping... 347/399 ... Suzanne (kucharka George Sand)
# Scraping... 348/399 ... Anna Młokosiewicz
# Scraping... 349/399 ... Ludwig van Beethoven
# Scraping... 350/399 ... Charles Duvernet
# Scraping... 351/399 ... Duke of Orleans Ferdinand Philippe
# Scraping... 352/399 ... von Stockhausen (baronowa)
# Scraping... 353/399 ... Baron de Montesquieu
# Scraping... 354/399 ... Adam Łyszczyński
# Scraping... 355/399 ... Catherine de Médicis, Queen consort of Henry II
# Scraping... 356/399 ... Paulina Plater (hrabianka)
# Scraping... 357/399 ... Paulina Viardot
# Scraping... 358/399 ... Giacomo Meyerbeer
# Scraping... 359/399 ... Michalina Rzyszczewska
# Scraping... 360/399 ... Francisca de Joinville (Princess of Brazil)
# Scraping... 361/399 ... Carlotta Marliani
# Scraping... 362/399 ... Stanisław Grabowski
# Scraping... 363/399 ... Antoni Barciński
# Scraping... 364/399 ... Alphonse de Lamartine
# Scraping... 365/399 ... Georgiana Somerset
# Scraping... 366/399 ... Izabela Chopin
# Scraping... 367/399 ... Henri Herz
# Scraping... 368/399 ... Félicité de Lamennais
# Scraping... 369/399 ... Lucie Maréchal
# Scraping... 370/399 ... Krystyn Ostrowski
# Scraping... 371/399 ... Louise de Lorraine (królowa)
# Scraping... 372/399 ... Klementyna Hoffmanowa
# Scraping... 373/399 ... Alexandre Dumas (syn)
# Scraping... 374/399 ... William Pitt (1. hrabia Chatham)
# Scraping... 375/399 ... Henryk Dorn
# Scraping... 376/399 ... Jan Matuszyński
# Scraping... 377/399 ... Pedro Calderón de la Barca
# Scraping... 378/399 ... Józef Elsner
# Scraping... 379/399 ... Theodor Döhler
# Scraping... 380/399 ... Jan (służący Fryderyka Chopina)
# Scraping... 381/399 ... Kamilla Zboińska
# Scraping... 382/399 ... Friederike Müller-Streicher
# Scraping... 383/399 ... Wolfgang Amadeusz Mozart
# Scraping... 384/399 ... Felicjan Mallefille
# Scraping... 385/399 ... Władysław Czartoryski (książę)
# Scraping... 386/399 ... Louis Viardot
# Scraping... 387/399 ... Hipolit Błotnicki
# Scraping... 388/399 ... María Cristina, Queen consort of Ferdinand VII
# Scraping... 389/399 ... Seweryn Goszczyński
# Scraping... 390/399 ... Marie Constance Albertine de Montaran (baronowa)
# Scraping... 391/399 ... Victoire de Saxe-Cobourg-Koháry (duchesse de Nemours)
# Scraping... 392/399 ... Louis Dupin de Francueil
# Scraping... 393/399 ... Antoni Radziwiłł
# Scraping... 394/399 ... Józef Bohdan Zaleski
# Scraping... 395/399 ... Eugène Lambert
# Scraping... 396/399 ... Maria Wirtemberska
# Scraping... 397/399 ... Juliette de Forget
# Scraping... 398/399 ... Pietro Mechetti

# %%
original_persons.sort(key=lambda d: d['search_name'])
print(len(original_persons))
original_persons
# Out:
# 285
# [{'search_name': 'Abraham Louis Breguet',
#   'page_name': 'Abraham-Louis Breguet',
#   'description': 'Swiss engineer and clockmaker',
#   'Qcode': 'Q123679',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q123679'},
#  {'search_name': 'Adam Jerzy Czartoryski',
#   'page_name': 'Adam Czartoryski',
#   'description': 'Polish nobleman, statesman, diplomat and author (1770-1861)',
#   'Qcode': 'Q342889',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q342889'},
#  {'search_name': 'Adam Mickiewicz',
#   'page_name': 'Adam Mickiewicz',
#   'description': 'Polish national poet, dramatist, essayist, publicist, translator, and political activist (1798-1855)',
#   'Qcode': 'Q79822',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q79822'},
#  {'search_name': 'Adam Łyszczyński',
#   'page_name': 'Q99639218',
#   'description': None,
#   'Qcode': 'Q99639218',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q99639218'},
#  {'search_name': 'Adolf Cichowski',
#   'page_name': 'Adolphe Cichowski',
#   'description': 'Polish soldier',
#   'Qcode': 'Q4505990',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q4505990'},
#  {'search_name': 'Adolf Gutmann',
#   'page_name': 'Adolf Gutmann',
#   'description': None,
#   'Qcode': 'Q77840132',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q77840132'},
#  {'search_name': 'Adolphe Thiers',
#   'page_name': 'Adolphe Thiers',
#   'description': 'President of the French Republic (1797–1877)',
#   'Qcode': 'Q5738',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q5738'},
#  {'search_name': 'Adolphe d Ennery',
#   'page_name': "Adolphe d'Ennery",
#   'description': 'French Jewish dramatist and novelist',
#   'Qcode': 'Q137819',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q137819'},
#  {'search_name': 'Adèle Hugo',
#   'page_name': 'Adèle Hugo',
#   'description': '2nd daughter of Victor Hugo',
#   'Qcode': 'Q2082427',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2082427'},
#  {'search_name': 'Albert, Prince of Schleswig-Holstein-Glücksburg',
#   'page_name': 'Prince Albrecht of Schleswig-Holstein-Sonderburg-Glücksburg',
#   'description': 'German prince (1863-1948)',
#   'Qcode': 'Q3608671',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3608671'},
#  {'search_name': 'Aleksander Colonna-Walewski (książę)',
#   'page_name': 'Alexandre Colonna-Walewski',
#   'description': 'French politician (1810-1868)',
#   'Qcode': 'Q435375',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q435375'},
#  {'search_name': 'Aleksander Jełowicki',
#   'page_name': 'Aleksander Jełowicki',
#   'description': 'Polish Roman Catholic priest and publisher',
#   'Qcode': 'Q9145532',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9145532'},
#  {'search_name': 'Alexandre Artôt',
#   'page_name': 'Joseph Artot',
#   'description': 'Belgian composer (1815-1845)',
#   'Qcode': 'Q20670032',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q20670032'},
#  {'search_name': 'Alexandre Dumas',
#   'page_name': 'Alexandre Dumas',
#   'description': 'French writer and dramatist (1802–1870)',
#   'Qcode': 'Q38337',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q38337'},
#  {'search_name': 'Alexandre Dumas (syn)',
#   'page_name': 'Alexandre Dumas fils',
#   'description': 'French writer and dramatist (1824-1895)',
#   'Qcode': 'Q169150',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q169150'},
#  {'search_name': 'Alphonse de Lamartine',
#   'page_name': 'Alphonse de Lamartine',
#   'description': 'French writer, poet, and politician (1790-1869)',
#   'Qcode': 'Q188697',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q188697'},
#  {'search_name': 'Ann Houston',
#   'page_name': 'Ann Houston Wiedie',
#   'description': 'Ph.D. University of Massachusetts Amherst 1995',
#   'Qcode': 'Q102194393',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q102194393'},
#  {'search_name': 'Anna Caroline Oury [de Belleville]',
#   'page_name': 'Anna Caroline Oury',
#   'description': 'German musician',
#   'Qcode': 'Q4766898',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q4766898'},
#  {'search_name': 'Anna Czartoryska',
#   'page_name': 'Anna Czartoryska',
#   'description': 'Polish actress',
#   'Qcode': 'Q11686228',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q11686228'},
#  {'search_name': 'Anna Liszt',
#   'page_name': 'Anna Liszt',
#   'description': 'Mother of Franz Liszt',
#   'Qcode': 'Q11285375',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q11285375'},
#  {'search_name': 'Anne Françoise Hyppolyte Boutet (Mademoiselle Mars)',
#   'page_name': 'Mademoiselle Mars',
#   'description': 'French actress (1779-1847)',
#   'Qcode': 'Q458156',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q458156'},
#  {'search_name': 'Antoine de Orléans',
#   'page_name': 'Prince Antoine, Duke of Montpensier',
#   'description': 'French Royal',
#   'Qcode': 'Q550766',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q550766'},
#  {'search_name': 'Antoine-Augustin Préault',
#   'page_name': 'Antoine-Augustin Préault',
#   'description': 'French artist',
#   'Qcode': 'Q2074586',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2074586'},
#  {'search_name': 'Anton Schindler',
#   'page_name': 'Anton Schindler',
#   'description': 'Associate, secretary, and early biographer of Ludwig van Beethoven (1795-1864)',
#   'Qcode': 'Q64862',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q64862'},
#  {'search_name': 'Antoni Barciński',
#   'page_name': 'Feliks Antoni Barcinski',
#   'description': None,
#   'Qcode': 'Q106489731',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q106489731'},
#  {'search_name': 'Antoni Kątski',
#   'page_name': 'Antoni Kątski',
#   'description': 'Polish musician (1817-1899)',
#   'Qcode': 'Q263091',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q263091'},
#  {'search_name': 'Antoni Orłowski',
#   'page_name': 'Antoni Orłowski',
#   'description': 'Polish journalist (1869-1921)',
#   'Qcode': 'Q9157202',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9157202'},
#  {'search_name': 'Antoni Radziwiłł',
#   'page_name': 'Antoni Radziwiłł',
#   'description': 'Polish and Prussian politician (1775-1833)',
#   'Qcode': 'Q561112',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q561112'},
#  {'search_name': 'Antoni Wodziński',
#   'page_name': 'Antoni Wodziński',
#   'description': 'writer and translator from Poland',
#   'Qcode': 'Q9157627',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9157627'},
#  {'search_name': 'Antonio Stradivari',
#   'page_name': 'Antonio Stradivari',
#   'description': 'Italian stringed instrument maker, 1644-1737',
#   'Qcode': 'Q182011',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q182011'},
#  {'search_name': 'Antony Deschamps',
#   'page_name': 'Antony Deschamps',
#   'description': 'writer and poet from France',
#   'Qcode': 'Q607998',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q607998'},
#  {'search_name': 'Ary Scheffer',
#   'page_name': 'Ary Scheffer',
#   'description': 'Dutch painter (1795-1858)',
#   'Qcode': 'Q436726',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q436726'},
#  {'search_name': 'Astolphe de Custine',
#   'page_name': 'Astolphe-Louis-Léonor de Custine, Marquis de Custine',
#   'description': 'French aristocrat and writer (1790-1857)',
#   'Qcode': 'Q727056',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q727056'},
#  {'search_name': 'August Franchomme',
#   'page_name': 'Auguste Franchomme',
#   'description': 'French musician (1808-1884)',
#   'Qcode': 'Q517132',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q517132'},
#  {'search_name': 'Auguste Léo',
#   'page_name': 'August Leo',
#   'description': None,
#   'Qcode': 'Q16054478',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q16054478'},
#  {'search_name': 'Auguste Maquet',
#   'page_name': 'Auguste Maquet',
#   'description': 'French writer',
#   'Qcode': 'Q766768',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q766768'},
#  {'search_name': 'Auguste Mathieu Panseron',
#   'page_name': 'Auguste Panseron',
#   'description': 'French composer',
#   'Qcode': 'Q713985',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q713985'},
#  {'search_name': 'Baron Carlo Marochetti',
#   'page_name': 'Carlo Marochetti',
#   'description': 'Italian-born French sculptor (1805-1867)',
#   'Qcode': 'Q2375473',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2375473'},
#  {'search_name': 'Baron de Montesquieu',
#   'page_name': 'Montesquieu',
#   'description': 'French social commentator and political thinker (1689-1755)',
#   'Qcode': 'Q15975',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q15975'},
#  {'search_name': 'Benjamin Lumley',
#   'page_name': 'Benjamin Lumley',
#   'description': 'British opera manager',
#   'Qcode': 'Q2896159',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2896159'},
#  {'search_name': 'Bohdan Zaleski',
#   'page_name': 'Bohdan Zaleski',
#   'description': 'Polish astronomer',
#   'Qcode': 'Q9176254',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9176254'},
#  {'search_name': 'Breitkopf & Härtel company',
#   'page_name': 'Hendrik Breitkopf',
#   'description': 'German botanist',
#   'Qcode': 'Q21338629',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q21338629'},
#  {'search_name': 'C. P. Sotte',
#   'page_name': 'Cornelis van Cleve',
#   'description': 'Flemish Renaissance painter',
#   'Qcode': 'Q2534918',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2534918'},
#  {'search_name': 'Camille Pleyel',
#   'page_name': 'Camille Pleyel',
#   'description': 'French musician',
#   'Qcode': 'Q1630994',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1630994'},
#  {'search_name': 'Carl Reinecke',
#   'page_name': 'Carl Reinecke',
#   'description': 'German composer, conductor and pianist',
#   'Qcode': 'Q159569',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q159569'},
#  {'search_name': 'Casimir Dudevant',
#   'page_name': 'Casimir Dudevant',
#   'description': 'illegitimate son of Baron Jean-François Dudevant and his mistress Augustine Soulé',
#   'Qcode': 'Q1047458',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1047458'},
#  {'search_name': 'Catherine de Médicis, Queen consort of Henry II',
#   'page_name': "Catherine de' Medici",
#   'description': 'queen-consort and regent of France (1519-1589)',
#   'Qcode': 'Q131552',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q131552'},
#  {'search_name': 'Charles Aubertin',
#   'page_name': 'Charles Aubertin',
#   'description': 'Physician; Born 1876 in Paris Death 1950',
#   'Qcode': 'Q109810560',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q109810560'},
#  {'search_name': 'Charles Duvernet',
#   'page_name': 'Charles Duvernet',
#   'description': 'French writer (1807-1874)',
#   'Qcode': 'Q62028861',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q62028861'},
#  {'search_name': 'Charles Gavard',
#   'page_name': 'Charles Gavard',
#   'description': None,
#   'Qcode': 'Q23060765',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q23060765'},
#  {'search_name': 'Charles Hugo',
#   'page_name': 'Charles Hugo',
#   'description': 'French journalist and photographer, son of Victor Hugo',
#   'Qcode': 'Q663856',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q663856'},
#  {'search_name': 'Charles Schunke',
#   'page_name': 'Karl Schunke',
#   'description': None,
#   'Qcode': 'Q55846558',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q55846558'},
#  {'search_name': 'Charles-Valentin Alkan',
#   'page_name': 'Charles-Valentin Alkan',
#   'description': 'French-Jewish composer and pianist',
#   'Qcode': 'Q217068',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q217068'},
#  {'search_name': 'Christian Friedrich Schönbein',
#   'page_name': 'Christian Friedrich Schönbein',
#   'description': 'German-Swiss chemist, discoverer of guncotton and ozone (1799-1868)',
#   'Qcode': 'Q61319',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q61319'},
#  {'search_name': 'Christopher Columbus',
#   'page_name': 'Christopher Columbus',
#   'description': 'Italian explorer, navigator, and colonizer (1451–1506)',
#   'Qcode': 'Q7322',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q7322'},
#  {'search_name': 'Cécile Mendelssohn-Bartholdy',
#   'page_name': 'Cécile Mendelssohn Bartholdy',
#   'description': 'Spouse of composer Félix Mendelsohnn',
#   'Qcode': 'Q114366',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q114366'},
#  {'search_name': 'Delfina Potocka',
#   'page_name': 'Delfina Potocka',
#   'description': 'socialite (1807-1877)',
#   'Qcode': 'Q3021581',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3021581'},
#  {'search_name': 'Dominik Dziewanowski',
#   'page_name': 'Dominik Dziewanowski',
#   'description': 'Polish general',
#   'Qcode': 'Q9209760',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9209760'},
#  {'search_name': 'Duke of Orleans Ferdinand Philippe',
#   'page_name': 'Prince Ferdinand Philippe, Duke of Orléans',
#   'description': 'French prince of the house of Orléans (1810-1842)',
#   'Qcode': 'Q458688',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q458688'},
#  {'search_name': 'Edmund Chojecki',
#   'page_name': 'Edmund Chojecki',
#   'description': None,
#   'Qcode': 'Q17551656',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q17551656'},
#  {'search_name': 'Edward Wolff',
#   'page_name': 'Edward Wolff',
#   'description': 'economist',
#   'Qcode': 'Q5345972',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q5345972'},
#  {'search_name': 'Elzéar de Sabran',
#   'page_name': 'Elzéar de Sabran',
#   'description': 'French writer',
#   'Qcode': 'Q3051916',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3051916'},
#  {'search_name': 'Emilia Chopin',
#   'page_name': 'Emilia Chopin',
#   'description': 'Polish composer',
#   'Qcode': 'Q8860780',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q8860780'},
#  {'search_name': 'Emmanuel Arago',
#   'page_name': 'Emmanuel Arago',
#   'description': 'French politician',
#   'Qcode': 'Q2658508',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2658508'},
#  {'search_name': 'Ernest Legouvé',
#   'page_name': 'Ernest Legouvé',
#   'description': 'French dramatist',
#   'Qcode': 'Q1333348',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1333348'},
#  {'search_name': 'Eugène Delacroix',
#   'page_name': 'Eugène Delacroix',
#   'description': 'French painter (1798-1863)',
#   'Qcode': 'Q33477',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q33477'},
#  {'search_name': 'Eugène Lambert',
#   'page_name': 'Eugène Lambert',
#   'description': 'French architect (1819-1875)',
#   'Qcode': 'Q22248714',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q22248714'},
#  {'search_name': 'Eugène-Théodore Troupenas',
#   'page_name': 'Eugène Troupenas',
#   'description': '1798-1850; Mathématicien. - Éditeur de musique',
#   'Qcode': 'Q55875031',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q55875031'},
#  {'search_name': 'Eustachy Marylski',
#   'page_name': 'Eustachy Anastazy Marylski',
#   'description': 'Polish landowner and writer, friend of Frédéric Chopin',
#   'Qcode': 'Q105330618',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q105330618'},
#  {'search_name': 'Fanny Hensel',
#   'page_name': 'Fanny Mendelssohn',
#   'description': 'German pianist and composer',
#   'Qcode': 'Q57286',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q57286'},
#  {'search_name': 'Fanny Persiani',
#   'page_name': 'Fanny Tacchinardi Persiani',
#   'description': 'Italian opera singer (soprano)',
#   'Qcode': 'Q269694',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q269694'},
#  {'search_name': 'Felix Mendelssohn-Bartholdy',
#   'page_name': 'Felix Mendelssohn',
#   'description': 'German composer, pianist, organist and conductor of Jewish descent',
#   'Qcode': 'Q46096',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q46096'},
#  {'search_name': 'Ferdinando Paër',
#   'page_name': 'Ferdinando Paer',
#   'description': 'Italian composer',
#   'Qcode': 'Q533022',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q533022'},
#  {'search_name': 'Ferdynand Hiller',
#   'page_name': 'Ferdinand Hiller',
#   'description': 'German composer and conductor',
#   'Qcode': 'Q213530',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q213530'},
#  {'search_name': 'Ferenc Liszt',
#   'page_name': 'Franz Liszt',
#   'description': 'Hungarian romantic composer and virtuoso pianist',
#   'Qcode': 'Q41309',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q41309'},
#  {'search_name': 'Félicien David',
#   'page_name': 'Félicien-César David',
#   'description': 'French composer',
#   'Qcode': 'Q951933',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q951933'},
#  {'search_name': 'Filippo Coletti',
#   'page_name': 'Filippo Coletti',
#   'description': 'Italian opera singer',
#   'Qcode': 'Q15429707',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q15429707'},
#  {'search_name': 'Francesco de Vico',
#   'page_name': 'Francesco de Vico',
#   'description': 'Italian astronomer (1805-1848)',
#   'Qcode': 'Q1441283',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1441283'},
#  {'search_name': 'Francisca de Joinville (Princess of Brazil)',
#   'page_name': 'Princess Francisca, Princess of Joinville',
#   'description': 'Princess of Brazil',
#   'Qcode': 'Q242159',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q242159'},
#  {'search_name': 'Francisco de Asís de Borbón (King, consort of Isabella II)',
#   'page_name': 'King Francisco of Spain',
#   'description': 'King Consort of Spain from 1846 to 1868',
#   'Qcode': 'Q356522',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q356522'},
#  {'search_name': 'Franciszek Skibicki',
#   'page_name': 'Franciszek Skibicki',
#   'description': None,
#   'Qcode': 'Q11698724',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q11698724'},
#  {'search_name': 'François Arago',
#   'page_name': 'François Arago',
#   'description': 'French mathematician, physicist, astronomer and politician (1786-1853)',
#   'Qcode': 'Q154353',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q154353'},
#  {'search_name': 'François Guizot',
#   'page_name': 'François Guizot',
#   'description': 'French historian, orator, and statesman (1787-1874)',
#   'Qcode': 'Q157324',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q157324'},
#  {'search_name': 'François-Antoine Habeneck',
#   'page_name': 'François Habeneck',
#   'description': 'French violinist and conductor (1781-1849)',
#   'Qcode': 'Q957041',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q957041'},
#  {'search_name': 'François-Joseph Fétis',
#   'page_name': 'François-Joseph Fétis',
#   'description': 'Belgian composer (1784-1871)',
#   'Qcode': 'Q523581',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q523581'},
#  {'search_name': 'François-Joseph Gossec',
#   'page_name': 'François Joseph Gossec',
#   'description': 'French composer and conductor',
#   'Qcode': 'Q313667',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q313667'},
#  {'search_name': 'François-Victor Hugo',
#   'page_name': 'François-Victor Hugo',
#   'description': "4th of Victor Hugo's 5 children",
#   'Qcode': 'Q3083678',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3083678'},
#  {'search_name': 'Friederike Müller-Streicher',
#   'page_name': 'Friederike Müller',
#   'description': None,
#   'Qcode': 'Q15451236',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q15451236'},
#  {'search_name': 'Friedrich Wilhelm Michael Kalkbrenner',
#   'page_name': 'Friedrich Kalkbrenner',
#   'description': 'German-born French pianist, composer, piano teacher and piano manufacturer (1784-1849)',
#   'Qcode': 'Q170270',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q170270'},
#  {'search_name': 'Fryderyk Chopin',
#   'page_name': 'Frédéric Chopin',
#   'description': 'Polish composer and pianist',
#   'Qcode': 'Q1268',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1268'},
#  {'search_name': 'Frédéric Villot',
#   'page_name': 'Frédéric Villot',
#   'description': 'French printmaker and art historian',
#   'Qcode': 'Q3090265',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3090265'},
#  {'search_name': 'Félicité de Lamennais',
#   'page_name': 'Félicité de La Mennais',
#   'description': 'French priest, philosopher and political theorist (1782–1854)',
#   'Qcode': 'Q334973',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q334973'},
#  {'search_name': 'Félix-Auguste Duvert',
#   'page_name': 'Félix-Auguste Duvert',
#   'description': 'French writer',
#   'Qcode': 'Q3092326',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3092326'},
#  {'search_name': 'Gabriel Bonnot de Mably',
#   'page_name': 'Gabriel Bonnot de Mably',
#   'description': 'French philosopher, historian, and writer (1709–1785)',
#   'Qcode': 'Q202555',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q202555'},
#  {'search_name': 'Gaetano Donizetti',
#   'page_name': 'Gaetano Donizetti',
#   'description': 'Italian opera composer (1797–1848)',
#   'Qcode': 'Q101698',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q101698'},
#  {'search_name': 'Gaspard Deguerry',
#   'page_name': 'Gaspard Deguerry',
#   'description': 'French priest',
#   'Qcode': 'Q21292828',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q21292828'},
#  {'search_name': 'Gemmy Brandus',
#   'page_name': 'Gemmy Brandus',
#   'description': None,
#   'Qcode': 'Q55902818',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q55902818'},
#  {'search_name': 'George Sand',
#   'page_name': 'George Sand',
#   'description': 'French novelist and memoirist; pseudonym of Lucile Aurore Dupin',
#   'Qcode': 'Q3816',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3816'},
#  {'search_name': 'Georgiana Somerset',
#   'page_name': 'Lady Georgiana Somerset',
#   'description': '(died 1884)',
#   'Qcode': 'Q75253339',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q75253339'},
#  {'search_name': 'Giacomo Meyerbeer',
#   'page_name': 'Giacomo Meyerbeer',
#   'description': 'German-French composer',
#   'Qcode': 'Q105237',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q105237'},
#  {'search_name': 'Gioacchino Rossini',
#   'page_name': 'Gioacchino Rossini',
#   'description': 'Italian opera composer',
#   'Qcode': 'Q9726',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9726'},
#  {'search_name': 'Giovanni Battista Pergolesi',
#   'page_name': 'Giovanni Battista Pergolesi',
#   'description': 'Italian composer, violinist and organist (1710–1736)',
#   'Qcode': 'Q185312',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q185312'},
#  {'search_name': 'Giovanni Mario',
#   'page_name': 'Giovanni Mario Crescimbeni',
#   'description': 'Italian poet',
#   'Qcode': 'Q766828',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q766828'},
#  {'search_name': 'Giulia Grisi',
#   'page_name': 'Giulia Grisi',
#   'description': 'Italian soprano (1811-1869)',
#   'Qcode': 'Q287344',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q287344'},
#  {'search_name': 'Giuseppe Verdi',
#   'page_name': 'Giuseppe Verdi',
#   'description': 'Italian composer of the Romantic Era',
#   'Qcode': 'Q7317',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q7317'},
#  {'search_name': 'Godefroi de Bouillon',
#   'page_name': 'Godfrey of Bouillon',
#   'description': 'Medieval Frankish knight',
#   'Qcode': 'Q76721',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q76721'},
#  {'search_name': 'Gustave Roger',
#   'page_name': 'Gustave-Roger Sandoz',
#   'description': 'French architectural historian, jeweler, and goldsmith',
#   'Qcode': 'Q104670236',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q104670236'},
#  {'search_name': 'Harriet Grote',
#   'page_name': 'Harriet Grote',
#   'description': 'British writer, known also for her salon',
#   'Qcode': 'Q5664138',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q5664138'},
#  {'search_name': 'Harriet Leveson-Gower, Duchess of Sutherland',
#   'page_name': 'Harriet Sutherland-Leveson-Gower, Duchess of Sutherland',
#   'description': 'British duchess (1806-1868)',
#   'Qcode': 'Q1184700',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1184700'},
#  {'search_name': 'Hector Berlioz',
#   'page_name': 'Hector Berlioz',
#   'description': 'French composer and conductor (1803–1869)',
#   'Qcode': 'Q1151',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1151'},
#  {'search_name': 'Heinrich Heine',
#   'page_name': 'Heinrich Heine',
#   'description': 'German poet, writer and literary critic (1797–1856)',
#   'Qcode': 'Q44403',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q44403'},
#  {'search_name': 'Helena Górska',
#   'page_name': 'Helena Górska',
#   'description': 'Polish actress',
#   'Qcode': 'Q102355196',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q102355196'},
#  {'search_name': 'Henri Herz',
#   'page_name': 'Henri Herz',
#   'description': 'Austrian musician',
#   'Qcode': 'Q572547',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q572547'},
#  {'search_name': 'Henri Vieuxtemps',
#   'page_name': 'Henri Vieuxtemps',
#   'description': 'Belgian violinist (1820-1881)',
#   'Qcode': 'Q312790',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q312790'},
#  {'search_name': 'Henry Fowler Broadwood',
#   'page_name': 'Henry Fowler Broadwood',
#   'description': 'British piano manufacturer',
#   'Qcode': 'Q18683978',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q18683978'},
#  {'search_name': 'Henry Victor Malan',
#   'page_name': 'Henry Victor de Merindol Malan',
#   'description': '(died 1879)',
#   'Qcode': 'Q75713522',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q75713522'},
#  {'search_name': 'Hipolit Błotnicki',
#   'page_name': 'Hipolit Blotnicki',
#   'description': None,
#   'Qcode': 'Q9292401',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9292401'},
#  {'search_name': 'Hippolyte Lucas',
#   'page_name': 'Hippolyte Lucas',
#   'description': 'French entomologist',
#   'Qcode': 'Q1620044',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1620044'},
#  {'search_name': 'Horace Vernet',
#   'page_name': 'Horace Vernet',
#   'description': 'French painter (1789–1863)',
#   'Qcode': 'Q161145',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q161145'},
#  {'search_name': 'Ignacy Jan Paderewski',
#   'page_name': 'Ignacy Jan Paderewski',
#   'description': "Polish pianist, composer, supporter of Poland's independence movements, politician, Prime Minister of reborn Poland (1860–1941)",
#   'Qcode': 'Q191957',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q191957'},
#  {'search_name': 'Ignacy Krasicki',
#   'page_name': 'Ignacy Krasicki',
#   'description': 'Polish writer and poet, Catholic archbishop',
#   'Qcode': 'Q380545',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q380545'},
#  {'search_name': 'Ignacy Krzyżanowski',
#   'page_name': 'Ignacy Krzyżanowski',
#   'description': 'Polish composer',
#   'Qcode': 'Q4240587',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q4240587'},
#  {'search_name': 'Ignaz Moscheles',
#   'page_name': 'Ignaz Moscheles',
#   'description': 'Bohemian conductor, music educator, composer and pianist (1794-1870)',
#   'Qcode': 'Q159551',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q159551'},
#  {'search_name': 'Isabella II, Queen of Spain',
#   'page_name': 'Isabella II of Spain',
#   'description': 'Queen of Spain (1833-1868)',
#   'Qcode': 'Q183085',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q183085'},
#  {'search_name': 'Izabela Chopin',
#   'page_name': 'Izabela Barcińska',
#   'description': 'Polish',
#   'Qcode': 'Q98112689',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q98112689'},
#  {'search_name': 'Jacques de Vaucanson',
#   'page_name': 'Jacques de Vaucanson',
#   'description': 'French inventor of mechanical automata',
#   'Qcode': 'Q454589',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q454589'},
#  {'search_name': 'Jan Białobłocki',
#   'page_name': 'Jan Nepomucen Białobłocki',
#   'description': 'Polish composer',
#   'Qcode': 'Q16198315',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q16198315'},
#  {'search_name': 'Jan Křtitel Pišek',
#   'page_name': 'Johann Baptist Pischek',
#   'description': '(1814-1873)',
#   'Qcode': 'Q1583163',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1583163'},
#  {'search_name': 'Jan Matuszyński',
#   'page_name': 'Jan Matuszyński',
#   'description': 'Polish doctor',
#   'Qcode': 'Q11718359',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q11718359'},
#  {'search_name': 'Jan Nepomuk Štěpánek',
#   'page_name': 'Jan Nepomuk Štěpánek',
#   'description': 'Czech playwright and actor (1783-1844)',
#   'Qcode': 'Q3507431',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3507431'},
#  {'search_name': 'Jan Paderewski',
#   'page_name': 'Ignacy Jan Paderewski',
#   'description': "Polish pianist, composer, supporter of Poland's independence movements, politician, Prime Minister of reborn Poland (1860–1941)",
#   'Qcode': 'Q191957',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q191957'},
#  {'search_name': 'Jan Sebastian Bach',
#   'page_name': 'Johann Sebastian Bach',
#   'description': 'German composer (1685–1750)',
#   'Qcode': 'Q1339',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1339'},
#  {'search_name': 'Jane Welsh Carlyle',
#   'page_name': 'Jane Welsh Carlyle',
#   'description': 'Scottish writer',
#   'Qcode': 'Q6152913',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q6152913'},
#  {'search_name': 'Jane Wilhelmina Stirling',
#   'page_name': 'Jane Stirling',
#   'description': 'Scottish amateur pianist',
#   'Qcode': 'Q3117939',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3117939'},
#  {'search_name': 'Jean Jacques Rousseau',
#   'page_name': 'Jean-Jacques Rousseau',
#   'description': 'Genevan philosopher, writer and composer (1712–1778)',
#   'Qcode': 'Q6527',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q6527'},
#  {'search_name': 'Jean Nicolas Marjolin',
#   'page_name': 'Jean-Nicolas Marjolin',
#   'description': 'French surgeon and pathologist',
#   'Qcode': 'Q2161733',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2161733'},
#  {'search_name': 'Jean de La Fontaine',
#   'page_name': 'Jean de La Fontaine',
#   'description': 'French poet, fabulist and writer (1621-1695)',
#   'Qcode': 'Q49496',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q49496'},
#  {'search_name': 'Jean-Antoine Letronne',
#   'page_name': 'Jean Antoine Letronne',
#   'description': 'French archaeologist',
#   'Qcode': 'Q574368',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q574368'},
#  {'search_name': 'Jean-Baptiste Clésinger',
#   'page_name': 'Auguste Clésinger',
#   'description': '19th-century French sculptor and painter (1814-1883)',
#   'Qcode': 'Q2871155',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2871155'},
#  {'search_name': 'Jean-Baptiste Massillon',
#   'page_name': 'Jean-Baptiste Massillon',
#   'description': 'French Catholic bishop and famous preacher',
#   'Qcode': 'Q1381729',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1381729'},
#  {'search_name': 'Jean-Baptiste-Antoine Lassus',
#   'page_name': 'Jean-Baptiste-Antoine Lassus',
#   'description': 'French architect',
#   'Qcode': 'Q3163757',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3163757'},
#  {'search_name': 'Jean-Delphin Alard',
#   'page_name': 'Jean-Delphin Alard',
#   'description': 'French musician',
#   'Qcode': 'Q633796',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q633796'},
#  {'search_name': 'Jean-François Lesueur',
#   'page_name': 'Jean-François Le Sueur',
#   'description': 'French composer',
#   'Qcode': 'Q559659',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q559659'},
#  {'search_name': 'Jean-Jacques Molin',
#   'page_name': 'Jean-Jacques Mercier-de Molin',
#   'description': '(1859-1932)',
#   'Qcode': 'Q3166351',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3166351'},
#  {'search_name': 'Jenny Lind',
#   'page_name': 'Jenny Lind',
#   'description': 'Swedish classical singer',
#   'Qcode': 'Q231345',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q231345'},
#  {'search_name': 'Joaquina Garcia',
#   'page_name': 'Joaquina García Balmaseda',
#   'description': 'Spanish journalist, poet, comedian, and writer',
#   'Qcode': 'Q5931650',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q5931650'},
#  {'search_name': 'Johann Gottfried Galle',
#   'page_name': 'Johann Gottfried Galle',
#   'description': 'German astronomer (1812-1910)',
#   'Qcode': 'Q76431',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q76431'},
#  {'search_name': 'Johannes Brahms',
#   'page_name': 'Johannes Brahms',
#   'description': 'German composer, pianist and conductor (1833–1897)',
#   'Qcode': 'Q7294',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q7294'},
#  {'search_name': 'John Hind',
#   'page_name': 'John Hind',
#   'description': 'Bishop of Chichester (born 1945)',
#   'Qcode': 'Q780817',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q780817'},
#  {'search_name': 'Josef Dessauer',
#   'page_name': 'Josef Dessauer',
#   'description': 'Czech composer',
#   'Qcode': 'Q322065',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q322065'},
#  {'search_name': 'Joseph Faber',
#   'page_name': 'Joseph Faber',
#   'description': 'Luxembourgish politician (1862-1933)',
#   'Qcode': 'Q16439150',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q16439150'},
#  {'search_name': 'Jules Janin',
#   'page_name': 'Jules Janin',
#   'description': 'French writer and critic',
#   'Qcode': 'Q956459',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q956459'},
#  {'search_name': 'Julian Fontana',
#   'page_name': 'Julian Fontana',
#   'description': 'Polish musician (1810-1869)',
#   'Qcode': 'Q1711991',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1711991'},
#  {'search_name': 'Juliette Drouet',
#   'page_name': 'Juliette Drouet',
#   'description': 'French actress',
#   'Qcode': 'Q440119',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q440119'},
#  {'search_name': 'Juliusz Dziewanowski',
#   'page_name': 'Juliusz Dziewanowski',
#   'description': None,
#   'Qcode': 'Q107338652',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q107338652'},
#  {'search_name': 'Juliusz Słowacki',
#   'page_name': 'Juliusz Słowacki',
#   'description': 'Polish poet',
#   'Qcode': 'Q243267',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q243267'},
#  {'search_name': 'Justyna Chopin',
#   'page_name': 'Tekla Justyna Chopin',
#   'description': 'mother of Frédéric Chopin',
#   'Qcode': 'Q9356382',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9356382'},
#  {'search_name': 'Józef Bem',
#   'page_name': 'Józef Bem',
#   'description': 'Polish general',
#   'Qcode': 'Q266339',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q266339'},
#  {'search_name': 'Józef Bełza',
#   'page_name': 'Józef Bełza',
#   'description': 'Polish chemist (1805-1888)',
#   'Qcode': 'Q11729930',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q11729930'},
#  {'search_name': 'Józef Bohdan Zaleski',
#   'page_name': 'Józef Bohdan Zaleski',
#   'description': 'Polish poet',
#   'Qcode': 'Q1355484',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1355484'},
#  {'search_name': 'Józef Brzowski',
#   'page_name': 'Józef Brzowski',
#   'description': 'Polish composer',
#   'Qcode': 'Q4086154',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q4086154'},
#  {'search_name': 'Józef Damse',
#   'page_name': 'Józef Damse',
#   'description': 'Polish composer and actor',
#   'Qcode': 'Q1350174',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1350174'},
#  {'search_name': 'Józef Dwernicki',
#   'page_name': 'Józef Dwernicki',
#   'description': 'Polish general (1779-1857)',
#   'Qcode': 'Q572132',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q572132'},
#  {'search_name': 'Józef Elsner',
#   'page_name': 'Józef Elsner',
#   'description': 'Polish composer',
#   'Qcode': 'Q471647',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q471647'},
#  {'search_name': 'Józef Haydn',
#   'page_name': 'Joseph Haydn',
#   'description': 'Austrian composer',
#   'Qcode': 'Q7349',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q7349'},
#  {'search_name': 'Józef Kurowski',
#   'page_name': 'Józef Kurowski',
#   'description': 'Polish botanist',
#   'Qcode': 'Q112609235',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q112609235'},
#  {'search_name': 'Józef Nowakowski',
#   'page_name': 'Józef Nowakowski',
#   'description': 'Polish Righteous Among the Nations',
#   'Qcode': 'Q109996468',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q109996468'},
#  {'search_name': 'Józef Stefani',
#   'page_name': 'Józef Stefani',
#   'description': 'Polish conductor and composer (1800-1876)',
#   'Qcode': 'Q1715110',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1715110'},
#  {'search_name': 'Karol Lipiński',
#   'page_name': 'Karol Lipiński',
#   'description': 'Polish musician',
#   'Qcode': 'Q390986',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q390986'},
#  {'search_name': 'Katarzyna Potocka (hrabina)',
#   'page_name': 'Katarzyna Branicka',
#   'description': 'Polish noblewoman',
#   'Qcode': 'Q6375196',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q6375196'},
#  {'search_name': 'Katherine Erskine',
#   'page_name': 'Katherine Erskine',
#   'description': 'Peerage person ID=16926',
#   'Qcode': 'Q75257538',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q75257538'},
#  {'search_name': 'Kazimierz Wernik',
#   'page_name': 'Kazimierz Wernik',
#   'description': 'Polish pianist and composer',
#   'Qcode': 'Q54837758',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q54837758'},
#  {'search_name': 'Kazimierz Wodziński',
#   'page_name': 'Tadeusz Kazimierz Wacław Bronisław Rzewuski',
#   'description': None,
#   'Qcode': 'Q96123950',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q96123950'},
#  {'search_name': 'King of France Francis I',
#   'page_name': 'Francis I of France',
#   'description': 'King of France (1494-1547)',
#   'Qcode': 'Q129857',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q129857'},
#  {'search_name': 'King of France Louis XV',
#   'page_name': 'Louis XV of France',
#   'description': 'King of France from 1715 to 1774',
#   'Qcode': 'Q7738',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q7738'},
#  {'search_name': 'King of Spain Charles III',
#   'page_name': 'Charles III of Spain',
#   'description': 'King of Spain from 1759 to 1788',
#   'Qcode': 'Q36234',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q36234'},
#  {'search_name': 'Klementyna Hoffmanowa',
#   'page_name': 'Klementyna Hoffmanowa',
#   'description': 'Polish prose writer, popularizer, translator, editor, one of the first Polish writers for children (1798-1845)',
#   'Qcode': 'Q433781',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q433781'},
#  {'search_name': 'Konstanty Gaszyński',
#   'page_name': 'Konstatny Gaszyński',
#   'description': None,
#   'Qcode': 'Q4893675',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q4893675'},
#  {'search_name': 'Konstanty Pruszak',
#   'page_name': 'Feliks Konstanty Pruszak',
#   'description': None,
#   'Qcode': 'Q96126292',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q96126292'},
#  {'search_name': 'Krystyn Ostrowski',
#   'page_name': 'Krystyn Ostrowski',
#   'description': None,
#   'Qcode': 'Q97695042',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q97695042'},
#  {'search_name': 'Laura Horsford',
#   'page_name': 'Laura Horsford',
#   'description': None,
#   'Qcode': 'Q18746840',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q18746840'},
#  {'search_name': 'Leopold Thun-Hohenstein',
#   'page_name': 'Leopold Thun-Hohenstein',
#   'description': '(1888-1944)',
#   'Qcode': 'Q112462366',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q112462366'},
#  {'search_name': 'Leopold von Baden',
#   'page_name': 'Prince Leopold of Baden',
#   'description': '(born 1971)',
#   'Qcode': 'Q75383615',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q75383615'},
#  {'search_name': 'Louis Boulanger',
#   'page_name': 'Louis Boulanger',
#   'description': 'French romantic painter (1806-1867)',
#   'Qcode': 'Q524582',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q524582'},
#  {'search_name': 'Louis Brandus',
#   'page_name': 'Louis Brandus',
#   'description': None,
#   'Qcode': 'Q115589643',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q115589643'},
#  {'search_name': 'Louis Charles Philippe Raphaël Orléans (duc de Nemours)',
#   'page_name': 'Prince Louis, Duke of Nemours',
#   'description': 'Duke of Nemours',
#   'Qcode': 'Q454297',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q454297'},
#  {'search_name': 'Louis Dupin de Francueil',
#   'page_name': 'Louis Dupin de Francueil',
#   'description': '(1715-1786)',
#   'Qcode': 'Q2959670',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2959670'},
#  {'search_name': 'Louis Hippolyte Lebas',
#   'page_name': 'Hippolyte Le Bas',
#   'description': 'French architect',
#   'Qcode': 'Q712867',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q712867'},
#  {'search_name': 'Louis James Alfred Lefébure-Wély',
#   'page_name': 'Louis James Alfred Lefébure-Wély',
#   'description': 'French composer and organist',
#   'Qcode': 'Q546919',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q546919'},
#  {'search_name': 'Louis Kleinwächter',
#   'page_name': 'Alois Kleinwächter',
#   'description': '(1807-1840)',
#   'Qcode': 'Q55853534',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q55853534'},
#  {'search_name': 'Louis Spohr',
#   'page_name': 'Louis Spohr',
#   'description': 'German composer, violinist and conductor',
#   'Qcode': 'Q57226',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q57226'},
#  {'search_name': 'Louis Viardot',
#   'page_name': 'Louis Viardot',
#   'description': 'French literary critic, impresario and translator (1800-1883)',
#   'Qcode': 'Q584292',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q584292'},
#  {'search_name': 'Louis-Philippe-Joseph Girod de Vienney (baron de Trémont)',
#   'page_name': 'Louis-Philippe-Joseph Girod de Vienney, baron de Trémont',
#   'description': 'French official (1779-1852)',
#   'Qcode': 'Q15639295',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q15639295'},
#  {'search_name': 'Lucie Maréchal',
#   'page_name': 'Lucie Guyant-Maréchal',
#   'description': 'researcher',
#   'Qcode': 'Q114410130',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q114410130'},
#  {'search_name': 'Ludovic Houston',
#   'page_name': 'Sir Ludovic Houston of Houston',
#   'description': '(died 1662)',
#   'Qcode': 'Q76252248',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q76252248'},
#  {'search_name': 'Ludwig van Beethoven',
#   'page_name': 'Ludwig van Beethoven',
#   'description': 'German composer (1770–1827)',
#   'Qcode': 'Q255',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q255'},
#  {'search_name': 'Ludwik Adam Dmuszewski',
#   'page_name': 'Ludwik Adam Dmuszewski',
#   'description': 'Polish actor',
#   'Qcode': 'Q8861068',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q8861068'},
#  {'search_name': 'Ludwik Filip I (król Francuzów)',
#   'page_name': 'Louis-Philippe I',
#   'description': 'King of the French (1773-1850)',
#   'Qcode': 'Q7771',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q7771'},
#  {'search_name': 'Ludwik Plater',
#   'page_name': 'Ludwik Plater',
#   'description': None,
#   'Qcode': 'Q823035',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q823035'},
#  {'search_name': 'Ludwika Chopin',
#   'page_name': 'Ludwika Jędrzejewicz Chopin',
#   'description': 'Polish musician (1807-1855)',
#   'Qcode': 'Q6699463',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q6699463'},
#  {'search_name': 'Ludwika Jędrzejewiczowa',
#   'page_name': 'Ludwika Jędrzejewicz Chopin',
#   'description': 'Polish musician (1807-1855)',
#   'Qcode': 'Q6699463',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q6699463'},
#  {'search_name': 'Luigi Cherubini',
#   'page_name': 'Luigi Cherubini',
#   'description': 'Italian Classical and Romantic composer (1760–1842)',
#   'Qcode': 'Q20721',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q20721'},
#  {'search_name': 'Luigi Lablache',
#   'page_name': 'Luigi Lablache',
#   'description': 'Italian opera singer (1794-1858)',
#   'Qcode': 'Q477681',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q477681'},
#  {'search_name': 'Léon Pillet',
#   'page_name': 'Léon Pillet',
#   'description': 'French journalist and opera company manager',
#   'Qcode': 'Q6711106',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q6711106'},
#  {'search_name': 'Léopoldine Hugo',
#   'page_name': 'Léopoldine Hugo',
#   'description': 'elder daughter of Victor Hugo',
#   'Qcode': 'Q3271923',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3271923'},
#  {'search_name': 'Madame Etienne',
#   'page_name': 'Madame Étienne Aubry',
#   'description': None,
#   'Qcode': 'Q105212185',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q105212185'},
#  {'search_name': 'Marcelina Czartoryska',
#   'page_name': 'Marcelina Czartoryska',
#   'description': 'Polish musician and aristocrat (1817-1894)',
#   'Qcode': 'Q6756303',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q6756303'},
#  {'search_name': 'Maria Kalergis',
#   'page_name': 'Maria Kalergis',
#   'description': 'Polish musician',
#   'Qcode': 'Q2022977',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2022977'},
#  {'search_name': 'Maria Wirtemberska',
#   'page_name': 'Princess Maria Czartoryska',
#   'description': 'Polish-Lithuanian noblewoman and writer',
#   'Qcode': 'Q458975',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q458975'},
#  {'search_name': 'Maria Wodzińska',
#   'page_name': 'Maria Wodzińska',
#   'description': 'Polish artist',
#   'Qcode': 'Q273923',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q273923'},
#  {'search_name': 'Marie Dorval',
#   'page_name': 'Marie Dorval',
#   'description': 'French actress',
#   'Qcode': 'Q2636224',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2636224'},
#  {'search_name': 'Marie de Rozières',
#   'page_name': 'Eugène de Rozière',
#   'description': 'French politician',
#   'Qcode': 'Q3060246',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3060246'},
#  {'search_name': 'Marie d’Agoult',
#   'page_name': "Marie d'Agoult",
#   'description': 'Franco-German romantic author and historian',
#   'Qcode': 'Q253453',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q253453'},
#  {'search_name': 'Marie-Amélie, Queen consort of Louis-Philippe',
#   'page_name': 'Maria Amalia of Naples and Sicily',
#   'description': 'Queen Consort of France (1830-1848)',
#   'Qcode': 'Q231457',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q231457'},
#  {'search_name': 'Marietta Alboni',
#   'page_name': 'Marietta Alboni',
#   'description': 'Italian operatic contralto (1826-1894)',
#   'Qcode': 'Q269130',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q269130'},
#  {'search_name': 'Mary Murray (Lady)',
#   'page_name': 'Lady Mary Murray',
#   'description': '(died 1814)',
#   'Qcode': 'Q75264800',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q75264800'},
#  {'search_name': 'Mary Rich',
#   'page_name': 'Mary Rich',
#   'description': '1789',
#   'Qcode': 'Q73284789',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q73284789'},
#  {'search_name': 'Mary, Queen of Scots',
#   'page_name': 'Mary, Queen of Scots',
#   'description': 'Queen of Scotland from 1542 to 1567',
#   'Qcode': 'Q131412',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q131412'},
#  {'search_name': 'María Luisa Fernanda de Borbón',
#   'page_name': 'Infanta Luisa Fernanda, Duchess of Montpensier',
#   'description': 'Princess of Spain',
#   'Qcode': 'Q240397',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q240397'},
#  {'search_name': 'Maurice Sand',
#   'page_name': 'Maurice Sand',
#   'description': 'French illustrator and writer (1823-1889)',
#   'Qcode': 'Q1385973',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1385973'},
#  {'search_name': 'Maurice Schlesinger',
#   'page_name': 'Maurice Schlesinger',
#   'description': 'German music publisher',
#   'Qcode': 'Q70457',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q70457'},
#  {'search_name': 'Maurycy Karasowski',
#   'page_name': 'Maurycy Karasowski',
#   'description': 'Polish composer and musicologist',
#   'Qcode': 'Q4214233',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q4214233'},
#  {'search_name': 'Michael William Balfe',
#   'page_name': 'Michael William Balfe',
#   'description': 'Irish composer (1808-1870)',
#   'Qcode': 'Q434171',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q434171'},
#  {'search_name': 'Michalina Rzyszczewska',
#   'page_name': 'Michalina Rzyszczewska',
#   'description': None,
#   'Qcode': 'Q104705986',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q104705986'},
#  {'search_name': 'Michał Skarbek',
#   'page_name': 'Q100591421',
#   'description': None,
#   'Qcode': 'Q100591421',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q100591421'},
#  {'search_name': 'Mikołaj Chopin',
#   'page_name': 'Nicolas Chopin',
#   'description': 'Polish teacher of French language and father of composer Frédéric Chopin (1771-1844)',
#   'Qcode': 'Q651253',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q651253'},
#  {'search_name': 'Napoleon Orda',
#   'page_name': 'Napoleon Orda',
#   'description': 'Polish–Lithuanian artist (1807-1883)',
#   'Qcode': 'Q941622',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q941622'},
#  {'search_name': 'Narcisse-Achille de Salvandy (comte)',
#   'page_name': 'Narcisse-Achille de Salvandy',
#   'description': 'French politician (1795-1856)',
#   'Qcode': 'Q1381121',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1381121'},
#  {'search_name': 'Nicolas Poussin',
#   'page_name': 'Nicolas Poussin',
#   'description': 'French painter (1594-1665)',
#   'Qcode': 'Q41554',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q41554'},
#  {'search_name': 'Norbert Alfons Kumelski',
#   'page_name': 'Norbert Alfons Kumelski',
#   'description': None,
#   'Qcode': 'Q4246922',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q4246922'},
#  {'search_name': 'Oskar Kolberg',
#   'page_name': 'Oskar Kolberg',
#   'description': 'Polish ethnologist, folklorist, and composer (1814-1890)',
#   'Qcode': 'Q195301',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q195301'},
#  {'search_name': 'Paul Delaroche',
#   'page_name': 'Paul Delaroche',
#   'description': 'French painter (1797-1856)',
#   'Qcode': 'Q322582',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q322582'},
#  {'search_name': 'Paul Gavarni',
#   'page_name': 'Paul Gavarni',
#   'description': 'French caricaturist (1804-1866)',
#   'Qcode': 'Q1074290',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1074290'},
#  {'search_name': 'Paulina Viardot',
#   'page_name': 'Pauline Viardot',
#   'description': 'French mezzo-soprano and composer',
#   'Qcode': 'Q122998',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q122998'},
#  {'search_name': 'Pedro Calderón de la Barca',
#   'page_name': 'Pedro Calderón de la Barca',
#   'description': 'Spanish dramatist (1600-1681)',
#   'Qcode': 'Q170800',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q170800'},
#  {'search_name': 'Peter Paul Rubens',
#   'page_name': 'Peter Paul Rubens',
#   'description': 'Flemish painter (1577-1640)',
#   'Qcode': 'Q5599',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q5599'},
#  {'search_name': 'Pierre Corneille',
#   'page_name': 'Pierre Corneille',
#   'description': 'French tragedian (1606–1684)',
#   'Qcode': 'Q747',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q747'},
#  {'search_name': 'Pierre Leroux',
#   'page_name': 'Pierre Leroux',
#   'description': 'French philosopher and political economist (1797-1871)',
#   'Qcode': 'Q704649',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q704649'},
#  {'search_name': 'Pierre-Marcel Gaubert',
#   'page_name': 'Pierre-Marcel Gaubert',
#   'description': 'French physician',
#   'Qcode': 'Q113126918',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q113126918'},
#  {'search_name': 'Pietro Mechetti',
#   'page_name': 'Pietro Mechetti',
#   'description': 'Publisher in Vienna (1777-1850)',
#   'Qcode': 'Q24705380',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q24705380'},
#  {'search_name': 'Piotr Sowiński',
#   'page_name': 'Piotr Sowinski',
#   'description': '(1940-1986) actor',
#   'Qcode': 'Q111021007',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q111021007'},
#  {'search_name': 'Regina Hiller',
#   'page_name': 'Regina Hiller',
#   'description': None,
#   'Qcode': 'Q95662884',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q95662884'},
#  {'search_name': 'René Vallet de Villeneuve',
#   'page_name': 'René Vallet de Villeneuve',
#   'description': 'French politician',
#   'Qcode': 'Q15968157',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q15968157'},
#  {'search_name': 'Robert Schumann',
#   'page_name': 'Robert Schumann',
#   'description': 'German composer (1810–1856)',
#   'Qcode': 'Q7351',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q7351'},
#  {'search_name': 'Rosine Stoltz',
#   'page_name': 'Rosine Stoltz',
#   'description': 'French operatic mezzo-soprano',
#   'Qcode': 'Q446126',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q446126'},
#  {'search_name': 'Sabine Heinefetter',
#   'page_name': 'Sabine Heinefetter',
#   'description': 'German singer and opera singer',
#   'Qcode': 'Q2209749',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2209749'},
#  {'search_name': 'Salis Schwabe',
#   'page_name': 'Salis Schwabe',
#   'description': 'Schwabe, Salis (1800–1853), calico printer and philanthropist',
#   'Qcode': 'Q18954554',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q18954554'},
#  {'search_name': 'Salomea Słowacka',
#   'page_name': 'Salomea Slowacka',
#   'description': '(1792-1855)',
#   'Qcode': 'Q9332959',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9332959'},
#  {'search_name': 'Samuel Carter Hall',
#   'page_name': 'Samuel Carter Hall',
#   'description': 'Irish-born Victorian journalist (1800-1889)',
#   'Qcode': 'Q2218070',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2218070'},
#  {'search_name': 'Schuberth & Co. company',
#   'page_name': 'Schuberth',
#   'description': 'bookbinder',
#   'Qcode': 'Q110219272',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q110219272'},
#  {'search_name': 'Seweryn Goszczyński',
#   'page_name': 'Seweryn Goszczyński',
#   'description': 'Polish writer',
#   'Qcode': 'Q1254858',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1254858'},
#  {'search_name': 'Sigismond von Neukomm',
#   'page_name': 'Sigismund von Neukomm',
#   'description': 'Austrian composer and pianist',
#   'Qcode': 'Q698066',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q698066'},
#  {'search_name': 'Solange Clésinger',
#   'page_name': 'Solange Dudevant-Sand',
#   'description': 'French novelist',
#   'Qcode': 'Q37886296',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q37886296'},
#  {'search_name': 'Solange Dudevant',
#   'page_name': 'Solange Dudevant-Sand',
#   'description': 'French novelist',
#   'Qcode': 'Q37886296',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q37886296'},
#  {'search_name': 'Stanisław Egbert Koźmian',
#   'page_name': 'Stanisław Egbert Koźmian',
#   'description': 'Polish translator',
#   'Qcode': 'Q3496754',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3496754'},
#  {'search_name': 'Stanisław Grabowski',
#   'page_name': 'Stanisław Grabowski',
#   'description': 'Polish sportsperson and athletics competitor',
#   'Qcode': 'Q9341976',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9341976'},
#  {'search_name': 'Stefan Witwicki',
#   'page_name': 'Stefan Witwicki',
#   'description': 'Polish poet (1801-1847)',
#   'Qcode': 'Q2891763',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2891763'},
#  {'search_name': 'Theodor Döhler',
#   'page_name': 'Theodor Döhler',
#   'description': 'German composer and pianist (1814-1856)',
#   'Qcode': 'Q1764820',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1764820'},
#  {'search_name': 'Thomas Albrecht',
#   'page_name': 'Thomas Albrecht',
#   'description': 'researcher ORCID ID = 0000-0002-9806-8884',
#   'Qcode': 'Q59748821',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q59748821'},
#  {'search_name': 'Thomas Bohier',
#   'page_name': 'Thomas Bohier',
#   'description': 'French politician (1460-1524)',
#   'Qcode': 'Q3524927',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3524927'},
#  {'search_name': 'Thomas Couture',
#   'page_name': 'Thomas Couture',
#   'description': 'French painter (1815-1879)',
#   'Qcode': 'Q326434',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q326434'},
#  {'search_name': 'Tomasz Nidecki',
#   'page_name': 'Tomasz Napoleon Nidecki',
#   'description': 'Polish composer (1807-1852)',
#   'Qcode': 'Q1767931',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1767931'},
#  {'search_name': 'Tytus Woyciechowski',
#   'page_name': 'Tytus Woyciechowski',
#   'description': 'Polish politician',
#   'Qcode': 'Q9363774',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9363774'},
#  {'search_name': 'Urbain Jean-Joseph Le Verrier',
#   'page_name': 'Urbain Le Verrier',
#   'description': 'French astronomer (1811-1877)',
#   'Qcode': 'Q104154',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q104154'},
#  {'search_name': 'Vera Rubio',
#   'page_name': 'Vera Cruz Rubio',
#   'description': 'researcher',
#   'Qcode': 'Q64015149',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q64015149'},
#  {'search_name': 'Victoire de Saxe-Cobourg-Koháry (duchesse de Nemours)',
#   'page_name': 'Princess Victoria, Duchess of Nemours',
#   'description': 'Saxe-Coburg and Gothan and French Royal',
#   'Qcode': 'Q61449',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q61449'},
#  {'search_name': 'Victor Borie',
#   'page_name': 'Victor Borie',
#   'description': 'French journalist',
#   'Qcode': 'Q29646607',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q29646607'},
#  {'search_name': 'Victor Hugo',
#   'page_name': 'Victor Hugo',
#   'description': 'French poet, novelist, politic and dramatist (1802–1885)',
#   'Qcode': 'Q535',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q535'},
#  {'search_name': 'Victoria, Queen of Great Britain',
#   'page_name': 'Queen of Great Britain Victoria',
#   'description': None,
#   'Qcode': 'Q56187806',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q56187806'},
#  {'search_name': 'Vinzenz Prießnitz',
#   'page_name': 'Vinzenz Priessnitz',
#   'description': None,
#   'Qcode': 'Q111668708',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q111668708'},
#  {'search_name': 'Václav Hanka',
#   'page_name': 'Václav Hanka',
#   'description': 'Czech archivist, poet, librarian, lexicographer, linguist, literature historian, publicist, translator, writer, university educator and science writer',
#   'Qcode': 'Q1354493',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1354493'},
#  {'search_name': 'Wilhelm Kolberg',
#   'page_name': 'Wilhelm Kolberg',
#   'description': None,
#   'Qcode': 'Q9374478',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9374478'},
#  {'search_name': 'Wilhelm Würfel',
#   'page_name': 'Wilhelm Würfel',
#   'description': 'Czech conductor, music educator, composer and pianist',
#   'Qcode': 'Q1364373',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1364373'},
#  {'search_name': 'William Herschel',
#   'page_name': 'William Herschel',
#   'description': 'German-born British astronomer, technical expert, and composer',
#   'Qcode': 'Q14277',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q14277'},
#  {'search_name': 'William Pitt (1. hrabia Chatham)',
#   'page_name': 'William Pitt, 1st Earl of Chatham',
#   'description': 'Prime Minister of Great Britain from 1766 to 1768',
#   'Qcode': 'Q208663',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q208663'},
#  {'search_name': 'Wojciech Grzymała',
#   'page_name': 'Wojciech Grzymała',
#   'description': 'Polish politician and banker (1793-1871)',
#   'Qcode': 'Q2831212',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q2831212'},
#  {'search_name': 'Wojciech Żywny',
#   'page_name': 'Wojciech Żywny',
#   'description': "Polish pianist, composer of Czech origin; Frédéric Chopin's piano teacher",
#   'Qcode': 'Q443519',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q443519'},
#  {'search_name': 'Wolfgang Amadeusz Mozart',
#   'page_name': 'Wolfgang Amadeus Mozart',
#   'description': 'Austrian composer of the Classical period',
#   'Qcode': 'Q254',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q254'},
#  {'search_name': 'Władysław Czartoryski',
#   'page_name': 'Władysław Czartoryski',
#   'description': 'Polish noble (1828-1894)',
#   'Qcode': 'Q696036',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q696036'},
#  {'search_name': 'Władysław Czartoryski (książę)',
#   'page_name': 'Władysław Czartoryski',
#   'description': 'Polish noble (1828-1894)',
#   'Qcode': 'Q696036',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q696036'},
#  {'search_name': 'Władysław Górski',
#   'page_name': 'Władysław Górski',
#   'description': None,
#   'Qcode': 'Q9381857',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9381857'},
#  {'search_name': 'Władysław Żeleński',
#   'page_name': 'Władysław Żeleński',
#   'description': 'Polish neoromantic composer, pianist and organist',
#   'Qcode': 'Q1391004',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q1391004'},
#  {'search_name': 'Xavier Durrieu',
#   'page_name': 'Joseph Emmanuel Durrieu',
#   'description': 'French politician',
#   'Qcode': 'Q16026753',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q16026753'},
#  {'search_name': 'Élisa de Lamartine',
#   'page_name': 'Elisa de Lamartine',
#   'description': 'French sculptor and painter (1790-1863)',
#   'Qcode': 'Q3051071',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q3051071'},
#  {'search_name': 'Élisabeth Rachel Félix',
#   'page_name': 'Rachel',
#   'description': 'French actress',
#   'Qcode': 'Q267985',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q267985'}]

# %%
input_qcodes = [d['Qcode'] for d in original_persons]
input_qcodes
# Out:
# ['Q123679',
#  'Q342889',
#  'Q79822',
#  'Q99639218',
#  'Q4505990',
#  'Q77840132',
#  'Q5738',
#  'Q137819',
#  'Q2082427',
#  'Q3608671',
#  'Q435375',
#  'Q9145532',
#  'Q20670032',
#  'Q38337',
#  'Q169150',
#  'Q188697',
#  'Q102194393',
#  'Q4766898',
#  'Q11686228',
#  'Q11285375',
#  'Q458156',
#  'Q550766',
#  'Q2074586',
#  'Q64862',
#  'Q106489731',
#  'Q263091',
#  'Q9157202',
#  'Q561112',
#  'Q9157627',
#  'Q182011',
#  'Q607998',
#  'Q436726',
#  'Q727056',
#  'Q517132',
#  'Q16054478',
#  'Q766768',
#  'Q713985',
#  'Q2375473',
#  'Q15975',
#  'Q2896159',
#  'Q9176254',
#  'Q21338629',
#  'Q2534918',
#  'Q1630994',
#  'Q159569',
#  'Q1047458',
#  'Q131552',
#  'Q109810560',
#  'Q62028861',
#  'Q23060765',
#  'Q663856',
#  'Q55846558',
#  'Q217068',
#  'Q61319',
#  'Q7322',
#  'Q114366',
#  'Q3021581',
#  'Q9209760',
#  'Q458688',
#  'Q17551656',
#  'Q5345972',
#  'Q3051916',
#  'Q8860780',
#  'Q2658508',
#  'Q1333348',
#  'Q33477',
#  'Q22248714',
#  'Q55875031',
#  'Q105330618',
#  'Q57286',
#  'Q269694',
#  'Q46096',
#  'Q533022',
#  'Q213530',
#  'Q41309',
#  'Q951933',
#  'Q15429707',
#  'Q1441283',
#  'Q242159',
#  'Q356522',
#  'Q11698724',
#  'Q154353',
#  'Q157324',
#  'Q957041',
#  'Q523581',
#  'Q313667',
#  'Q3083678',
#  'Q15451236',
#  'Q170270',
#  'Q1268',
#  'Q3090265',
#  'Q334973',
#  'Q3092326',
#  'Q202555',
#  'Q101698',
#  'Q21292828',
#  'Q55902818',
#  'Q3816',
#  'Q75253339',
#  'Q105237',
#  'Q9726',
#  'Q185312',
#  'Q766828',
#  'Q287344',
#  'Q7317',
#  'Q76721',
#  'Q104670236',
#  'Q5664138',
#  'Q1184700',
#  'Q1151',
#  'Q44403',
#  'Q102355196',
#  'Q572547',
#  'Q312790',
#  'Q18683978',
#  'Q75713522',
#  'Q9292401',
#  'Q1620044',
#  'Q161145',
#  'Q191957',
#  'Q380545',
#  'Q4240587',
#  'Q159551',
#  'Q183085',
#  'Q98112689',
#  'Q454589',
#  'Q16198315',
#  'Q1583163',
#  'Q11718359',
#  'Q3507431',
#  'Q191957',
#  'Q1339',
#  'Q6152913',
#  'Q3117939',
#  'Q6527',
#  'Q2161733',
#  'Q49496',
#  'Q574368',
#  'Q2871155',
#  'Q1381729',
#  'Q3163757',
#  'Q633796',
#  'Q559659',
#  'Q3166351',
#  'Q231345',
#  'Q5931650',
#  'Q76431',
#  'Q7294',
#  'Q780817',
#  'Q322065',
#  'Q16439150',
#  'Q956459',
#  'Q1711991',
#  'Q440119',
#  'Q107338652',
#  'Q243267',
#  'Q9356382',
#  'Q266339',
#  'Q11729930',
#  'Q1355484',
#  'Q4086154',
#  'Q1350174',
#  'Q572132',
#  'Q471647',
#  'Q7349',
#  'Q112609235',
#  'Q109996468',
#  'Q1715110',
#  'Q390986',
#  'Q6375196',
#  'Q75257538',
#  'Q54837758',
#  'Q96123950',
#  'Q129857',
#  'Q7738',
#  'Q36234',
#  'Q433781',
#  'Q4893675',
#  'Q96126292',
#  'Q97695042',
#  'Q18746840',
#  'Q112462366',
#  'Q75383615',
#  'Q524582',
#  'Q115589643',
#  'Q454297',
#  'Q2959670',
#  'Q712867',
#  'Q546919',
#  'Q55853534',
#  'Q57226',
#  'Q584292',
#  'Q15639295',
#  'Q114410130',
#  'Q76252248',
#  'Q255',
#  'Q8861068',
#  'Q7771',
#  'Q823035',
#  'Q6699463',
#  'Q6699463',
#  'Q20721',
#  'Q477681',
#  'Q6711106',
#  'Q3271923',
#  'Q105212185',
#  'Q6756303',
#  'Q2022977',
#  'Q458975',
#  'Q273923',
#  'Q2636224',
#  'Q3060246',
#  'Q253453',
#  'Q231457',
#  'Q269130',
#  'Q75264800',
#  'Q73284789',
#  'Q131412',
#  'Q240397',
#  'Q1385973',
#  'Q70457',
#  'Q4214233',
#  'Q434171',
#  'Q104705986',
#  'Q100591421',
#  'Q651253',
#  'Q941622',
#  'Q1381121',
#  'Q41554',
#  'Q4246922',
#  'Q195301',
#  'Q322582',
#  'Q1074290',
#  'Q122998',
#  'Q170800',
#  'Q5599',
#  'Q747',
#  'Q704649',
#  'Q113126918',
#  'Q24705380',
#  'Q111021007',
#  'Q95662884',
#  'Q15968157',
#  'Q7351',
#  'Q446126',
#  'Q2209749',
#  'Q18954554',
#  'Q9332959',
#  'Q2218070',
#  'Q110219272',
#  'Q1254858',
#  'Q698066',
#  'Q37886296',
#  'Q37886296',
#  'Q3496754',
#  'Q9341976',
#  'Q2891763',
#  'Q1764820',
#  'Q59748821',
#  'Q3524927',
#  'Q326434',
#  'Q1767931',
#  'Q9363774',
#  'Q104154',
#  'Q64015149',
#  'Q61449',
#  'Q29646607',
#  'Q535',
#  'Q56187806',
#  'Q111668708',
#  'Q1354493',
#  'Q9374478',
#  'Q1364373',
#  'Q14277',
#  'Q208663',
#  'Q2831212',
#  'Q443519',
#  'Q254',
#  'Q696036',
#  'Q696036',
#  'Q9381857',
#  'Q1391004',
#  'Q16026753',
#  'Q3051071',
#  'Q267985']

# %%
input_persons_wo_qcode = set(input) - {d['search_name'] for d in original_persons}
with open ("input_persons_wo_qcode.txt", "w") as f:
    f.write(str(input_persons_wo_qcode))
print(len(input_persons_wo_qcode))
input_persons_wo_qcode
# Out:
# 114
# {'Adam Crémieux',
#  'Adam Towiański',
#  'Agnès (Mlle)',
#  'Aleksander Julian Hofman',
#  'Aleksandra Karasowska',
#  'Alojzy Janowicz (pułkownik)',
#  'Amélie Franchomme',
#  'Amélie Grille de Beuzelin',
#  'Angelika Catalani',
#  'Anna Maria Walewska (księżna)',
#  'Anna Młokosiewicz',
#  'Anna z Tańkowskich Paderewska',
#  'Anne Elizabeth Louise Delaroche',
#  'Antoni Żelisław Jędrzejewicz',
#  'Antonina  Wilkońska',
#  'August Clésinger',
#  'Augustine Brault',
#  'Augustine Marie Bertholdi',
#  'Carl Helminger',
#  'Carlotta Marliani',
#  'Casimir Stanislas d Arpentigny',
#  'Catherine de Souzzo (księżna)',
#  'Charlotte Marliani',
#  'Charlotte Rothschild (baronowa)',
#  'Christian Rudolf Wessel',
#  'Clotilde Elisabeth Villetard',
#  'Cécile Franchomme',
#  'Emil Jenike',
#  'Ernest Canut',
#  'Eugénie de Bonnechose',
#  'Felicjan Mallefille',
#  'Feliks Wodziński',
#  'Fernand de Préaulx',
#  'Fontana Juanna Camila',
#  'Françoise (pokojowa George Sand)',
#  'Friederich Kalkbrenner',
#  'Fryderyk Bolesław Jędrzejewicz',
#  'Fryderyk Skarbek (hrabia)',
#  'Frédéric Hénique',
#  'Gustaw Planche',
#  'Heinrich Albert Probst',
#  'Henryk Dorn',
#  'Henryk Jędrzejewicz',
#  'Hippolyte Chatiron',
#  'Honorata Dziewanowska',
#  'Härtel from Breitkopf & Härtel company',
#  'Hélène de Mecklembourg-Schwerin (księżna)',
#  'Isabella di Ricci (Księżna)',
#  'Izabella Barcińska',
#  'Izabella Działyńska (hrabina)',
#  'Jadwiga Klementyna Sapieha (księżna)',
#  'Jadwiga Ramm',
#  'Jakub Fromental Halévy',
#  'Jan (służący Fryderyka Chopina)',
#  'Jan Barciński',
#  'Jean-Baptiste Pierret',
#  'Jeanne-Gabrielle Clésinger',
#  'Juliette de Forget',
#  'Józef Kalasanty Jędrzejewicz',
#  'Józef Michał Poniatowski (książę)',
#  'Józefa Dziewanowska',
#  'Józefa Turowska',
#  'Kamila Billing de Courbonne',
#  'Kamilla Zboińska',
#  'Karol Franciszek Szulczewski',
#  'Karol Gavard',
#  'Karol Olizar',
#  'Karol Szulczewski',
#  'Karolina Elsner',
#  'Katarzyna Diller de Pereira',
#  'Ksawera Grocholska',
#  'Ksawery Zboiński (hrabia)',
#  'Laura Czosnowska (hrabina)',
#  'Leon Szmitkowski',
#  'Leopold Louis Sina',
#  'Louise Franchomme',
#  'Louise de Lorraine (królowa)',
#  'Lucie (służąca George Sand)',
#  'Ludwik Piotr Norblin',
#  'Ludwika Dziewanowska',
#  'Ludwika Magdalena Ciechomska',
#  'Ludwika Nakwaska',
#  'Marcelina Czartoryska (księżna)',
#  'Maria de Rozières',
#  'Marie Constance Albertine de Montaran (baronowa)',
#  'Marie Thérèse Ducroc de Brassac',
#  'María Cristina, Queen consort of Ferdinand VII',
#  'Maurycy Dudevant',
#  'Małgorzata Barcińska',
#  'Michał Babiański',
#  'Natalia Obreskow (księżna)',
#  'Ojciec macochy kompozytora, Anny z Tańkowskich Paderewskiej',
#  'Paulina Plater (hrabianka)',
#  'Pelagia Skarbkowa',
#  'Pierre (służący Fryderyka Chopina)',
#  'Poliksena Paderewska',
#  'René Franchomme',
#  'Susanne Gibson-Milner',
#  'Suzanne (kucharka George Sand)',
#  'Teresa Wodzińska',
#  'Thérèse Albrecht',
#  'Thérèse Gavard',
#  'Walenty Barciński',
#  'William Cavendish (4. diuk Devonshire)',
#  'Wincenty Władysław Grzymała',
#  'Zofia Rosengardt-Zaleska',
#  'Zofia Rozengart',
#  'de Perthuis (hrabia)',
#  'dr Fraenkel',
#  'the Commitee of the Concert Society',
#  'von Stockhausen (baronowa)',
#  'Édouard Herbault',
#  'Élise Gavard',
#  'Émilie de Perthuis (hrabina)'}

# %% [markdown]
# # Humans associated with names from original_list ```(N levels of depth...)```

# %%
rdf_info = recursive_get_rdf_info(input_qcodes, level=3)
print(f"{len(rdf_info.keys())=}")
# Out:
# Done:  ['Q123679', 'Q342889', 'Q79822', 'Q99639218', 'Q4505990', 'Q77840132', 'Q5738', 'Q137819', 'Q2082427', 'Q3608671', 'Q435375', 'Q9145532', 'Q20670032', 'Q38337', 'Q169150', 'Q188697', 'Q102194393', 'Q4766898', 'Q11686228', 'Q11285375', 'Q458156', 'Q550766', 'Q2074586', 'Q64862', 'Q106489731', 'Q263091', 'Q9157202', 'Q561112', 'Q9157627', 'Q182011', 'Q607998', 'Q436726', 'Q727056', 'Q517132', 'Q16054478', 'Q766768', 'Q713985', 'Q2375473', 'Q15975', 'Q2896159', 'Q9176254', 'Q21338629', 'Q2534918', 'Q1630994', 'Q159569', 'Q1047458', 'Q131552', 'Q109810560', 'Q62028861', 'Q23060765', 'Q663856', 'Q55846558', 'Q217068', 'Q61319', 'Q7322', 'Q114366', 'Q3021581', 'Q9209760', 'Q458688', 'Q17551656', 'Q5345972', 'Q3051916', 'Q8860780', 'Q2658508', 'Q1333348', 'Q33477', 'Q22248714', 'Q55875031', 'Q105330618', 'Q57286', 'Q269694', 'Q46096', 'Q533022', 'Q213530', 'Q41309', 'Q951933', 'Q15429707', 'Q1441283', 'Q242159', 'Q356522', 'Q11698724', 'Q154353', 'Q157324', 'Q957041', 'Q523581', 'Q313667', 'Q3083678', 'Q15451236', 'Q170270', 'Q1268', 'Q3090265', 'Q334973', 'Q3092326', 'Q202555', 'Q101698', 'Q21292828', 'Q55902818', 'Q3816', 'Q75253339', 'Q105237', 'Q9726', 'Q185312', 'Q766828', 'Q287344', 'Q7317', 'Q76721', 'Q104670236', 'Q5664138', 'Q1184700', 'Q1151', 'Q44403', 'Q102355196', 'Q572547', 'Q312790', 'Q18683978', 'Q75713522', 'Q9292401', 'Q1620044', 'Q161145', 'Q191957', 'Q380545', 'Q4240587', 'Q159551', 'Q183085', 'Q98112689', 'Q454589', 'Q16198315', 'Q1583163', 'Q11718359', 'Q3507431', 'Q191957', 'Q1339', 'Q6152913', 'Q3117939', 'Q6527', 'Q2161733', 'Q49496', 'Q574368', 'Q2871155', 'Q1381729', 'Q3163757', 'Q633796', 'Q559659', 'Q3166351', 'Q231345', 'Q5931650', 'Q76431', 'Q7294', 'Q780817', 'Q322065', 'Q16439150', 'Q956459', 'Q1711991', 'Q440119', 'Q107338652', 'Q243267', 'Q9356382', 'Q266339', 'Q11729930', 'Q1355484', 'Q4086154', 'Q1350174', 'Q572132', 'Q471647', 'Q7349', 'Q112609235', 'Q109996468', 'Q1715110', 'Q390986', 'Q6375196', 'Q75257538', 'Q54837758', 'Q96123950', 'Q129857', 'Q7738', 'Q36234', 'Q433781', 'Q4893675', 'Q96126292', 'Q97695042', 'Q18746840', 'Q112462366', 'Q75383615', 'Q524582', 'Q115589643', 'Q454297', 'Q2959670', 'Q712867', 'Q546919', 'Q55853534', 'Q57226', 'Q584292', 'Q15639295', 'Q114410130', 'Q76252248', 'Q255', 'Q8861068', 'Q7771', 'Q823035', 'Q6699463', 'Q6699463', 'Q20721', 'Q477681', 'Q6711106', 'Q3271923', 'Q105212185', 'Q6756303', 'Q2022977', 'Q458975', 'Q273923', 'Q2636224', 'Q3060246', 'Q253453', 'Q231457', 'Q269130', 'Q75264800', 'Q73284789', 'Q131412', 'Q240397', 'Q1385973', 'Q70457', 'Q4214233', 'Q434171', 'Q104705986', 'Q100591421', 'Q651253', 'Q941622', 'Q1381121', 'Q41554', 'Q4246922', 'Q195301', 'Q322582', 'Q1074290', 'Q122998', 'Q170800', 'Q5599', 'Q747', 'Q704649', 'Q113126918', 'Q24705380', 'Q111021007', 'Q95662884', 'Q15968157', 'Q7351', 'Q446126', 'Q2209749', 'Q18954554', 'Q9332959', 'Q2218070', 'Q110219272', 'Q1254858', 'Q698066', 'Q37886296', 'Q37886296', 'Q3496754', 'Q9341976', 'Q2891763', 'Q1764820', 'Q59748821', 'Q3524927', 'Q326434', 'Q1767931', 'Q9363774', 'Q104154', 'Q64015149', 'Q61449', 'Q29646607', 'Q535', 'Q56187806', 'Q111668708', 'Q1354493', 'Q9374478', 'Q1364373', 'Q14277', 'Q208663', 'Q2831212', 'Q443519', 'Q254', 'Q696036', 'Q696036', 'Q9381857', 'Q1391004', 'Q16026753', 'Q3051071', 'Q267985']
# Done:  ['Q97340227', 'Q349948', 'Q455182', 'Q458975', 'Q695474', 'Q696036', 'Q711045', 'Q4767640', 'Q6101516', 'Q8028432', 'Q8073357', 'Q5679', 'Q61971', 'Q380545', 'Q982015', 'Q1354652', 'Q2625574', 'Q2779162', 'Q5058073', 'Q9145737', 'Q9262738', 'Q11684340', 'Q11768867', 'Q11770887', 'Q18155978', 'Q54602937', 'Q91095161', 'Q3587960', 'Q58311526', 'Q535', 'Q663856', 'Q2825429', 'Q3059936', 'Q3083678', 'Q3271923', 'Q61782', 'Q63086', 'Q107789', 'Q1459695', 'Q2534736', 'Q2673104', 'Q3423507', 'Q7243988', 'Q50062358', 'Q75389657', 'Q75389658', 'Q75389669', 'Q75389670', 'Q517', 'Q7723', 'Q62024', 'Q90227', 'Q155545', 'Q237931', 'Q267985', 'Q286802', 'Q1332164', 'Q1390993', 'Q9145284', 'Q9323749', 'Q18615292', 'Q22673596', 'Q30049901', 'Q9250943', 'Q1373788', 'Q169150', 'Q572684', 'Q1125847', 'Q1525640', 'Q39386930', 'Q83386067', 'Q108652484', 'Q108652515', 'Q108652531', 'Q108652533', 'Q108652538', 'Q38337', 'Q3123741', 'Q3275679', 'Q18405585', 'Q20758189', 'Q28099228', 'Q30147827', 'Q3051071', 'Q24625745', 'Q96074174', 'Q96074175', 'Q88181424', 'Q215333', 'Q9341775', 'Q41309', 'Q350325', 'Q1089209', 'Q3270594', 'Q3275294', 'Q19799512', 'Q21007317', 'Q21007361', 'Q64138344', 'Q7771', 'Q72795', 'Q218879', 'Q231457', 'Q237129', 'Q240277', 'Q240397', 'Q242879', 'Q454297', 'Q454337', 'Q458688', 'Q586877', 'Q712502', 'Q2303777', 'Q2960519', 'Q3847230', 'Q42309300', 'Q75364209', 'Q75364226', 'Q75364250', 'Q75364276', 'Q75364279', 'Q364498', 'Q2857134', 'Q18758747', 'Q819749', 'Q618892', 'Q61197878', 'Q95204912', 'Q95335465', 'Q62274', 'Q72544', 'Q77693', 'Q133752', 'Q1662531', 'Q2721092', 'Q4285388', 'Q22981310', 'Q60843648', 'Q75330867', 'Q7090429', 'Q78587492', 'Q1974859', 'Q163543', 'Q184212', 'Q223274', 'Q321579', 'Q362704', 'Q1065263', 'Q1098330', 'Q1514066', 'Q2871088', 'Q3163756', 'Q5171180', 'Q5788598', 'Q6215626', 'Q19284313', 'Q21286499', 'Q21290695', 'Q26936772', 'Q93261544', 'Q105946170', 'Q348431', 'Q23926082', 'Q42529327', 'Q2477161', 'Q3166112', 'Q6688769', 'Q19642629', 'Q59821947', 'Q2845703', 'Q105670208', 'Q2959690', 'Q5928631', 'Q22259984', 'Q153472', 'Q314019', 'Q437228', 'Q7351', 'Q46096', 'Q273661', 'Q290788', 'Q1356732', 'Q3840209', 'Q4394342', 'Q4990297', 'Q28563768', 'Q3816', 'Q1385973', 'Q20204155', 'Q37886296', 'Q53448', 'Q132545', 'Q132548', 'Q134309', 'Q176041', 'Q220845', 'Q242336', 'Q272509', 'Q312612', 'Q318380', 'Q378232', 'Q577162', 'Q1122656', 'Q1134100', 'Q4542229', 'Q318448', 'Q2082427', 'Q15339037', 'Q18762412', 'Q104525387', 'Q1589056', 'Q4526913', 'Q6101', 'Q24766', 'Q34943', 'Q75079', 'Q186138', 'Q318580', 'Q321563', 'Q325909', 'Q452379', 'Q463646', 'Q1056171', 'Q1406718', 'Q2410239', 'Q2838760', 'Q3436617', 'Q5868869', 'Q92054', 'Q95209', 'Q55852981', 'Q55912644', 'Q56256675', 'Q94742221', 'Q94749612', 'Q94751555', 'Q94844743', 'Q11779943', 'Q60748', 'Q354477', 'Q502885', 'Q550766', 'Q16875195', 'Q29571085', 'Q38011010', 'Q102810718', 'Q103053949', 'Q1268', 'Q651253', 'Q6699463', 'Q9356382', 'Q98112689', 'Q154353', 'Q3385585', 'Q21578760', 'Q1355203', 'Q1488840', 'Q1948324', 'Q2085926', 'Q2422896', 'Q2958113', 'Q2958798', 'Q3130385', 'Q3385333', 'Q15275633', 'Q16725879', 'Q19569779', 'Q2941038', 'Q4796342', 'Q110409234', 'Q255', 'Q1339', 'Q58857', 'Q70138', 'Q95404', 'Q452414', 'Q460587', 'Q560757', 'Q1810407', 'Q2061251', 'Q4255225', 'Q28653656', 'Q117800836', 'Q644420', 'Q2280304', 'Q57286', 'Q76997', 'Q114366', 'Q159551', 'Q1029284', 'Q5077278', 'Q55010', 'Q106434', 'Q151953', 'Q325295', 'Q527514', 'Q543336', 'Q15450999', 'Q93980225', 'Q51088', 'Q57178', 'Q66075', 'Q75789', 'Q155540', 'Q213772', 'Q214019', 'Q214805', 'Q252416', 'Q253453', 'Q311387', 'Q316920', 'Q366536', 'Q447133', 'Q457863', 'Q533022', 'Q557478', 'Q577658', 'Q636941', 'Q671682', 'Q721465', 'Q817556', 'Q1289013', 'Q1339344', 'Q1452729', 'Q2940035', 'Q4982446', 'Q5783822', 'Q5829952', 'Q11285375', 'Q13409402', 'Q13409406', 'Q16169825', 'Q19119765', 'Q20437514', 'Q53032647', 'Q523581', 'Q1450915', 'Q4025366', 'Q939', 'Q84239',  ...
# len(rdf_info.keys())=13171

# %%
# ^ czas działania recursive_get_rdf_info:
# rdf_info = recursive_get_rdf_info(input_qcodes, level=2)      # działało 3m 36s dla input-codes=['Q131861', 'Q255'] i zwróciło rdf_info dla 228 osób (104772 linijek słownika)
# rdf_info = recursive_get_rdf_info(input_qcodes, level=2)      # działało 41s dla input-codes=['Q131861'] i zwróciło rdf_info dla 36 osób (17376 linijek słownika)

# rdf_info = recursive_get_rdf_info(input_qcodes, level=3)      # działało 423m 35s dla input_codes z pliku .txt (399 osób (>1 słowo) z listów Chopina i Paderewskiego); len(rdf_info.keys())=13171; rdf_info 5 mln linijek;
                                                                # 180 MB json z indent=4; 117MB json w jednej linijce;

# %%
# import json
# with open("rdf_info.json", "w") as f:
#     json.dump(rdf_info, f)  # no idntent arg if you want smaller filesize

# rdf_info

# %%
qcodes_to_check = set()
for Q in rdf_info.keys():
    qcodes_to_check.add(Q)
    for rdf_tuple in rdf_info[Q]:
        if rdf_tuple[4] == "FactGrid item ID":
            continue
        object_url = rdf_tuple[2]
        qcode = object_url[object_url.rfind('Q'):]
        if len(qcode) > 1:
            if qcode[1:].isdigit():
                qcodes_to_check.add(qcode)
                if (qcode=='Q383232'):
                    print(Q, rdf_info[Q])
print(f"{len(qcodes_to_check) = }")

qcodes_to_check_split = []
n_size = 500  # splitting qcodes_to_check into lists of n_size (500) elements, because URI cannot be too large in function get_all_human_objects()
length = len(qcodes_to_check)
temp = []
for i, qcode in enumerate(qcodes_to_check):
    temp.append(qcode)
    if i%n_size == n_size-1:
        qcodes_to_check_split.append(temp)
        temp = []
    if i == length-1:
        if len(temp) > 0:
            qcodes_to_check_split.append(temp)
print(f"{len(qcodes_to_check_split) = }")

all_humans = []
n_lists = len(qcodes_to_check_split)
for i, lista in enumerate(qcodes_to_check_split):
    temp_list = get_all_human_objects(lista)
    all_humans += temp_list
# ^ 1m 30s dla len(qcodes_to_check) = 60829
# Out:
# len(qcodes_to_check) = 60829
# len(qcodes_to_check_split) = 122
# len(all_humans) = 29966

# %%
print(f"{len(all_humans) = }")
all_humans
# Out:
# len(all_humans) = 29966
# [('Q57112', 'http://www.wikidata.org/entity/Q57112', 'Oswald Spengler'),
#  ('Q61221',
#   'http://www.wikidata.org/entity/Q61221',
#   'Amalie Auguste of Bavaria'),
#  ('Q63653',
#   'http://www.wikidata.org/entity/Q63653',
#   'Prince Alfons of Bavaria'),
#  ('Q64235',
#   'http://www.wikidata.org/entity/Q64235',
#   'Princess Elisabeth of Saxe-Altenburg'),
#  ('Q64704',
#   'http://www.wikidata.org/entity/Q64704',
#   'Prince Sigismund of Prussia'),
#  ('Q65038',
#   'http://www.wikidata.org/entity/Q65038',
#   'Frederick III, Duke of Saxe-Gotha-Altenburg'),
#  ('Q65648', 'http://www.wikidata.org/entity/Q65648', 'Charles Hallé'),
#  ('Q66746', 'http://www.wikidata.org/entity/Q66746', 'Christiane Vulpius'),
#  ('Q87575',
#   'http://www.wikidata.org/entity/Q87575',
#   'Philip Maurice, Count of Hanau-Münzenberg'),
#  ('Q91211',
#   'http://www.wikidata.org/entity/Q91211',
#   'Gottfried Christoph Beireis'),
#  ('Q110158', 'http://www.wikidata.org/entity/Q110158', 'Paul Homeyer'),
#  ('Q116972',
#   'http://www.wikidata.org/entity/Q116972',
#   'Nuno José Severo de Mendoça Rolim de Moura Barreto, 1st Duke of Loulé'),
#  ('Q123238',
#   'http://www.wikidata.org/entity/Q123238',
#   'Guillaume Henri Dufour'),
#  ('Q145654',
#   'http://www.wikidata.org/entity/Q145654',
#   'Prince Frederick of Great Britain'),
#  ('Q161336', 'http://www.wikidata.org/entity/Q161336', 'Peter Lely'),
#  ('Q205779',
#   'http://www.wikidata.org/entity/Q205779',
#   'Camillo Borghese, 6th Prince of Sulmona'),
#  ('Q206512', 'http://www.wikidata.org/entity/Q206512', 'Thomas Wolsey'),
#  ('Q213049', 'http://www.wikidata.org/entity/Q213049', 'Abraham van Dijck'),
#  ('Q213625',
#   'http://www.wikidata.org/entity/Q213625',
#   'Prince Paul of Württemberg'),
#  ('Q215989',
#   'http://www.wikidata.org/entity/Q215989',
#   'Johann August von Starck'),
#  ('Q231856',
#   'http://www.wikidata.org/entity/Q231856',
#   'Archduchess Adelaide of Austria'),
#  ('Q232159',
#   'http://www.wikidata.org/entity/Q232159',
#   'Grand Duchess Anastasia Mikhailovna of Russia'),
#  ('Q234251',
#   'http://www.wikidata.org/entity/Q234251',
#   'Louisa Ulrika of Prussia'),
#  ('Q234542',
#   'http://www.wikidata.org/entity/Q234542',
#   'Princess Victoria of the United Kingdom'),
#  ('Q248459', 'http://www.wikidata.org/entity/Q248459', 'Alessandro Farnese'),
#  ('Q256663',
#   'http://www.wikidata.org/entity/Q256663',
#   'Anne-Geneviève de Bourbon'),
#  ('Q268702', 'http://www.wikidata.org/entity/Q268702', 'Mary Somerville'),
#  ('Q273200', 'http://www.wikidata.org/entity/Q273200', 'Sophie Gay'),
#  ('Q281698', 'http://www.wikidata.org/entity/Q281698', 'Hippolyte Lefèbvre'),
#  ('Q318077', 'http://www.wikidata.org/entity/Q318077', 'Joaquín Turina'),
#  ('Q318622', 'http://www.wikidata.org/entity/Q318622', 'Martin Bucer'),
#  ('Q333183', 'http://www.wikidata.org/entity/Q333183', 'Manuel García'),
#  ('Q338195', 'http://www.wikidata.org/entity/Q338195', 'Pierre Villette'),
#  ('Q374039', 'http://www.wikidata.org/entity/Q374039', 'Ferdinand Bol'),
#  ('Q446962',
#   'http://www.wikidata.org/entity/Q446962',
#   "Maria Teresa Felicitas d'Este"),
#  ('Q454053',
#   'http://www.wikidata.org/entity/Q454053',
#   'Arthur III, Duke of Brittany'),
#  ('Q464898', 'http://www.wikidata.org/entity/Q464898', 'Pierre Subleyras'),
#  ('Q520252',
#   'http://www.wikidata.org/entity/Q520252',
#   'Princess Geneviève, Marchioness of Chaponay-Morance'),
#  ('Q537169', 'http://www.wikidata.org/entity/Q537169', 'Balthasar Gérard'),
#  ('Q565942', 'http://www.wikidata.org/entity/Q565942', 'Anne du Bourg'),
#  ('Q570491',
#   'http://www.wikidata.org/entity/Q570491',
#   'Archduke Karl Pius of Austria, Prince of Tuscany'),
#  ('Q610309', 'http://www.wikidata.org/entity/Q610309', 'Lambert of Auxerre'),
#  ('Q633817', 'http://www.wikidata.org/entity/Q633817', 'François Bazin'),
#  ('Q663856', 'http://www.wikidata.org/entity/Q663856', 'Charles Hugo'),
#  ('Q665262', 'http://www.wikidata.org/entity/Q665262', 'Gennaro Manna'),
#  ('Q710199', 'http://www.wikidata.org/entity/Q710199', 'Stephen Heller'),
#  ('Q712502',
#   'http://www.wikidata.org/entity/Q712502',
#   'Prince Henri, Duke of Aumale'),
#  ('Q730008', 'http://www.wikidata.org/entity/Q730008', 'Bruno Liljefors'),
#  ('Q736277',
#   'http://www.wikidata.org/entity/Q736277',
#   'Louis Claude Cadet de Gassicourt'),
#  ('Q772541',
#   'http://www.wikidata.org/entity/Q772541',
#   'Countess Ina Marie von Bassewitz'),
#  ('Q776006', 'http://www.wikidata.org/entity/Q776006', 'Fabrizio Serbelloni'),
#  ('Q824322',
#   'http://www.wikidata.org/entity/Q824322',
#   'Charles Philip of Brandenburg-Schwedt'),
#  ('Q938972', 'http://www.wikidata.org/entity/Q938972', 'Epiktetos'),
#  ('Q968435',
#   'http://www.wikidata.org/entity/Q968435',
#   'Samuel Anton Jacob Bach'),
#  ('Q1168587',
#   'http://www.wikidata.org/entity/Q1168587',
#   'Paolo Dagomari di Prato'),
#  ('Q1249964', 'http://www.wikidata.org/entity/Q1249964', 'Sarah Fairbrother'),
#  ('Q1358546', 'http://www.wikidata.org/entity/Q1358546', 'Ernst Hefel'),
#  ('Q1398812', 'http://www.wikidata.org/entity/Q1398812', 'Walter Runeberg'),
#  ('Q1597701', 'http://www.wikidata.org/entity/Q1597701', 'Heinrich I'),
#  ('Q1647010',
#   'http://www.wikidata.org/entity/Q1647010',
#   'Jeanne de Rothschild'),
#  ('Q1965530',
#   'http://www.wikidata.org/entity/Q1965530',
#   'Charles of Lorraine, duke of Guise'),
#  ('Q2060258',
#   'http://www.wikidata.org/entity/Q2060258',
#   'Louise Rosalie Allan-Despreaux'),
#  ('Q2297336',
#   'http://www.wikidata.org/entity/Q2297336',
#   'Louis Joseph of Lorraine, Duke of Guise'),
#  ('Q2356668',
#   'http://www.wikidata.org/entity/Q2356668',
#   'Giovanni Niccolò Servandoni'),
#  ('Q2393004',
#   'http://www.wikidata.org/entity/Q2393004',
#   'Marie Anne de Bourbon'),
#  ('Q2604669',
#   'http://www.wikidata.org/entity/Q2604669',
#   'Henri de Braekeleer'),
#  ('Q2635585',
#   'http://www.wikidata.org/entity/Q2635585',
#   'Maria of Aragon, Lady of Cameros'),
#  ('Q2839877', 'http://www.wikidata.org/entity/Q2839877', 'Alphonse Leroy'),
#  ('Q2839895', 'http://www.wikidata.org/entity/Q2839895', 'Alphonse Mancini'),
#  ('Q2840006',
#   'http://www.wikidata.org/entity/Q2840006',
#   'Alphonse de Bauffremont'),
#  ('Q2853550',
#   'http://www.wikidata.org/entity/Q2853550',
#   'Antoine-Rémy Mauduit'),
#  ('Q2900103',
#   'http://www.wikidata.org/entity/Q2900103',
#   'Bethsabée de Rothschild'),
#  ('Q3034322',
#   'http://www.wikidata.org/entity/Q3034322',
#   'Dom Antoine de Savoie'),
#  ('Q3056949', 'http://www.wikidata.org/entity/Q3056949', 'Ernest Feray'),
#  ('Q3122216', 'http://www.wikidata.org/entity/Q3122216', 'Guy XVI de Laval'),
#  ('Q3160236',
#   'http://www.wikidata.org/entity/Q3160236',
#   'Jacques de Bauffremont'),
#  ('Q3260584',
#   'http://www.wikidata.org/entity/Q3260584',
#   'Louis-Henri de Pardaillan de Gondrin'),
#  ('Q3261116', 'http://www.wikidata.org/entity/Q3261116', 'Louis Aston Knight'),
#  ('Q3288887', 'http://www.wikidata.org/entity/Q3288887', 'Marcel Desmet'),
#  ('Q3290803',
#   'http://www.wikidata.org/entity/Q3290803',
#   'Marguerite, Duchess of Rohan'),
#  ('Q3300885', 'http://www.wikidata.org/entity/Q3300885', 'Maurice Gérard'),
#  ('Q3371884', 'http://www.wikidata.org/entity/Q3371884', 'Paul Mounet'),
#  ('Q3372466', 'http://www.wikidata.org/entity/Q3372466', 'Paul de Chaulnes'),
#  ('Q3388039',
#   'http://www.wikidata.org/entity/Q3388039',
#   'Pieter van Schuppen'),
#  ('Q3473264',
#   'http://www.wikidata.org/entity/Q3473264',
#   'Sara Elisabeth Moræa'),
#  ('Q3557576', 'http://www.wikidata.org/entity/Q3557576', 'Victor Segoffin'),
#  ('Q3568633', 'http://www.wikidata.org/entity/Q3568633', 'William De Morgan'),
#  ('Q3629555',
#   'http://www.wikidata.org/entity/Q3629555',
#   'Princess Augusta of Urach'),
#  ('Q3646546',
#   'http://www.wikidata.org/entity/Q3646546',
#   'Konstanty Tyzenhauz'),
#  ('Q3824574', 'http://www.wikidata.org/entity/Q3824574', 'Sor Patrocinio'),
#  ('Q3847234',
#   'http://www.wikidata.org/entity/Q3847234',
#   "Maria Cristina de' Medici"),
#  ('Q3852178', 'http://www.wikidata.org/entity/Q3852178', 'Matteo Polo'),
#  ('Q4125793',
#   'http://www.wikidata.org/entity/Q4125793',
#   'Elizaveta Vorontsova'),
#  ('Q4281713',
#   'http://www.wikidata.org/entity/Q4281713',
#   'Infanta Maria Theresa of Portugal'),
#  ('Q4533461', 'http://www.wikidata.org/entity/Q4533461', 'You Ruo'),
#  ('Q4720562',
#   'http://www.wikidata.org/entity/Q4720562',
#   'Alexandra, Princess of Leiningen'),
#  ('Q4893653', 'http://www.wikidata.org/entity/Q4893653', 'Dio of Alexandria'),
#  ('Q4954713', 'http://www.wikidata.org/entity/Q4954713', 'Bradford Leslie'),
#  ('Q4980866',
#   'http://www.wikidata.org/entity/Q4980866',
#   'Ulrika von Strussenfelt'),
#  ('Q5262858',
#   'http://www.wikidata.org/entity/Q5262858',
#   'George Douglas, Master of Angus'),
#  ('Q5338688',
#   'http://www.wikidata.org/entity/Q5338688',
#   'Edith Vane-Tempest-Stewart, Marchioness of Londonderry'),
#  ('Q5434026', 'http://www.wikidata.org/entity/Q5434026', 'Fanny Davies'),
#  ('Q5538112', 'http://www.wikidata.org/entity/Q5538112', 'George Cooper'),
#  ('Q5541503', 'http://www.wikidata.org/entity/Q5541503', 'George Lamb'),
#  ('Q5541909', 'http://www.wikidata.org/entity/Q5541909', 'Georg Achen'),
#  ('Q5726713', 'http://www.wikidata.org/entity/Q5726713', 'Henry Parker'),
#  ('Q6001076', 'http://www.wikidata.org/entity/Q6001076', 'Ilona Vincze-Kraus'),
#  ('Q6696710', 'http://www.wikidata.org/entity/Q6696710', 'Lucian Grigorescu'),
#  ('Q6781037', 'http://www.wikidata.org/entity/Q6781037', 'Mary of Bourbon'),
#  ('Q7029353', 'http://www.wikidata.org/entity/Q7029353', 'Nicolaes Lastman'),
#  ('Q8054878', 'http://www.wikidata.org/entity/Q8054878', 'Yona Ettlinger'),
#  ('Q8073362', 'http://www.wikidata.org/entity/Q8073362', 'Zofia Branicka'),
#  ('Q8860407', 'http://www.wikidata.org/entity/Q8860407', 'Wanda Bacewicz'),
#  ('Q9155454',
#   'http://www.wikidata.org/entity/Q9155454',
#   'Countess Palatine Maria Anna of Zweibrücken-Birkenfeld'),
#  ('Q9250943', 'http://www.wikidata.org/entity/Q9250943', 'Edward Jełowicki'),
#  ('Q10018149',
#   'http://www.wikidata.org/entity/Q10018149',
#   'Józef Felicjan Potocki'),
#  ('Q11550450', 'http://www.wikidata.org/entity/Q11550450', 'Hideki Nagano'),
#  ('Q11686983', 'http://www.wikidata.org/entity/Q11686983', 'Augustyn Wessel'),
#  ('Q11717590', 'http://www.wikidata.org/entity/Q11717590', 'Jan Grek'),
#  ('Q11919405',
#   'http://www.wikidata.org/entity/Q11919405',
#   'Sophie Henriette Reuss of Ebersdorf'),
#  ('Q11938748', 'http://www.wikidata.org/entity/Q11938748', 'Nicolás Ledesma'),
#  ('Q12379240',
#   'http://www.wikidata.org/entity/Q12379240',
#   'William Charles Chamberlain'),
#  ('Q15060896',
#   'http://www.wikidata.org/entity/Q15060896',
#   'Mariya Shcherbatova'),
#  ('Q15314881',
#   'http://www.wikidata.org/entity/Q15314881',
#   'Charles Georges-Picot'),
#  ('Q15448761', 'http://www.wikidata.org/entity/Q15448761', 'Anton Averkamp'),
#  ('Q15997320', 'http://www.wikidata.org/entity/Q15997320', 'Ida Darwin'),
#  ('Q16859575',
#   'http://www.wikidata.org/entity/Q16859575',
#   'Alexander Stuart, 5th Lord Blantyre'),
#  ('Q17276661', 'http://www.wikidata.org/entity/Q17276661', 'Johannes Holbek'),
#  ('Q17282332', 'http://www.wikidata.org/entity/Q17282332', 'Jan Dobřenský'),
#  ('Q17423529',
#   'http://www.wikidata.org/entity/Q17423529',
#   'Harriet Leveson-Gower, Countess Granville'),
#  ('Q17929365',
#   'http://www.wikidata.org/entity/Q17929365',
#   'Paul-Alfred Colin'),
#  ('Q18517293',
#   'http://www.wikidata.org/entity/Q18517293',
#   'Charlotte Nathan Rothschild'),
#  ('Q18707150', 'http://www.wikidata.org/entity/Q18707150', 'Demetrius'),
#  ('Q19717360',
#   'http://www.wikidata.org/entity/Q19717360',
#   'Philip von Saltza'),
#  ('Q19951807',
#   'http://www.wikidata.org/entity/Q19951807',
#   'Denis de La Barde'),
#  ('Q20261216', 'http://www.wikidata.org/entity/Q20261216', 'Axel Hou'),
#  ('Q20752333',
#   'http://www.wikidata.org/entity/Q20752333',
#   'Christian August of Solms-Laubach'),
#  ('Q21634448', 'http://www.wikidata.org/entity/Q21634448', 'Ernest Buttura'),
#  ('Q22209991',
#   'http://www.wikidata.org/entity/Q22209991',
#   'Jean-Baptiste-Denis Bucquet'),
#  ('Q24816230', 'http://www.wikidata.org/entity/Q24816230', 'Karl Lokotsch'),
#  ('Q25693022', 'http://www.wikidata.org/entity/Q25693022', 'Ary Belinfante'),
#  ('Q26277142',
#   'http://www.wikidata.org/entity/Q26277142',
#   'Lord Robert Spencer'),
#  ('Q26933708',
#   'http://www.wikidata.org/entity/Q26933708',
#   'Augustin Alexandre Thierriat'),
#  ('Q28111197',
#   'http://www.wikidata.org/entity/Q28111197',
#   'Jost Prinz zu Stolberg-Rossla'),
#  ('Q28949137',
#   'http://www.wikidata.org/entity/Q28949137',
#   'Antonio Luigi Piatti'),
#  ('Q30005991',
#   'http://www.wikidata.org/entity/Q30005991',
#   'Marguerite Alibert'),
#  ('Q41269072',
#   'http://www.wikidata.org/entity/Q41269072',
#   'Charles Meissonier'),
#  ('Q42532067', 'http://www.wikidata.org/entity/Q42532067', 'John Haussermann'),
#  ('Q44739932',
#   'http://www.wikidata.org/entity/Q44739932',
#   'Filippo Massimiliano Del Drago Biscia Gentili, II principe di Mazzano ed Antuni'),
#  ('Q47488256', 'http://www.wikidata.org/entity/Q47488256', 'Carl Fiebig'),
#  ('Q55858586',
#   'http://www.wikidata.org/entity/Q55858586',
#   'Heinrich Freiherr von Pereira-Arnstein'),
#  ('Q56054645',
#   'http://www.wikidata.org/entity/Q56054645',
#   'Johann von und zu Trauttmansdorff-Weinsberg'),
#  ('Q61870683',
#   'http://www.wikidata.org/entity/Q61870683',
#   'Aleksandra Volkonskaya'),
#  ('Q64485152', 'http://www.wikidata.org/entity/Q64485152', 'E. C.  Grassi'),
#  ('Q65563144', 'http://www.wikidata.org/entity/Q65563144', 'Victor Aitay'),
#  ('Q66372485', 'http://www.wikidata.org/entity/Q66372485', 'Jamie Bernstein'),
#  ('Q75247400',
#   'http://www.wikidata.org/entity/Q75247400',
#   'Juana Alfonsa Milan y Quinones de Leon'),
#  ('Q75257177', 'http://www.wikidata.org/entity/Q75257177', 'Margaret Neville'),
#  ('Q75257515', 'http://www.wikidata.org/entity/Q75257515', 'Dorothy Grey'),
#  ('Q75264723',
#   'http://www.wikidata.org/entity/Q75264723',
#   'Lady Sarah Hay-Drummond'),
#  ('Q75265109',
#   'http://www.wikidata.org/entity/Q75265109',
#   'Margaret Tennison'),
#  ('Q75265713', 'http://www.wikidata.org/entity/Q75265713', 'Mabel Graham'),
#  ('Q75272764',
#   'http://www.wikidata.org/entity/Q75272764',
#   'Sir Humphrey Bourchier'),
#  ('Q75272894', 'http://www.wikidata.org/entity/Q75272894', 'Ursula Stourton'),
#  ('Q75289557',
#   'http://www.wikidata.org/entity/Q75289557',
#   'Magdalene Sofie von Anhalt-Zerbst'),
#  ('Q75291521', 'http://www.wikidata.org/entity/Q75291521', 'Anne de Lorraine'),
#  ('Q75292208', 'http://www.wikidata.org/entity/Q75292208', 'Amelia Murray'),
#  ('Q75293389',
#   'http://www.wikidata.org/entity/Q75293389',
#   'Prince Wolrad of Waldeck and Pyrmont'),
#  ('Q75295115',
#   'http://www.wikidata.org/entity/Q75295115',
#   'Maximilian Prinz von Auersperg-Breunner'),
#  ('Q75295768',
#   'http://www.wikidata.org/entity/Q75295768',
#   'Principessa Maria Cristina di Savoia-Carignano (?)'),
#  ('Q75304815',
#   'http://www.wikidata.org/entity/Q75304815',
#   'Friedrich Gustav von Stein-Liebenstein'),
#  ('Q75310201', 'http://www.wikidata.org/entity/Q75310201', 'Janet Bruce'),
#  ('Q75310254',
#   'http://www.wikidata.org/entity/Q75310254',
#   'Lilah Georgiana Augusta Constance Agar-Ellis'),
#  ('Q75312880', 'http://www.wikidata.org/entity/Q75312880', 'Margaret Gordon'),
#  ('Q75318740',
#   'http://www.wikidata.org/entity/Q75318740',
#   'Jacintha Catherine Hesketh'),
#  ('Q75330048',
#   'http://www.wikidata.org/entity/Q75330048',
#   'unnamed daughter von Hohenzollern'),
#  ('Q75331012', 'http://www.wikidata.org/entity/Q75331012', 'Charlotte Maude'),
#  ('Q75337826',
#   'http://www.wikidata.org/entity/Q75337826',
#   'Lady Mabel FitzGerald'),
#  ('Q75351774',
#   'http://www.wikidata.org/entity/Q75351774',
#   'Prince Philipp Ernst of Thurn and Taxis'),
#  ('Q75369947',
#   'http://www.wikidata.org/entity/Q75369947',
#   'Doña Maria Teresa González-Conde y de Borbón'),
#  ('Q75369949',
#   'http://www.wikidata.org/entity/Q75369949',
#   'Maria de los Dolores de Borbón y de la Torre'),
#  ('Q75370000',
#   'http://www.wikidata.org/entity/Q75370000',
#   'Clotilda Gallo y Díaz de Bustamente'),
#  ('Q75370201',
#   'http://www.wikidata.org/entity/Q75370201',
#   'Maria de la Concepcion de Pablo y Garcia-Barzanallana'),
#  ('Q75370471',
#   'http://www.wikidata.org/entity/Q75370471',
#   'Victoria Güell y Alberti'),
#  ('Q75371110',
#   'http://www.wikidata.org/entity/Q75371110',
#   'Rodolfo dei Principi del Drago'),
#  ('Q75371435',
#   'http://www.wikidata.org/entity/Q75371435',
#   'Inesa Travesedo y Bernaldo de Quirós'),
#  ('Q75374080',
#   'http://www.wikidata.org/entity/Q75374080',
#   'Friedrich Botho Graf zu Solms-Laubach'),
#  ('Q75381525', 'http://www.wikidata.org/entity/Q75381525', 'Louisa Bulteel'),
#  ('Q75384910',
#   'http://www.wikidata.org/entity/Q75384910',
#   'Lady Augusta Hervey'),
#  ('Q75385627',
#   'http://www.wikidata.org/entity/Q75385627',
#   'Alexandrine Erzherzogin von Österreich'),
#  ('Q75389578',
#   'http://www.wikidata.org/entity/Q75389578',
#   'Richard Stewart, 3rd Lord Innermeath'),
#  ('Q75413386', 'http://www.wikidata.org/entity/Q75413386', 'Anne Ashley'),
#  ('Q75417939',
#   'http://www.wikidata.org/entity/Q75417939',
#   'Jean Marjorie Baird'),
#  ('Q75497486', 'http://www.wikidata.org/entity/Q75497486', 'Sir James Graham'),
#  ('Q75519293',
#   'http://www.wikidata.org/entity/Q75519293',
#   'François-Xavier Sapieha, Prince Sapieha'),
#  ('Q75519364',
#   'http://www.wikidata.org/entity/Q75519364',
#   'León Kazimierz Sapieha, Prince Sapieha'),
#  ('Q75784032',
#   'http://www.wikidata.org/entity/Q75784032',
#   'Charles Killigrew'),
#  ('Q75804477',
#   'http://www.wikidata.org/entity/Q75804477',
#   'Lady Ann Hastings'),
#  ('Q75917715',
#   'http://www.wikidata.org/entity/Q75917715',
#   'Anna Gertrude Fuller Maitland'),
#  ('Q75925037',
#   'http://www.wikidata.org/entity/Q75925037',
#   'Elizabeth Elphinstone'),
#  ('Q75926906', 'http://www.wikidata.org/entity/Q75926906', 'Phillip Boteler'),
#  ('Q75963754',
#   'http://www.wikidata.org/entity/Q75963754',
#   'Blanche Emily Isabella Maude'),
#  ('Q75983901',
#   'http://www.wikidata.org/entity/Q75983901',
#   'Henry Bickersteth Mayor'),
#  ('Q76012007',
#   'http://www.wikidata.org/entity/Q76012007',
#   'Granville Beckford Pitt-Rivers'),
#  ('Q76036621',
#   'http://www.wikidata.org/entity/Q76036621',
#   'Katherine Abercromby'),
#  ('Q76112866', 'http://www.wikidata.org/entity/Q76112866', 'Virginia Baker'),
#  ('Q76159873',
#   'http://www.wikidata.org/entity/Q76159873',
#   'George Cameron Day'),
#  ('Q76237501',
#   'http://www.wikidata.org/entity/Q76237501',
#   'Margaret Stirling'),
#  ('Q76269857',
#   'http://www.wikidata.org/entity/Q76269857',
#   'Sir Patrick Houstoun, 5th Bt.'),
#  ('Q76277814',
#   'http://www.wikidata.org/entity/Q76277814',
#   'Charlotte Williams'),
#  ('Q76282842', 'http://www.wikidata.org/entity/Q76282842', 'Henry Howard'),
#  ('Q76312183',
#   'http://www.wikidata.org/entity/Q76312183',
#   'William Ochterlony of Kellie'),
#  ('Q76321086',
#   'http://www.wikidata.org/entity/Q76321086',
#   'Charles Edward Walsh'),
#  ('Q76321586',
#   'http://www.wikidata.org/entity/Q76321586',
#   'Richard Brooke Michell'),
#  ('Q76321592',
#   'http://www.wikidata.org/entity/Q76321592',
#   'Walter Gordon Michell'),
#  ('Q76323473', 'http://www.wikidata.org/entity/Q76323473', 'Amelia Murray'),
#  ('Q87443085',
#   'http://www.wikidata.org/entity/Q87443085',
#   'Bertil Andreas Matton'),
#  ('Q94803854', 'http://www.wikidata.org/entity/Q94803854', 'Karl Ritter'),
#  ('Q94899104',
#   'http://www.wikidata.org/entity/Q94899104',
#   'Ferdinand Schumann'),
#  ('Q94989587',
#   'http://www.wikidata.org/entity/Q94989587',
#   'Friedrich Ernst Euseb Waldburg'),
#  ('Q96074175',
#   'http://www.wikidata.org/entity/Q96074175',
#   'Julia de Lamartine'),
#  ('Q96089292', 'http://www.wikidata.org/entity/Q96089292', 'Joan Shakespeare'),
#  ('Q96245691', 'http://www.wikidata.org/entity/Q96245691', 'Emily Haskell'),
#  ('Q97605410',
#   'http://www.wikidata.org/entity/Q97605410',
#   'Maria von Lobkowitz'),
#  ('Q99858178',
#   'http://www.wikidata.org/entity/Q99858178',
#   'Lotten Axelsson Puke'),
#  ('Q101069561',
#   'http://www.wikidata.org/entity/Q101069561',
#   'Agathe Alexandrine Gavaudan'),
#  ('Q102212193', 'http://www.wikidata.org/entity/Q102212193', 'Anna Stein'),
#  ('Q102511547',
#   'http://www.wikidata.org/entity/Q102511547',
#   'Walter Dunham Gainer'),
#  ('Q102814997',
#   'http://www.wikidata.org/entity/Q102814997',
#   'Louise de Pisseleu'),
#  ('Q102815760',
#   'http://www.wikidata.org/entity/Q102815760',
#   "Jacques Chabot, Seigneur d'Aspremont et de Brion"),
#  ('Q102823027', 'http://www.wikidata.org/entity/Q102823027', 'Isabelle Babou'),
#  ('Q103017066', 'http://www.wikidata.org/entity/Q103017066', 'Daniel Rie'),
#  ('Q104565537',
#   'http://www.wikidata.org/entity/Q104565537',
#   'Amalie Mauthner'),
#  ('Q106520084',
#   'http://www.wikidata.org/entity/Q106520084',
#   'Ethel Mildred Schmitt'),
#  ('Q106634044', 'http://www.wikidata.org/entity/Q106634044', 'François Denis'),
#  ('Q107293797',
#   'http://www.wikidata.org/entity/Q107293797',
#   'Françoise Blosset, Dame de Colombières, le Plessis-Paté'),
#  ('Q109012058',
#   'http://www.wikidata.org/entity/Q109012058',
#   'Anne Marie Télésie de Girardin'),
#  ('Q109573312',
#   'http://www.wikidata.org/entity/Q109573312',
#   'Marie Edmée Tassaert'),
#  ('Q110381417',
#   'http://www.wikidata.org/entity/Q110381417',
#   'Louise de Timbrune de Valence'),
#  ('Q110550413',
#   'http://www.wikidata.org/entity/Q110550413',
#   'Mechtild von Virneburg'),
#  ('Q113319890',
#   'http://www.wikidata.org/entity/Q113319890',
#   'Louis-Marie Robert de La Mennais'),
#  ('Q113584891',
#   'http://www.wikidata.org/entity/Q113584891',
#   'Charlotte Quiding'),
#  ('Q113621609',
#   'http://www.wikidata.org/entity/Q113621609',
#   'Gabriel de Clermont, baron de Thoury'),
#  ('Q113969189',
#   'http://www.wikidata.org/entity/Q113969189',
#   'Françoise de Maignelais'),
#  ('Q116003445',
#   'http://www.wikidata.org/entity/Q116003445',
#   'Philippine de Gournay'),
#  ('Q116128505', 'http://www.wikidata.org/entity/Q116128505', 'NN'),
#  ('Q116946341',
#   'http://www.wikidata.org/entity/Q116946341',
#   'Clara Louisa Peel'),
#  ('Q117275086', 'http://www.wikidata.org/entity/Q117275086', 'Thomas Arden'),
#  ('Q38082', 'http://www.wikidata.org/entity/Q38082', 'Lewis Carroll'),
#  ('Q45337', 'http://www.wikidata.org/entity/Q45337', 'Ernst von Wildenbruch'),
#  ('Q49698',
#   'http://www.wikidata.org/entity/Q49698',
#   'Johann Alexander Döderlein'),
#  ('Q51717', 'http://www.wikidata.org/entity/Q51717', 'Baldwin I of Jerusalem'),
#  ('Q57221',
#   'http://www.wikidata.org/entity/Q57221',
#   'Elizabeth Charlotte, Princess Palatine'),
#  ('Q60951', 'http://www.wikidata.org/entity/Q60951', 'Albert of Mainz'),
#  ('Q61245',
#   'http://www.wikidata.org/entity/Q61245',
#   'Frederick II, Elector Palatine'),
#  ('Q69755', 'http://www.wikidata.org/entity/Q69755', 'August Breithaupt'),
#  ('Q71139',
#   'http://www.wikidata.org/entity/Q71139',
#   'Prince Moritz of Anhalt-Dessau'),
#  ('Q76723', 'http://www.wikidata.org/entity/Q76723', 'Maurice de Saxe'),
#  ('Q79183', 'http://www.wikidata.org/entity/Q79183', 'Ernst Pauer'),
#  ('Q88600',
#   'http://www.wikidata.org/entity/Q88600',
#   'Gustav Heine von Geldern'),
#  ('Q108370',
#   'http://www.wikidata.org/entity/Q108370',
#   'Johann Theodor Jablonski'),
#  ('Q110313', 'http://www.wikidata.org/entity/Q110313', 'Paul Ernst Jablonski'),
#  ('Q112866',
#   'http://www.wikidata.org/entity/Q112866',
#   'Archduke Rudolf of Austria'),
#  ('Q113063', 'http://www.wikidata.org/entity/Q113063', 'Ignaz Lachner'),
#  ('Q118992', 'http://www.wikidata.org/entity/Q118992', 'Menander'),
#  ('Q122732', 'http://www.wikidata.org/entity/Q122732', 'Emmanuel Stupanus'),
#  ('Q152099',
#   'http://www.wikidata.org/entity/Q152099',
#   'Constantine I of Greece'),
#  ('Q155566',
#   'http://www.wikidata.org/entity/Q155566',
#   'Princess Alice of the United Kingdom'),
#  ('Q155971', 'http://www.wikidata.org/entity/Q155971', 'Benedict XIII'),
#  ('Q157776',
#   'http://www.wikidata.org/entity/Q157776',
#   'John, King of Denmark'),
#  ('Q170467', 'http://www.wikidata.org/entity/Q170467', 'Philip V of Spain'),
#  ('Q179680', 'http://www.wikidata.org/entity/Q179680', 'Alfred de Musset'),
#  ('Q190055', 'http://www.wikidata.org/entity/Q190055', 'Roxana'),
#  ('Q192062',
#   'http://www.wikidata.org/entity/Q192062',
#   'Bartolomé Esteban Murillo'),
#  ('Q215691',
#   'http://www.wikidata.org/entity/Q215691',
#   'Karl August Varnhagen von Ense'),
#  ('Q243536', 'http://www.wikidata.org/entity/Q243536', 'Howard Temin'),
#  ('Q261889',
#   'http://www.wikidata.org/entity/Q261889',
#   'Princess Maria Anna of Hesse-Homburg'),
#  ('Q262012',
#   'http://www.wikidata.org/entity/Q262012',
#   'Gustav Graben-Hoffmann'),
#  ('Q267651', 'http://www.wikidata.org/entity/Q267651', 'Faustina Bordoni'),
#  ('Q268705', 'http://www.wikidata.org/entity/Q268705', 'Édouard Cibot'),
#  ('Q271799', 'http://www.wikidata.org/entity/Q271799', 'Christine of Saxony'),
#  ('Q312587',
#   'http://www.wikidata.org/entity/Q312587',
#   'Claude Louis Berthollet'),
#  ('Q313093', 'http://www.wikidata.org/entity/Q313093', 'Herman Boerhaave'),
#  ('Q316820', 'http://www.wikidata.org/entity/Q316820', 'Ferenc Erkel'),
#  ('Q321546', 'http://www.wikidata.org/entity/Q321546', 'Charles of Lorraine'),
#  ('Q362340', 'http://www.wikidata.org/entity/Q362340', 'Theodor Leschetizky'),
#  ('Q376124', 'http://www.wikidata.org/entity/Q376124', 'Petrus Ramus'),
#  ('Q381092', 'http://www.wikidata.org/entity/Q381092', 'Augustin Thierry'),
#  ('Q442242',
#   'http://www.wikidata.org/entity/Q442242',
#   'Sophia Eleonore of Hesse-Darmstadt'),
#  ('Q465131',
#   'http://www.wikidata.org/entity/Q465131',
#   'Sophie Charlotte of Hesse-Kassel'),
#  ('Q545020', 'http://www.wikidata.org/entity/Q545020', 'Ervin Nyiregyházi'),
#  ('Q559903', 'http://www.wikidata.org/entity/Q559903', 'Jagdish Bhagwati'),
#  ('Q597101', 'http://www.wikidata.org/entity/Q597101', 'Ralph Kirkpatrick'),
#  ('Q606748', 'http://www.wikidata.org/entity/Q606748', 'Antonius Thysius'),
#  ('Q693480',
#   'http://www.wikidata.org/entity/Q693480',
#   'Christian, Prince-Elect of Denmark'),
#  ('Q708709', 'http://www.wikidata.org/entity/Q708709', 'Sébastien Érard'),
#  ('Q719792',
#   'http://www.wikidata.org/entity/Q719792',
#   'Walter Devereux, 1st Earl of Essex'),
#  ('Q721680',
#   'http://www.wikidata.org/entity/Q721680',
#   'Peter II, Duke of Bourbon'),
#  ('Q730234', 'http://www.wikidata.org/entity/Q730234', 'Nicola Fago'),
#  ('Q846572', 'http://www.wikidata.org/entity/Q846572', 'Bridget of York'),
#  ('Q934384',
#   'http://www.wikidata.org/entity/Q934384',
#   'Richard Woodville, 1st Earl Rivers'),
#  ('Q941468',
#   'http://www.wikidata.org/entity/Q941468',
#   'Michał Elwiro Andriolli'),
#  ('Q950141', 'http://www.wikidata.org/entity/Q950141', 'John Ogdon'),
#  ('Q972656',
#   'http://www.wikidata.org/entity/Q972656',
#   'Princess Dagmar of Denmark'),
#  ('Q1000924', 'http://www.wikidata.org/entity/Q1000924', 'György Festetics'),
#  ('Q1032756',
#   'http://www.wikidata.org/entity/Q1032756',
#   'Ferdinande Henriette, Countess of Stolberg-Gedern'),
#  ('Q1148049', 'http://www.wikidata.org/entity/Q1148049', 'Sanai'),
#  ('Q1178104', 'http://www.wikidata.org/entity/Q1178104', 'Mnesarchus'),
#  ('Q1311013', 'http://www.wikidata.org/entity/Q1311013', 'Germain Boffrand'),
#  ('Q1336025',
#   'http://www.wikidata.org/entity/Q1336025',
#   'Emil Gottfried von Herder'),
#  ('Q1385973', 'http://www.wikidata.org/entity/Q1385973', 'Maurice Sand'),
#  ('Q1440898', 'http://www.wikidata.org/entity/Q1440898', 'Francesco Alciati'),
#  ('Q1451014', 'http://www.wikidata.org/entity/Q1451014', 'François Dumont'),
#  ('Q1459228',
#   'http://www.wikidata.org/entity/Q1459228',
#   'Friedrich Georg Göthe'),
#  ('Q1464117',
#   'http://www.wikidata.org/entity/Q1464117',
#   'Prince Friedrich of Hohenlohe-Öhringen'),
#  ('Q1613558', 'http://www.wikidata.org/entity/Q1613558', 'Hermesianax'),
#  ('Q1685811', 'http://www.wikidata.org/entity/Q1685811', 'Jean Salmon Macrin'),
#  ('Q1807597', 'http://www.wikidata.org/entity/Q1807597', 'Otto Bache'),
#  ('Q1934374',
#   'http://www.wikidata.org/entity/Q1934374',
#   'Jan Gillisz van Vliet'),
#  ('Q2140000',
#   'http://www.wikidata.org/entity/Q2140000',
#   'Alexandre Falguière'),
#  ('Q2143613', 'http://www.wikidata.org/entity/Q2143613', 'Alessandro Rolla'),
#  ('Q2245450', 'http://www.wikidata.org/entity/Q2245450', 'Satyrus of Milan'),
#  ('Q2318556',
#   'http://www.wikidata.org/entity/Q2318556',
#   'Juliana of Nassau-Dillenburg'),
#  ('Q2398687',
#   'http://www.wikidata.org/entity/Q2398687',
#   'Isaac de Jouderville'),
#  ('Q2562144',
#   'http://www.wikidata.org/entity/Q2562144',
#   'Princess Karoline Mathilde of Schleswig-Holstein-Sonderburg-Augustenburg'),
#  ('Q2625979', 'http://www.wikidata.org/entity/Q2625979', 'Henry Lerolle'),
#  ('Q2749909', 'http://www.wikidata.org/entity/Q2749909', 'Félix de Vigne'),
#  ('Q2839291', 'http://www.wikidata.org/entity/Q2839291', 'Alonso de Molina'),
#  ('Q2848134',
#   'http://www.wikidata.org/entity/Q2848134',
#   'André Lecomte du Noüy'),
#  ('Q2856713', 'http://www.wikidata.org/entity/Q2856713', 'Antoine Sartoris'),
#  ('Q2899671', 'http://www.wikidata.org/entity/Q2899671', 'Bertrand Schwartz'),
#  ('Q2955937', 'http://www.wikidata.org/entity/Q2955937', 'Chamaeleon'),
#  ('Q2959250', 'http://www.wikidata.org/entity/Q2959250', 'Charles Grandon'),
#  ('Q3031626',
#   'http://www.wikidata.org/entity/Q3031626',
#   'Pierre-Nolasque Bergeret'),
#  ('Q3066384',
#   'http://www.wikidata.org/entity/Q3066384',
#   'John Ponsonby, 1st Viscount Ponsonby'),
#  ('Q3077328', 'http://www.wikidata.org/entity/Q3077328', 'George Hermonymus'),
#  ('Q3158719', 'http://www.wikidata.org/entity/Q3158719', 'Jacques Desmarets'),
#  ('Q3165470',
#   'http://www.wikidata.org/entity/Q3165470',
#   'Jean Francois Blondel'),
#  ('Q3171416', 'http://www.wikidata.org/entity/Q3171416', 'Jean Coquelin'),
#  ('Q3175295', 'http://www.wikidata.org/entity/Q3175295', 'Jean de Boullonges'),
#  ('Q3184524', 'http://www.wikidata.org/entity/Q3184524', 'Joseph Arago'),
#  ('Q3185687', 'http://www.wikidata.org/entity/Q3185687', 'Joseph Tournois'),
#  ('Q3271589', 'http://www.wikidata.org/entity/Q3271589', 'Léonce Hainez'),
#  ('Q3272778',
#   'http://www.wikidata.org/entity/Q3272778',
#   'Aleksander Ludwik Radziwiłł'),
#  ('Q3292354',
#   'http://www.wikidata.org/entity/Q3292354',
#   'Marie Anne Louise Fontaine'),
#  ('Q3336066', 'http://www.wikidata.org/entity/Q3336066', 'Narcisse Brunette'),
#  ('Q3350444',
#   'http://www.wikidata.org/entity/Q3350444',
#   'Grand Duchess Olga Pavlovna of Russia'),
#  ('Q3370399',
#   'http://www.wikidata.org/entity/Q3370399',
#   'Paul-Émile Pissarro'),
#  ('Q3385294', 'http://www.wikidata.org/entity/Q3385294', 'Ariadna Scriabina'),
#  ('Q3401368', 'http://www.wikidata.org/entity/Q3401368', 'Edward Tudor'),
#  ('Q3448732',
#   'http://www.wikidata.org/entity/Q3448732',
#   'Prince Luís Gastão, Prince Imperial of Brazil'),
#  ('Q3680247', 'http://www.wikidata.org/entity/Q3680247', 'Claudio Toscanini'),
#  ('Q3807670',
#   'http://www.wikidata.org/entity/Q3807670',
#   'Jean Gordon, Countess of Bothwell'),
#  ('Q3837121', 'http://www.wikidata.org/entity/Q3837121', "Lorenzo de' Medici"),
#  ('Q3840451',
#   'http://www.wikidata.org/entity/Q3840451',
#   'Duchess Louise Frederica of Württemberg'),
#  ('Q4389594', 'http://www.wikidata.org/entity/Q4389594', 'Carl Heinrich Rahl'),
#  ('Q4965960',
#   'http://www.wikidata.org/entity/Q4965960',
#   "Marie Louise d'Aspremont"),
#  ('Q4980310', 'http://www.wikidata.org/entity/Q4980310', 'Elsa Stenhammar'),
#  ('Q4988299', 'http://www.wikidata.org/entity/Q4988299', "Ebba d'Aubert"),
#  ('Q5082844', 'http://www.wikidata.org/entity/Q5082844', 'Charles Talbot'),
#  ('Q5412309', 'http://www.wikidata.org/entity/Q5412309', 'Juliet Glass'),
#  ('Q5542870', 'http://www.wikidata.org/entity/Q5542870', 'Axel Adlersparre'),
#  ('Q5894411', 'http://www.wikidata.org/entity/Q5894411', 'Henri Dieupart'),
#  ('Q5928631',
#   'http://www.wikidata.org/entity/Q5928631',
#   'Jean-Baptiste de Secondat'),
#  ('Q5992403',
#   'http://www.wikidata.org/entity/Q5992403',
#   'John Graham, 3rd Earl of Montrose'),
#  ('Q6025915', 'http://www.wikidata.org/entity/Q6025915', 'Jørgen Olrik'),
#  ('Q6151202',
#   'http://www.wikidata.org/entity/Q6151202',
#   'Jane Browne, Viscountess Montague'),
#  ('Q6184886',
#   'http://www.wikidata.org/entity/Q6184886',
#   'Carl Axel Ambjörn Sparre'),
#  ('Q6265913', 'http://www.wikidata.org/entity/Q6265913', 'John van Campen'),
#  ('Q6376230',
#   'http://www.wikidata.org/entity/Q6376230',
#   'Katharine Russell, Viscountess Amberley'),
#  ('Q6376371',
#   'http://www.wikidata.org/entity/Q6376371',
#   'Katherine FitzGerald, Viscountess Grandison'),
#  ('Q6820940',
#   'http://www.wikidata.org/entity/Q6820940',
#   'Mervyn Tuchet, 4th Earl of Castlehaven'),
#  ('Q6856845',
#   'http://www.wikidata.org/entity/Q6856845',
#   'Charles Stuart, Duke of Kendal'),
#  ('Q7244108',
#   'http://www.wikidata.org/entity/Q7244108',
#   'Prince Joseph Clemens of Bavaria'),
#  ('Q7527853',
#   'http://www.wikidata.org/entity/Q7527853',
#   'Sir John Inglis, 2nd Baronet'),
#  ('Q7792758',
#   'http://www.wikidata.org/entity/Q7792758',
#   'Thomas Noel, 2nd Viscount Wentworth'),
#  ('Q9176889',
#   'http://www.wikidata.org/entity/Q9176889',
#   'Boleslav Stanislavovič Potocki'),
#  ('Q9341598', 'http://www.wikidata.org/entity/Q9341598', 'Stanisław Bełza'),
#  ('Q9341775',
#   'http://www.wikidata.org/entity/Q9341775',
#   'Stanisław Czartoryski'),
#  ('Q10380535',
#   'http://www.wikidata.org/entity/Q10380535',
#   'Princess Teresa Teodora of Orléans-Braganza'),
#  ('Q10916692', 'http://www.wikidata.org/entity/Q10916692', 'Q10916692'),
#  ('Q11113010', 'http://www.wikidata.org/entity/Q11113010', 'Michał Butler'),
#  ('Q11688464',
#   'http://www.wikidata.org/entity/Q11688464',
#   'Bogusław Leszczyński'),
#  ('Q15967924', 'http://www.wikidata.org/entity/Q15967924', 'Jean Suau'),
#  ('Q15970454',
#   'http://www.wikidata.org/entity/Q15970454',
#   'Jacques Marcel Auburtin'),
#  ('Q16023504',
#   'http://www.wikidata.org/entity/Q16023504',
#   'Marcia Van Dresser'),
#  ('Q16538609',
#   'http://www.wikidata.org/entity/Q16538609',
#   'Charles de France'),
#  ('Q16859480',
#   'http://www.wikidata.org/entity/Q16859480',
#   'Thomas Pitt of Boconnoc'),
#  ('Q16859736',
#   'http://www.wikidata.org/entity/Q16859736',
#   'Henry Clinton, 2nd Earl of Lincoln'),
#  ('Q17452640', 'http://www.wikidata.org/entity/Q17452640', 'Gabriel Guay'),
#  ('Q17651011',
#   'http://www.wikidata.org/entity/Q17651011',
#   'Jules Michel Lecomte'),
#  ('Q17985915',
#   'http://www.wikidata.org/entity/Q17985915',
#   'Richard James Holwell Birch'),
#  ('Q18214143',
#   'http://www.wikidata.org/entity/Q18214143',
#   'Victor-François-Eloi Biennourry'),
#  ('Q18399091', 'http://www.wikidata.org/entity/Q18399091', 'Q18399091'),
#  ('Q18411753',
#   'http://www.wikidata.org/entity/Q18411753',
#   'Franz Ludwig von Holnstein'),
#  ('Q19799443',
#   'http://www.wikidata.org/entity/Q19799443',
#   'Benjamin Boutet de Monvel'),
#  ('Q19874012',
#   'http://www.wikidata.org/entity/Q19874012',
#   'William Hay, 10th Earl of Erroll'),
#  ('Q19964878',
#   'http://www.wikidata.org/entity/Q19964878',
#   'Theresia Emanuela of Bavaria'),
#  ('Q20003391', 'http://www.wikidata.org/entity/Q20003391', 'Jean-Étienne Rey'),
#  ('Q20118064',
#   'http://www.wikidata.org/entity/Q20118064',
#   'Marie-Emma Boulouze'),
#  ('Q20643898',
#   'http://www.wikidata.org/entity/Q20643898',
#   'Marie-Jeanne Boucher'),
#  ('Q21081425', 'http://www.wikidata.org/entity/Q21081425', 'Jeanne Raunay'),
#  ('Q22969354', 'http://www.wikidata.org/entity/Q22969354', 'Lambert Ryckx'),
#  ('Q22973682',
#   'http://www.wikidata.org/entity/Q22973682',
#   'Jean-François Périer'),
#  ('Q23822752',
#   'http://www.wikidata.org/entity/Q23822752',
#   'Geneviève Jacqueline Pecoul'),
#  ('Q27898150',
#   'http://www.wikidata.org/entity/Q27898150',
#   'Joseph-Auguste Rousselin'),
#  ('Q28800554',
#   'http://www.wikidata.org/entity/Q28800554',
#   'Maria Moors Cabot'),
#  ('Q34951272',
#   'http://www.wikidata.org/entity/Q34951272',
#   'Gustav Alfred Kasimir Xaver von Bojanowski'),
#  ('Q39283790',
#   'http://www.wikidata.org/entity/Q39283790',
#   'Pierre-Jacques Duret'),
#  ('Q45837061', 'http://www.wikidata.org/entity/Q45837061', 'Rune Larsson'),
#  ('Q50062358',
#   'http://www.wikidata.org/entity/Q50062358',
#   'Princess Marie of Schleswig-Holstein-Sonderburg-Glücksburg'),
#  ('Q50975420',
#   'http://www.wikidata.org/entity/Q50975420',
#   'Louisa Murray, 2nd Countess of Mansfield'),
#  ('Q52156348', 'http://www.wikidata.org/entity/Q52156348', 'Louis Busière'),
#  ('Q55835700',
#   'http://www.wikidata.org/entity/Q55835700',
#   "Pierre, Conde d'Abbys Poncet de La Rivière"),
#  ('Q56161141',
#   'http://www.wikidata.org/entity/Q56161141',
#   'Jean-Jacques Bouglé'),
#  ('Q56260310',
#   'http://www.wikidata.org/entity/Q56260310',
#   'Clara Mendelssohn'),
#  ('Q56668949',
#   'http://www.wikidata.org/entity/Q56668949',
#   'Mariana of Austria'),
#  ('Q57731279',
#   'http://www.wikidata.org/entity/Q57731279',
#   'Maria Getrude Buonaparte'),
#  ('Q61197878',
#   'http://www.wikidata.org/entity/Q61197878',
#   'Charles de Kontski'),
#  ('Q61934634', 'http://www.wikidata.org/entity/Q61934634', 'Jacob Jørgensen'),
#  ('Q63314315',
#   'http://www.wikidata.org/entity/Q63314315',
#   'Johann Jakob von Mayer'),
#  ('Q63485943', 'http://www.wikidata.org/entity/Q63485943', 'Carmen Studer'),
#  ('Q64864955',
#   'http://www.wikidata.org/entity/Q64864955',
#   'Christian Bonnesen'),
#  ('Q65547175', 'http://www.wikidata.org/entity/Q65547175', 'François Mattei'),
#  ('Q71439643',
#   'http://www.wikidata.org/entity/Q71439643',
#   'Victoria Sanseverino'),
#  ('Q75248165',
#   'http://www.wikidata.org/entity/Q75248165',
#   'Katherine Cavendish'),
#  ('Q75251920',
#   'http://www.wikidata.org/entity/Q75251920',
#   'Rosemary Grosvenor'),
#  ('Q75264798', 'http://www.wikidata.org/entity/Q75264798', 'Lady Jane Murray'),
#  ('Q75268019',
#   'http://www.wikidata.org/entity/Q75268019',
#   'Lady Blanche Linnie Somerset'),
#  ('Q75269886',
#   'http://www.wikidata.org/entity/Q75269886',
#   "Rinaldo Francesco d'Este"),
#  ('Q75274554',
#   'http://www.wikidata.org/entity/Q75274554',
#   'Lady Frances Hastings'),
#  ('Q75288133',
#   'http://www.wikidata.org/entity/Q75288133',
#   'Josef Franz von Österreich-Este'),
#  ('Q75291881', 'http://www.wikidata.org/entity/Q75291881', 'Leonora Maresco'),
#  ('Q75296311',
#   'http://www.wikidata.org/entity/Q75296311',
#   'Isabella di Borbone, Principessa di Borbone delle Due Sicilie'),
#  ('Q75299114', 'http://www.wikidata.org/entity/Q75299114', 'Lucy Campbell'),
#  ('Q75304303',
#   'http://www.wikidata.org/entity/Q75304303',
#   'Viktoria Gräfin zu Solms-Baruth'),
#  ('Q75308657',
#   'http://www.wikidata.org/entity/Q75308657',
#   'Charlotte Gough-Calthorpe'),
#  ('Q75313814',
#   'http://www.wikidata.org/entity/Q75313814',
#   'Charles Henry Wynn'),
#  ('Q75317998',
#   'http://www.wikidata.org/entity/Q75317998',
#   'Alfonso Sanz y Martínez de Arrizala'),
#  ('Q75330878', 'http://www.wikidata.org/entity/Q75330878', 'Harriet McNab'),
#  ('Q75337815',
#   'http://www.wikidata.org/entity/Q75337815',
#   'Elizabeth Dorothea Maud Fleetwood-Hesketh'),
#  ('Q75347648',
#   'http://www.wikidata.org/entity/Q75347648',
#   'Cecilia Mahony, Comtesse Mahony'),
#  ('Q75387651',
#   'http://www.wikidata.org/entity/Q75387651',
#   'John Grey, 2nd Viscount Lisle'),
#  ('Q75388789',
#   'http://www.wikidata.org/entity/Q75388789',
#   'Lucy Beaufoy Tranter'),
#  ('Q75388852',
#   'http://www.wikidata.org/entity/Q75388852',
#   'unnamed daughter Bernadotte'),
#  ('Q75390858',
#   'http://www.wikidata.org/entity/Q75390858',
#   'Lady Elizabeth Douglas'),
#  ('Q75391266',
#   'http://www.wikidata.org/entity/Q75391266',
#   'Duchess Sophie of Württemberg'),
#  ('Q75391354',
#   'http://www.wikidata.org/entity/Q75391354',
#   'Viktor Prinz von Sachsen-Meiningen'),
#  ('Q75392333',
#   'http://www.wikidata.org/entity/Q75392333',
#   'Clemens Graf von Waldstein-Wartenberg'),
#  ('Q75392656',
#   'http://www.wikidata.org/entity/Q75392656',
#   'Maria Carolina Giovanna Rosa Cecilia di Borbone, Principessa di Borbone delle Due Sicilie'),
#  ('Q75493678', 'http://www.wikidata.org/entity/Q75493678', "Henry O'Brien"),
#  ('Q75534142',
#   'http://www.wikidata.org/entity/Q75534142',
#   'Henry Mildred Birch'),
#  ('Q75569112',
#   'http://www.wikidata.org/entity/Q75569112',
#   'Luise Karoline Gräfin zu Ortenburg'),
#  ('Q75569133',
#   'http://www.wikidata.org/entity/Q75569133',
#   'Charlotte Sophie Louise of Nassau-Siegen'),
#  ('Q75576236',
#   'http://www.wikidata.org/entity/Q75576236',
#   'Sarah Elizabeth Wedgwood'),
#  ('Q75590054', 'http://www.wikidata.org/entity/Q75590054', 'John Booth'),
#  ('Q75757206',
#   'http://www.wikidata.org/entity/Q75757206',
#   'Charles Edward Henry Ryder'),
#  ('Q75760401',
#   'http://www.wikidata.org/entity/Q75760401',
#   'Franziska Sophie Gräfin von Bayerstorff'),
#  ('Q75766329',
#   'http://www.wikidata.org/entity/Q75766329',
#   'Guido-Taddeo Pepoli'),
#  ('Q76004759',
#   'http://www.wikidata.org/entity/Q76004759',
#   'William Hans Sloane-Stanley'),
#  ('Q76020015', 'http://www.wikidata.org/entity/Q76020015', 'Juliana Curzon'),
#  ('Q76053112', 'http://www.wikidata.org/entity/Q76053112', 'Susan Darwin'),
#  ('Q76112549',
#   'http://www.wikidata.org/entity/Q76112549',
#   'John Napier of Culcreuch'),
#  ('Q76180144', 'http://www.wikidata.org/entity/Q76180144', 'John Galbraith'),
#  ('Q76264994',
#   'http://www.wikidata.org/entity/Q76264994',
#   'Claude Francis Arthur Egerton'),
#  ('Q76285474',
#   'http://www.wikidata.org/entity/Q76285474',
#   'Andrew John Drummond'),
#  ('Q76341730', 'http://www.wikidata.org/entity/Q76341730', 'Pierce Meyrick'),
#  ('Q91028210',
#   'http://www.wikidata.org/entity/Q91028210',
#   'Zofia Frąckiewicz-Radzimińska'),
#  ('Q92893883', 'http://www.wikidata.org/entity/Q92893883', 'Józef Puzyna'),
#  ('Q94656288', 'http://www.wikidata.org/entity/Q94656288', 'Amálie Janáčková'),
#  ('Q94764345', 'http://www.wikidata.org/entity/Q94764345', 'Eva Klengel'),
#  ('Q94776945',
#   'http://www.wikidata.org/entity/Q94776945',
#   'Jeanne Hermine Tours'),
#  ('Q94821162',
#   'http://www.wikidata.org/entity/Q94821162',
#   'Bruno Reichenbach'),
#  ('Q95058723',
#   'http://www.wikidata.org/entity/Q95058723',
#   'Salvatore Leonardi'),
#  ('Q96085532', 'http://www.wikidata.org/entity/Q96085532', 'Henry Parry'),
#  ('Q96288675',
#   'http://www.wikidata.org/entity/Q96288675',
#   'Catherine de la Béraudière, Dame de Villenon'),
#  ('Q98127272', 'http://www.wikidata.org/entity/Q98127272', 'Jonah de Maistre'),
#  ('Q102512119',
#   'http://www.wikidata.org/entity/Q102512119',
#   'William Abdollah Dellalfar'),
#  ('Q102852779', 'http://www.wikidata.org/entity/Q102852779', 'Subhendu Roy'),
#  ('Q102965260', 'http://www.wikidata.org/entity/Q102965260', 'Qianli Wu'),
#  ('Q103165746',
#   'http://www.wikidata.org/entity/Q103165746',
#   'Johannes Franz Stader'),
#  ('Q104848699',
#   'http://www.wikidata.org/entity/Q104848699',
#   'Nikolay Repninsky'),
#  ('Q108433354',
#   'http://www.wikidata.org/entity/Q108433354',
#   "Alessandro de' Medici"),
#  ('Q108654832',
#   'http://www.wikidata.org/entity/Q108654832',
#   'Magdalene Lucia Grote'),
#  ('Q109012092',
#   'http://www.wikidata.org/entity/Q109012092',
#   'Charles René de Maillé de La Tour-Landry, 1.Duc de Maillé'),
#  ('Q109740466',
#   'http://www.wikidata.org/entity/Q109740466',
#   'Aurelius Ambrosius'),
#  ('Q111028941',
#   'http://www.wikidata.org/entity/Q111028941',
#   'Élisabeth Quévanne'),
#  ('Q111655102',
#   'http://www.wikidata.org/entity/Q111655102',
#   'Madalena Sá e Costa'),
#  ('Q111697799', 'http://www.wikidata.org/entity/Q111697799', 'Alex E. Roche'),
#  ('Q113501493',
#   'http://www.wikidata.org/entity/Q113501493',
#   'Anne de Joyeuse'),
#  ('Q114356942', 'http://www.wikidata.org/entity/Q114356942', 'Madeleine Budé'),
#  ('Q117186606',
#   'http://www.wikidata.org/entity/Q117186606',
#   "Diane d'Estrées"),
#  ('Q27684', 'http://www.wikidata.org/entity/Q27684', 'Peter Forsskål'),
#  ('Q41554', 'http://www.wikidata.org/entity/Q41554', 'Nicolas Poussin'),
#  ('Q57257', 'http://www.wikidata.org/entity/Q57257', 'Peter Cornelius'),
#  ('Q60560', 'http://www.wikidata.org/entity/Q60560', 'Mary of Guelders'),
#  ('Q61255', 'http://www.wikidata.org/entity/Q61255', 'Kuno Fischer'),
#  ('Q62022',
#   'http://www.wikidata.org/entity/Q62022',
#   'Prince Wilhelm of Prussia'),
#  ('Q63490', 'http://www.wikidata.org/entity/Q63490', 'Johann Peter Salomon'),
#  ('Q70632',
#   'http://www.wikidata.org/entity/Q70632',
#   'Prince Frederick of Prussia'),
#  ('Q76997', 'http://www.wikidata.org/entity/Q76997', 'Moses Mendelssohn'),
#  ('Q83229', 'http://www.wikidata.org/entity/Q83229', 'Edward VI of England'),
#  ('Q90545', 'http://www.wikidata.org/entity/Q90545', 'Paul Hensel'),
#  ('Q111858', 'http://www.wikidata.org/entity/Q111858', 'Ernst Adam'),
#  ('Q122848',
#   'http://www.wikidata.org/entity/Q122848',
#   'Theodor Zwinger the Younger'),
#  ('Q163755',
#   'http://www.wikidata.org/entity/Q163755',
#   'Karl Philipp, Prince of Schwarzenberg'),
#  ('Q164498',
#   'http://www.wikidata.org/entity/Q164498',
#   'Ludwig IV, Grand Duke of Hesse'),
#  ('Q170205',
#   'http://www.wikidata.org/entity/Q170205',
#   'Maria Ludovika of Austria-Este'),
#  ('Q177769',
#   'http://www.wikidata.org/entity/Q177769',
#   'Princess Feodora of Saxe-Meiningen'),
#  ('Q213846',
#   'http://www.wikidata.org/entity/Q213846',
#   'Charles William, Duke of Saxe-Meiningen'),
#  ('Q213937', 'http://www.wikidata.org/entity/Q213937', 'Harry von Arnim'),
#  ('Q215747', 'http://www.wikidata.org/entity/Q215747', 'Hugo Wolf'),
#  ('Q217547', 'http://www.wikidata.org/entity/Q217547', 'Antonio Urceo'),
#  ('Q223183',
#   'http://www.wikidata.org/entity/Q223183',
#   'Peter II of Yugoslavia'),
#  ('Q223744', 'http://www.wikidata.org/entity/Q223744', 'Farinelli'),
#  ('Q229202',
#   'http://www.wikidata.org/entity/Q229202',
#   'Lady Margaret Beaufort'),
#  ('Q233888',
#   'http://www.wikidata.org/entity/Q233888',
#   'Louise Marie Adélaïde de Bourbon'),
#  ('Q242819', 'http://www.wikidata.org/entity/Q242819', 'Lucullus'),
#  ('Q242862',
#   'http://www.wikidata.org/entity/Q242862',
#   'Princess Sophie of the Netherlands'),
#  ('Q252416', 'http://www.wikidata.org/entity/Q252416', 'Árpád Szendy'),
#  ('Q254451', 'http://www.wikidata.org/entity/Q254451', 'Cecilia Gallerani'),
#  ('Q280872', 'http://www.wikidata.org/entity/Q280872', 'Timon of Phlius'),
#  ('Q310146',
#   'http://www.wikidata.org/entity/Q310146',
#   'Charles, Duke of Orléans'),
#  ('Q310566',
#   'http://www.wikidata.org/entity/Q310566',
#   'Diego Velazquez de Cuéllar'),
#  ('Q320534', 'http://www.wikidata.org/entity/Q320534', 'Carlo Pallavicino'),
#  ('Q322582', 'http://www.wikidata.org/entity/Q322582', 'Paul Delaroche'),
#  ('Q327728', 'http://www.wikidata.org/entity/Q327728', 'Georges Valiron'),
#  ('Q328588',
#   'http://www.wikidata.org/entity/Q328588',
#   'Friederike of Saxe-Gotha-Altenburg'),
#  ('Q330244', 'http://www.wikidata.org/entity/Q330244', 'Alfred Jaëll'),
#  ('Q336657',
#   'http://www.wikidata.org/entity/Q336657',
#   'Alexander Hamilton, 10th Duke of Hamilton'),
#  ('Q347871', 'http://www.wikidata.org/entity/Q347871', 'Sigismond Thalberg'),
#  ('Q354730', 'http://www.wikidata.org/entity/Q354730', 'Adelheid Wette'),
#  ('Q360469',
#   'http://www.wikidata.org/entity/Q360469',
#   'Carlo III, Duke of Parma'),
#  ('Q361369',
#   'http://www.wikidata.org/entity/Q361369',
#   'Theobald II of Champagne'),
#  ('Q363992',
#   'http://www.wikidata.org/entity/Q363992',
#   "Louis d'Orléans, Duke of Orléans"),
#  ('Q364498', 'http://www.wikidata.org/entity/Q364498', "David d'Angers"),
#  ('Q374354',
#   'http://www.wikidata.org/entity/Q374354',
#   'Duchess Auguste Elisabeth of Württemberg'),
#  ('Q381698', 'http://www.wikidata.org/entity/Q381698', 'John Michael Wright'),
#  ('Q382582', 'http://www.wikidata.org/entity/Q382582', 'Maine de Biran'),
#  ('Q386484',
#   'http://www.wikidata.org/entity/Q386484',
#   'Karol Stanisław "Panie Kochanku" Radziwiłł'),
#  ('Q431961', 'http://www.wikidata.org/entity/Q431961', 'Aymé Kunc'),
#  ('Q434601', 'http://www.wikidata.org/entity/Q434601', 'Franz Schmidt'),
#  ('Q447149', 'http://www.wikidata.org/entity/Q447149', 'Julie Manet'),
#  ('Q450114', 'http://www.wikidata.org/entity/Q450114', 'Henry de Groux'),
#  ('Q459183', 'http://www.wikidata.org/entity/Q459183', 'Pompeia Paulina'),
#  ('Q466300', 'http://www.wikidata.org/entity/Q466300', 'Isabella of Bourbon'),
#  ('Q468618', 'http://www.wikidata.org/entity/Q468618', 'Dominique Vivant'),
#  ('Q536033',
#   'http://www.wikidata.org/entity/Q536033',
#   'Charles, Duke of Vendôme'),
#  ('Q547301', 'http://www.wikidata.org/entity/Q547301', 'Joachim Raff'),
#  ('Q561662', 'http://www.wikidata.org/entity/Q561662', 'Janusz Radziwiłł'),
#  ('Q598388',
#   'http://www.wikidata.org/entity/Q598388',
#   'Jozef Michal Poniatowski'),
#  ('Q611233',
#   'http://www.wikidata.org/entity/Q611233',
#   'Jean-Baptiste Robinet'),
#  ('Q638678',
#   'http://www.wikidata.org/entity/Q638678',
#   'Archduke Leopold Ludwig of Austria'),
# ...
#  ('Q907686', 'http://www.wikidata.org/entity/Q907686', 'Frigyes Dohnányi'),
#  ('Q924704', 'http://www.wikidata.org/entity/Q924704', 'Victor Laloux'),
#  ('Q1038477',
#   'http://www.wikidata.org/entity/Q1038477',
#   'Carl Gustaf Qvarnström'),
#  ('Q1063325',
#   'http://www.wikidata.org/entity/Q1063325',
#   'Charles Alexis Pierre Brulart de Genlis Sillery'),
#  ('Q1113645',
#   'http://www.wikidata.org/entity/Q1113645',
#   'Lucrezia Tornabuoni'),
#  ('Q1152256',
#   'http://www.wikidata.org/entity/Q1152256',
#   'Giovanni Paolo I Sforza'),
#  ('Q1279245', 'http://www.wikidata.org/entity/Q1279245', 'Marie Arago'),
#  ('Q1348288',
#   'http://www.wikidata.org/entity/Q1348288',
#   'Paluzzo Paluzzi Altieri degli Albertoni'),
#  ('Q1449991', 'http://www.wikidata.org/entity/Q1449991', 'François de Savoie'),
#  ('Q1451181', 'http://www.wikidata.org/entity/Q1451181', 'François Sabatier'),
#  ('Q1463561', 'http://www.wikidata.org/entity/Q1463561', 'Friedrich of Baden'),
#  ('Q1468233', 'http://www.wikidata.org/entity/Q1468233', 'Nándor Zsolt'),
#  ('Q1648677',
#   'http://www.wikidata.org/entity/Q1648677',
#   "Emmanuel Théodose de La Tour d'Auvergne"),
#  ('Q1707079', 'http://www.wikidata.org/entity/Q1707079', 'Joseph Garnier'),
#  ('Q1871585',
#   'http://www.wikidata.org/entity/Q1871585',
#   'Charles de Saint-Albin'),
#  ('Q1897464', 'http://www.wikidata.org/entity/Q1897464', 'Marie Proksch'),
#  ('Q1906507',
#   'http://www.wikidata.org/entity/Q1906507',
#   'Infanta Maria del Pilar of Spain'),
#  ('Q2062312',
#   'http://www.wikidata.org/entity/Q2062312',
#   'Louise Marie Anne de Bourbon'),
#  ('Q2263152', 'http://www.wikidata.org/entity/Q2263152', 'Arcadie Claret'),
#  ('Q2264967',
#   'http://www.wikidata.org/entity/Q2264967',
#   'Duarte Nuno, Duke of Braganza'),
#  ('Q2306331',
#   'http://www.wikidata.org/entity/Q2306331',
#   'Princess Henriette of Schönaich-Carolath'),
#  ('Q2327761',
#   'http://www.wikidata.org/entity/Q2327761',
#   'Gianfrancesco Penni'),
#  ('Q2331097', 'http://www.wikidata.org/entity/Q2331097', 'Nicolas Levasseur'),
#  ('Q2412713',
#   'http://www.wikidata.org/entity/Q2412713',
#   'Infanta Maria Cristina of Spain'),
#  ('Q2440428',
#   'http://www.wikidata.org/entity/Q2440428',
#   'Stanisław Szczęsny Potocki'),
#  ('Q2469933',
#   'http://www.wikidata.org/entity/Q2469933',
#   'Peter of Castile, Lord of Cameros'),
#  ('Q2854294', 'http://www.wikidata.org/entity/Q2854294', 'Antoine Omer Talon'),
#  ('Q2856740', 'http://www.wikidata.org/entity/Q2856740', 'Antoine Simon'),
#  ('Q2857221', 'http://www.wikidata.org/entity/Q2857221', 'Antonio Buttura'),
#  ('Q2960260', 'http://www.wikidata.org/entity/Q2960260', 'Charles Stourm'),
#  ('Q2960634', 'http://www.wikidata.org/entity/Q2960634', 'Charles de Maistre'),
#  ('Q3046654',
#   'http://www.wikidata.org/entity/Q3046654',
#   'Prince Erik, Count of Rosenborg'),
#  ('Q3048033',
#   'http://www.wikidata.org/entity/Q3048033',
#   'Edmond du Motier de La Fayette'),
#  ('Q3060154', 'http://www.wikidata.org/entity/Q3060154', 'Eugène Rouart'),
#  ('Q3094011', 'http://www.wikidata.org/entity/Q3094011', 'Gabriel de Cool'),
#  ('Q3098807',
#   'http://www.wikidata.org/entity/Q3098807',
#   'Gaspard Théodore Mollien'),
#  ('Q3099040', 'http://www.wikidata.org/entity/Q3099040', 'Gaston Jobbé-Duval'),
#  ('Q3101917',
#   'http://www.wikidata.org/entity/Q3101917',
#   'Sir George Sitwell, 4th Baronet'),
#  ('Q3121280',
#   'http://www.wikidata.org/entity/Q3121280',
#   'Gustave Oelsner-Monmerqué'),
#  ('Q3122259',
#   'http://www.wikidata.org/entity/Q3122259',
#   'Guy de Laval-Bois-Dauphin'),
#  ('Q3129338',
#   'http://www.wikidata.org/entity/Q3129338',
#   'Hedvig Eleonora von Fersen'),
#  ('Q3130385',
#   'http://www.wikidata.org/entity/Q3130385',
#   'Henri-François Riesener'),
#  ('Q3132810', 'http://www.wikidata.org/entity/Q3132810', 'Henry Greffulhe'),
#  ('Q3158820', 'http://www.wikidata.org/entity/Q3158820', 'Jacques Durand'),
#  ('Q3160282', 'http://www.wikidata.org/entity/Q3160282', 'Giacomo di Foix'),
#  ('Q3167428', 'http://www.wikidata.org/entity/Q3167428', 'Jean-Marc Luisada'),
#  ('Q3170873', 'http://www.wikidata.org/entity/Q3170873', 'Jean Boucher'),
#  ('Q3172102',
#   'http://www.wikidata.org/entity/Q3172102',
#   'Jean François Bozio'),
#  ('Q3262482',
#   'http://www.wikidata.org/entity/Q3262482',
#   'Louis Le Peletier de Rosanbo'),
#  ('Q3263392',
#   'http://www.wikidata.org/entity/Q3263392',
#   'Louis de Bourbon-Roussillon'),
#  ('Q3291625',
#   'http://www.wikidata.org/entity/Q3291625',
#   'Marie-Charlotte Hippolyte de Campet de Saujon'),
#  ('Q3302760',
#   'http://www.wikidata.org/entity/Q3302760',
#   'Maximilien Louis Bourgeois'),
#  ('Q3595563',
#   'http://www.wikidata.org/entity/Q3595563',
#   'Franciszek Kostrzewski'),
#  ('Q3680440', 'http://www.wikidata.org/entity/Q3680440', 'Clemente Althaus'),
#  ('Q3963952',
#   'http://www.wikidata.org/entity/Q3963952',
#   'Sophia Charlotte of Schleswig-Holstein-Sonderburg-Beck'),
#  ('Q4065295', 'http://www.wikidata.org/entity/Q4065295', 'Richard Andersson'),
#  ('Q4106036', 'http://www.wikidata.org/entity/Q4106036', 'Yuliya Veysberg'),
#  ('Q4283267', 'http://www.wikidata.org/entity/Q4283267', 'Frank Marshall'),
#  ('Q4669300',
#   'http://www.wikidata.org/entity/Q4669300',
#   'Abraham van Blijenberch'),
#  ('Q4709611', 'http://www.wikidata.org/entity/Q4709611', 'Albert Alan Owen'),
#  ('Q4798011', 'http://www.wikidata.org/entity/Q4798011', 'Arthur Birch'),
#  ('Q4953327', 'http://www.wikidata.org/entity/Q4953327', 'Sara Heinze'),
#  ('Q5056012',
#   'http://www.wikidata.org/entity/Q5056012',
#   'Cecil Clementi Smith'),
#  ('Q5077278',
#   'http://www.wikidata.org/entity/Q5077278',
#   'Charles Edward Horsley'),
#  ('Q5082845', 'http://www.wikidata.org/entity/Q5082845', 'Charles Talbot'),
#  ('Q5126007',
#   'http://www.wikidata.org/entity/Q5126007',
#   'Clara Kathleen Rogers'),
#  ('Q5271173', 'http://www.wikidata.org/entity/Q5271173', 'Diana Gould'),
#  ('Q5274623',
#   'http://www.wikidata.org/entity/Q5274623',
#   'Diego Colón de Toledo, 4th Admiral of the Indies'),
#  ('Q5298213',
#   'http://www.wikidata.org/entity/Q5298213',
#   'Dorota Barbara Jabłonowska'),
#  ('Q5973389', 'http://www.wikidata.org/entity/Q5973389', 'Eleanor of Castile'),
#  ('Q6470028',
#   'http://www.wikidata.org/entity/Q6470028',
#   'Lady Charles Bentinck'),
#  ('Q6470224', 'http://www.wikidata.org/entity/Q6470224', 'Lady Helena Gibbs'),
#  ('Q6761550', 'http://www.wikidata.org/entity/Q6761550', 'Maria Rosetti'),
#  ('Q7243972',
#   'http://www.wikidata.org/entity/Q7243972',
#   'Prince Eugen of Schaumburg-Lippe'),
#  ('Q7934272', 'http://www.wikidata.org/entity/Q7934272', 'Virginia Gabriel'),
#  ('Q8018797', 'http://www.wikidata.org/entity/Q8018797', 'William Steuart'),
#  ('Q9146521',
#   'http://www.wikidata.org/entity/Q9146521',
#   'Aleksandra Grabowska'),
#  ('Q11769043', 'http://www.wikidata.org/entity/Q11769043', 'Mariya Mohylanka'),
#  ('Q11916146',
#   'http://www.wikidata.org/entity/Q11916146',
#   'Cristòfor Taltabull i Balaguer'),
#  ('Q12324302', 'http://www.wikidata.org/entity/Q12324302', 'Leopold Hartmann'),
#  ('Q13530344',
#   'http://www.wikidata.org/entity/Q13530344',
#   'Henry Pelham, 3rd Earl of Chichester'),
#  ('Q15147708',
#   'http://www.wikidata.org/entity/Q15147708',
#   'Théophile Poilpot'),
#  ('Q15528381', 'http://www.wikidata.org/entity/Q15528381', 'Lester Wallack'),
#  ('Q15854636', 'http://www.wikidata.org/entity/Q15854636', 'William Byron'),
#  ('Q16250326',
#   'http://www.wikidata.org/entity/Q16250326',
#   'Honor Plantagenet, Viscountess Lisle'),
#  ('Q16590330', 'http://www.wikidata.org/entity/Q16590330', 'Pieter De Groot'),
#  ('Q16747640', 'http://www.wikidata.org/entity/Q16747640', 'Margaret Stewart'),
#  ('Q18533862', 'http://www.wikidata.org/entity/Q18533862', 'René Piot'),
#  ('Q18611793',
#   'http://www.wikidata.org/entity/Q18611793',
#   'Pierre Carolus-Duran'),
#  ('Q19325559',
#   'http://www.wikidata.org/entity/Q19325559',
#   'Elizabeth Mounsey'),
#  ('Q20991602', 'http://www.wikidata.org/entity/Q20991602', 'Thérèse Geraldy'),
#  ('Q21459042', 'http://www.wikidata.org/entity/Q21459042', "Borso d'Este"),
#  ('Q21459138',
#   'http://www.wikidata.org/entity/Q21459138',
#   'Auguste Aristide Fernand Constantin'),
#  ('Q23675253', 'http://www.wikidata.org/entity/Q23675253', 'Edward Kilenyi'),
#  ('Q25391094', 'http://www.wikidata.org/entity/Q25391094', 'Q25391094'),
#  ('Q26763709',
#   'http://www.wikidata.org/entity/Q26763709',
#   "Joseph-Aimé d'Hervilly"),
#  ('Q28004096',
#   'http://www.wikidata.org/entity/Q28004096',
#   'Franz Josef von Waldstein'),
#  ('Q28056891', 'http://www.wikidata.org/entity/Q28056891', 'Paul Edward Beem'),
#  ('Q28778560',
#   'http://www.wikidata.org/entity/Q28778560',
#   'Karl Prinz von Hessen-Philippsthal'),
#  ('Q29169646', 'http://www.wikidata.org/entity/Q29169646', 'Povl Olrik'),
#  ('Q39386930',
#   'http://www.wikidata.org/entity/Q39386930',
#   'Marie Alexandrine Dumas'),
#  ('Q41667133',
#   'http://www.wikidata.org/entity/Q41667133',
#   'Johannes Herman Brandt'),
#  ('Q44627219',
#   'http://www.wikidata.org/entity/Q44627219',
#   'Daniella Sophia Louisa Winge'),
#  ('Q55122281',
#   'http://www.wikidata.org/entity/Q55122281',
#   'Peter von Osterwald'),
#  ('Q55681042',
#   'http://www.wikidata.org/entity/Q55681042',
#   'Friedrich Johann Nepomuk von Thurn und Taxis'),
#  ('Q55848354', 'http://www.wikidata.org/entity/Q55848354', 'Jacob Herz Beer'),
#  ('Q55856279',
#   'http://www.wikidata.org/entity/Q55856279',
#   'Arthur von Mensdorff-Pouilly'),
#  ('Q56260633', 'http://www.wikidata.org/entity/Q56260633', 'Gordon Manley'),
#  ('Q60467540', 'http://www.wikidata.org/entity/Q60467540', 'František Dvořák'),
#  ('Q63645174',
#   'http://www.wikidata.org/entity/Q63645174',
#   'Catherine Gordon Byron'),
#  ('Q64140974', 'http://www.wikidata.org/entity/Q64140974', 'Aleksandr Kyui'),
#  ('Q64747059',
#   'http://www.wikidata.org/entity/Q64747059',
#   'Johann Philipp Burkhard'),
#  ('Q75239905',
#   'http://www.wikidata.org/entity/Q75239905',
#   'Karl Edward von der Pfalz'),
#  ('Q75245606',
#   'http://www.wikidata.org/entity/Q75245606',
#   'Wilhelm Ernst von Sachsen-Weimar-Eisenach'),
#  ('Q75248661',
#   'http://www.wikidata.org/entity/Q75248661',
#   'Lady Mary Lowther'),
#  ('Q75249284',
#   'http://www.wikidata.org/entity/Q75249284',
#   'Frederick Arthur Aylmer'),
#  ('Q75249466',
#   'http://www.wikidata.org/entity/Q75249466',
#   'Castalia Rosalind Campbell'),
#  ('Q75249680',
#   'http://www.wikidata.org/entity/Q75249680',
#   'Lady Margaret Percy'),
#  ('Q75250984',
#   'http://www.wikidata.org/entity/Q75250984',
#   'Lady Anne Villiers'),
#  ('Q75264610', 'http://www.wikidata.org/entity/Q75264610', 'Lady Julia Gore'),
#  ('Q75274626',
#   'http://www.wikidata.org/entity/Q75274626',
#   'Mary Ursula Sealy'),
#  ('Q75286670',
#   'http://www.wikidata.org/entity/Q75286670',
#   'Philipp von Habsburg'),
#  ('Q75298927',
#   'http://www.wikidata.org/entity/Q75298927',
#   'Donata Gräfin zu Solms-Baruth'),
#  ('Q75306029',
#   'http://www.wikidata.org/entity/Q75306029',
#   'Monica Margaret Grenfell'),
#  ('Q75317486',
#   'http://www.wikidata.org/entity/Q75317486',
#   'Georges de Bourbon'),
#  ('Q75337227',
#   'http://www.wikidata.org/entity/Q75337227',
#   'William Arthur Baird'),
#  ('Q75363900', 'http://www.wikidata.org/entity/Q75363900', 'Anne de MacMahon'),
#  ('Q75364276',
#   'http://www.wikidata.org/entity/Q75364276',
#   'Prince Luis of Orléans'),
#  ('Q75369846',
#   'http://www.wikidata.org/entity/Q75369846',
#   'Alfonso de Borbón y de Leon, Marques de Squilache'),
#  ('Q75370123',
#   'http://www.wikidata.org/entity/Q75370123',
#   'Ramon Bertran de Lis'),
#  ('Q75370888',
#   'http://www.wikidata.org/entity/Q75370888',
#   'Fernando Sanchez de Toca y Munoz, Duque de Vista Alegre'),
#  ('Q75371200',
#   'http://www.wikidata.org/entity/Q75371200',
#   'Emma dei Conti Lucich'),
#  ('Q75375534',
#   'http://www.wikidata.org/entity/Q75375534',
#   'Joseph Prinz von Lobkowicz'),
#  ('Q75383610',
#   'http://www.wikidata.org/entity/Q75383610',
#   'Princess Johanna Marie, Countess of Solms-Laubach'),
#  ('Q75385577',
#   'http://www.wikidata.org/entity/Q75385577',
#   'Alexander Prinz von Baden'),
#  ('Q75390913',
#   'http://www.wikidata.org/entity/Q75390913',
#   'Lovisa Hedvig of Sweden'),
#  ('Q75391507',
#   'http://www.wikidata.org/entity/Q75391507',
#   'Leopoldine Blanche Prinzessin von Sachsen-Coburg und Gotha'),
#  ('Q75392662',
#   'http://www.wikidata.org/entity/Q75392662',
#   'Princess Marie Thérèse of Bourbon-Parma'),
#  ('Q75392695',
#   'http://www.wikidata.org/entity/Q75392695',
#   'Francesco Alfonso di Borbone, Principe di Parma'),
#  ('Q75392848',
#   'http://www.wikidata.org/entity/Q75392848',
#   'Count Bernard Pecori-Sauréz'),
#  ('Q75394437',
#   'http://www.wikidata.org/entity/Q75394437',
#   'Prince Carlo Emanuele of Savoy'),
#  ('Q75394999', 'http://www.wikidata.org/entity/Q75394999', 'Aurelia Spinola'),
#  ('Q75455500',
#   'http://www.wikidata.org/entity/Q75455500',
#   'Lady Sophia Fermor'),
#  ('Q75534294',
#   'http://www.wikidata.org/entity/Q75534294',
#   'Isabella Ann Corrance'),
#  ('Q75565257',
#   'http://www.wikidata.org/entity/Q75565257',
#   'Elizabeth Compton Cavendish'),
#  ('Q75567586',
#   'http://www.wikidata.org/entity/Q75567586',
#   'Maria Sophie Herschel'),
#  ('Q75614894',
#   'http://www.wikidata.org/entity/Q75614894',
#   'Leonard Wilson-Wright'),
#  ('Q75629011', 'http://www.wikidata.org/entity/Q75629011', 'Charles Cochrane'),
#  ('Q75731166', 'http://www.wikidata.org/entity/Q75731166', 'Jessica Williams'),
#  ('Q75766332', 'http://www.wikidata.org/entity/Q75766332', 'Carolina Pepoli'),
#  ('Q75803670', 'http://www.wikidata.org/entity/Q75803670', 'Dudley Knollys'),
#  ('Q75807687', 'http://www.wikidata.org/entity/Q75807687', 'Blanche Hunsdon'),
#  ('Q75889309', 'http://www.wikidata.org/entity/Q75889309', 'Elinor Dobbs'),
#  ('Q75966143',
#   'http://www.wikidata.org/entity/Q75966143',
#   'Adèle Marie Julie Laure Victorine Hugo'),
#  ('Q76013070',
#   'http://www.wikidata.org/entity/Q76013070',
#   'Anna Carolina Prinzessin von Isenburg-Budingen-Wachtersbach'),
#  ('Q76064375',
#   'http://www.wikidata.org/entity/Q76064375',
#   'Charles Anthony Vincent'),
#  ('Q76196787', 'http://www.wikidata.org/entity/Q76196787', 'Mary Oswald'),
#  ('Q76275576',
#   'http://www.wikidata.org/entity/Q76275576',
#   'Christopher James'),
#  ('Q76302668',
#   'http://www.wikidata.org/entity/Q76302668',
#   'Joseph Henry Storie Jekyll'),
#  ('Q76326979', 'http://www.wikidata.org/entity/Q76326979', 'Catherine Gibbon'),
#  ('Q76361741',
#   'http://www.wikidata.org/entity/Q76361741',
#   'Maria Josepha Irene Gräfin Jörger zu Tollet'),
#  ('Q76367989', 'http://www.wikidata.org/entity/Q76367989', 'Marie Rossi'),
#  ('Q76373086', 'http://www.wikidata.org/entity/Q76373086', 'Janet McCormack'),
#  ('Q78587492',
#   'http://www.wikidata.org/entity/Q78587492',
#   'Francesco Stradivari'),
#  ('Q93499214',
#   'http://www.wikidata.org/entity/Q93499214',
#   'Magdalena de Creus y Ximines'),
#  ('Q96073520',
#   'http://www.wikidata.org/entity/Q96073520',
#   'Maj. William Henry Birch'),
#  ('Q96634048', 'http://www.wikidata.org/entity/Q96634048', 'Pierre Boudan'),
#  ('Q96694925', 'http://www.wikidata.org/entity/Q96694925', 'Jean Risler'),
#  ('Q102816344', 'http://www.wikidata.org/entity/Q102816344', 'Anne Briçonnet'),
#  ('Q105873133',
#   'http://www.wikidata.org/entity/Q105873133',
#   'Maria Theresia Anna, Gräfin von Trauttmansdorff'),
#  ('Q106361032',
#   'http://www.wikidata.org/entity/Q106361032',
#   'Henriette Josephine Clémence Saisset'),
#  ('Q106729090',
#   'http://www.wikidata.org/entity/Q106729090',
#   'Jean Jacques Mercier I'),
#  ('Q108652533', 'http://www.wikidata.org/entity/Q108652533', 'Anna Bauer'),
#  ('Q108838539',
#   'http://www.wikidata.org/entity/Q108838539',
#   'Edouard Bernhardt'),
#  ('Q108839139', 'http://www.wikidata.org/entity/Q108839139', 'Jean Racine'),
#  ('Q109012266',
#   'http://www.wikidata.org/entity/Q109012266',
#   'Vicomte Gaspard de Castellane'),
#  ('Q109687089',
#   'http://www.wikidata.org/entity/Q109687089',
#   'Thekla von Gorska'),
#  ('Q110214583',
#   'http://www.wikidata.org/entity/Q110214583',
#   'Richard T. Dooner'),
#  ('Q110381761',
#   'http://www.wikidata.org/entity/Q110381761',
#   'Edmée Nicole Pulcherie Brûlart'),
#  ('Q110504259',
#   'http://www.wikidata.org/entity/Q110504259',
#   'Regina Bartholotti von Porthenfeld'),
#  ('Q111272196',
#   'http://www.wikidata.org/entity/Q111272196',
#   'Isabel Mary Wells'),
#  ...]

# %% [markdown]
# # Creating neo4j graph

# %% [markdown]
# ## connect to database

# %%
driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "password"))
driver.verify_connectivity()
session = driver.session(database="wikidatadev")

# %% [markdown]
# ## create Person nodes

# %%
all_humans_qcodes = []
for human in all_humans:
    qcode, wd_url, name = human
    all_humans_qcodes.append(qcode)
    try:
        cypher_query = f"""MERGE (:Person{{name: "{name}", wd_url: "{wd_url}"}})"""
        session.run(cypher_query)
    except CypherSyntaxError:  #  Karol Stanisław "Panie Kochanku" Radziwiłł (Q386484) 
        cypher_query = f"""MERGE (:Person{{name: '{name}', wd_url: '{wd_url}'}})"""
        session.run(cypher_query)
# ^ 2m16s dla len(all_humans) =~ 30_000 (powstałe z 399 osób z inputu)

# %% [markdown]
# ## create other nodes, edges & connect to Person nodes

# %%
ERRORS = []
for qcode in rdf_info.keys():
    for t in rdf_info[qcode]:
        object_name, object_url = t[5].replace("'", "\\'"), t[2].replace("'", "\\'")

        object_label = "wdLabel"
        object_qcode = object_url[object_url.rfind("Q"):]
        if object_qcode in all_humans_qcodes: # in rdf_info.keys():  # in all_humans_qcodes: HERE
            object_label = "Person"
        else:
            cypher_query = f"""MERGE (:{object_label}{{name: '{object_name}', wd_url: '{object_url}'}})"""
            try:
                session.run(cypher_query)
            except Exception as e:
                ERRORS.append(("MERGE NODE", object_url, cypher_query, e))

        cypher_illegal_edgename_chars = ["'", ",", "(", ")", "-", ".", "/", "&", "’", "+", "+d'-", ":"]
        edge_name = t[4].replace(' ', '_').replace("–", "_")
        for c in cypher_illegal_edgename_chars:
            edge_name = edge_name.replace(c, "")
        edge_name = edge_name.upper()
        edge_url = t[1]

        subject_url = t[0].replace("'", "\\'")
        person_name = t[3].replace("'", "\\'")
        try:
            s = f"""
            MATCH (p:Person), (l:{object_label}) 
            WHERE p.name="{person_name}" AND p.wd_url="{subject_url}" AND l.name='{object_name}' AND l.wd_url='{object_url}'
            MERGE (p) - [:`{edge_name}` {{wd_url: '{edge_url}', source: 'wikidata'}}] -> (l)
            """
            session.run(s)
        except CypherSyntaxError:  # Karol Stanisław "Panie Kochanku" Radziwiłł (Q386484)
            s = f"""
            MATCH (p:Person), (l:{object_label}) 
            WHERE p.name='{person_name}' AND p.wd_url="{subject_url}" AND l.name='{object_name}' AND l.wd_url='{object_url}'
            MERGE (p) - [:`{edge_name}` {{wd_url: '{edge_url}', source: 'wikidata'}}] -> (l)
            """
            session.run(s)
        except Exception as e:
            ERRORS.append(("MERGE EDGE", object_url, s, e))

# %%
# ^ 45s dla len(rdf_info.keys()) = 36 len(all_humans) = 170
# ^ 936m 52s dla len(rdf_info.keys()) = 13171 len(all_humans) = 29966

# %%
ERRORS
# ^ lista ERRORS była pusta dla 936m 52s dla len(rdf_info.keys()) = 13171 len(all_humans) = 29966. To pewnie jakiś błąd jupytera(?), może za długo komórka działała. Jakeiś errory musiały się pojawić....
# Out:
# []

# %% [markdown]
# ## delete all nodes

# %%
# # DELETE ALL
# s="""MATCH (n)
# CALL { WITH n
# DETACH DELETE n
# } IN TRANSACTIONS;"""
# session.run(s)

# %% [markdown]
# ## session close

# %%
# session.close()

# %% [markdown]
# ## sample cypher queries

# %%
# UWAGA: nie można traktować uzyskanych wyników jako prawdę odzwierdciedlającą rzeczywistość; dane są niekompletne i pewnie niektóre nawet są nieprawdziwe.

# MATCH (n) WHERE n.name =~ ".*Chopin.*" RETURN n

# match (n:Person)-[e:OCCUPATION]-(s) WHERE s.name CONTAINS "composer" return n,s

# MATCH (p:Person)-[l:residence]-(s)
# WHERE p.name=~'.*Chopin' or p.name=~'.*Liszt'
# RETURN p, s

# MATCH (p:Person)-[l:RESIDENCE]-(s)
# WHERE p.name=~'.*Chopin' or p.name=~'.*Beethoven.*'
# RETURN p, s

# MATCH (p:Person)-[l:STUDENT_OF]-(s)
# WHERE p.name=~'.*Frédéric Chopin.*' or p.name=~'.*Franz Liszt.*'
# RETURN p, s

# Match(p:Person)-[e:date_of_birth]-(l:Label) return p, l

# match (n:Person) WHERE n.name CONTAINS "Bee" return n

# MATCH (p:Person)-[e:OCCUPATION]-(s:wdLabel) WHERE s.name =~ ".*singer.*" RETURN p,s

# MATCH w=(p:Person)-[e:INSTRUMENT]-(s:wdLabel)
# WITH s, COLLECT(w) as test
# ORDER BY SIZE(test) DESC
# RETURN s.name, SIZE(test)

# MATCH (p:Person)-[e:DATE_OF_BIRTH]-(d:wdLabel)
# WHERE datetime({year: 1770, month:7}) <= datetime(d.name) < datetime({year: 1771})
# WITH p, d
# ORDER BY d.name DESC
# RETURN p, d, p.name, d.name

# MATCH (p:Person)-[e:HANDEDNESS]-(s:wdLabel), (p)-[i:INSTRUMENT]-(s2:wdLabel)
# WHERE s.name =~ '.*left.*' 
# RETURN *  

# MATCH (p:Person)-[e:HANDEDNESS]-(s:wdLabel)
# WHERE s.name =~ '.*left.*' 
# RETURN *

# %% [markdown]
# # Komentarze
# Zbiór niezbyt dobrze uporządkowanych myśli i nieścisłych wyrażeń *(informacje dla mnie, po jakimś czasie i tak przestałem aktualizować tę sekcję)*

# %% [markdown]
# Co zrobiłem:
# * uporządkowałem kod
# * odrzuciłem pojedyncze nazwy z listy osób, np. "Pierre"
# * ```get_all_triples_and_qcodes()``` dodałem opcję zostawienia tych objects, które nie są Qcodami w wikidata (różne literały, często są to jakieś id w muzeach czy innych zbiorach danych, wcześniej to odrzuciłem bo wydało mi się nieprzydatne)
# * ^ ale wd_url będzie wtedy literałem, a nie urlem w grafie. Nie jest to chyba duży problem i może tak zostać. ( ale TODO do poprawy)
# * dla krawędzi: uppercase nazw i dodanie atrybutu ```source: 'wikidata' ```
# * dla każdego subject z listy sprawdzenie wszystkich powiązanych objects i zapisanie qcodów tych obiektów, które są ```instance_of``` --> ```human```
# * ```scrape_qcodes(list, humans_only=False, first_only=False)``` dodałem sposób na dostanie Qcode tylko pierwszego znalezionego człowieka na wikidata
# * zrezygnowałem z atrybutu ```description``` dla scrapeowanych qcodów (w grafie)
# * rekurencyjne pobieranie info o ludziach połączonych z ludźmi z inputu
#
# Kilka problematycznych kwestii:
# * osoba, o którą nam chodzi nie jest pierwszym wynikiem na liście wyszukiwania w wikidata
# * niektórych osób z input listy nie wyszukuje w wikdata. Jak się usunie dopiski w nawiasach, to już tak, np. dla "Józef Michał Poniatowski (książę)". Z 399 osób w input list, zostało 285 z Qcodami (ale nie wiem, czy poprawnymi). TODO do poprawy
# * czy kontrolujemy manualnie poprawność osób dodanych z wikidata? (chodzi o osoby z input_list)
# * biblioteka SPARQLWrapper nie działa dobrze, zwraca często zmultiplikowane wyniki i spowalnia działanie programu
# * osoby, które są na najniższym poziome (liście drzewa) nie mają żadnych atrybutów (trójek rdf), bo kiedyś ten łańcuch trzeba skończyć. Pytanie w jaki sposób.
# * w grafie prawdopodobnie będą błędy, np. randomowe osoby nazywające się tak samo jak np. te wspomniane w listach, a tych wspomnianych nie będzie w grafie
# * będą sobie pływały randomowe węzły osób w tym grafie, np. Q383232 (Afiat Yuris Wirawan, gracz badmintona) bo np Rachmaninov ma "FactGrid item ID": Q383232
# * ^ EDIT:   naprawiłem to dla tego specyficznego przypadku krawędzi "FactGrid item ID", u nich wszystkie ID są postaci takiej jak Qcody na wikidata
# * ^         ale mogą się pojawić inne randomowe osoby i przez to nie będzie tworzony węzęł z obiektem o nazwie np. Q123 i nie będzie krawędzi między subjectem(osobą) a obiektem/randomową osobą
# * a może nie brać osób z listów Paderewskiego, a zostawić tylko osoby z listów Chopina?
#
# ['Etienne',
#  'Perrichet',
#  'Pierre',
#  'Alexis',
#  'Grandville',
#  'Rafael',
#  'Voltaire']
#
# Granville https://www.wikidata.org/wiki/Q744442 ???
#
# Voltaire https://www.wikidata.org/wiki/Q9068 ???
#
# Pierre służący Fryderyka Chopina ???
#
#
#
# --- na razie robię sobie przerwę od tego projektu, muszę zacząć robić pracę inżynierską i mam też inny projekt

# %% [markdown]
# # TODO

# %% [markdown]
# * Zbyt długo trwa robienie grafu. Może zrobienie csv i potem wczytywanie csv do neo4j będzie szybsze niż pojedyncze robienie węzłów i krawędzi. Zrobić indeksy, zwiększyć limity pamięci w neo4j desktop, zrobić CSV do krawędzi i LOAD CSV, CALL IN TRANSACTIONS. Do zrobienia.
# * Niektórych osób z input listy nie wyszukuje w wikdata. Jak się usunie dopiski w nawiasach, to już tak, np. dla "Józef Michał Poniatowski (książę)". Do zrobienia.
# * w np. DATE_OF_BIRTH są jakieś śmieci czasami, np. http://www.wikidata.org/.well-known/genid/c9a8b2f22783c60e6bf383200d9285f7. Pewnie można by w "create other nodes, edges & connect to Person nodes" sprawdzać wartość dla qcodów dat np date_of_birth, date_of_costam. Do zrobienia.
# * A może by tak oznaczać osoby (węzeł :Person), które nie mają atrybutów z wikidata (czyli w grafie powiązań z węzłami wdLabel) jakąś inną etykietą, lub jakimś atrybutem, np. "leaf"/"no_further_info"/"no_". Są to "osoby-liście", na których kończy się rekurencyjne pobieranie info o ludziach. ({all_humans} - {rdf_info.keys()}).
# * Biblioteka SPARQLWrapper nie działa dobrze, zwraca często zmultiplikowane wyniki i spowalnia działanie programu, można spróbować użyć innej biblioteki lub samemu napisać.
# * Może nie brać osób z listów Paderewskiego, a zostawić tylko osoby z listów Chopina?
# * [EDIT] [nieważne, neo4j browser nie wyświetla krawędzi czasami] czemu wielu kompozytorów nie ma OCCUPATION -> composer? np. Robert Schumann... Wygląda na to, że czasamiu niektóre krawędzie się nie tworzą, zbadać przyczynę i naprawić. Do zrobienia.
#
# * Na githuba wrzucic kod i na discorda linka do https://query.wikidata.org/ jakby ktos chcial sie zajac pobieraniem innych danych nie dotyczacych osob itp.
#
# ** TYLKO POMYSŁ: sporo czasu by trzeba poświęcić na sprawdzanie czy pierszy scrape'owany human z wikidata search to osoba której chcemy (czyli w jakiś sposób powiązana z Chopinem/osobami na grafie).

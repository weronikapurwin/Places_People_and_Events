# %% [markdown]
# # Imports

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import sys
import copy
import re
import csv
from neo4j import GraphDatabase
from neo4j.exceptions import CypherSyntaxError
from SPARQLWrapper import SPARQLWrapper, JSON  # pip install sparqlwrapper

# %% [markdown]
# # Defined functions

# %%
def get_sparql_results(endpoint_url, query):
    # Helper function
    user_agent = f"WDQS-example Python/{sys.version_info[0]}.{sys.version_info[1]}"  # https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %%
def preprocess_input_list(input_list):
    # Helper function
    augmented = copy.deepcopy(input_list)
    for name in input_list:
        name_without_parentheses = re.sub(r"\([^()]*\)", "", name)
        if name != name_without_parentheses:
            augmented.append(name_without_parentheses)
    return augmented

# %%
def scrape_qcodes(list, humans_only=False, first_only=False):
    """
    Gets Q codes and urls for wikidata pages from the first page of search results.
    
    list: list of search names, eg. ['Fryderyk Chopin', 'Ferenc Liszt', 'Wojciech Żywny']
    first_only: if True, gets data from the first link (result) only
    returns: list of dicts (search_name, page_name, description, Qcode, wiki_url)
             if page with given name doesn't exist, its qcode is ommited
    """
    list = preprocess_input_list(list)
    retv = []
    input_length = len(list)
    for i, search_name in enumerate(list):
        print(f"Scraping... {i+1}/{input_length} ... " + search_name)
        url = f"https://www.wikidata.org/w/index.php?go=Go&search={search_name}"
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "html.parser")
        for item in soup.find_all('li', class_="mw-search-result mw-search-result-ns-0"):
            page_name = item.find('a', title=True)['title'].lstrip('\u200e').split('\u200e')[0]
            try:
                description = item.find('a', title=True)['title'].lstrip('\u200e').split('\u200e')[2]
            except IndexError:
                description = None
            href = item.find('a', href=True).get('href')
            Qcode = href.lstrip('/wiki/')
            wiki_url = f"https://www.wikidata.org{href}"
            if humans_only:
                human_test = get_all_human_objects([Qcode])
                if human_test:
                    if Qcode not in [d['Qcode'] for d in retv]:
                        retv.append({'search_name': search_name, 'page_name': page_name, 'description':description, 'Qcode': Qcode, 'wiki_url': wiki_url,})
                    if first_only:
                        break
            else:
                if Qcode not in [d['Qcode'] for d in retv]:
                    retv.append({'search_name': search_name, 'page_name': page_name, 'description':description, 'Qcode': Qcode, 'wiki_url': wiki_url,})
                if first_only:
                    break
    return retv

# %%
def get_all_triples_and_qcodes(Qcode, allow_literals=True):
    """
    Args:
        Qcode: wikidata subject Qcode, eg.: 'Q255'
        allow_literals: whether to allow returning literal objects (objects not represented as wikidata/wikimedia pages) associated with subject's Qcode

    Returns (First value returned): 
        list of tuples representig RDF triples (object-predicate-subject) and labels associated with each wikidata entity

        Example tuple representing RDF triple:
            ('http://www.wikidata.org/entity/Q255',
            'http://www.wikidata.org/entity/P19',
            'http://www.wikidata.org/entity/Q586',
            'Ludwig van Beethoven',
            'place of birth',
            'Bonn')
        Tuple contents:
            (object,
            predicate,
            subject,
            objectLabel,
            predicateLabel,
            subjectLabel)

    Returns (Second value returned): 
        list of all Qcodes of wikidata objects associated with provided subject (Qcode)

        Example:
            ['Q255', Q'1268']
    """
    #  UWAGA:  Z jakiegoś powodu query poniżej zwraca wielokrotnie zduplikowane wyniki, pewnie błąd leży po stronie twórców biblioteki SPARQLWrapper.
    #          To samo zapytanie wprwadzowne w https://query.wikidata.org/ zwraca normalne, nie powielane wyniki.
    #          Poprawiłem to dopiero przy dodawaniu krotek do listy trójek RDF.
    

    if isinstance(Qcode, list):
        list_of_wdqcodes = ["wd:" + qcode for qcode in Qcode]
        query = """SELECT DISTINCT ?s ?sLabel ?wd ?wdLabel ?o ?oLabel   WHERE {{
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en,pl". }}
        VALUES ?s {{ {} }}
        # ?s ?wdt ?o.
        # ?wd wikibase:directClaim ?wdt.
        # ?wd rdfs:label ?wdLabel.
        FILTER((LANG(?wdLabel)) = "en")
        }}
        ORDER BY (xsd:integer(STRAFTER(STR(?wd), "http://www.wikidata.org/entity/P")))""".format(' '.join(list_of_wdqcodes))
    else:
        query = """SELECT DISTINCT ?s ?sLabel ?wd ?wdLabel ?o ?oLabel   WHERE {
        SERVICE wikibase:label { bd:serviceParam wikibase:language "en,pl". }
        VALUES ?s { wd:%s }
        # ?s ?wdt ?o.
        # ?wd wikibase:directClaim ?wdt.
        # ?wd rdfs:label ?wdLabel.
        FILTER((LANG(?wdLabel)) = "en")
        }
        ORDER BY (xsd:integer(STRAFTER(STR(?wd), "http://www.wikidata.org/entity/P")))"""%(Qcode)
    # print(query) 
    endpoint_url = "https://query.wikidata.org/sparql"
    results = get_sparql_results(endpoint_url, query)

    # list_of_wdqcodes = ["wd:" + qcode for qcode in list_of_qcodes]
    # query_check_objects = """SELECT ?qcode ?qcodeLabel WHERE {{
    # SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en,pl". }}
    # VALUES ?qcode {{ {} }}
    # ?qcode wdt:P31 wd:Q5.
    # }}""".format(' '.join(list_of_wdqcodes))

    list_of_triples = []
    for result in results["results"]["bindings"]:
        # print(result['wdLabel']['value'])
        try:
            if result['wdLabel']['value'].__contains__('date'):  # np. Personendatenbank Germania Sacra tu wchodzi, ale to nie data...
                if "http://www.wikidata.org/.well-known" in result['oLabel']['value']:  # http://www.wikidata.org/.well-known/genid/c9a8b2f22783c60e6bf383200d9285f7 czasem są randomowe cosie w miejsach na daty
                    # t = (result['s']['value'], result['wd']['value'], result['o']['datatype'], result['sLabel']['value'], result['wdLabel']['value'], "NoData")
                    # stop = True
                    continue
                else:
                    t = (result['s']['value'], result['wd']['value'], result['o']['datatype'], result['sLabel']['value'], result['wdLabel']['value'], result['oLabel']['value'])
        except KeyError: # Personendatenbank Germania Sacra... 
            pass  # Personendatenbank Germania Sacra... 
        if not allow_literals:
            if result['o']['type'] != 'literal':
                t = (result['s']['value'], result['wd']['value'], result['o']['value'], result['sLabel']['value'], result['wdLabel']['value'], result['oLabel']['value'])
        else:
            t = (result['s']['value'], result['wd']['value'], result['o']['value'], result['sLabel']['value'], result['wdLabel']['value'], result['oLabel']['value'])
        if t not in list_of_triples:
            list_of_triples.append(t)

        # ^ WTF, ten kod wyżej nie ma sensu, nie wiem co myślałem jak to pisałem i ... czemu to działa to z datami? Jeśli result['wdLabel']['value'].__contains__('date') i allow_literals=True, czemu nie daje to błędów? 

    object_qcodes = []
    for t in list_of_triples:
        object_url = t[2]
        if "http://www.wikidata.org/entity/Q" in object_url:
            Qcode = object_url[object_url.rfind('Q'):]
            object_qcodes.append(Qcode)

    return list_of_triples, object_qcodes

# %%
def get_all_human_objects(list_of_qcodes):
    """
    Filters wikidata objects based on provided Qcodes. Returns only objects which are instance_of human.

    Args:
        list_of_qcodes example: ['Q255', Q'1268']
    
    Returns:
        list of tuples representing humans (qcode, wikidata object url, name)
    """
    #  UWAGA:  Z jakiegoś powodu query poniżej zwraca wielokrotnie zduplikowane wyniki, pewnie błąd leży po stronie twórców biblioteki SPARQLWrapper.
    #          To samo zapytanie wprwadzowne w https://query.wikidata.org/ zwraca normalne, nie powielane wyniki.
    #          Poprawiłem to przy przygotowywaniu zwracanego wyniku
    list_of_wdqcodes = ["wd:" + qcode for qcode in list_of_qcodes]
    query_check_objects = """SELECT ?qcode ?qcodeLabel WHERE {{
    SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en,pl". }}
    VALUES ?qcode {{ {} }}
    # ?qcode wdt:P31 wd:Q5.
    }}""".format(' '.join(list_of_wdqcodes))
    endpoint_url="https://query.wikidata.org/sparql"
    humans = get_sparql_results(endpoint_url, query_check_objects)
    urls_qcodes_names = []
    for r in humans["results"]["bindings"]:
        url_qcode_and_name = (r['qcode']['value'][r['qcode']['value'].rfind('Q'):], r['qcode']['value'], r['qcodeLabel']['value'])
        if url_qcode_and_name not in urls_qcodes_names:
            urls_qcodes_names.append(url_qcode_and_name)
    return urls_qcodes_names

# %%
# rdf_dict = dict()
# ALL_VISITED_QCODES = []
# def recursive_get_rdf_info(input_qcodes, level=3):
#     """For each provided qcode gets all rdf triples from wikidata. Also gets all rdf triples for humans associated with provided qcodes.
#     If level=2, then also gets all rdf triples for humans associated with humans associated provided qcodes, etc...

#     Args:
#         input_qcodes (List): list of qcodes
#         level (int, optional): "Depth of the recursive tree". Defaults to 3.

#     Returns:
#         Dict: Dictionary with qcodsccanocfdsgjwkdbfj:)lk]dsgdsa TODO ogarnąć docstringa i funkcję(przyspieszyć/napisać innym sposobem) 
#     """
#     print("Doing: ", input_qcodes)
#     # rdf_dict = dict()
#     global rdf_dict
#     global ALL_VISITED_QCODES
#     current_humans = []
#     length = len(input_qcodes)
#     for i, Q in enumerate(input_qcodes):
#         if Q in ALL_VISITED_QCODES:  # TODO HERE
#             continue
#         triples, all_qcodes = get_all_triples_and_qcodes(Q, allow_literals=True)
#         rdf_dict[Q] = triples
#         ALL_VISITED_QCODES.append(Q)
#         tuples = get_all_human_objects(all_qcodes)
#         humans = [t[0] for t in tuples]  # human qcodes associated with Q qcode
#         for new_qcode in humans:
#             if new_qcode not in current_humans:
#                 current_humans.append(new_qcode)
#             # triples, all_qcodes = get_all_triples_and_qcodes(new_qcode, allow_literals=True)  # czy to jest tu potrzebne??? moze w kolejnym kroku zrobimy get all triples and qcodes tam wyzej, gdy ten qcode czlowiek bedzie w inpucie funkcji.   ... ALL_VISITED_QCODES
#             # rdf_dict[new_qcode] = triples
#         print(f"Level {level} {i+1}/{length}")
#     if level > 1:
#         print("Done: ", input_qcodes)
#         return recursive_get_rdf_info(current_humans, level=level-1)
#     else:  # level == 1
#         print("Done: ", input_qcodes)
#         return rdf_dict

# %%
rdf_dict = dict()
ALL_VISITED_QCODES_WITH_GATHERED_RDF_INFO = []
def recursive_get_rdf_info(input_qcodes, level=3):
    """For each provided qcode gets all rdf triples from wikidata. Also gets all rdf triples for humans associated with provided qcodes.
    If level=2, then also gets all rdf triples for humans associated with humans associated provided qcodes, etc...

    Args:
        input_qcodes (List): list of qcodes
        level (int, optional): "Depth of the recursive tree". Defaults to 3.

    Returns:
        Dict: Dictionary with qcodsccanocfdsgjwkdbfj:)lk]dsgdsa TODO ogarnąć docstringa i funkcję(przyspieszyć/napisać innym sposobem) 
    """
    print("Doing: ", input_qcodes)
    global rdf_dict
    global ALL_VISITED_QCODES_WITH_GATHERED_RDF_INFO
    current_humans = []
    length = len(input_qcodes)

    for i, Q in enumerate(input_qcodes):
        if Q in ALL_VISITED_QCODES:
            continue
        triples, all_qcodes = get_all_triples_and_qcodes(Q, allow_literals=True)
        rdf_dict[Q] = triples
        ALL_VISITED_QCODES_WITH_GATHERED_RDF_INFO.append(Q)
        tuples = get_all_human_objects(all_qcodes)
        humans = [t[0] for t in tuples]  # human qcodes associated with Q qcode

        for new_qcode in humans:
            if new_qcode not in current_humans and new_qcode not in ALL_VISITED_QCODES_WITH_GATHERED_RDF_INFO:
                current_humans.append(new_qcode)

        # for new_qcode in humans:
        #     if new_qcode not in current_humans:
        #         current_humans.append(new_qcode)
        #     triples, all_qcodes = get_all_triples_and_qcodes(new_qcode, allow_literals=True)  # czy to jest tu potrzebne??? moze w kolejnym kroku zrobimy get all triples and qcodes tam wyzej, gdy ten qcode czlowiek bedzie w inpucie funkcji.   ... ALL_VISITED_QCODES
        #     rdf_dict[new_qcode] = triples

        #     if Q in ALL_VISITED_QCODES_WITH_GATHERED_RDF_INFO:
        #         continue

        print(f"Level {level} {i+1}/{length}")
    if level > 0:
        print("Done: ", input_qcodes)
        return recursive_get_rdf_info(current_humans, level=level-1)
    else:  # level == 0
        print("Done: ", input_qcodes)
        return rdf_dict

# %%
ALL_LIST = list()
ALL_DICT = dict()
def return_humans(input_humans, stop_level=4):
    global ALL_DICT
    global ALL_LIST
    if stop_level==0:
        print("reached stop level, not doing ", input_humans)
        return ALL_DICT
    print(f"doing {stop_level}", input_humans)
    humans_new_input = []
    for Q in input_humans:
        if Q not in ALL_LIST:
            triples, qcodes = get_all_triples_and_qcodes(Q, allow_literals=True)
            ALL_DICT[Q] = triples
            ALL_LIST.append(Q)
            humans_new_input += [t[0] for t in get_all_human_objects(qcodes)]
    print("ALL_LIST len = ", len(ALL_LIST))
    return return_humans(humans_new_input, stop_level=stop_level-1)

# %% [markdown]
# # TESTY

# %%
# test_list = ['Q4531778', 'Q102218631', 'Q4410600', 'Q4531778', 'Q112605288', 'Q4535388', 'Q4535389', 'Q4535407', 'Q28500400', 'Q1247154', 'Q4535403', 'Q4535407', 'Q19478933', 'Q110160394', 'Q4375007', 'Q4535407', 'Q12142901', 'Q4375007', 'Q4394319', 'Q4535407', 'Q65034322', 'Q101208715', 'Q102432232', 'Q105839650', 'Q115013896', 'Q55103281', 'Q105839650', 'Q4719881', 'Q2026959', 'Q4719881', 'Q61982644', 'Q107294414', 'Q107294416', 'Q4129572', 'Q4719881', 'Q4719881', 'Q112384645', 'Q1964761', 'Q2067058', 'Q2380794', 'Q4125775', 'Q4155513', 'Q29358858', 'Q61198110', 'Q235611', 'Q1964761', 'Q2380794', 'Q4125775', 'Q21644012', 'Q21711184', 'Q61198110', 'Q104706141', 'Q235611', 'Q1964761', 'Q2067058', 'Q4125775', 'Q61198110', 'Q235611', 'Q1964761', 'Q2067058', 'Q2380794', 'Q2713079', 'Q4125760', 'Q21723130', 'Q61198091', 'Q104634182', 'Q235611', 'Q61198122', 'Q3335862', 'Q3784285', 'Q3784470', 'Q19916444', 'Q61198167', 'Q61198191', 'Q109127940', 'Q2834383', 'Q3784470', 'Q4313557', 'Q61198191', 'Q2834383', 'Q3784285', 'Q3784470', 'Q109127940', 'Q109796556', 'Q109796591', 'Q1651756', 'Q3911020', 'Q3960168', 'Q4111755', 'Q5362962', 'Q5540511', 'Q5623705', 'Q5801949', 'Q7345451', 'Q7509123', 'Q75253381', 'Q75268252', 'Q75276782', 'Q75278573', 'Q76281589', 'Q76297706', 'Q76297708', 'Q337595', 'Q1063510', 'Q3911020', 'Q4111755', 'Q4719715', 'Q7345451', 'Q75253381', 'Q75268252', 'Q75274768', 'Q75276782', 'Q75278573', 'Q75281989', 'Q75631188', 'Q337595', 'Q1651756', 'Q3723423', 'Q3911020', 'Q4111579', 'Q7345451', 'Q75251358', 'Q75253381', 'Q75268252', 'Q75276782', 'Q75278573', 'Q75280057', 'Q75347169', 'Q75347173', 'Q337595', 'Q1651756', 'Q3911020', 'Q4111755', 'Q7794690', 'Q23614621', 'Q75249398', 'Q75251362', 'Q75260050', 'Q75268252', 'Q75276782', 'Q75278573', 'Q75677852', 'Q337595', 'Q1651756', 'Q3911020', 'Q4111755', 'Q5537356', 'Q75253381', 'Q75276782', 'Q75278573', 'Q337595', 'Q1651756', 'Q3911020', 'Q4111755', 'Q7327762', 'Q7327763', 'Q7345437', 'Q75253381', 'Q75268252', 'Q75278573', 'Q75281883', 'Q75281885', 'Q75940386', 'Q337595', 'Q1651756', 'Q3911020', 'Q4111755', 'Q5935407', 'Q75253381', 'Q75268252', 'Q75276782', 'Q4527260', 'Q15060960', 'Q15407959', 'Q18280384', 'Q84720837', 'Q88944302', 'Q984563', 'Q1506392', 'Q11307766', 'Q15060960', 'Q18280384', 'Q102177202', 'Q104368599', 'Q778295', 'Q4527275', 'Q15064867', 'Q20165319', 'Q23925203', 'Q75318089', 'Q75318092', 'Q75318111', 'Q75318160', 'Q101242405', 'Q4125786', 'Q4125787', 'Q4346487', 'Q16389857', 'Q16478232', 'Q16798198', 'Q33381132', 'Q61638016', 'Q76352808', 'Q116247736', 'Q1439976', 'Q4125791', 'Q16389857', 'Q16478232', 'Q16798198', 'Q75391796', 'Q1439976', 'Q4125787', 'Q4527275', 'Q16389857', 'Q16798198', 'Q103942821', 'Q1439976', 'Q4125787', 'Q4523074', 'Q16389857', 'Q16478232', 'Q61637775', 'Q75246898', 'Q75970451', 'Q75970453', 'Q75970454', 'Q75970455', 'Q1439976', 'Q16389857', 'Q76287573', 'Q76352811', 'Q101081838', 'Q1439976', 'Q4308386', 'Q16389857', 'Q4076493', 'Q105957578', 'Q106547622', 'Q106547728', 'Q4076491', 'Q105957578', 'Q106547862', 'Q367109', 'Q4374909', 'Q4767540', 'Q11731188', 'Q91813941', 'Q91813952', 'Q367109', 'Q4374916', 'Q5975640', 'Q9357360', 'Q11125465', 'Q11731188', 'Q11766641', 'Q11769839', 'Q36742', 'Q367109', 'Q1361286', 'Q9256429', 'Q367109', 'Q4374916', 'Q4767540', 'Q5703795', 'Q7599212', 'Q367109', 'Q4374911', 'Q4723654', 'Q6320794', 'Q6761317', 'Q7362134', 'Q12110477', 'Q16200028', 'Q220030', 'Q4723654', 'Q5298213', 'Q6320538', 'Q6420482', 'Q7702125', 'Q16200028', 'Q85538', 'Q220030', 'Q898557', 'Q2506976', 'Q4723654', 'Q6320794', 'Q60391559', 'Q1361286', 'Q2439671', 'Q2832518', 'Q3672163', 'Q5368719', 'Q6306549', 'Q11742831', 'Q975395', 'Q3672163', 'Q5368719', 'Q6306549', 'Q6320568', 'Q11742831', 'Q349948', 'Q690123', 'Q975395', 'Q2439671', 'Q5368719', 'Q6306549', 'Q6761676', 'Q11742831', 'Q36742', 'Q975395', 'Q2439671', 'Q3672163', 'Q6306549', 'Q11742831', 'Q550652', 'Q558139', 'Q975395', 'Q2439671', 'Q3672163', 'Q5368719', 'Q6306549', 'Q100151843', 'Q9151537', 'Q11750339', 'Q975395', 'Q1361286', 'Q4374905', 'Q6968070', 'Q9162035', 'Q11771789', 'Q41414', 'Q2832518', 'Q6968070', 'Q7599129', 'Q9162035', 'Q11742832', 'Q11771789', 'Q2832518', 'Q2972188', 'Q4374905', 'Q6761317', 'Q9162035', 'Q11771789', 'Q2832518', 'Q4374905', 'Q6968070', 'Q9162035', 'Q11686963', 'Q11771794', 'Q25776', 'Q63184609', 'Q25776', 'Q47145827', 'Q65922309', 'Q65922485', 'Q105697795', 'Q105697796', 'Q25776', 'Q11749206', 'Q17552544', 'Q27556004', 'Q105697795', 'Q105697796', 'Q9262636', 'Q107380248', 'Q9262636', 'Q11814387', 'Q3647036', 'Q4767640', 'Q9155230', 'Q9356981', 'Q11731319', 'Q26611', 'Q3920109', 'Q6373177', 'Q11731319', 'Q3136526', 'Q3917274', 'Q11737678', 'Q17045211', 'Q22911301', 'Q63184609', 'Q63184639', 'Q2991218', 'Q3136526', 'Q3917274', 'Q11737678', 'Q17063837', 'Q63184609', 'Q64031190', 'Q380545', 'Q11735941', 'Q11735941', 'Q11735941', 'Q27118276', 'Q27539092', 'Q102536331', 'Q646034', 'Q4394264', 'Q9341597', 'Q63184593', 'Q102536340', 'Q111451587', 'Q4374912', 'Q6836005', 'Q63184593', 'Q105085428']
# t, q = get_all_triples_and_qcodes(Qcode=['Q254', 'Q255', 'Q1268', 'Q9148844', 'Q65095948', 'Q16588072']+test_list, allow_literals=True)
# t, q = get_all_triples_and_qcodes(Qcode='Q254', allow_literals=True)  # TODO sprawdzić działanie get_all_triples_and_qcodes z listą qcodów jako inputem, może będzie szybsze niż pojedyncze szukanie rdfów

# %% [markdown]
# # Input: List of persons ```(names from .txt file)```

# %%
with open("unique_persons.txt", 'r') as f:
    input = [name for name in f.read().splitlines() if len(name.split())!=1]
# input = ['Beethoven', 'Rachmaninoff', 'Mahler', 'Delta rzeki Okawango', 'Susanne Gibson-Milne', 'asfa fafasfs', 'sekwoja', 'Pierre']
input = ['Alojzy Janowicz (pułkownik)', 'Dariusz Gotlib', 'Piotr Franciszek Branicki']
# input = ['Waldemar Izdebski', 'Dariusz Gotlib', 'Jacek Marciniak', 'Robert Olszewski', 'Michał Wyszomirski']

# %%
print(len(input))
input
# Out:
# 3
# ['Alojzy Janowicz (pułkownik)', 'Dariusz Gotlib', 'Piotr Franciszek Branicki']

# %% [markdown]
# # Q-codes for names from input_list ```(Q-codes from wikidata search page)```

# %%
original_persons = scrape_qcodes(list=input, humans_only=True, first_only=True)  # 8m 30s dla 399 osób z listów z pliu .txt
# Out:
# Scraping... 1/4 ... Alojzy Janowicz (pułkownik)
# Scraping... 2/4 ... Dariusz Gotlib
# Scraping... 3/4 ... Piotr Franciszek Branicki
# Scraping... 4/4 ... Alojzy Janowicz

# %%
original_persons.sort(key=lambda d: d['search_name'])
print(len(original_persons))
original_persons
# Out:
# 3
# [{'search_name': 'Alojzy Janowicz ',
#   'page_name': 'Alojzy Janowicz',
#   'description': None,
#   'Qcode': 'Q9148844',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q9148844'},
#  {'search_name': 'Dariusz Gotlib',
#   'page_name': 'Dariusz Gotlib',
#   'description': 'Polish engineer',
#   'Qcode': 'Q65095948',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q65095948'},
#  {'search_name': 'Piotr Franciszek Branicki',
#   'page_name': 'Q16588072',
#   'description': None,
#   'Qcode': 'Q16588072',
#   'wiki_url': 'https://www.wikidata.org/wiki/Q16588072'}]

# %%
input_qcodes = [d['Qcode'] for d in original_persons]
input_qcodes
# Out:
# ['Q9148844', 'Q65095948', 'Q16588072']

# %%
input_persons_wo_qcode = set(input) - {d['search_name'] for d in original_persons}
# with open ("input_persons_wo_qcode.txt", "w") as f:
#     f.write(str(input_persons_wo_qcode))
print(len(input_persons_wo_qcode))
input_persons_wo_qcode
# Out:
# 1
# {'Alojzy Janowicz (pułkownik)'}

# %%
extra_persons_w_qcode = {d['search_name'] for d in original_persons} - set(input)
# with open ("extra_persons_w_qcode.txt", "w") as f:
#     f.write(str(extra_persons_w_qcode))
print(len(extra_persons_w_qcode))
extra_persons_w_qcode
# Out:
# 1
# {'Alojzy Janowicz '}

# %% [markdown]
# # Humans associated with names from original_list ```(N levels of depth...)```

# %%
# SLOW... prszyspeszyć działanie funkcji TODO
# oho, już widzę jeden błąd... dla level=5 i input = ['Waldemar Izdebski', 'Dariusz Gotlib', 'Jacek Marciniak', 'Robert Olszewski', 'Michał Wyszomirski']... (naprawioned? dodałem ALL_VISITED_QCODES... work in progress)

# rdf_info = recursive_get_rdf_info(input_qcodes, level=5)
rdf_info = return_humans(input_qcodes, stop_level=6)
# Out:
# doing 6 ['Q9148844', 'Q65095948', 'Q16588072']
# ALL_LIST len =  3
# doing 5 ['Q1349049', 'Q9253321', 'Q26882450', 'Q105679898']
# ALL_LIST len =  7
# doing 4 ['Q2028738', 'Q2670161', 'Q4125793', 'Q8073362', 'Q11737046', 'Q16588072', 'Q26882450', 'Q26882457', 'Q2628182', 'Q16588072', 'Q40989542', 'Q1349049', 'Q16588072', 'Q24263182', 'Q16588072']
# ALL_LIST len =  16
# doing 3 ['Q1349049', 'Q2670161', 'Q4095822', 'Q4125793', 'Q6375196', 'Q7386598', 'Q8073362', 'Q9252846', 'Q9382095', 'Q11737046', 'Q11742884', 'Q11750335', 'Q26882457', 'Q97497657', 'Q1349049', 'Q2028738', 'Q4125793', 'Q8073362', 'Q11737046', 'Q26882457', 'Q61809857', 'Q61809861', 'Q466151', 'Q1349049', 'Q2028738', 'Q2670161', 'Q4125779', 'Q8073362', 'Q11737046', 'Q26882457', 'Q61637815', 'Q1349049', 'Q2028738', 'Q2670161', 'Q4125793', 'Q4801655', 'Q9139711', 'Q11737046', 'Q26882457', 'Q1349049', 'Q2028738', 'Q2670161', 'Q4125793', 'Q6961400', 'Q8073362', 'Q9146738', 'Q26882457', 'Q1349049', 'Q2028738', 'Q2670161', 'Q4125793', 'Q8073362', 'Q11737046', 'Q9253321', 'Q40989542', 'Q2628182', 'Q3920112', 'Q9253321', 'Q63184580', 'Q26882450']
# ALL_LIST len =  35
# doing 2 ['Q2028738', 'Q6375196', 'Q7386598', 'Q104519534', 'Q457413', 'Q2028738', 'Q4095822', 'Q4801684', 'Q7386598', 'Q7386600', 'Q9139711', 'Q9391911', 'Q2028738', 'Q2440428', 'Q4095822', 'Q4222109', 'Q4374904', 'Q4776193', 'Q6320792', 'Q6375196', 'Q6429869', 'Q6961400', 'Q7253406', 'Q9176889', 'Q9252846', 'Q9382095', 'Q9382789', 'Q11685100', 'Q11742884', 'Q11750335', 'Q11779943', 'Q18590242', 'Q29932576', 'Q97497657', 'Q110393958', 'Q245355', 'Q2028738', 'Q4237839', 'Q7386598', 'Q2028738', 'Q4284239', 'Q7386598', 'Q62780720', 'Q2028738', 'Q4095822', 'Q6121572', 'Q7386598', 'Q11750332', 'Q2028738', 'Q7386598', 'Q2028738', 'Q7386598', 'Q17328870', 'Q43255437', 'Q1995842', 'Q2073326', 'Q2670161', 'Q4531778', 'Q4535407', 'Q61809861', 'Q105839650', 'Q112384637', 'Q1995842', 'Q2073326', 'Q2670161', 'Q4531778', 'Q4535407', 'Q4719881', 'Q61809857', 'Q105839650', 'Q107294416', 'Q1964761', 'Q3784470', 'Q3911020', 'Q4125779', 'Q4125793', 'Q61637815', 'Q466151', 'Q4125793', 'Q466151', 'Q4125793', 'Q15060960', 'Q16389857', 'Q105957578', 'Q367109', 'Q4723654', 'Q6306549', 'Q8073362', 'Q9139711', 'Q9151537', 'Q457413', 'Q4801655', 'Q4801684', 'Q6375196', 'Q7386600', 'Q8073362', 'Q9391911', 'Q2440428', 'Q4222109', 'Q4374904', 'Q6320792', 'Q6429869', 'Q7386598', 'Q9146738', 'Q9176889', 'Q9382789', 'Q11685100', 'Q11737046', 'Q11779943', 'Q18590242', 'Q29932576', 'Q6961400', 'Q9162035', 'Q11737046', 'Q25776', 'Q9262636', 'Q11731319', 'Q11733366', 'Q40989542', 'Q63184580', 'Q63184609', 'Q3920112', 'Q9262636', 'Q11731319', 'Q11733366', 'Q11735941', 'Q40989542', 'Q63184593']
# ALL_LIST len =  88
# doing 1 ['Q4095822', 'Q2060128', 'Q4801684', 'Q6375196', 'Q7386600', 'Q9139711', 'Q9391911', 'Q457413', 'Q6375196', 'Q7386594', 'Q7386600', 'Q9139711', 'Q9391911', 'Q93160853', 'Q55841', 'Q457413', 'Q4237839', 'Q4801684', 'Q5341534', 'Q6375196', 'Q9139711', 'Q9139852', 'Q9391911', 'Q457413', 'Q4801684', 'Q6375196', 'Q7386600', 'Q7606336', 'Q8041258', 'Q9139711', 'Q2587802', 'Q2977753', 'Q4222109', 'Q4374904', 'Q5553282', 'Q6320792', 'Q6429869', 'Q6961400', 'Q7386598', 'Q9176889', 'Q9382789', 'Q11685100', 'Q11779943', 'Q18590242', 'Q22970782', 'Q29932576', 'Q64339371', 'Q106575217', 'Q110394707', 'Q717801', 'Q2440428', 'Q2977753', 'Q4374904', 'Q6961400', 'Q7386598', 'Q9176889', 'Q9382789', 'Q11685100', 'Q11779943', 'Q18590242', 'Q1978660', 'Q2440428', 'Q2977753', 'Q4222109', 'Q6961400', 'Q7386598', 'Q9176889', 'Q9382789', 'Q11685100', 'Q11779943', 'Q18590242', 'Q104474913', 'Q6320574', 'Q6699467', 'Q7253406', 'Q7386598', 'Q110393958', 'Q58428', 'Q2440428', 'Q6429869', 'Q6961400', 'Q7386598', 'Q9149354', 'Q9382789', 'Q18590242', 'Q29932576', 'Q64339371', 'Q106575217', 'Q110394707', 'Q367109', 'Q1293297', 'Q2440428', 'Q6320792', 'Q6961400', 'Q7386598', 'Q9151537', 'Q9382789', 'Q18590242', 'Q29932576', 'Q4776193', 'Q7386598', 'Q7599108', 'Q107380248', 'Q2440428', 'Q2977753', 'Q4222109', 'Q4374904', 'Q6961400', 'Q7386598', 'Q9382789', 'Q11685100', 'Q11779943', 'Q15340362', 'Q18590242', 'Q109128842', 'Q2440428', 'Q4222109', 'Q4374904', 'Q6320792', 'Q6429869', 'Q6961400', 'Q7386598', 'Q9176889', 'Q11685100', 'Q11779943', 'Q18590242', 'Q29932576', 'Q2440428', 'Q2977753', 'Q4222109', 'Q4374904', 'Q6961400', 'Q7386598', 'Q9176889', 'Q9382789', 'Q11779943', 'Q18590242', 'Q2440428', 'Q2977753', 'Q3021581', 'Q4222109', 'Q4374904', 'Q6961400', 'Q7386598', 'Q9176889', 'Q9382789', 'Q11685100', 'Q18590242', 'Q21591124', 'Q2440428', 'Q4222109', 'Q4374904', 'Q6320792', 'Q6429869', 'Q6961400', 'Q7386598', 'Q9176889', 'Q9382789', 'Q11685100', 'Q11779943', 'Q29932576', 'Q2440428', 'Q3920403', 'Q3920420', 'Q6320792', 'Q6429869', 'Q6961400', 'Q7386598', 'Q9382789', 'Q11814387', 'Q18590242', 'Q67131119', 'Q75519293', 'Q75528170', 'Q514713', 'Q4776193', 'Q7386598', 'Q9341534', 'Q28973658', 'Q98593668', 'Q107379994', 'Q5679', 'Q9235', 'Q60070', 'Q79025', 'Q176163', 'Q888263', 'Q2255276', 'Q4237839', 'Q6761045', 'Q9252846', 'Q64024895', 'Q245355', 'Q6761045', 'Q7386600', 'Q9139852', 'Q9252846', 'Q36450', 'Q2079114', 'Q4284126', 'Q9382095', 'Q11736206', 'Q13031216', 'Q62780720', 'Q75330584', 'Q75330678', 'Q75330723', 'Q3920403', 'Q4284239', 'Q9382095', 'Q62882758', 'Q6149595', 'Q7386596', 'Q7599119', 'Q11742884', 'Q11750332', 'Q6121572', 'Q11684270', 'Q11742884', 'Q43255437', 'Q76281374', 'Q97497657', 'Q17328870', 'Q43255418', 'Q63255363', 'Q97497657', 'Q276487', 'Q4264001', 'Q10357801', 'Q61809573', 'Q61809857', 'Q61809861', 'Q3434234', 'Q4141563', 'Q4141564', 'Q4141593', 'Q15065427', 'Q16637490', 'Q61809857', 'Q61809861', 'Q108843934', 'Q12103888', 'Q47393713', 'Q61809857', 'Q61809861', 'Q112605315', 'Q1247154', 'Q4535388', 'Q12142898', 'Q28500400', 'Q61809857', 'Q61809861', 'Q15060863', 'Q61809857', 'Q61809861', 'Q105839669', 'Q61809857', 'Q116877323', 'Q243201', 'Q61809861', 'Q104870236', 'Q106834602', 'Q112384642', 'Q243201', 'Q61809861', 'Q104870236', 'Q106834602', 'Q235611', 'Q466151', 'Q2067058', 'Q2380794', 'Q3784470', 'Q3911020', 'Q4125775', 'Q61198110', 'Q466151', 'Q1964761', 'Q2834383', 'Q3784285', 'Q3911020', 'Q61198191', 'Q337595', 'Q466151', 'Q1651756', 'Q1964761', 'Q3784470', 'Q4111755', 'Q75253381', 'Q75268252', 'Q75276782', 'Q75278573', 'Q984563', 'Q16389857', 'Q61637815', 'Q84720837', 'Q105957578', 'Q643004', 'Q1439976', 'Q4125787', 'Q15060960', 'Q16478232', 'Q16798198', 'Q61637815', 'Q76352808', 'Q116247736', 'Q4076491', 'Q4076493', 'Q15060960', 'Q61637815', 'Q4374916', 'Q4723654', 'Q4767540', 'Q4801655', 'Q6306549', 'Q6429869', 'Q9151537', 'Q11718497', 'Q11731188', 'Q98270879', 'Q220030', 'Q367109', 'Q4801655', 'Q6306549', 'Q6320794', ...
# ALL_LIST len =  236
# reached stop level, not doing  ['Q457413', 'Q2506397', 'Q2584741', 'Q2626847', 'Q6375220', 'Q9342860', 'Q26903834', 'Q675408', 'Q4801684', 'Q5764903', 'Q9160738', 'Q11742940', 'Q93160853', 'Q4801684', 'Q7386594', 'Q9255980', 'Q28973658', 'Q5341534', 'Q7386600', 'Q20028199', 'Q76071149', 'Q55841', 'Q6761045', 'Q7386600', 'Q9311770', 'Q11736274', 'Q4237839', 'Q7386600', 'Q8041258', 'Q8068123', 'Q9391911', 'Q7606012', 'Q7606336', 'Q9391911', 'Q2440428', 'Q10018149', 'Q22970782', 'Q22970794', 'Q28811997', 'Q114637673', 'Q1977625', 'Q2440428', 'Q4222109', 'Q4374904', 'Q9176889', 'Q11685100', 'Q11731689', 'Q11779943', 'Q2440428', 'Q16561043', 'Q2440428', 'Q2587802', 'Q7599212', 'Q22978336', 'Q114637673', 'Q2440428', 'Q2977753', 'Q6320792', 'Q9176889', 'Q2440428', 'Q3123862', 'Q6320792', 'Q444445', 'Q2440428', 'Q6320792', 'Q110394399', 'Q110394796', 'Q111028469', 'Q114086205', 'Q4222109', 'Q104665676', 'Q114797050', 'Q114797093', 'Q114837271', 'Q2833841', 'Q3784285', 'Q4313560', 'Q4374904', 'Q104474913', 'Q1978660', 'Q4374904', 'Q15060958', 'Q18280384', 'Q75376569', 'Q101082110', 'Q104474754', 'Q104475101', 'Q104475363', 'Q4374918', 'Q4776193', 'Q6699467', 'Q11731189', 'Q936342', 'Q4776193', 'Q6320574', 'Q58424', 'Q58426', 'Q6150019', 'Q6320792', 'Q9149354', 'Q67147086', 'Q58428', 'Q214949', 'Q6320792', 'Q75396887', 'Q6429869', 'Q9259607', 'Q9311770', 'Q87112319', 'Q6149595', 'Q7253406', 'Q9155125', 'Q7253406', 'Q11780890', 'Q107380259', 'Q4406026', 'Q9176889', 'Q15344816', 'Q109128842', 'Q4444046', 'Q9176889', 'Q15060896', 'Q15340362', 'Q11779943', 'Q11779943', 'Q20789776', 'Q3920420', 'Q11718640', 'Q29932576', 'Q62780720', 'Q62882758', 'Q75826009', 'Q2607550', 'Q3920403', 'Q11766000', 'Q29932576', 'Q67131119', 'Q9262636', 'Q29932576', 'Q75519293', 'Q75528170', 'Q75625422', 'Q3920420', 'Q6430255', 'Q7818392', 'Q29932576', 'Q67131094', 'Q11814387', 'Q29932576', 'Q75519294', 'Q75519297', 'Q75519298', 'Q75519311', 'Q75519313', 'Q75519362', 'Q75519364', 'Q11814387', 'Q29932576', 'Q75330563', 'Q75530746', 'Q4185792', 'Q8073357', 'Q9341534', 'Q28973658', 'Q98593668', 'Q107379994', 'Q110393958', 'Q514713', 'Q17095533', 'Q110393958', 'Q514713', 'Q8545241', 'Q9255980', 'Q9345168', 'Q9382057', 'Q93160853', 'Q110393958', 'Q514713', 'Q9152782', 'Q11285857', 'Q11294112', 'Q110393958', 'Q514713', 'Q107379986', 'Q107380004', 'Q110393958', 'Q7259', 'Q45546', 'Q251926', 'Q272161', 'Q276241', 'Q453699', 'Q460066', 'Q631635', 'Q2837843', 'Q6217401', 'Q21438188', 'Q63645174', 'Q859', 'Q868', 'Q6527', 'Q9191', 'Q9312', 'Q15975', 'Q35802', 'Q41155', 'Q43939', 'Q60070', 'Q64623', 'Q76576', 'Q76725', 'Q77017', 'Q86130', 'Q102585', 'Q134189', 'Q154751', 'Q271809', 'Q21198339', 'Q22340304', 'Q102515598', 'Q102515921', 'Q859', 'Q5879', 'Q9047', 'Q9235', 'Q9312', 'Q35802', 'Q36330', 'Q63928', 'Q75889', 'Q77017', 'Q91342', 'Q97296', 'Q102585', 'Q102875', 'Q155547', 'Q168004', 'Q611233', 'Q1479519', 'Q1613305', 'Q1693342', 'Q1693612', 'Q2063773', 'Q12780018', 'Q15832909', 'Q55127316', 'Q94766239', 'Q22230907', 'Q61716917', 'Q75914101', 'Q75960521', 'Q75960526', 'Q75960528', 'Q75960529', 'Q245355', 'Q11718128', 'Q29653042', 'Q64024895', 'Q9235', 'Q60070', 'Q245355', 'Q4237839', 'Q5341534', 'Q11736274', 'Q245355', 'Q888263', 'Q62090851', 'Q64024926', 'Q15189', 'Q54019', 'Q61826', 'Q69255', 'Q151789', 'Q243201', 'Q540752', 'Q699473', 'Q2040517', 'Q3609589', 'Q4269209', 'Q4283756', 'Q4284126', 'Q4284239', 'Q11736206', 'Q13031216', 'Q62780763', 'Q77711', 'Q454204', 'Q2079114', 'Q3919822', 'Q4284239', 'Q11736206', 'Q13031216', 'Q28949706', 'Q28949767', 'Q75330584', 'Q75330678', 'Q75330723', 'Q2079114', 'Q4284126', 'Q4284239', 'Q11714732', 'Q13031216', 'Q75330556', 'Q2079114', 'Q4284126', 'Q4284239', 'Q11736206', 'Q75330578', 'Q75330579', 'Q75330580', 'Q4284126', 'Q4284239', 'Q27516690', 'Q75330587', 'Q75330603', 'Q75330636', 'Q75330640', 'Q75330671', 'Q4284126', 'Q4284239', 'Q75330681', 'Q75330682', 'Q75330685', 'Q75330693', 'Q75330700', 'Q75330702', 'Q75330705', 'Q75 ...

# %%
# ^ czas działania recursive_get_rdf_info:
# rdf_info = recursive_get_rdf_info(input_qcodes, level=2)      # działało 3m 36s dla input-codes=['Q131861', 'Q255'] i zwróciło rdf_info dla 228 osób (104772 linijek słownika)
# rdf_info = recursive_get_rdf_info(input_qcodes, level=2)      # działało 41s dla input-codes=['Q131861'] i zwróciło rdf_info dla 36 osób (17376 linijek słownika)

# rdf_info = recursive_get_rdf_info(input_qcodes, level=3)      # działało 423m 35s dla input_codes z pliku .txt (399 osób (>1 słowo) z listów Chopina i Paderewskiego); len(rdf_info.keys())=13171; rdf_info 5 mln linijek;
                                                                # 180 MB json z indent=4; 117MB json w jednej linijce;

# recursive_get_rdf_info(input_qcodes, level=3) 18m 40s ['Q9148844', 'Q65095948', 'Q16588072', 'Q254']  len(rdf_info.keys())=571
# recursive_get_rdf_info(input_qcodes, level=3) 1m 7s ['Q9148844', 'Q65095948', 'Q16588072']  len(rdf_info.keys())=33

# %%
# input = ['Alojzy Janowicz (pułkownik)', 'Dariusz Gotlib', 'Piotr Franciszek Branicki']
# 4m 40s len(rdf_info.keys())=236 len(all_humans) = 643 recursive_get_rdf_info(input_qcodes, level=5) V poprzednia z jednym ALL_COSTAM
# 1m 2s  len(rdf_info.keys())=88 len(all_humans) = 236 recursive_get_rdf_info(input_qcodes, level=5) V terazniejsza - zakomentowana
# 2m 54s len(rdf_info.keys())=236 len(all_humans) = 643 recursive_get_rdf_info(input_qcodes, level=6) V terazniejsza - zakomentowana
# 3m 50s len(rdf_info.keys())=236 len(all_humans) = 643 recursive_get_rdf_info(input_qcodes, level=5) V terazniejsza eskperymenty
# 2m 42s len(rdf_info.keys())=236 len(all_humans) = 643 return_humans(input_qcodes, stop_level=6) V terazniejsza return_humans
print(f"{len(rdf_info.keys())=}")
rdf_info
# Out:
# len(rdf_info.keys())=236
# {'Q9148844': [('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P20',
#    'http://www.wikidata.org/entity/Q171689',
#    'Alojzy Janowicz',
#    'place of death',
#    '12th arrondissement of Paris'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581097',
#    'Alojzy Janowicz',
#    'sex or gender',
#    'male'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P27',
#    'http://www.wikidata.org/entity/Q172107',
#    'Alojzy Janowicz',
#    'country of citizenship',
#    'Polish–Lithuanian Commonwealth'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Alojzy Janowicz',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P53',
#    'http://www.wikidata.org/entity/Q63531372',
#    'Alojzy Janowicz',
#    'family',
#    'Janowiczowie herbu Radwan'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P119',
#    'http://www.wikidata.org/entity/Q746647',
#    'Alojzy Janowicz',
#    'place of burial',
#    'Montmartre Cemetery'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q21877407',
#    'Alojzy Janowicz',
#    'award received',
#    'Gold Cross of the Virtuti Militari'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q21877428',
#    'Alojzy Janowicz',
#    'award received',
#    "Knight's Cross of the Virtuti Militari"),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P214',
#    '9487151778243718130009',
#    'Alojzy Janowicz',
#    'VIAF ID',
#    '9487151778243718130009'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P569',
#    '1792-01-01T00:00:00Z',
#    'Alojzy Janowicz',
#    'date of birth',
#    '1792-01-01T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P570',
#    '1849-07-27T00:00:00Z',
#    'Alojzy Janowicz',
#    'date of death',
#    '1849-07-27T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P735',
#    'http://www.wikidata.org/entity/Q4734282',
#    'Alojzy Janowicz',
#    'given name',
#    'Alojzy'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P7293',
#    '9810592819405606',
#    'Alojzy Janowicz',
#    'PLWABN ID',
#    '9810592819405606'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P7859',
#    'viaf-9487151778243718130009',
#    'Alojzy Janowicz',
#    'WorldCat Identities ID',
#    'viaf-9487151778243718130009'),
#   ('http://www.wikidata.org/entity/Q9148844',
#    'http://www.wikidata.org/entity/P8172',
#    '8.395.19',
#    'Alojzy Janowicz',
#    'Sejm-Wielki.pl profile ID',
#    '8.395.19')],
#  'Q65095948': [('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581097',
#    'Dariusz Gotlib',
#    'sex or gender',
#    'male'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P27',
#    'http://www.wikidata.org/entity/Q36',
#    'Dariusz Gotlib',
#    'country of citizenship',
#    'Poland'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Dariusz Gotlib',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P69',
#    'http://www.wikidata.org/entity/Q1718656',
#    'Dariusz Gotlib',
#    'educated at',
#    'Warsaw University of Technology'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P106',
#    'http://www.wikidata.org/entity/Q1734662',
#    'Dariusz Gotlib',
#    'occupation',
#    'cartographer'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P108',
#    'http://www.wikidata.org/entity/Q1718656',
#    'Dariusz Gotlib',
#    'employer',
#    'Warsaw University of Technology'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P214',
#    '251004359',
#    'Dariusz Gotlib',
#    'VIAF ID',
#    '251004359'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P496',
#    '0000-0001-7532-4497',
#    'Dariusz Gotlib',
#    'ORCID iD',
#    '0000-0001-7532-4497'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P569',
#    '1971-09-09T00:00:00Z',
#    'Dariusz Gotlib',
#    'date of birth',
#    '1971-09-09T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P734',
#    'http://www.wikidata.org/entity/Q36955693',
#    'Dariusz Gotlib',
#    'family name',
#    'Gotlib'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P735',
#    'http://www.wikidata.org/entity/Q1166014',
#    'Dariusz Gotlib',
#    'given name',
#    'Dariusz'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P1153',
#    '55604936800',
#    'Dariusz Gotlib',
#    'Scopus author ID',
#    '55604936800'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P1412',
#    'http://www.wikidata.org/entity/Q809',
#    'Dariusz Gotlib',
#    'languages spoken, written or signed',
#    'Polish'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P1559',
#    'Dariusz Gotlib',
#    'Dariusz Gotlib',
#    'name in native language',
#    'Dariusz Gotlib'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P2671',
#    '/g/11fl8_xqj0',
#    'Dariusz Gotlib',
#    'Google Knowledge Graph ID',
#    '/g/11fl8_xqj0'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P3124',
#    '103937',
#    'Dariusz Gotlib',
#    'Polish scientist ID',
#    '103937'),
#   ('http://www.wikidata.org/entity/Q65095948',
#    'http://www.wikidata.org/entity/P7293',
#    '9810617045805606',
#    'Dariusz Gotlib',
#    'PLWABN ID',
#    '9810617045805606')],
#  'Q16588072': [('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P20',
#    'http://www.wikidata.org/entity/Q36036',
#    'Piotr Franciszek Branicki',
#    'place of death',
#    'Lviv'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581097',
#    'Piotr Franciszek Branicki',
#    'sex or gender',
#    'male'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P22',
#    'http://www.wikidata.org/entity/Q105679898',
#    'Piotr Franciszek Branicki',
#    'father',
#    'Branicki Józef'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P26',
#    'http://www.wikidata.org/entity/Q26882450',
#    'Piotr Franciszek Branicki',
#    'spouse',
#    'Waleria Melania Szembek'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P27',
#    'http://www.wikidata.org/entity/Q172107',
#    'Piotr Franciszek Branicki',
#    'country of citizenship',
#    'Polish–Lithuanian Commonwealth'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Piotr Franciszek Branicki',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q11743102',
#    'Piotr Franciszek Branicki',
#    'position held',
#    'Confederate of the Confederacy'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q13133493',
#    'Piotr Franciszek Branicki',
#    'position held',
#    'kasztelan bracławski'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q28934332',
#    'Piotr Franciszek Branicki',
#    'position held',
#    'deputy to the Sejm of the First Polish Republic'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q66791441',
#    'Piotr Franciszek Branicki',
#    'position held',
#    'chorąży halicki'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q1349049',
#    'Piotr Franciszek Branicki',
#    'child',
#    'Franciszek Ksawery Branicki'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q9253321',
#    'Piotr Franciszek Branicki',
#    'child',
#    'Elżbieta Branicka'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P53',
#    'http://www.wikidata.org/entity/Q3064992',
#    'Piotr Franciszek Branicki',
#    'family',
#    'Branicki (Korczak) family'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q84020',
#    'Piotr Franciszek Branicki',
#    'award received',
#    'Order of the White Eagle'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P214',
#    '311600917',
#    'Piotr Franciszek Branicki',
#    'VIAF ID',
#    '311600917'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P227',
#    '1061112535',
#    'Piotr Franciszek Branicki',
#    'GND ID',
#    '1061112535'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P410',
#    'http://www.wikidata.org/entity/Q640375',
#    'Piotr Franciszek Branicki',
#    'military rank',
#    'cavalry master'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P570',
#    '1762-02-14T00:00:00Z',
#    'Piotr Franciszek Branicki',
#    'date of death',
#    '1762-02-14T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P734',
#    'http://www.wikidata.org/entity/Q21448614',
#    'Piotr Franciszek Branicki',
#    'family name',
#    'Branicki'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P735',
#    'http://www.wikidata.org/entity/Q15897269',
#    'Piotr Franciszek Branicki',
#    'given name',
#    'Piotr'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P1185',
#    '417194',
#    'Piotr Franciszek Branicki',
#    'Rodovid ID',
#    '417194'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P1343',
#    'http://www.wikidata.org/entity/Q1485141',
#    'Piotr Franciszek Branicki',
#    'described by source',
#    'Polish Biographical Dictionary'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P1819',
#    'I00093555',
#    'Piotr Franciszek Branicki',
#    'genealogics.org person ID',
#    'I00093555'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P1871',
#    'cnp02113470',
#    'Piotr Franciszek Branicki',
#    'CERL Thesaurus ID',
#    'cnp02113470'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P2671',
#    '/g/1yg58j447',
#    'Piotr Franciszek Branicki',
#    'Google Knowledge Graph ID',
#    '/g/1yg58j447'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P4159',
#    'Piotr_Branicki_(1)',
#    'Piotr Franciszek Branicki',
#    'WeRelate person ID',
#    'Piotr_Branicki_(1)'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P7293',
#    '9810618748105606',
#    'Piotr Franciszek Branicki',
#    'PLWABN ID',
#    '9810618748105606'),
#   ('http://www.wikidata.org/entity/Q16588072',
#    'http://www.wikidata.org/entity/P8172',
#    '2.261.75',
#    'Piotr Franciszek Branicki',
#    'Sejm-Wielki.pl profile ID',
#    '2.261.75')],
#  'Q1349049': [('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P18',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/Franciszek%20Ksawery%20Branicki.jpg',
#    'Franciszek Ksawery Branicki',
#    'image',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/Franciszek%20Ksawery%20Branicki.jpg'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P19',
#    'http://www.wikidata.org/entity/Q270',
#    'Franciszek Ksawery Branicki',
#    'place of birth',
#    'Warsaw'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P20',
#    'http://www.wikidata.org/entity/Q33342',
#    'Franciszek Ksawery Branicki',
#    'place of death',
#    'Bila Tserkva'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581097',
#    'Franciszek Ksawery Branicki',
#    'sex or gender',
#    'male'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P22',
#    'http://www.wikidata.org/entity/Q16588072',
#    'Franciszek Ksawery Branicki',
#    'father',
#    'Piotr Franciszek Branicki'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P25',
#    'http://www.wikidata.org/entity/Q26882450',
#    'Franciszek Ksawery Branicki',
#    'mother',
#    'Waleria Melania Szembek'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P26',
#    'http://www.wikidata.org/entity/Q2670161',
#    'Franciszek Ksawery Branicki',
#    'spouse',
#    'Alexandra von Engelhardt'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P27',
#    'http://www.wikidata.org/entity/Q34266',
#    'Franciszek Ksawery Branicki',
#    'country of citizenship',
#    'Russian Empire'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P27',
#    'http://www.wikidata.org/entity/Q172107',
#    'Franciszek Ksawery Branicki',
#    'country of citizenship',
#    'Polish–Lithuanian Commonwealth'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Franciszek Ksawery Branicki',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q121998',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'ambassador'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q185106',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'Artillery General of Lithuania'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q467899',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'field crown hetman'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q2596808',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'Regimentarz'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q2631485',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'great crown hetman'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q9394406',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'łowczy wielki koronny'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q11743102',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'Confederate of the Confederacy'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q11820704',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'Podstola the Great Crown'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q28934332',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'deputy to the Sejm of the First Polish Republic'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q30041909',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'Polish elector'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q64786742',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'starosta przemyski'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q65108095',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'starosta halicki'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q65113895',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'starosta białocerkiewski'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q66200890',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'starosta jaworowski'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q66200911',
#    'Franciszek Ksawery Branicki',
#    'position held',
#    'starosta lubomelski'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q2028738',
#    'Franciszek Ksawery Branicki',
#    'child',
#    'Władysław Grzegorz Branicki'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q4125793',
#    'Franciszek Ksawery Branicki',
#    'child',
#    'Elizaveta Vorontsova'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q8073362',
#    'Franciszek Ksawery Branicki',
#    'child',
#    'Zofia Branicka'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q11737046',
#    'Franciszek Ksawery Branicki',
#    'child',
#    'Katarzyna Branicka'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q26882457',
#    'Franciszek Ksawery Branicki',
#    'child',
#    'Aleksander Branicki'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P53',
#    'http://www.wikidata.org/entity/Q3064992',
#    'Franciszek Ksawery Branicki',
#    'family',
#    'Branicki (Korczak) family'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P94',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/POL%20COA%20Korczak.svg',
#    'Franciszek Ksawery Branicki',
#    'coat of arms image',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/POL%20COA%20Korczak.svg'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P106',
#    'http://www.wikidata.org/entity/Q82955',
#    'Franciszek Ksawery Branicki',
#    'occupation',
#    'politician'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P106',
#    'http://www.wikidata.org/entity/Q193391',
#    'Franciszek Ksawery Branicki',
#    'occupation',
#    'diplomat'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P106',
#    'http://www.wikidata.org/entity/Q4991371',
#    'Franciszek Ksawery Branicki',
#    'occupation',
#    'soldier'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P140',
#    'http://www.wikidata.org/entity/Q1841',
#    'Franciszek Ksawery Branicki',
#    'religion or worldview',
#    'Catholicism'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q84020',
#    'Franciszek Ksawery Branicki',
#    'award received',
#    'Order of the White Eagle'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q113403',
#    'Franciszek Ksawery Branicki',
#    'award received',
#    'Order of Saint Stanislaus'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q1126563',
#    'Franciszek Ksawery Branicki',
#    'award received',
#    'Order of St. Andrew'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q15831432',
#    'Franciszek Ksawery Branicki',
#    'award received',
#    'Knight of the Order of St. Alexander Nevsky'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P213',
#    '0000 0001 0978 1171',
#    'Franciszek Ksawery Branicki',
#    'ISNI',
#    '0000 0001 0978 1171'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P214',
#    '60215691',
#    'Franciszek Ksawery Branicki',
#    'VIAF ID',
#    '60215691'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P227',
#    '131484699',
#    'Franciszek Ksawery Branicki',
#    'GND ID',
#    '131484699'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P373',
#    'Franciszek Ksawery Branicki',
#    'Franciszek Ksawery Branicki',
#    'Commons category',
#    'Franciszek Ksawery Branicki'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P410',
#    'http://www.wikidata.org/entity/Q83460',
#    'Franciszek Ksawery Branicki',
#    'military rank',
#    'general'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P463',
#    'http://www.wikidata.org/entity/Q911889',
#    'Franciszek Ksawery Branicki',
#    'member of',
#    'Targowica Confederation'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P551',
#    'http://www.wikidata.org/entity/Q656',
#    'Franciszek Ksawery Branicki',
#    'residence',
#    'Saint Petersburg'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P551',
#    'http://www.wikidata.org/entity/Q33342',
#    'Franciszek Ksawery Branicki',
#    'residence',
#    'Bila Tserkva'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P551',
#    'http://www.wikidata.org/entity/Q974468',
#    'Franciszek Ksawery Branicki',
#    'residence',
#    'Liuboml'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P569',
#    '1731-01-01T00:00:00Z',
#    'Franciszek Ksawery Branicki',
#    'date of birth',
#    '1731-01-01T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P570',
#    '1819-01-01T00:00:00Z',
#    'Franciszek Ksawery Branicki',
#    'date of death',
#    '1819-01-01T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P646',
#    '/m/048k_w',
#    'Franciszek Ksawery Branicki',
#    'Freebase ID',
#    '/m/048k_w'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P691',
#    'js2011661310',
#    'Franciszek Ksawery Branicki',
#    'NKCR AUT ID',
#    'js2011661310'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P734',
#    'http://www.wikidata.org/entity/Q21448614',
#    'Franciszek Ksawery Branicki',
#    'family name',
#    'Branicki'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P735',
#    'http://www.wikidata.org/entity/Q15207702',
#    'Franciszek Ksawery Branicki',
#    'given name',
#    'Franciszek'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P945',
#    'http://www.wikidata.org/entity/Q34266',
#    'Franciszek Ksawery Branicki',
#    'allegiance',
#    'Russian Empire'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P973',
#    'https://www.polskipetersburg.pl/hasla/branicki-franciszek-ksawery',
#    'Franciszek Ksawery Branicki',
#    'described at URL',
#    'https://www.polskipetersburg.pl/hasla/branicki-franciszek-ksawery'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1185',
#    '229833',
#    'Franciszek Ksawery Branicki',
#    'Rodovid ID',
#    '229833'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1207',
#    'n2005088460',
#    'Franciszek Ksawery Branicki',
#    'NUKAT ID',
#    'n2005088460'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1343',
#    'http://www.wikidata.org/entity/Q1485141',
#    'Franciszek Ksawery Branicki',
#    'described by source',
#    'Polish Biographical Dictionary'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1343',
#    'http://www.wikidata.org/entity/Q1766280',
#    'Franciszek Ksawery Branicki',
#    'described by source',
#    'Svensk uppslagsbok'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1343',
#    'http://www.wikidata.org/entity/Q1960551',
#    'Franciszek Ksawery Branicki',
#    'described by source',
#    'Russian Biographical Dictionary'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1343',
#    'http://www.wikidata.org/entity/Q19180675',
#    'Franciszek Ksawery Branicki',
#    'described by source',
#    'Small Brockhaus and Efron Encyclopedic Dictionary'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1343',
#    'http://www.wikidata.org/entity/Q19219752',
#    'Franciszek Ksawery Branicki',
#    'described by source',
#    'Meyers Konversations-Lexikon, 4th edition (1885–1890)'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1343',
#    'http://www.wikidata.org/entity/Q20078554',
#    'Franciszek Ksawery Branicki',
#    'described by source',
#    'Great Soviet Encyclopedia (1926–1947)'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1343',
#    'http://www.wikidata.org/entity/Q67311526',
#    'Franciszek Ksawery Branicki',
#    'described by source',
#    'Obalky knih.cz'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1344',
#    'http://www.wikidata.org/entity/Q16837743',
#    'Franciszek Ksawery Branicki',
#    'participant in',
#    '1764 Polish–Lithuanian royal election'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1399',
#    'http://www.wikidata.org/entity/Q329821',
#    'Franciszek Ksawery Branicki',
#    'convicted of',
#    'high treason'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1559',
#    'Franciszek Ksawery Branicki',
#    'Franciszek Ksawery Branicki',
#    'name in native language',
#    'Franciszek Ksawery Branicki'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1819',
#    'I00093254',
#    'Franciszek Ksawery Branicki',
#    'genealogics.org person ID',
#    'I00093254'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1871',
#    'cnp00805743',
#    'Franciszek Ksawery Branicki',
#    'CERL Thesaurus ID',
#    'cnp00805743'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P1871',
#    'cnp01878611',
#    'Franciszek Ksawery Branicki',
#    'CERL Thesaurus ID',
#    'cnp01878611'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P3065',
#    '02-A024084609',
#    'Franciszek Ksawery Branicki',
#    'RERO ID (obsolete)',
#    '02-A024084609'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P4159',
#    'Franciszek_Ksawery_Branicki_(1)',
#    'Franciszek Ksawery Branicki',
#    'WeRelate person ID',
#    'Franciszek_Ksawery_Branicki_(1)'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P5019',
#    'branicki-franciszek-ksawery-franz-xaver-graf',
#    'Franciszek Ksawery Branicki',
#    'Brockhaus Enzyklopädie online ID',
#    'branicki-franciszek-ksawery-franz-xaver-graf'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P7293',
#    '9810629500005606',
#    'Franciszek Ksawery Branicki',
#    'PLWABN ID',
#    '9810629500005606'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P7305',
#    '3880357',
#    'Franciszek Ksawery Branicki',
#    'Online PWN Encyclopedia ID',
#    '3880357'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P7666',
#    'franciszek-ksawery-branicki',
#    'Franciszek Ksawery Branicki',
#    'Visuotinė lietuvių enciklopedija ID',
#    'franciszek-ksawery-branicki'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P7699',
#    'LNB:LfX;=Bg',
#    'Franciszek Ksawery Branicki',
#    'National Library of Lithuania ID',
#    'LNB:LfX;=Bg'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P7859',
#    'viaf-60215691',
#    'Franciszek Ksawery Branicki',
#    'WorldCat Identities ID',
#    'viaf-60215691'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P8130',
#    'franciszek-ksawery-branicki-h-korczak-zm-1819-hetman-wielki-koronny',
#    'Franciszek Ksawery Branicki',
#    'Internetowy Polski Słownik Biograficzny ID',
#    'franciszek-ksawery-branicki-h-korczak-zm-1819-hetman-wielki-koronny'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P8172',
#    '2.261.80',
#    'Franciszek Ksawery Branicki',
#    'Sejm-Wielki.pl profile ID',
#    '2.261.80'),
#   ('http://www.wikidata.org/entity/Q1349049',
#    'http://www.wikidata.org/entity/P10033',
#    'branickij-graf-franc-ksaverij-petrovich',
#    'Franciszek Ksawery Branicki',
#    'Biografija.ru ID',
#    'branickij-graf-franc-ksaverij-petrovich')],
#  'Q9253321': [('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P18',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/Carmontelle%20-%20Portrait%20of%20Elizabeth%2C%20Countess%20Sapieha.jpg',
#    'Elżbieta Branicka',
#    'image',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/Carmontelle%20-%20Portrait%20of%20Elizabeth%2C%20Countess%20Sapieha.jpg'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P20',
#    'http://www.wikidata.org/entity/Q2682641',
#    'Elżbieta Branicka',
#    'place of death',
#    'Kodeń'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581072',
#    'Elżbieta Branicka',
#    'sex or gender',
#    'female'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P22',
#    'http://www.wikidata.org/entity/Q16588072',
#    'Elżbieta Branicka',
#    'father',
#    'Piotr Franciszek Branicki'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P26',
#    'http://www.wikidata.org/entity/Q40989542',
#    'Elżbieta Branicka',
#    'spouse',
#    'Jan Sapieha'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P27',
#    'http://www.wikidata.org/entity/Q172107',
#    'Elżbieta Branicka',
#    'country of citizenship',
#    'Polish–Lithuanian Commonwealth'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Elżbieta Branicka',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q2628182',
#    'Elżbieta Branicka',
#    'child',
#    'Kazimierz Nestor Sapieha'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P53',
#    'http://www.wikidata.org/entity/Q700746',
#    'Elżbieta Branicka',
#    'family',
#    'House of Sapieha'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P53',
#    'http://www.wikidata.org/entity/Q3064992',
#    'Elżbieta Branicka',
#    'family',
#    'Branicki (Korczak) family'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P106',
#    'http://www.wikidata.org/entity/Q82955',
#    'Elżbieta Branicka',
#    'occupation',
#    'politician'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P214',
#    '5123151778222618130006',
#    'Elżbieta Branicka',
#    'VIAF ID',
#    '5123151778222618130006'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P569',
#    '1733-01-01T00:00:00Z',
#    'Elżbieta Branicka',
#    'date of birth',
#    '1733-01-01T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P569',
#    '1734-01-01T00:00:00Z',
#    'Elżbieta Branicka',
#    'date of birth',
#    '1734-01-01T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P570',
#    '1800-01-01T00:00:00Z',
#    'Elżbieta Branicka',
#    'date of death',
#    '1800-01-01T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P646',
#    '/m/0wf1t12',
#    'Elżbieta Branicka',
#    'Freebase ID',
#    '/m/0wf1t12'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P735',
#    'http://www.wikidata.org/entity/Q1334508',
#    'Elżbieta Branicka',
#    'given name',
#    'Elżbieta'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P1207',
#    'n2008115348',
#    'Elżbieta Branicka',
#    'NUKAT ID',
#    'n2008115348'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P1343',
#    'http://www.wikidata.org/entity/Q1485141',
#    'Elżbieta Branicka',
#    'described by source',
#    'Polish Biographical Dictionary'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P7293',
#    '9810667575105606',
#    'Elżbieta Branicka',
#    'PLWABN ID',
#    '9810667575105606'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P7859',
#    'viaf-5123151778222618130006',
#    'Elżbieta Branicka',
#    'WorldCat Identities ID',
#    'viaf-5123151778222618130006'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P8130',
#    'elzbieta-sapiezyna-z-branickich',
#    'Elżbieta Branicka',
#    'Internetowy Polski Słownik Biograficzny ID',
#    'elzbieta-sapiezyna-z-branickich'),
#   ('http://www.wikidata.org/entity/Q9253321',
#    'http://www.wikidata.org/entity/P8172',
#    '2.261.81',
#    'Elżbieta Branicka',
#    'Sejm-Wielki.pl profile ID',
#    '2.261.81')],
#  'Q26882450': [('http://www.wikidata.org/entity/Q26882450',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581072',
#    'Waleria Melania Szembek',
#    'sex or gender',
#    'female'),
#   ('http://www.wikidata.org/entity/Q26882450',
#    'http://www.wikidata.org/entity/P22',
#    'http://www.wikidata.org/entity/Q24263182',
#    'Waleria Melania Szembek',
#    'father',
#    'Piotr Wojciech Szembek'),
#   ('http://www.wikidata.org/entity/Q26882450',
#    'http://www.wikidata.org/entity/P26',
#    'http://www.wikidata.org/entity/Q16588072',
#    'Waleria Melania Szembek',
#    'spouse',
#    'Piotr Franciszek Branicki'),
#   ('http://www.wikidata.org/entity/Q26882450',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Waleria Melania Szembek',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q26882450',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q1349049',
#    'Waleria Melania Szembek',
#    'child',
#    'Franciszek Ksawery Branicki'),
#   ('http://www.wikidata.org/entity/Q26882450',
#    'http://www.wikidata.org/entity/P1819',
#    'I00558545',
#    'Waleria Melania Szembek',
#    'genealogics.org person ID',
#    'I00558545'),
#   ('http://www.wikidata.org/entity/Q26882450',
#    'http://www.wikidata.org/entity/P4159',
#    'Melania_Szembek_(1)',
#    'Waleria Melania Szembek',
#    'WeRelate person ID',
#    'Melania_Szembek_(1)'),
#   ('http://www.wikidata.org/entity/Q26882450',
#    'http://www.wikidata.org/entity/P8172',
#    '2.261.77',
#    'Waleria Melania Szembek',
#    'Sejm-Wielki.pl profile ID',
#    '2.261.77')],
#  'Q105679898': [('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581097',
#    'Branicki Józef',
#    'sex or gender',
#    'male'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P27',
#    'http://www.wikidata.org/entity/Q172107',
#    'Branicki Józef',
#    'country of citizenship',
#    'Polish–Lithuanian Commonwealth'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Branicki Józef',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q64850119',
#    'Branicki Józef',
#    'position held',
#    'kasztelan halicki'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q16588072',
#    'Branicki Józef',
#    'child',
#    'Piotr Franciszek Branicki'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P53',
#    'http://www.wikidata.org/entity/Q3064992',
#    'Branicki Józef',
#    'family',
#    'Branicki (Korczak) family'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P214',
#    '99151110798637062841',
#    'Branicki Józef',
#    'VIAF ID',
#    '99151110798637062841'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P227',
#    '1072476142',
#    'Branicki Józef',
#    'GND ID',
#    '1072476142'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P570',
#    '1735-01-01T00:00:00Z',
#    'Branicki Józef',
#    'date of death',
#    '1735-01-01T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P1343',
#    'http://www.wikidata.org/entity/Q1485141',
#    'Branicki Józef',
#    'described by source',
#    'Polish Biographical Dictionary'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P1871',
#    'cnp02125065',
#    'Branicki Józef',
#    'CERL Thesaurus ID',
#    'cnp02125065'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P7293',
#    '9810635980505606',
#    'Branicki Józef',
#    'PLWABN ID',
#    '9810635980505606'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P7859',
#    'viaf-99151110798637062841',
#    'Branicki Józef',
#    'WorldCat Identities ID',
#    'viaf-99151110798637062841'),
#   ('http://www.wikidata.org/entity/Q105679898',
#    'http://www.wikidata.org/entity/P8172',
#    '2.261.71',
#    'Branicki Józef',
#    'Sejm-Wielki.pl profile ID',
#    '2.261.71')],
#  'Q2028738': [('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P18',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/%D0%91%D1%80%D0%B0%D0%BD%D0%B8%D1%86%D0%BA%D0%B8%D0%B9.jpg',
#    'Władysław Grzegorz Branicki',
#    'image',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/%D0%91%D1%80%D0%B0%D0%BD%D0%B8%D1%86%D0%BA%D0%B8%D0%B9.jpg'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P19',
#    'http://www.wikidata.org/entity/Q270',
#    'Władysław Grzegorz Branicki',
#    'place of birth',
#    'Warsaw'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P19',
#    'http://www.wikidata.org/entity/Q656',
#    'Władysław Grzegorz Branicki',
#    'place of birth',
#    'Saint Petersburg'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P20',
#    'http://www.wikidata.org/entity/Q270',
#    'Władysław Grzegorz Branicki',
#    'place of death',
#    'Warsaw'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581097',
#    'Władysław Grzegorz Branicki',
#    'sex or gender',
#    'male'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P22',
#    'http://www.wikidata.org/entity/Q1349049',
#    'Władysław Grzegorz Branicki',
#    'father',
#    'Franciszek Ksawery Branicki'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P25',
#    'http://www.wikidata.org/entity/Q2670161',
#    'Władysław Grzegorz Branicki',
#    'mother',
#    'Alexandra von Engelhardt'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P26',
#    'http://www.wikidata.org/entity/Q7386598',
#    'Władysław Grzegorz Branicki',
#    'spouse',
#    'Countess Róża Potocka'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P27',
#    'http://www.wikidata.org/entity/Q34266',
#    'Władysław Grzegorz Branicki',
#    'country of citizenship',
#    'Russian Empire'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Władysław Grzegorz Branicki',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q4095822',
#    'Władysław Grzegorz Branicki',
#    'child',
#    'Aleksander Branicki'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q6375196',
#    'Władysław Grzegorz Branicki',
#    'child',
#    'Katarzyna Branicka'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q9252846',
#    'Władysław Grzegorz Branicki',
#    'child',
#    'Eliza Krasińska'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q9382095',
#    'Władysław Grzegorz Branicki',
#    'child',
#    'Count Ladislaus Branicki'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q11742884',
#    'Władysław Grzegorz Branicki',
#    'child',
#    'Konstanty Branicki'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q11750335',
#    'Władysław Grzegorz Branicki',
#    'child',
#    'Xavier Branicki'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q97497657',
#    'Władysław Grzegorz Branicki',
#    'child',
#    'Zofia Branicka'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P53',
#    'http://www.wikidata.org/entity/Q3064992',
#    'Władysław Grzegorz Branicki',
#    'family',
#    'Branicki (Korczak) family'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P97',
#    'http://www.wikidata.org/entity/Q3519259',
#    'Władysław Grzegorz Branicki',
#    'noble title',
#    'count'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P106',
#    'http://www.wikidata.org/entity/Q47064',
#    'Władysław Grzegorz Branicki',
#    'occupation',
#    'military personnel'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P106',
#    'http://www.wikidata.org/entity/Q82955',
#    'Władysław Grzegorz Branicki',
#    'occupation',
#    'politician'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P140',
#    'http://www.wikidata.org/entity/Q1841',
#    'Władysław Grzegorz Branicki',
#    'religion or worldview',
#    'Catholicism'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q93732',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of the Red Eagle'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q156478',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Pour le Mérite'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q298950',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of Leopold'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q392204',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of the White Eagle'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q566888',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Kulm Cross'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q661851',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of Military Merit (Württemberg)'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q707685',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Military Order of Max Joseph'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q1501067',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of St. Vladimir'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q2633112',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Gold Sword for Bravery'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q14905810',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of St. George, 4th class'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q15056034',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Pour le Mérite for Sciences and Arts order'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q15972369',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of Saint Anna, 1st class'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q15972370',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of Saint Anna, 2nd class'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q19344818',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of St. Vladimir, 3rd class'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q21148960',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of St. Vladimir, 4th class'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P166',
#    'http://www.wikidata.org/entity/Q32360670',
#    'Władysław Grzegorz Branicki',
#    'award received',
#    'Order of Saint John of Jerusalem'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P214',
#    '53144648222273551499',
#    'Władysław Grzegorz Branicki',
#    'VIAF ID',
#    '53144648222273551499'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P227',
#    '1077319754',
#    'Władysław Grzegorz Branicki',
#    'GND ID',
#    '1077319754'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P373',
#    'Wladyslaw Branicki',
#    'Władysław Grzegorz Branicki',
#    'Commons category',
#    'Wladyslaw Branicki'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P410',
#    'http://www.wikidata.org/entity/Q157148',
#    'Władysław Grzegorz Branicki',
#    'military rank',
#    'major general'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P569',
#    '1783-02-13T00:00:00Z',
#    'Władysław Grzegorz Branicki',
#    'date of birth',
#    '1783-02-13T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q2028738',
#    'http://www.wikidata.org/entity/P570',
#    '1843-08-15T00:00:00Z',
#    'Władysław Grzegorz Branicki',
#    'date of death',
#    '1843-08-15T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q2028738',
# ...
#    '6000000010762622870',
#    'Konstancja Sapieha',
#    'Geni.com profile ID',
#    '6000000010762622870'),
#   ('http://www.wikidata.org/entity/Q22911301',
#    'http://www.wikidata.org/entity/P4638',
#    'p25385.htm#i253847',
#    'Konstancja Sapieha',
#    'The Peerage person ID',
#    'p25385.htm#i253847'),
#   ('http://www.wikidata.org/entity/Q22911301',
#    'http://www.wikidata.org/entity/P8172',
#    'dw.9291',
#    'Konstancja Sapieha',
#    'Sejm-Wielki.pl profile ID',
#    'dw.9291')],
#  'Q11717108': [('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P18',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/Castle%20in%20Lidzbark%20Warminski%2C%20Jan%20Bozy%20Krasicki.jpg',
#    'Jan Boży Krasicki',
#    'image',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/Castle%20in%20Lidzbark%20Warminski%2C%20Jan%20Bozy%20Krasicki.jpg'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581097',
#    'Jan Boży Krasicki',
#    'sex or gender',
#    'male'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P22',
#    'http://www.wikidata.org/entity/Q11735941',
#    'Jan Boży Krasicki',
#    'father',
#    'Karol Aleksander Krasicki'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P27',
#    'http://www.wikidata.org/entity/Q172107',
#    'Jan Boży Krasicki',
#    'country of citizenship',
#    'Polish–Lithuanian Commonwealth'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Jan Boży Krasicki',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q64850170',
#    'Jan Boży Krasicki',
#    'position held',
#    'kasztelan chełmski'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q380545',
#    'Jan Boży Krasicki',
#    'child',
#    'Ignacy Krasicki'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P53',
#    'http://www.wikidata.org/entity/Q4237846',
#    'Jan Boży Krasicki',
#    'family',
#    'Krasicki'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P214',
#    '311308695',
#    'Jan Boży Krasicki',
#    'VIAF ID',
#    '311308695'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P569',
#    '1704-01-01T00:00:00Z',
#    'Jan Boży Krasicki',
#    'date of birth',
#    '1704-01-01T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P570',
#    '1751-09-26T00:00:00Z',
#    'Jan Boży Krasicki',
#    'date of death',
#    '1751-09-26T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P646',
#    '/m/0t_9l62',
#    'Jan Boży Krasicki',
#    'Freebase ID',
#    '/m/0t_9l62'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P735',
#    'http://www.wikidata.org/entity/Q12173670',
#    'Jan Boży Krasicki',
#    'given name',
#    'Jan'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P1207',
#    'n2010301032',
#    'Jan Boży Krasicki',
#    'NUKAT ID',
#    'n2010301032'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P7293',
#    '9810563571005606',
#    'Jan Boży Krasicki',
#    'PLWABN ID',
#    '9810563571005606'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P7859',
#    'viaf-311308695',
#    'Jan Boży Krasicki',
#    'WorldCat Identities ID',
#    'viaf-311308695'),
#   ('http://www.wikidata.org/entity/Q11717108',
#    'http://www.wikidata.org/entity/P8172',
#    '12.270.177',
#    'Jan Boży Krasicki',
#    'Sejm-Wielki.pl profile ID',
#    '12.270.177')],
#  'Q102536331': [('http://www.wikidata.org/entity/Q102536331',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581097',
#    'Adam Wladyslaw Krasicki',
#    'sex or gender',
#    'male'),
#   ('http://www.wikidata.org/entity/Q102536331',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Adam Wladyslaw Krasicki',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q102536331',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q11735941',
#    'Adam Wladyslaw Krasicki',
#    'child',
#    'Karol Aleksander Krasicki'),
#   ('http://www.wikidata.org/entity/Q102536331',
#    'http://www.wikidata.org/entity/P570',
#    '1677-01-01T00:00:00Z',
#    'Adam Wladyslaw Krasicki',
#    'date of death',
#    '1677-01-01T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q102536331',
#    'http://www.wikidata.org/entity/P735',
#    'http://www.wikidata.org/entity/Q347181',
#    'Adam Wladyslaw Krasicki',
#    'given name',
#    'Adam'),
#   ('http://www.wikidata.org/entity/Q102536331',
#    'http://www.wikidata.org/entity/P1819',
#    'I00305177',
#    'Adam Wladyslaw Krasicki',
#    'genealogics.org person ID',
#    'I00305177')],
#  'Q102536333': [('http://www.wikidata.org/entity/Q102536333',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581072',
#    'Izabela Malinska',
#    'sex or gender',
#    'female'),
#   ('http://www.wikidata.org/entity/Q102536333',
#    'http://www.wikidata.org/entity/P22',
#    'http://www.wikidata.org/entity/Q27539092',
#    'Izabela Malinska',
#    'father',
#    'Микола Єло-Малинський'),
#   ('http://www.wikidata.org/entity/Q102536333',
#    'http://www.wikidata.org/entity/P25',
#    'http://www.wikidata.org/entity/Q27118276',
#    'Izabela Malinska',
#    'mother',
#    'Вишневецька Христина'),
#   ('http://www.wikidata.org/entity/Q102536333',
#    'http://www.wikidata.org/entity/P26',
#    'http://www.wikidata.org/entity/Q102536331',
#    'Izabela Malinska',
#    'spouse',
#    'Adam Wladyslaw Krasicki'),
#   ('http://www.wikidata.org/entity/Q102536333',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Izabela Malinska',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q102536333',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q11735941',
#    'Izabela Malinska',
#    'child',
#    'Karol Aleksander Krasicki'),
#   ('http://www.wikidata.org/entity/Q102536333',
#    'http://www.wikidata.org/entity/P735',
#    'http://www.wikidata.org/entity/Q17525055',
#    'Izabela Malinska',
#    'given name',
#    'Izabela'),
#   ('http://www.wikidata.org/entity/Q102536333',
#    'http://www.wikidata.org/entity/P1819',
#    'I00305178',
#    'Izabela Malinska',
#    'genealogics.org person ID',
#    'I00305178')],
#  'Q6836005': [('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P18',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/Micha%C5%82%20Florian%20Rzewuski.PNG',
#    'Michał Florian Rzewuski',
#    'image',
#    'http://commons.wikimedia.org/wiki/Special:FilePath/Micha%C5%82%20Florian%20Rzewuski.PNG'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P19',
#    'http://www.wikidata.org/entity/Q193965',
#    'Michał Florian Rzewuski',
#    'place of birth',
#    'Kamianets-Podilskyi'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P20',
#    'http://www.wikidata.org/entity/Q36036',
#    'Michał Florian Rzewuski',
#    'place of death',
#    'Lviv'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581097',
#    'Michał Florian Rzewuski',
#    'sex or gender',
#    'male'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P22',
#    'http://www.wikidata.org/entity/Q9341597',
#    'Michał Florian Rzewuski',
#    'father',
#    'Stanisław Beydo Rzewuski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P25',
#    'http://www.wikidata.org/entity/Q111451587',
#    'Michał Florian Rzewuski',
#    'mother',
#    'Anna Czerniejowska de Rozdol'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P26',
#    'http://www.wikidata.org/entity/Q102536340',
#    'Michał Florian Rzewuski',
#    'spouse',
#    'Anna Potocka'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P27',
#    'http://www.wikidata.org/entity/Q172107',
#    'Michał Florian Rzewuski',
#    'country of citizenship',
#    'Polish–Lithuanian Commonwealth'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Michał Florian Rzewuski',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q9373095',
#    'Michał Florian Rzewuski',
#    'position held',
#    'wielkorządca krakowsko-sandomierski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q11820687',
#    'Michał Florian Rzewuski',
#    'position held',
#    'podskarbi nadworny koronny'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q28934332',
#    'Michał Florian Rzewuski',
#    'position held',
#    'deputy to the Sejm of the First Polish Republic'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q30041909',
#    'Michał Florian Rzewuski',
#    'position held',
#    'Polish elector'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q65720325',
#    'Michał Florian Rzewuski',
#    'position held',
#    'pisarz ziemski lwowski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q65927067',
#    'Michał Florian Rzewuski',
#    'position held',
#    'skarbnik lwowski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q65952560',
#    'Michał Florian Rzewuski',
#    'position held',
#    'podwojewodzi lwowski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q66190037',
#    'Michał Florian Rzewuski',
#    'position held',
#    'starosta chełmski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P39',
#    'http://www.wikidata.org/entity/Q66200863',
#    'Michał Florian Rzewuski',
#    'position held',
#    'starosta nowosielski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q646034',
#    'Michał Florian Rzewuski',
#    'child',
#    'Adam Rzewuski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q4394264',
#    'Michał Florian Rzewuski',
#    'child',
#    'Stanisław Mateusz Rzewuski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q63184593',
#    'Michał Florian Rzewuski',
#    'child',
#    'Eleonora Anna Rzewuska'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P53',
#    'http://www.wikidata.org/entity/Q360489',
#    'Michał Florian Rzewuski',
#    'family',
#    'Rzewuski family'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P106',
#    'http://www.wikidata.org/entity/Q82955',
#    'Michał Florian Rzewuski',
#    'occupation',
#    'politician'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P214',
#    '51151776810118012181',
#    'Michał Florian Rzewuski',
#    'VIAF ID',
#    '51151776810118012181'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P373',
#    'Michał Florian Rzewuski',
#    'Michał Florian Rzewuski',
#    'Commons category',
#    'Michał Florian Rzewuski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P570',
#    '1687-01-01T00:00:00Z',
#    'Michał Florian Rzewuski',
#    'date of death',
#    '1687-01-01T00:00:00Z'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P646',
#    '/m/0hgmr2w',
#    'Michał Florian Rzewuski',
#    'Freebase ID',
#    '/m/0hgmr2w'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P734',
#    'http://www.wikidata.org/entity/Q64705280',
#    'Michał Florian Rzewuski',
#    'family name',
#    'Rzewuski'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P735',
#    'http://www.wikidata.org/entity/Q6835978',
#    'Michał Florian Rzewuski',
#    'given name',
#    'Michał'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P1185',
#    '432587',
#    'Michał Florian Rzewuski',
#    'Rodovid ID',
#    '432587'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P1344',
#    'http://www.wikidata.org/entity/Q16837727',
#    'Michał Florian Rzewuski',
#    'participant in',
#    '1674 Polish–Lithuanian royal election'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P1819',
#    'I00184072',
#    'Michał Florian Rzewuski',
#    'genealogics.org person ID',
#    'I00184072'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P2949',
#    'Beydo-Rzewuski-4',
#    'Michał Florian Rzewuski',
#    'WikiTree person ID',
#    'Beydo-Rzewuski-4'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P7293',
#    '9810540664705606',
#    'Michał Florian Rzewuski',
#    'PLWABN ID',
#    '9810540664705606'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P7305',
#    '3970716',
#    'Michał Florian Rzewuski',
#    'Online PWN Encyclopedia ID',
#    '3970716'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P7859',
#    'viaf-51151776810118012181',
#    'Michał Florian Rzewuski',
#    'WorldCat Identities ID',
#    'viaf-51151776810118012181'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P8130',
#    'michal-florian-rzewuski-h-krzywda',
#    'Michał Florian Rzewuski',
#    'Internetowy Polski Słownik Biograficzny ID',
#    'michal-florian-rzewuski-h-krzywda'),
#   ('http://www.wikidata.org/entity/Q6836005',
#    'http://www.wikidata.org/entity/P8172',
#    '5.444.42',
#    'Michał Florian Rzewuski',
#    'Sejm-Wielki.pl profile ID',
#    '5.444.42')],
#  'Q102536340': [('http://www.wikidata.org/entity/Q102536340',
#    'http://www.wikidata.org/entity/P21',
#    'http://www.wikidata.org/entity/Q6581072',
#    'Anna Potocka',
#    'sex or gender',
#    'female'),
#   ('http://www.wikidata.org/entity/Q102536340',
#    'http://www.wikidata.org/entity/P22',
#    'http://www.wikidata.org/entity/Q4374912',
#    'Anna Potocka',
#    'father',
#    'Paweł Potocki'),
#   ('http://www.wikidata.org/entity/Q102536340',
#    'http://www.wikidata.org/entity/P25',
#    'http://www.wikidata.org/entity/Q105085428',
#    'Anna Potocka',
#    'mother',
#    'Yelena Saltykova'),
#   ('http://www.wikidata.org/entity/Q102536340',
#    'http://www.wikidata.org/entity/P26',
#    'http://www.wikidata.org/entity/Q6836005',
#    'Anna Potocka',
#    'spouse',
#    'Michał Florian Rzewuski'),
#   ('http://www.wikidata.org/entity/Q102536340',
#    'http://www.wikidata.org/entity/P31',
#    'http://www.wikidata.org/entity/Q5',
#    'Anna Potocka',
#    'instance of',
#    'human'),
#   ('http://www.wikidata.org/entity/Q102536340',
#    'http://www.wikidata.org/entity/P40',
#    'http://www.wikidata.org/entity/Q63184593',
#    'Anna Potocka',
#    'child',
#    'Eleonora Anna Rzewuska'),
#   ('http://www.wikidata.org/entity/Q102536340',
#    'http://www.wikidata.org/entity/P735',
#    'http://www.wikidata.org/entity/Q666578',
#    'Anna Potocka',
#    'given name',
#    'Anna'),
#   ('http://www.wikidata.org/entity/Q102536340',
#    'http://www.wikidata.org/entity/P1819',
#    'I00347879',
#    'Anna Potocka',
#    'genealogics.org person ID',
#    'I00347879')]}

# %%
# import json
# with open("rdf_info.json", "w") as f:
#     json.dump(rdf_info, f)  # no idntent arg if you want smaller filesize

# %%
qcodes_to_check = set()
for Q in rdf_info.keys():
    qcodes_to_check.add(Q)
    for rdf_tuple in rdf_info[Q]:
        if rdf_tuple[4] == "FactGrid item ID":
            continue
        object_url = rdf_tuple[2]
        qcode = object_url[object_url.rfind('Q'):]
        if len(qcode) > 1:
            if qcode[1:].isdigit():
                qcodes_to_check.add(qcode)
                if (qcode=='Q383232'):
                    print(Q, rdf_info[Q])
print(f"{len(qcodes_to_check) = }")

qcodes_to_check_split = []
n_size = 500  # splitting qcodes_to_check into lists of n_size (500) elements, because URI cannot be too large in function get_all_human_objects()
length = len(qcodes_to_check)
temp = []
for i, qcode in enumerate(qcodes_to_check):
    temp.append(qcode)
    if i%n_size == n_size-1:
        qcodes_to_check_split.append(temp)
        temp = []
    if i == length-1:
        if len(temp) > 0:
            qcodes_to_check_split.append(temp)
print(f"{len(qcodes_to_check_split) = }")

all_humans = []
n_lists = len(qcodes_to_check_split)
for i, lista in enumerate(qcodes_to_check_split):
    temp_list = get_all_human_objects(lista)
    all_humans += temp_list
# ^ 1m 30s dla len(qcodes_to_check) = 60829
# Out:
# len(qcodes_to_check) = 1791
# len(qcodes_to_check_split) = 4

# %%
print(f"{len(all_humans) = }")
all_humans
# Out:
# len(all_humans) = 643
# [('Q9312', 'http://www.wikidata.org/entity/Q9312', 'Immanuel Kant'),
#  ('Q36450', 'http://www.wikidata.org/entity/Q36450', 'Catherine II of Russia'),
#  ('Q43939', 'http://www.wikidata.org/entity/Q43939', 'Anselm of Canterbury'),
#  ('Q45662', 'http://www.wikidata.org/entity/Q45662', 'Klemens von Metternich'),
#  ('Q54019',
#   'http://www.wikidata.org/entity/Q54019',
#   'Stanisław August Poniatowski'),
#  ('Q60070',
#   'http://www.wikidata.org/entity/Q60070',
#   'Friedrich Wilhelm Joseph Schelling'),
#  ('Q79025', 'http://www.wikidata.org/entity/Q79025', 'Walter Scott'),
#  ('Q134189', 'http://www.wikidata.org/entity/Q134189', 'Plotinus'),
#  ('Q154751', 'http://www.wikidata.org/entity/Q154751', 'Nicholas of Cusa'),
#  ('Q168004',
#   'http://www.wikidata.org/entity/Q168004',
#   'Friedrich Heinrich Jacobi'),
#  ('Q176163', 'http://www.wikidata.org/entity/Q176163', 'August Cieszkowski'),
#  ('Q272161', 'http://www.wikidata.org/entity/Q272161', 'Anne Isabella Byron'),
#  ('Q454204', 'http://www.wikidata.org/entity/Q454204', 'Marie de Castellane'),
#  ('Q457413',
#   'http://www.wikidata.org/entity/Q457413',
#   'Andrzej Kazimierz Potocki'),
#  ('Q611233',
#   'http://www.wikidata.org/entity/Q611233',
#   'Jean-Baptiste Robinet'),
#  ('Q631635', 'http://www.wikidata.org/entity/Q631635', 'Luigi Pulci'),
#  ('Q778295',
#   'http://www.wikidata.org/entity/Q778295',
#   'Pyotr Andreyevich Shuvalov'),
#  ('Q898557',
#   'http://www.wikidata.org/entity/Q898557',
#   'Prince Franz de Paula of Liechtenstein'),
#  ('Q936342', 'http://www.wikidata.org/entity/Q936342', 'Stanisław Lubomirski'),
#  ('Q984563', 'http://www.wikidata.org/entity/Q984563', 'Pavel Shuvalov'),
#  ('Q1349049',
#   'http://www.wikidata.org/entity/Q1349049',
#   'Franciszek Ksawery Branicki'),
#  ('Q1479519',
#   'http://www.wikidata.org/entity/Q1479519',
#   'Félix Ravaisson-Mollien'),
#  ('Q1651756',
#   'http://www.wikidata.org/entity/Q1651756',
#   'Catherine Murray, Countess of Dunmore'),
#  ('Q1978660', 'http://www.wikidata.org/entity/Q1978660', 'Lev Naryshkin'),
#  ('Q2026959', 'http://www.wikidata.org/entity/Q2026959', 'Alexander Samoylov'),
#  ('Q2040517',
#   'http://www.wikidata.org/entity/Q2040517',
#   'Alexander Vasilchikov'),
#  ('Q2060128', 'http://www.wikidata.org/entity/Q2060128', 'Andrzej Potocki'),
#  ('Q2079114',
#   'http://www.wikidata.org/entity/Q2079114',
#   'Antoni Albrecht Wilhelm Radziwiłł'),
#  ('Q2439671',
#   'http://www.wikidata.org/entity/Q2439671',
#   'Stanisław Lubomirski'),
#  ('Q2440428',
#   'http://www.wikidata.org/entity/Q2440428',
#   'Stanisław Szczęsny Potocki'),
#  ('Q2506976',
#   'http://www.wikidata.org/entity/Q2506976',
#   'Prince Alfred of Liechtenstein'),
#  ('Q2584741',
#   'http://www.wikidata.org/entity/Q2584741',
#   'Feliks Kazimierz Potocki'),
#  ('Q2587802',
#   'http://www.wikidata.org/entity/Q2587802',
#   'Franciszek Salezy Potocki'),
#  ('Q3136526', 'http://www.wikidata.org/entity/Q3136526', 'Paweł Sanguszko'),
#  ('Q3646997',
#   'http://www.wikidata.org/entity/Q3646997',
#   'Karol Józef Sapieha'),
#  ('Q3911020',
#   'http://www.wikidata.org/entity/Q3911020',
#   'Catherine Vorontsov'),
#  ('Q3920109',
#   'http://www.wikidata.org/entity/Q3920109',
#   'Aleksander Antoni Sapieha'),
#  ('Q3920112', 'http://www.wikidata.org/entity/Q3920112', 'Ignacy Sapieha'),
#  ('Q3960168',
#   'http://www.wikidata.org/entity/Q3960168',
#   'Sidney Herbert, 14th Earl of Pembroke'),
#  ('Q4076491', 'http://www.wikidata.org/entity/Q4076491', 'Nikolay Balashov'),
#  ('Q4076493', 'http://www.wikidata.org/entity/Q4076493', 'Pyotr Balashyov'),
#  ('Q4095822',
#   'http://www.wikidata.org/entity/Q4095822',
#   'Aleksander Branicki'),
#  ('Q4125775', 'http://www.wikidata.org/entity/Q4125775', 'Roman Vorontsov'),
#  ('Q4125793',
#   'http://www.wikidata.org/entity/Q4125793',
#   'Elizaveta Vorontsova'),
#  ('Q4129572', 'http://www.wikidata.org/entity/Q4129572', 'Nikolay Vysotsky'),
#  ('Q4141591', 'http://www.wikidata.org/entity/Q4141591', 'Sergey Golitsyn'),
#  ('Q4141593',
#   'http://www.wikidata.org/entity/Q4141593',
#   'Sergej Sergeevič Golicyn'),
#  ('Q4222109', 'http://www.wikidata.org/entity/Q4222109', 'Zofia Kisielew'),
#  ('Q4283756',
#   'http://www.wikidata.org/entity/Q4283756',
#   'Elizabeth Radziwill'),
#  ('Q4342524',
#   'http://www.wikidata.org/entity/Q4342524',
#   'Pavel Petrovič Palen'),
#  ('Q4374904', 'http://www.wikidata.org/entity/Q4374904', 'Olga Potocka'),
#  ('Q4374905', 'http://www.wikidata.org/entity/Q4374905', 'Anna Potocka'),
#  ('Q4374909',
#   'http://www.wikidata.org/entity/Q4374909',
#   'Lev Severinovich, graf Potot͡skiĭ'),
#  ('Q4406026', 'http://www.wikidata.org/entity/Q4406026', 'Aleksandr Saltykov'),
#  ('Q4527260', 'http://www.wikidata.org/entity/Q4527260', 'Andrey Shuvalov'),
#  ('Q4535389',
#   'http://www.wikidata.org/entity/Q4535389',
#   'Boris Grigorievich Yusupov'),
#  ('Q4723654',
#   'http://www.wikidata.org/entity/Q4723654',
#   'Alfred Wojciech Potocki'),
#  ('Q5540511',
#   'http://www.wikidata.org/entity/Q5540511',
#   'George Herbert, 13th Earl of Pembroke'),
#  ('Q5553282',
#   'http://www.wikidata.org/entity/Q5553282',
#   'Gertruda Komorowska'),
#  ('Q5801949',
#   'http://www.wikidata.org/entity/Q5801949',
#   'Michael Henry Herbert'),
#  ('Q5975640',
#   'http://www.wikidata.org/entity/Q5975640',
#   'Józef Kanty Ossoliński'),
#  ('Q6150019', 'http://www.wikidata.org/entity/Q6150019', 'Jan Szembek'),
#  ('Q6320794',
#   'http://www.wikidata.org/entity/Q6320794',
#   'Józefina Maria Czartoryska'),
#  ('Q6761045',
#   'http://www.wikidata.org/entity/Q6761045',
#   'Maria Beatrix Krasińska'),
#  ('Q6761317',
#   'http://www.wikidata.org/entity/Q6761317',
#   'Maria Klementyna Sanguszko'),
#  ('Q6761676',
#   'http://www.wikidata.org/entity/Q6761676',
#   'Maria Zofia Czartoryska'),
#  ('Q6836005',
#   'http://www.wikidata.org/entity/Q6836005',
#   'Michał Florian Rzewuski'),
#  ('Q6968070', 'http://www.wikidata.org/entity/Q6968070', 'Natalia Potocka'),
#  ('Q7362134', 'http://www.wikidata.org/entity/Q7362134', 'Roman Potocki'),
#  ('Q7386598',
#   'http://www.wikidata.org/entity/Q7386598',
#   'Countess Róża Potocka'),
#  ('Q7509123',
#   'http://www.wikidata.org/entity/Q7509123',
#   'Sir Sidney Herbert, 1st Baronet'),
#  ('Q7599108',
#   'http://www.wikidata.org/entity/Q7599108',
#   'Stanisław Antoni Potocki'),
#  ('Q7599212', 'http://www.wikidata.org/entity/Q7599212', 'Stanisław Potocki'),
#  ('Q7606336', 'http://www.wikidata.org/entity/Q7606336', 'Stefan Zamoyski'),
#  ('Q7702125', 'http://www.wikidata.org/entity/Q7702125', 'Teresa Czartoryska'),
#  ('Q7818392',
#   'http://www.wikidata.org/entity/Q7818392',
#   'Tomasz Franciszek Zamoyski'),
#  ('Q8073357', 'http://www.wikidata.org/entity/Q8073357', 'Zofia Czartoryska'),
#  ('Q8545241',
#   'http://www.wikidata.org/entity/Q8545241',
#   'Stanisław Sebastian Lubomirski'),
#  ('Q9151537',
#   'http://www.wikidata.org/entity/Q9151537',
#   'Andrzej Bernard Potocki'),
#  ('Q9311770',
#   'http://www.wikidata.org/entity/Q9311770',
#   'Roger Maurycy Raczyński'),
#  ('Q9341534',
#   'http://www.wikidata.org/entity/Q9341534',
#   'Stanisław Antoni Zamoyski'),
#  ('Q9341597',
#   'http://www.wikidata.org/entity/Q9341597',
#   'Stanisław Beydo Rzewuski'),
#  ('Q9342860', 'http://www.wikidata.org/entity/Q9342860', 'Stanisław Potocki'),
#  ('Q9357360', 'http://www.wikidata.org/entity/Q9357360', 'Teresa Stadnicka'),
#  ('Q9382057',
#   'http://www.wikidata.org/entity/Q9382057',
#   'Władysław Lubomirski'),
#  ('Q9382789',
#   'http://www.wikidata.org/entity/Q9382789',
#   'Włodzimierz Potocki'),
#  ('Q9391911',
#   'http://www.wikidata.org/entity/Q9391911',
#   'Zofia z Potockich Zamoyska'),
#  ('Q11125465',
#   'http://www.wikidata.org/entity/Q11125465',
#   'Józef Salezy Ossoliński'),
#  ('Q11684270', 'http://www.wikidata.org/entity/Q11684270', 'Adam Branicki'),
#  ('Q11685100',
#   'http://www.wikidata.org/entity/Q11685100',
#   'Aleksander Potocki'),
#  ('Q11731188', 'http://www.wikidata.org/entity/Q11731188', 'Józef Potocki'),
#  ('Q11737046',
#   'http://www.wikidata.org/entity/Q11737046',
#   'Katarzyna Branicka'),
#  ('Q11739878', 'http://www.wikidata.org/entity/Q11739878', 'Klaudyna Potocka'),
#  ('Q11742884',
#   'http://www.wikidata.org/entity/Q11742884',
#   'Konstanty Branicki'),
#  ('Q11780890',
#   'http://www.wikidata.org/entity/Q11780890',
#   'Mikołaj Sapieha (1779-1843)'),
#  ('Q11814387', 'http://www.wikidata.org/entity/Q11814387', 'Paul Sapieha'),
#  ('Q15060863', 'http://www.wikidata.org/entity/Q15060863', 'Q15060863'),
#  ('Q15060896',
#   'http://www.wikidata.org/entity/Q15060896',
#   'Mariya Shcherbatova'),
#  ('Q15064867',
#   'http://www.wikidata.org/entity/Q15064867',
#   'Tekla Valentinovich'),
#  ('Q15065427',
#   'http://www.wikidata.org/entity/Q15065427',
#   'Fedor Sergeevich Golytsin'),
#  ('Q15407959',
#   'http://www.wikidata.org/entity/Q15407959',
#   'Catherine Saltykova'),
#  ('Q16389857',
#   'http://www.wikidata.org/entity/Q16389857',
#   'Yelizaveta Vorontsova-Dashkova'),
#  ('Q16478232',
#   'http://www.wikidata.org/entity/Q16478232',
#   'Alexandra Shuvalova'),
#  ('Q16798198',
#   'http://www.wikidata.org/entity/Q16798198',
#   'Irina Sheremeteva'),
#  ('Q17328870',
#   'http://www.wikidata.org/entity/Q17328870',
#   'Baldassarre Odescalchi'),
#  ('Q17552544',
#   'http://www.wikidata.org/entity/Q17552544',
#   'Mikołaj Lew Sołomerecki'),
#  ('Q18280384', 'http://www.wikidata.org/entity/Q18280384', 'Pyotr Shuvalov'),
#  ('Q20789776',
#   'http://www.wikidata.org/entity/Q20789776',
#   'Emmanuela Potocka'),
#  ('Q22970782',
#   'http://www.wikidata.org/entity/Q22970782',
#   'Anna Elżbieta Potocka'),
#  ('Q26882457',
#   'http://www.wikidata.org/entity/Q26882457',
#   'Aleksander Branicki'),
#  ('Q27118276',
#   'http://www.wikidata.org/entity/Q27118276',
#   'Вишневецька Христина'),
#  ('Q27556004',
#   'http://www.wikidata.org/entity/Q27556004',
#   'Regina Sołomerecka'),
#  ('Q33381132', 'http://www.wikidata.org/entity/Q33381132', 'Sofiya Demidova'),
#  ('Q40989542', 'http://www.wikidata.org/entity/Q40989542', 'Jan Sapieha'),
#  ('Q60391559',
#   'http://www.wikidata.org/entity/Q60391559',
#   'Heinrich Karl August Liechtenstein'),
#  ('Q61637815', 'http://www.wikidata.org/entity/Q61637815', 'Sofya Vorontsova'),
#  ('Q62780763',
#   'http://www.wikidata.org/entity/Q62780763',
#   'Dorothy Parker Deacon'),
#  ('Q62893281', 'http://www.wikidata.org/entity/Q62893281', 'Marianna Potocka'),
#  ('Q63184593',
#   'http://www.wikidata.org/entity/Q63184593',
#   'Eleonora Anna Rzewuska'),
#  ('Q63184609',
#   'http://www.wikidata.org/entity/Q63184609',
#   'Krystyna Sanguszko'),
#  ('Q64024895',
#   'http://www.wikidata.org/entity/Q64024895',
#   'Maria Urszula Radziwiłł'),
#  ('Q64339371',
#   'http://www.wikidata.org/entity/Q64339371',
#   'Szczęsny Jerzy Potocki'),
#  ('Q65034322', 'http://www.wikidata.org/entity/Q65034322', 'Tatyana Yusupova'),
#  ('Q65095948', 'http://www.wikidata.org/entity/Q65095948', 'Dariusz Gotlib'),
#  ('Q67131094', 'http://www.wikidata.org/entity/Q67131094', 'Maria Zamoyska'),
#  ('Q75274768',
#   'http://www.wikidata.org/entity/Q75274768',
#   'Lady Constance Murray'),
#  ('Q75276782',
#   'http://www.wikidata.org/entity/Q75276782',
#   'Lady Elizabeth Herbert'),
#  ('Q75318092',
#   'http://www.wikidata.org/entity/Q75318092',
#   'Aleksandr Shuvalov'),
#  ('Q75318160', 'http://www.wikidata.org/entity/Q75318160', 'Olga Shuvalova'),
#  ('Q75330578',
#   'http://www.wikidata.org/entity/Q75330578',
#   'Baroness Olga de Simolin-Wettberg'),
#  ('Q75330716',
#   'http://www.wikidata.org/entity/Q75330716',
#   'Princess Wanda Lubomirski'),
#  ('Q75330729',
#   'http://www.wikidata.org/entity/Q75330729',
#   'Count Jan Tyszkiewicz'),
#  ('Q75347169', 'http://www.wikidata.org/entity/Q75347169', 'George Herbert'),
#  ('Q75376569', 'http://www.wikidata.org/entity/Q75376569', 'Sofya Shuvalova'),
#  ('Q75519293',
#   'http://www.wikidata.org/entity/Q75519293',
#   'François-Xavier Sapieha, Prince Sapieha'),
#  ('Q75519311',
#   'http://www.wikidata.org/entity/Q75519311',
#   'Countess Ludwika Pac-Malachowska'),
#  ('Q75970451',
#   'http://www.wikidata.org/entity/Q75970451',
#   'Sergey Sheremetev'),
#  ('Q76281589',
#   'http://www.wikidata.org/entity/Q76281589',
#   'Lady Elizabeth Maude Herbert'),
#  ('Q76287573',
#   'http://www.wikidata.org/entity/Q76287573',
#   'Illarion Vorontsov-Dashkov'),
#  ('Q76297706',
#   'http://www.wikidata.org/entity/Q76297706',
#   'William Reginald Herbert'),
#  ('Q84720837',
#   'http://www.wikidata.org/entity/Q84720837',
#   'Varvara Shakhovskaya'),
#  ('Q102177202',
#   'http://www.wikidata.org/entity/Q102177202',
#   'Yelizaveta Shakhovskaya'),
#  ('Q102218631',
#   'http://www.wikidata.org/entity/Q102218631',
#   'Sofya Engelhardt'),
#  ('Q102536331',
#   'http://www.wikidata.org/entity/Q102536331',
#   'Adam Wladyslaw Krasicki'),
#  ('Q104151458',
#   'http://www.wikidata.org/entity/Q104151458',
#   'Yuliya Kurakina'),
#  ('Q104474754',
#   'http://www.wikidata.org/entity/Q104474754',
#   'Yelena Shuvalova'),
#  ('Q104475101',
#   'http://www.wikidata.org/entity/Q104475101',
#   'Olga Dolgorukova'),
#  ('Q104519534',
#   'http://www.wikidata.org/entity/Q104519534',
#   'Władysław Branicki'),
#  ('Q104634182',
#   'http://www.wikidata.org/entity/Q104634182',
#   'Mariya Vorontsova'),
#  ('Q104870236',
#   'http://www.wikidata.org/entity/Q104870236',
#   'Mariya Potyomkina'),
#  ('Q105839669',
#   'http://www.wikidata.org/entity/Q105839669',
#   'Pyotr Engelhardt'),
#  ('Q106575217',
#   'http://www.wikidata.org/entity/Q106575217',
#   'Ludwika Potocka'),
#  ('Q106834602',
#   'http://www.wikidata.org/entity/Q106834602',
#   'Pelageya Potyomkina'),
#  ('Q107294414',
#   'http://www.wikidata.org/entity/Q107294414',
#   'Nikolay Samoylov'),
#  ('Q107379994',
#   'http://www.wikidata.org/entity/Q107379994',
#   'Zdzisław Zamoyski'),
#  ('Q107485036', 'http://www.wikidata.org/entity/Q107485036', 'Lev Golitsyn'),
#  ('Q110160394',
#   'http://www.wikidata.org/entity/Q110160394',
#   'Praskovya Pavlovna Yusupova'),
#  ('Q110394399', 'http://www.wikidata.org/entity/Q110394399', 'Q110394399'),
#  ('Q110394707',
#   'http://www.wikidata.org/entity/Q110394707',
#   'Wiktoria de Choiseul-Gouffier'),
#  ('Q111451587',
#   'http://www.wikidata.org/entity/Q111451587',
#   'Anna Czerniejowska de Rozdol'),
#  ('Q112384637',
#   'http://www.wikidata.org/entity/Q112384637',
#   'Andrei Yurievich Engelhardt'),
#  ('Q112605288', 'http://www.wikidata.org/entity/Q112605288', 'Q112605288'),
#  ('Q112605315', 'http://www.wikidata.org/entity/Q112605315', 'Q112605315'),
#  ('Q114797050',
#   'http://www.wikidata.org/entity/Q114797050',
#   'Constantine Pavlovich Prezhbiano'),
#  ('Q5879',
#   'http://www.wikidata.org/entity/Q5879',
#   'Johann Wolfgang von Goethe'),
#  ('Q7259', 'http://www.wikidata.org/entity/Q7259', 'Ada Lovelace'),
#  ('Q25776',
#   'http://www.wikidata.org/entity/Q25776',
#   'Wladyslaw Jehoshaphat Sapieha'),
#  ('Q26611',
#   'http://www.wikidata.org/entity/Q26611',
#   'Józef Aleksander Jabłonowski'),
#  ('Q36330', 'http://www.wikidata.org/entity/Q36330', 'Giordano Bruno'),
#  ('Q41155', 'http://www.wikidata.org/entity/Q41155', 'Heraclitus'),
#  ('Q45546', 'http://www.wikidata.org/entity/Q45546', 'William Wordsworth'),
#  ('Q55841',
#   'http://www.wikidata.org/entity/Q55841',
#   'Edward Bernard Raczyński'),
#  ('Q58426',
#   'http://www.wikidata.org/entity/Q58426',
#   'Jan Karol Wandalin Mniszech'),
#  ('Q64623', 'http://www.wikidata.org/entity/Q64623', 'Johann Eduard Erdmann'),
#  ('Q69255',
#   'http://www.wikidata.org/entity/Q69255',
#   'Frederick Augustus, Prince of Anhalt-Zerbst'),
#  ('Q75889', 'http://www.wikidata.org/entity/Q75889', 'Friedrich Hölderlin'),
#  ('Q77017', 'http://www.wikidata.org/entity/Q77017', 'Jakob Böhme'),
#  ('Q85538',
#   'http://www.wikidata.org/entity/Q85538',
#   'Prince Aloys Franz de Paula Maria'),
#  ('Q91342',
#   'http://www.wikidata.org/entity/Q91342',
#   'Gottlob Christian Storr'),
#  ('Q97296', 'http://www.wikidata.org/entity/Q97296', 'Johann Friedrich Flatt'),
#  ('Q214949', 'http://www.wikidata.org/entity/Q214949', 'Heinrich von Brühl'),
#  ('Q220030', 'http://www.wikidata.org/entity/Q220030', 'Alfred Józef Potocki'),
#  ('Q243201', 'http://www.wikidata.org/entity/Q243201', 'Grigory Potemkin'),
#  ('Q245355', 'http://www.wikidata.org/entity/Q245355', 'Zygmunt Krasiński'),
#  ('Q276241',
#   'http://www.wikidata.org/entity/Q276241',
#   'Elizabeth Medora Leigh'),
#  ('Q380545', 'http://www.wikidata.org/entity/Q380545', 'Ignacy Krasicki'),
#  ('Q453699', 'http://www.wikidata.org/entity/Q453699', 'Augusta Leigh'),
#  ('Q460066', 'http://www.wikidata.org/entity/Q460066', 'Claire Clairmont'),
#  ('Q514713',
#   'http://www.wikidata.org/entity/Q514713',
#   'Andrzej Artur Zamoyski'),
#  ('Q975395',
#   'http://www.wikidata.org/entity/Q975395',
#   'Aleksandra Lubomirska'),
#  ('Q1063510',
#   'http://www.wikidata.org/entity/Q1063510',
#   'Charles Murray, 7th Earl of Dunmore'),
#  ('Q1693342',
#   'http://www.wikidata.org/entity/Q1693342',
#   'Johann Erich Berger'),
#  ('Q1964761', 'http://www.wikidata.org/entity/Q1964761', 'Semyon Vorontsov'),
#  ('Q2067058',
#   'http://www.wikidata.org/entity/Q2067058',
#   'Elizaveta Vorontsova'),
#  ('Q2255276',
#   'http://www.wikidata.org/entity/Q2255276',
#   'Bronisław Trentowski'),
#  ('Q2670161',
#   'http://www.wikidata.org/entity/Q2670161',
#   'Alexandra von Engelhardt'),
#  ('Q2707608', 'http://www.wikidata.org/entity/Q2707608', 'Lorenzo Litta'),
#  ('Q2837843', 'http://www.wikidata.org/entity/Q2837843', 'Allegra Byron'),
#  ('Q2977753', 'http://www.wikidata.org/entity/Q2977753', 'Sofia Potocka'),
#  ('Q2991218', 'http://www.wikidata.org/entity/Q2991218', 'Paweł Jan Sapieha'),
#  ('Q3647036', 'http://www.wikidata.org/entity/Q3647036', 'Leon Sapieha'),
#  ('Q3723423',
#   'http://www.wikidata.org/entity/Q3723423',
#   'Elizabeth Herbert, Countess of Pembroke and Montgomery'),
#  ('Q3784470',
#   'http://www.wikidata.org/entity/Q3784470',
#   'Ekaterina Senyavina'),
#  ('Q4111579',
#   'http://www.wikidata.org/entity/Q4111579',
#   'Henry Herbert, Earl of Pembroke'),
#  ('Q4141563',
#   'http://www.wikidata.org/entity/Q4141563',
#   'Vladimir Sergeevich Golitsyn'),
#  ('Q4155513', 'http://www.wikidata.org/entity/Q4155513', 'Mikhail Dashkov'),
#  ('Q4269209', 'http://www.wikidata.org/entity/Q4269209', 'Anna Petrovna'),
#  ('Q4284239',
#   'http://www.wikidata.org/entity/Q4284239',
#   'Maria Róża Radziwiłłowa'),
#  ('Q4346487', 'http://www.wikidata.org/entity/Q4346487', 'Irina Paskevich'),
#  ('Q4394264',
#   'http://www.wikidata.org/entity/Q4394264',
#   'Stanisław Mateusz Rzewuski'),
#  ('Q4394319',
#   'http://www.wikidata.org/entity/Q4394319',
#   'Alexander Ivanovich Ribopier'),
#  ('Q4406738', 'http://www.wikidata.org/entity/Q4406738', 'Yuliya Samoylova'),
#  ('Q4444046',
#   'http://www.wikidata.org/entity/Q4444046',
#   'Grigorij Sergeevič Stroganov'),
#  ('Q4527275', 'http://www.wikidata.org/entity/Q4527275', 'Pavel Shuvalov'),
#  ('Q4535407', 'http://www.wikidata.org/entity/Q4535407', 'Tatyana Yusupova'),
#  ('Q4719715',
#   'http://www.wikidata.org/entity/Q4719715',
#   'Alexander Murray, 6th Earl of Dunmore'),
#  ('Q4719881', 'http://www.wikidata.org/entity/Q4719881', 'Alexander Potemkin'),
#  ('Q4801684',
#   'http://www.wikidata.org/entity/Q4801684',
#   'Artur Władysław Potocki'),
#  ('Q5298213',
#   'http://www.wikidata.org/entity/Q5298213',
#   'Dorota Barbara Jabłonowska'),
#  ('Q5362962',
#   'http://www.wikidata.org/entity/Q5362962',
#   'Elizabeth Herbert, Baroness Herbert of Lea'),
#  ('Q5537356',
#   'http://www.wikidata.org/entity/Q5537356',
#   'George Brudenell-Bruce, 2nd Marquess of Ailesbury'),
#  ('Q5623705',
#   'http://www.wikidata.org/entity/Q5623705',
#   'Gwladys Robinson, Marchioness of Ripon'),
#  ('Q5703795', 'http://www.wikidata.org/entity/Q5703795', 'Helena Zamoyska'),
#  ('Q5764903',
#   'http://www.wikidata.org/entity/Q5764903',
#   'Krzysztof Mikołaj Radziwiłł'),
#  ('Q6306549', 'http://www.wikidata.org/entity/Q6306549', 'Julia Lubomirska'),
#  ('Q6320538',
#   'http://www.wikidata.org/entity/Q6320538',
#   'Józef Klemens Czartoryski'),
#  ('Q6373177',
#   'http://www.wikidata.org/entity/Q6373177',
#   'Karolina Teresa Radziwiłł'),
#  ('Q6375196', 'http://www.wikidata.org/entity/Q6375196', 'Katarzyna Branicka'),
#  ('Q6375220', 'http://www.wikidata.org/entity/Q6375220', 'Katarzyna Potocka'),
#  ('Q6429869', 'http://www.wikidata.org/entity/Q6429869', 'Konstancja Potocka'),
#  ('Q6430255', 'http://www.wikidata.org/entity/Q6430255', 'Konstanty Zamoyski'),
#  ('Q6699467', 'http://www.wikidata.org/entity/Q6699467', 'Ludwika Lubomirska'),
#  ('Q6961400',
#   'http://www.wikidata.org/entity/Q6961400',
#   'Stanislav Stanislavovič Potocki'),
#  ('Q7253406', 'http://www.wikidata.org/entity/Q7253406', 'Przemysław Potocki'),
#  ('Q7327763',
#   'http://www.wikidata.org/entity/Q7327763',
#   'Richard Meade, 4th Earl of Clanwilliam'),
#  ('Q7345451',
#   'http://www.wikidata.org/entity/Q7345451',
#   'Robert Herbert, 12th Earl of Pembroke'),
#  ('Q7386600', 'http://www.wikidata.org/entity/Q7386600', 'Róża Potocka'),
#  ('Q7794690',
#   'http://www.wikidata.org/entity/Q7794690',
#   'Thomas Vesey, 3rd Viscount de Vesci'),
#  ('Q8041258',
#   'http://www.wikidata.org/entity/Q8041258',
#   'Władysław Zdzisław Zamoyski'),
#  ('Q8068123', 'http://www.wikidata.org/entity/Q8068123', 'Zdzisław Zamoyski'),
#  ('Q9148844', 'http://www.wikidata.org/entity/Q9148844', 'Alojzy Janowicz'),
#  ('Q9149354',
#   'http://www.wikidata.org/entity/Q9149354',
#   'Maria Amalia Mniszchowa'),
#  ('Q9160738', 'http://www.wikidata.org/entity/Q9160738', 'Artur Radziwiłł'),
#  ('Q9176889',
#   'http://www.wikidata.org/entity/Q9176889',
#   'Boleslav Stanislavovič Potocki'),
#  ('Q9252846', 'http://www.wikidata.org/entity/Q9252846', 'Eliza Krasińska'),
#  ('Q9262636',
#   'http://www.wikidata.org/entity/Q9262636',
#   'Franciszek Ksawery Sapieha'),
#  ('Q9382095',
#   'http://www.wikidata.org/entity/Q9382095',
#   'Count Ladislaus Branicki'),
#  ('Q10357801',
#   'http://www.wikidata.org/entity/Q10357801',
#   'Paul Martinovich Skavronsky'),
#  ('Q11285857',
#   'http://www.wikidata.org/entity/Q11285857',
#   'Jerzy Henryk Lubomirski'),
#  ('Q11307766',
#   'http://www.wikidata.org/entity/Q11307766',
#   'Adolphe de Polier'),
#  ('Q11717108',
#   'http://www.wikidata.org/entity/Q11717108',
#   'Jan Boży Krasicki'),
#  ('Q11718497',
#   'http://www.wikidata.org/entity/Q11718497',
#   'Jan Nepomucen Eryk Potocki'),
#  ('Q11731189', 'http://www.wikidata.org/entity/Q11731189', 'Józef Potocki'),
#  ('Q11750332', 'http://www.wikidata.org/entity/Q11750332', 'Ksawery Branicki'),
#  ('Q11750339',
#   'http://www.wikidata.org/entity/Q11750339',
#   'Ksawery Działyński'),
#  ('Q11771789', 'http://www.wikidata.org/entity/Q11771789', 'Maurycy Potocki'),
#  ('Q15029506', 'http://www.wikidata.org/entity/Q15029506', 'Ignacy Potocki'),
#  ('Q15060958', 'http://www.wikidata.org/entity/Q15060958', 'Pavel Shuvalov'),
#  ('Q15060960', 'http://www.wikidata.org/entity/Q15060960', 'Andrey Shuvalov'),
#  ('Q15832909',
#   'http://www.wikidata.org/entity/Q15832909',
#   'Ludwig Joseph Uhland'),
#  ('Q16200269',
#   'http://www.wikidata.org/entity/Q16200269',
#   'Marie-Clementine Bagration'),
#  ('Q16561043', 'http://www.wikidata.org/entity/Q16561043', 'Jakub Komorowski'),
#  ('Q16637490',
#   'http://www.wikidata.org/entity/Q16637490',
#   'Alexander Sergeevich Golitsyn'),
#  ('Q18590242', 'http://www.wikidata.org/entity/Q18590242', 'Jarosław Potocki'),
#  ('Q19916444', 'http://www.wikidata.org/entity/Q19916444', 'Grigory Senyavin'),
#  ('Q21591124',
#   'http://www.wikidata.org/entity/Q21591124',
#   'Felix-Nicolas Potocki'),
#  ('Q21711184',
#   'http://www.wikidata.org/entity/Q21711184',
#   'Aleksandr Polyansky'),
#  ('Q21723130', 'http://www.wikidata.org/entity/Q21723130', 'Q21723130'),
#  ('Q22978336', 'http://www.wikidata.org/entity/Q22978336', 'Marianna Łaszcz'),
#  ('Q23614621',
#   'http://www.wikidata.org/entity/Q23614621',
#   'John Vesey, 4th Viscount de Vesci'),
#  ('Q26903834', 'http://www.wikidata.org/entity/Q26903834', 'Zofia Kalinowska'),
#  ('Q27539092',
#   'http://www.wikidata.org/entity/Q27539092',
#   'Микола Єло-Малинський'),
#  ('Q28949706',
#   'http://www.wikidata.org/entity/Q28949706',
#   'Elizabeth Matilda Radziwill'),
#  ('Q28973658', 'http://www.wikidata.org/entity/Q28973658', 'Róża Zamoyska'),
#  ('Q43255418',
#   'http://www.wikidata.org/entity/Q43255418',
#   "Innozenz Fürst von Odescalchi d'Erba"),
#  ('Q43255437',
#   'http://www.wikidata.org/entity/Q43255437',
#   'Livio Odescalchi, V principe Odescalchi'),
#  ('Q55103281',
#   'http://www.wikidata.org/entity/Q55103281',
#   'Aleksandr Engelhardt'),
#  ('Q61198091', 'http://www.wikidata.org/entity/Q61198091', 'Anna Maslowa'),
#  ('Q61198122', 'http://www.wikidata.org/entity/Q61198122', 'Q61198122'),
#  ('Q61809573',
#   'http://www.wikidata.org/entity/Q61809573',
#   'Maria Gräfin Skowronska'),
#  ('Q62090851',
#   'http://www.wikidata.org/entity/Q62090851',
#   'Dominik Radziwiłł'),
#  ('Q62500946',
#   'http://www.wikidata.org/entity/Q62500946',
#   'Viktor Odescalchi'),
#  ('Q62882758',
#   'http://www.wikidata.org/entity/Q62882758',
#   'Rozalia Róża Mostowska'),
#  ('Q65922485', 'http://www.wikidata.org/entity/Q65922485', 'Ewa Skaszewska'),
#  ('Q67147086', 'http://www.wikidata.org/entity/Q67147086', 'Konstancja Tarło'),
#  ('Q75251362',
#   'http://www.wikidata.org/entity/Q75251362',
#   'Frances Isabella Catherine Vesey'),
#  ('Q75268252',
#   'http://www.wikidata.org/entity/Q75268252',
#   'Mary Caroline Brudenell-Bruce, Marchioness of Ailesbury'),
#  ('Q75278573',
#   'http://www.wikidata.org/entity/Q75278573',
#   'Lady Georgiana Herbert'),
#  ('Q75281883', 'http://www.wikidata.org/entity/Q75281883', 'Sidney Meade'),
#  ('Q75330563', 'http://www.wikidata.org/entity/Q75330563', 'Pelagia Sapieha'),
#  ('Q75330579',
#   'http://www.wikidata.org/entity/Q75330579',
#   'Prince Anton Radziwill'),
#  ('Q75330584',
#   'http://www.wikidata.org/entity/Q75330584',
#   'Princess Roza Radziwill'),
#  ('Q75330636',
#   'http://www.wikidata.org/entity/Q75330636',
#   'Prince Andrew Swiatopelk-Czetwertynski'),
#  ('Q75330640',
#   'http://www.wikidata.org/entity/Q75330640',
#   'Princess Roza Swiatopelk-Czetwertynski'),
#  ('Q75330671',
#   'http://www.wikidata.org/entity/Q75330671',
#   'Princess Marie Elizabeth Swiatopelk-Czetwertynski'),
#  ('Q75330693',
#   'http://www.wikidata.org/entity/Q75330693',
#   'Prince Stanislaw Lubomirski'),
#  ('Q75330700',
#   'http://www.wikidata.org/entity/Q75330700',
#   'Prince Zdislaw Lubomirski'),
#  ('Q75330723',
#   'http://www.wikidata.org/entity/Q75330723',
#   'Princess Elizabeth Radziwill'),
#  ('Q75330727',
#   'http://www.wikidata.org/entity/Q75330727',
#   'Count Alfred Tyszkiewicz'),
#  ('Q75347173', 'http://www.wikidata.org/entity/Q75347173', 'Charles Herbert'),
#  ('Q75519294',
#   'http://www.wikidata.org/entity/Q75519294',
#   'Countess Constanza Honorata Sobanska'),
#  ('Q75519297',
#   'http://www.wikidata.org/entity/Q75519297',
#   'Pawel Sapieha, Prince Sapieha'),
#  ('Q75530746',
#   'http://www.wikidata.org/entity/Q75530746',
#   'Joanna Tyszkiewiczowna'),
#  ('Q75631188',
#   'http://www.wikidata.org/entity/Q75631188',
#   'Lady Alexandrina Victoria Murray'),
#  ('Q75826009', 'http://www.wikidata.org/entity/Q75826009', 'Mary Bold'),
#  ('Q75940386',
#   'http://www.wikidata.org/entity/Q75940386',
#   'Herbert George Philip Meade'),
#  ('Q75960521', 'http://www.wikidata.org/entity/Q75960521', 'Anne Scott'),
#  ('Q75960528', 'http://www.wikidata.org/entity/Q75960528', 'Walter Scott'),
#  ('Q76114512',
#   'http://www.wikidata.org/entity/Q76114512',
#   'Catherine Giustiniani'),
#  ('Q76114570',
#   'http://www.wikidata.org/entity/Q76114570',
#   'Giambattista Rospigliosi'),
#  ('Q76281374',
#   'http://www.wikidata.org/entity/Q76281374',
#   'Princess Flaminia Odescalchi'),
#  ('Q88944302',
#   'http://www.wikidata.org/entity/Q88944302',
#   'Praskovya Golitsyna'),
#  ('Q94766239',
#   'http://www.wikidata.org/entity/Q94766239',
#   'Julie von Eichhorn'),
#  ('Q98270879',
#   'http://www.wikidata.org/entity/Q98270879',
#   'Jan Zbigniew Potocki'),
#  ('Q100151843',
#   'http://www.wikidata.org/entity/Q100151843',
#   'Isabela Marie Rzewuská'),
#  ('Q100276864',
#   'http://www.wikidata.org/entity/Q100276864',
#   'Anna Chernyshyova'),
#  ('Q100276879',
#   'http://www.wikidata.org/entity/Q100276879',
#   'Fyodor Golitsyn'),
#  ('Q102432232',
#   'http://www.wikidata.org/entity/Q102432232',
#   'Ivan Ribeaupierre'),
#  ('Q102515921',
#   'http://www.wikidata.org/entity/Q102515921',
#   'Maria Magdalena Louisa Fromm'),
#  ('Q102536340', 'http://www.wikidata.org/entity/Q102536340', 'Anna Potocka'),
#  ('Q103942821',
#   'http://www.wikidata.org/entity/Q103942821',
#   'Mariya Shuvalova'),
#  ('Q104705939',
#   'http://www.wikidata.org/entity/Q104705939',
#   'Yekaterina Golitsyna'),
#  ('Q105679898', 'http://www.wikidata.org/entity/Q105679898', 'Branicki Józef'),
#  ('Q105839650',
#   'http://www.wikidata.org/entity/Q105839650',
#   'Pyotr Vasilyevich Engelhardt'),
#  ('Q106547622', 'http://www.wikidata.org/entity/Q106547622', 'Pyotr Balashov'),
#  ('Q106547862',
#   'http://www.wikidata.org/entity/Q106547862',
#   'Mariya Kantakuzen'),
#  ('Q107294416',
#   'http://www.wikidata.org/entity/Q107294416',
#   'Darya Kondyreva'),
#  ('Q107380259', 'http://www.wikidata.org/entity/Q107380259', 'Idalia Potocka'),
#  ('Q108843925', 'http://www.wikidata.org/entity/Q108843925', 'Q108843925'),
#  ('Q108843934', 'http://www.wikidata.org/entity/Q108843934', 'Q108843934'),
#  ('Q109128842',
#   'http://www.wikidata.org/entity/Q109128842',
#   'Maria Stroganova (Potockaya)'),
#  ('Q109796591',
#   'http://www.wikidata.org/entity/Q109796591',
#   'Justina Susanna von Bradke'),
#  ('Q110393958', 'http://www.wikidata.org/entity/Q110393958', 'Róża Potocka'),
#  ('Q112384642',
#   'http://www.wikidata.org/entity/Q112384642',
#   'Vasili Silich Potyomkin'),
#  ('Q112384645',
#   'http://www.wikidata.org/entity/Q112384645',
#   'Sila Semenovich Potyomkin'),
#  ('Q112384648', 'http://www.wikidata.org/entity/Q112384648', 'NN'),
#  ('Q114086205',
#   'http://www.wikidata.org/entity/Q114086205',
#   'Artur Octavien François de Choiseul-Gouffier'),
#  ('Q114637673',
#   'http://www.wikidata.org/entity/Q114637673',
#   'Ludwika Pelagia Potocka'),
#  ('Q114797093',
#   'http://www.wikidata.org/entity/Q114797093',
#   'Aleksandra Pavlova Prezhbiano'),
#  ('Q115013896', 'http://www.wikidata.org/entity/Q115013896', 'Q115013896'),
#  ('Q255', 'http://www.wikidata.org/entity/Q255', 'Ludwig van Beethoven'),
#  ('Q859', 'http://www.wikidata.org/entity/Q859', 'Plato'),
#  ('Q868', 'http://www.wikidata.org/entity/Q868', 'Aristotle'),
#  ('Q5679', 'http://www.wikidata.org/entity/Q5679', 'Lord Byron'),
#  ('Q9047',
#   'http://www.wikidata.org/entity/Q9047',
#   'Gottfried Wilhelm Leibniz'),
#  ('Q9191', 'http://www.wikidata.org/entity/Q9191', 'René Descartes'),
#  ('Q15189', 'http://www.wikidata.org/entity/Q15189', 'Paul I of Russia'),
#  ('Q36742', 'http://www.wikidata.org/entity/Q36742', 'Ignacy Potocki'),
#  ('Q58424',
#   'http://www.wikidata.org/entity/Q58424',
#   'Józef Wandalin Mniszech'),
#  ('Q58428', 'http://www.wikidata.org/entity/Q58428', 'Jerzy August Mniszech'),
#  ('Q61826',
#   'http://www.wikidata.org/entity/Q61826',
#   'Joanna Elisabeth of Holstein-Gottorp'),
#  ('Q63928', 'http://www.wikidata.org/entity/Q63928', 'Caroline Schelling'),
#  ('Q76576',
#   'http://www.wikidata.org/entity/Q76576',
#   'Friedrich Schleiermacher'),
#  ('Q76725', 'http://www.wikidata.org/entity/Q76725', 'Max Stirner'),
#  ('Q102585',
#   'http://www.wikidata.org/entity/Q102585',
#   'Johann Gottlieb Fichte'),
#  ('Q102875',
#   'http://www.wikidata.org/entity/Q102875',
#   'Christian Friedrich von Schnurrer'),
#  ('Q151789', 'http://www.wikidata.org/entity/Q151789', 'Peter III of Russia'),
#  ('Q155547',
#   'http://www.wikidata.org/entity/Q155547',
#   'Johann Gottfried Herder'),
#  ('Q235611', 'http://www.wikidata.org/entity/Q235611', 'Yekaterina Dashkova'),
#  ('Q251926',
#   'http://www.wikidata.org/entity/Q251926',
#   'Giovanni Battista Casti'),
#  ('Q276487', 'http://www.wikidata.org/entity/Q276487', 'Catherine Bagration'),
#  ('Q337595',
#   'http://www.wikidata.org/entity/Q337595',
#   'Sidney Herbert, 1st Baron Herbert of Lea'),
#  ('Q367109', 'http://www.wikidata.org/entity/Q367109', 'Jan Potocki'),
#  ('Q444445',
#   'http://www.wikidata.org/entity/Q444445',
#   'Aleksej Nikolajevič Bahmetjev'),
#  ('Q466151', 'http://www.wikidata.org/entity/Q466151', 'Mikhail Vorontsov'),
#  ('Q558139',
#   'http://www.wikidata.org/entity/Q558139',
#   'Wacław Seweryn Rzewuski'),
#  ('Q643004',
#   'http://www.wikidata.org/entity/Q643004',
#   'Pavel Andreyevich Shuvalov'),
#  ('Q675408',
#   'http://www.wikidata.org/entity/Q675408',
#   'Maciej Mikołaj Radziwiłł'),
#  ('Q690123',
#   'http://www.wikidata.org/entity/Q690123',
#   'August Aleksander Czartoryski'),
#  ('Q699473',
#   'http://www.wikidata.org/entity/Q699473',
#   'Christian August, Prince of Anhalt-Zerbst'),
#  ('Q717801', 'http://www.wikidata.org/entity/Q717801', 'Pavel Kiselyov'),
#  ('Q1293297', 'http://www.wikidata.org/entity/Q1293297', 'Edward Raczyński'),
#  ('Q1361286',
#   'http://www.wikidata.org/entity/Q1361286',
#   'Stanisław Kostka Potocki'),
#  ('Q1506392',
#   'http://www.wikidata.org/entity/Q1506392',
#   'Georg Wilding von Butera und Radali'),
#  ('Q1693612',
#   'http://www.wikidata.org/entity/Q1693612',
#   'Johann Friedrich LeBret'),
#  ('Q1995842',
#   'http://www.wikidata.org/entity/Q1995842',
#   'Yekaterina von Engelhardt'),
#  ('Q2073326', 'http://www.wikidata.org/entity/Q2073326', 'Varvara Golitsyna'),
#  ('Q2380794',
#   'http://www.wikidata.org/entity/Q2380794',
#   'Alexander Vorontsov'),
#  ('Q2626847', 'http://www.wikidata.org/entity/Q2626847', 'Józef Potocki'),
#  ('Q2628182',
#   'http://www.wikidata.org/entity/Q2628182',
#   'Kazimierz Nestor Sapieha'),
#  ('Q2832518',
#   'http://www.wikidata.org/entity/Q2832518',
#   'Aleksander Stanisław Potocki'),
#  ('Q2833841',
#   'http://www.wikidata.org/entity/Q2833841',
#   'Alexander Lvovich Naryshkin'),
#  ('Q2834383', 'http://www.wikidata.org/entity/Q2834383', 'Alexei Senyavin'),
#  ('Q2972188', 'http://www.wikidata.org/entity/Q2972188', 'Roman Sanguszko'),
#  ('Q3021581', 'http://www.wikidata.org/entity/Q3021581', 'Delfina Potocka'),
#  ('Q3123862', 'http://www.wikidata.org/entity/Q3123862', 'Józef Kossakowski'),
#  ('Q3335862', 'http://www.wikidata.org/entity/Q3335862', 'Naum Senyavin'),
#  ('Q3434234',
#   'http://www.wikidata.org/entity/Q3434234',
#   'Sergej Fedorovič Golicyn'),
#  ('Q3609589', 'http://www.wikidata.org/entity/Q3609589', 'Alexey  Bobrinsky'),
#  ('Q3672163', 'http://www.wikidata.org/entity/Q3672163', 'Izabela Lubomirska'),
#  ('Q3784285', 'http://www.wikidata.org/entity/Q3784285', 'Maria Senyavina'),
#  ('Q3917274',
#   'http://www.wikidata.org/entity/Q3917274',
#   'Anna Katarzyna Radziwiłłowa'),
#  ('Q3920420', 'http://www.wikidata.org/entity/Q3920420', 'Franciszek Sapieha'),
#  ('Q4111755',
#   'http://www.wikidata.org/entity/Q4111755',
#   'George Herbert, 11th Earl of Pembroke'),
#  ('Q4125760', 'http://www.wikidata.org/entity/Q4125760', 'Ivan Vorontsov'),
#  ('Q4125779', 'http://www.wikidata.org/entity/Q4125779', 'Semyon Vorontsov'),
#  ('Q4125786',
#   'http://www.wikidata.org/entity/Q4125786',
#   'Ivan Vorontsov-Dashkov'),
#  ('Q4125791',
#   'http://www.wikidata.org/entity/Q4125791',
#   'Mariya Vorontsova-Dashkova'),
#  ('Q4141564',
#   'http://www.wikidata.org/entity/Q4141564',
#   'Grigory Sergeevich Golitsyn'),
#  ('Q4141606',
#   'http://www.wikidata.org/entity/Q4141606',
#   "Natal'ja Stepanovna Apraksina"),
#  ('Q4185792',
#   'http://www.wikidata.org/entity/Q4185792',
#   'Stanisław Kostka Zamoyski'),
#  ('Q4237839',
#   'http://www.wikidata.org/entity/Q4237839',
#   'Władysław Krasiński'),
#  ('Q4308386',
#   'http://www.wikidata.org/entity/Q4308386',
#   'Vladimir Musin-Pushkin'),
#  ('Q4313557', 'http://www.wikidata.org/entity/Q4313557', 'Kirill Naryshkin'),
#  ('Q4313560', 'http://www.wikidata.org/entity/Q4313560', 'Lev Naryshkin'),
#  ('Q4374911',
#   'http://www.wikidata.org/entity/Q4374911',
#   'Józef Mikołaj Potocki'),
#  ('Q4374912', 'http://www.wikidata.org/entity/Q4374912', 'Paweł Potocki'),
#  ('Q4374916', 'http://www.wikidata.org/entity/Q4374916', 'Seweryn Potocki'),
#  ('Q4374918', 'http://www.wikidata.org/entity/Q4374918', 'Stanisław Potocki'),
#  ('Q4410600', 'http://www.wikidata.org/entity/Q4410600', 'Nikanor Svechin'),
#  ('Q4421309',
#   'http://www.wikidata.org/entity/Q4421309',
#   'Count Martyn Karlovich Skavronsky'),
#  ('Q4535388', 'http://www.wikidata.org/entity/Q4535388', 'Boris Yusupov'),
#  ('Q4535403',
#   'http://www.wikidata.org/entity/Q4535403',
#   'Zinaida Ivanovna Yusupova'),
#  ('Q4767540',
#   'http://www.wikidata.org/entity/Q4767540',
#   'Anna Teresa Ossolińska'),
#  ('Q4776193', 'http://www.wikidata.org/entity/Q4776193', 'Antoni Potocki'),
#  ('Q5935407',
#   'http://www.wikidata.org/entity/Q5935407',
#   'Henry Petty-Fitzmaurice, 4th Marquess of Lansdowne'),
#  ('Q6149595',
#   'http://www.wikidata.org/entity/Q6149595',
#   'Jan Nepomucen Potocki'),
#  ('Q6239436',
#   'http://www.wikidata.org/entity/Q6239436',
#   'John Hobart Caradoc, 2nd Baron Howden'),
#  ('Q6320568', 'http://www.wikidata.org/entity/Q6320568', 'Józef Lubomirski'),
#  ('Q6320574',
#   'http://www.wikidata.org/entity/Q6320574',
#   'Józef Makary Potocki'),
#  ('Q6320792',
#   'http://www.wikidata.org/entity/Q6320792',
#   'Józefina Amalia Mniszech'),
#  ('Q7345437', 'http://www.wikidata.org/entity/Q7345437', 'Robert Henry Meade'),
#  ('Q7386596',
#   'http://www.wikidata.org/entity/Q7386596',
#   'Róża Maria Wodzicka'),
#  ('Q7599129',
#   'http://www.wikidata.org/entity/Q7599129',
#   'Stanisław Dunin-Wąsowicz'),
#  ('Q8073362', 'http://www.wikidata.org/entity/Q8073362', 'Zofia Branicka'),
#  ('Q9146738',
#   'http://www.wikidata.org/entity/Q9146738',
#   'Aleksandra z Potockich Potocka'),
#  ('Q9152782', 'http://www.wikidata.org/entity/Q9152782', 'Andrzej Lubomirski'),
#  ('Q9155125', 'http://www.wikidata.org/entity/Q9155125', 'Anna Potocka'),
#  ('Q9155230',
#   'http://www.wikidata.org/entity/Q9155230',
#   'Anna Jadwiga Sapieżyna'),
#  ('Q9162035', 'http://www.wikidata.org/entity/Q9162035', 'August Potocki'),
#  ('Q9253321', 'http://www.wikidata.org/entity/Q9253321', 'Elżbieta Branicka'),
#  ('Q9256429', 'http://www.wikidata.org/entity/Q9256429', 'Eustachy Potocki'),
#  ('Q9354623', 'http://www.wikidata.org/entity/Q9354623', 'Tadeusz Mostowski'),
#  ('Q9356981',
#   'http://www.wikidata.org/entity/Q9356981',
#   'Teofila Strzeżysława z Jabłonowskich Sapieżyna'),
#  ('Q11294112',
#   'http://www.wikidata.org/entity/Q11294112',
#   'Kazimierz Lubomirski'),
#  ('Q11686222',
#   'http://www.wikidata.org/entity/Q11686222',
#   'Anna Branicka-Wolska'),
#  ('Q11714732',
#   'http://www.wikidata.org/entity/Q11714732',
#   'Izabella Róża Radziwiłłowa'),
#  ('Q11718128', 'http://www.wikidata.org/entity/Q11718128', 'Jan Krasiński'),
#  ('Q11731319', 'http://www.wikidata.org/entity/Q11731319', 'Józef Sapieha'),
#  ('Q11736206',
#   'http://www.wikidata.org/entity/Q11736206',
#   'Karol Mikołaj Radziwiłł'),
#  ('Q11737678',
#   'http://www.wikidata.org/entity/Q11737678',
#   'Kazimierz Antoni Sanguszko'),
#  ('Q11738455',
#   'http://www.wikidata.org/entity/Q11738455',
#   'Kazimierz Wodzicki'),
#  ('Q11742831',
#   'http://www.wikidata.org/entity/Q11742831',
#   'Konstancja Małgorzata Lubomirska'),
#  ('Q11742832',
#   'http://www.wikidata.org/entity/Q11742832',
#   'Konstancja Poniatowska'),
#  ('Q11742940',
#   'http://www.wikidata.org/entity/Q11742940',
#   'Konstanty Mikołaj Radziwiłł II'),
#  ('Q11750335', 'http://www.wikidata.org/entity/Q11750335', 'Xavier Branicki'),
#  ('Q11766000',
#   'http://www.wikidata.org/entity/Q11766000',
#   'Magdalena Agnieszka Sapieżyna'),
#  ('Q11766641',
#   'http://www.wikidata.org/entity/Q11766641',
#   'Maksymilian Hilary Ossoliński'),
#  ('Q11769839',
#   'http://www.wikidata.org/entity/Q11769839',
#   'Marianna Mniszech'),
#  ('Q11771794',
#   'http://www.wikidata.org/entity/Q11771794',
#   'Maurycy Stanisław Potocki'),
#  ('Q11779943',
#   'http://www.wikidata.org/entity/Q11779943',
#   'Mieczysław Franciszek Potocki'),
#  ('Q12103888',
#   'http://www.wikidata.org/entity/Q12103888',
#   'Pavel Vasilyevich Engelhardt'),
#  ('Q12110477',
#   'http://www.wikidata.org/entity/Q12110477',
#   'Klementyna Tyszkiewicz'),
#  ('Q12142898',
#   'http://www.wikidata.org/entity/Q12142898',
#   'Alexandr Mikhailovich Potemkin'),
#  ('Q12142901',
#   'http://www.wikidata.org/entity/Q12142901',
#   'Tatiana Borisovna Potemkina'),
#  ('Q12780018', 'http://www.wikidata.org/entity/Q12780018', 'Clara Waitz'),
#  ('Q13031216',
#   'http://www.wikidata.org/entity/Q13031216',
#   'Leon Władysław Radziwiłł'),
#  ('Q15340362', 'http://www.wikidata.org/entity/Q15340362', 'Marie Potocka'),
#  ('Q16200028',
#   'http://www.wikidata.org/entity/Q16200028',
#   'Ewa Józefina Julia Potocka'),
#  ('Q16588072',
#   'http://www.wikidata.org/entity/Q16588072',
#   'Piotr Franciszek Branicki'),
#  ('Q17063837',
#   'http://www.wikidata.org/entity/Q17063837',
#   'Hieronim Sanguszko'),
#  ('Q17095533',
#   'http://www.wikidata.org/entity/Q17095533',
#   'Adam Zdzisław Zamoyski'),
#  ('Q19478933', 'http://www.wikidata.org/entity/Q19478933', 'Nikolay Yusupov'),
#  ('Q19772461',
#   'http://www.wikidata.org/entity/Q19772461',
#   'Aleksandr Golitsyn-Prozorovsky'),
#  ('Q21198339',
#   'http://www.wikidata.org/entity/Q21198339',
#   'Georg Ludwig Hegel'),
#  ('Q21644012',
#   'http://www.wikidata.org/entity/Q21644012',
#   'Aleksandr Polyansky'),
#  ('Q22340304', 'http://www.wikidata.org/entity/Q22340304', 'Marie von Tucher'),
#  ('Q22911301',
#   'http://www.wikidata.org/entity/Q22911301',
#   'Konstancja Sapieha'),
#  ('Q22970794',
#   'http://www.wikidata.org/entity/Q22970794',
#   'Teofila Teresa Cetner'),
#  ('Q23925203', 'http://www.wikidata.org/entity/Q23925203', 'Andrey Shuvalov'),
#  ('Q27516690',
#   'http://www.wikidata.org/entity/Q27516690',
#   'Prince Ludwik Swiatopelk-Czetwertynski'),
#  ('Q28497379',
#   'http://www.wikidata.org/entity/Q28497379',
#   'Anna Alexandrovna Golitsyna'),
#  ('Q29358858', 'http://www.wikidata.org/entity/Q29358858', 'Pavel Dashkov'),
#  ('Q29932576', 'http://www.wikidata.org/entity/Q29932576', 'Pelagia Sapieha'),
#  ('Q43255423',
#   'http://www.wikidata.org/entity/Q43255423',
#   'Prince Balthazar Odescalchi'),
#  ('Q47145827', 'http://www.wikidata.org/entity/Q47145827', 'Fryderyk Sapieha'),
#  ('Q47393713',
#   'http://www.wikidata.org/entity/Q47393713',
#   'Vasily Engelhardt'),
#  ('Q47992127',
#   'http://www.wikidata.org/entity/Q47992127',
#   'Maria Nikolayevna Stroganova'),
#  ('Q61198110',
#   'http://www.wikidata.org/entity/Q61198110',
#   'Marfa Ivanovna Surmina'),
#  ('Q61198167', 'http://www.wikidata.org/entity/Q61198167', 'Nenilla Yazykova'),
#  ('Q61198191',
#   'http://www.wikidata.org/entity/Q61198191',
#   'Anna Elisabeth von Bradke'),
#  ('Q61637775',
#   'http://www.wikidata.org/entity/Q61637775',
#   'Praskovya Sheremeteva'),
#  ('Q61638016',
#   'http://www.wikidata.org/entity/Q61638016',
#   'Aleksandra Naryshkina'),
#  ('Q61809857',
#   'http://www.wikidata.org/entity/Q61809857',
#   'Vassili von Engelhardt'),
#  ('Q61809861',
#   'http://www.wikidata.org/entity/Q61809861',
#   'Yelena Potyomkina'),
#  ('Q61982644',
#   'http://www.wikidata.org/entity/Q61982644',
#   'Yekaterina Samoylova'),
#  ('Q62780720',
#   'http://www.wikidata.org/entity/Q62780720',
#   'Maria Aniela Sapieha'),
#  ('Q63255363',
#   'http://www.wikidata.org/entity/Q63255363',
#   'Babette Countess Keglevich de Buzin'),
#  ('Q63645174',
#   'http://www.wikidata.org/entity/Q63645174',
#   'Catherine Gordon Byron'),
#  ('Q64024926',
#   'http://www.wikidata.org/entity/Q64024926',
#   'Konstancja Czapska'),
#  ('Q67131119', 'http://www.wikidata.org/entity/Q67131119', 'Aniela Sapieha'),
#  ('Q75246898',
#   'http://www.wikidata.org/entity/Q75246898',
#   'Nikolay Sheremetev'),
#  ('Q75249398', 'http://www.wikidata.org/entity/Q75249398', 'Beatrice Vesey'),
#  ('Q75253381',
#   'http://www.wikidata.org/entity/Q75253381',
#   'Lady Emma Herbert'),
#  ('Q75280057',
#   'http://www.wikidata.org/entity/Q75280057',
#   'Lady Diana Herbert'),
#  ('Q75281989',
#   'http://www.wikidata.org/entity/Q75281989',
#   'Lady Susan Murray'),
#  ('Q75330556',
#   'http://www.wikidata.org/entity/Q75330556',
#   'Princess Izabella Radziwill'),
#  ('Q75330587',
#   'http://www.wikidata.org/entity/Q75330587',
#   'Prince Jerzy Swiatopelk-Czetwertynski'),
#  ('Q75330603',
#   'http://www.wikidata.org/entity/Q75330603',
#   'Prince Stanislaw Swiatopelk-Czetwertynski'),
#  ('Q75330681',
#   'http://www.wikidata.org/entity/Q75330681',
#   'Prince Hubert Lubomirski'),
#  ('Q75330682',
#   'http://www.wikidata.org/entity/Q75330682',
#   'Prince Jan Lubomirski'),
#  ('Q75330685',
#   'http://www.wikidata.org/entity/Q75330685',
#   'Prince Hubert Lubomirski'),
#  ('Q75330702',
#   'http://www.wikidata.org/entity/Q75330702',
#   'Prince Henryk Lubomirski'),
#  ('Q75330728',
#   'http://www.wikidata.org/entity/Q75330728',
#   'Wladimir Zeromski'),
#  ('Q75330730', 'http://www.wikidata.org/entity/Q75330730', 'Jadwiga Żeromska'),
#  ('Q75519298',
#   'http://www.wikidata.org/entity/Q75519298',
#   'María Karolina Sapieha, Princess Sapieha'),
#  ('Q75519313',
#   'http://www.wikidata.org/entity/Q75519313',
#   'Louis Benoît Joseph Sapieha, Prince Sapieha'),
#  ('Q75519362',
#   'http://www.wikidata.org/entity/Q75519362',
#   'Ksawery Franciszek Sapieha, Prince Sapieha'),
#  ('Q75528170',
#   'http://www.wikidata.org/entity/Q75528170',
#   'Leon Ludwick Sapieha'),
#  ('Q75625422',
#   'http://www.wikidata.org/entity/Q75625422',
#   'Teresa Suffcyznska'),
#  ('Q75677852',
#   'http://www.wikidata.org/entity/Q75677852',
#   'Georgiana Mary Vesey'),
#  ('Q75960529', 'http://www.wikidata.org/entity/Q75960529', 'Anne Rutherford'),
#  ('Q75970453',
#   'http://www.wikidata.org/entity/Q75970453',
#   'Yelizaveta Sheremeteva'),
#  ('Q75970454',
#   'http://www.wikidata.org/entity/Q75970454',
#   'Yekaterina Sheremeteva'),
#  ('Q76297708',
#   'http://www.wikidata.org/entity/Q76297708',
#   'Lady Mary Catherine Herbert'),
#  ('Q76352811',
#   'http://www.wikidata.org/entity/Q76352811',
#   'Sofiya Vorontsova-Dashkova'),
#  ('Q84312899',
#   'http://www.wikidata.org/entity/Q84312899',
#   'Natalya Golitsyna'),
#  ('Q87112319', 'http://www.wikidata.org/entity/Q87112319', 'Teresa Raczyńska'),
#  ('Q91813941', 'http://www.wikidata.org/entity/Q91813941', 'Wanda Potocki'),
#  ('Q91813952',
#   'http://www.wikidata.org/entity/Q91813952',
#   'Anna Teresa Sapieha'),
#  ('Q93160853', 'http://www.wikidata.org/entity/Q93160853', 'Q93160853'),
#  ('Q101082110',
#   'http://www.wikidata.org/entity/Q101082110',
#   'Varvara Shuvalova'),
#  ('Q102536333',
#   'http://www.wikidata.org/entity/Q102536333',
#   'Izabela Malinska'),
#  ('Q104474913',
#   'http://www.wikidata.org/entity/Q104474913',
#   'Sofya Naryshkina'),
#  ('Q104475363',
#   'http://www.wikidata.org/entity/Q104475363',
#   'Mariya Shuvalova'),
#  ('Q104665676',
#   'http://www.wikidata.org/entity/Q104665676',
#   'Praskovya Urusova'),
#  ('Q104706141',
#   'http://www.wikidata.org/entity/Q104706141',
#   'Anna Aleksandrovna Polyanskaya'),
#  ('Q105085428',
#   'http://www.wikidata.org/entity/Q105085428',
#   'Yelena Saltykova'),
#  ('Q105697795',
#   'http://www.wikidata.org/entity/Q105697795',
#   'Andrzej Franciszek Sapieha'),
#  ('Q105697796',
#   'http://www.wikidata.org/entity/Q105697796',
#   'Stanisłaŭ Kazimier Sapieha'),
#  ('Q105957578',
#   'http://www.wikidata.org/entity/Q105957578',
#   'Yekaterina Shuvalova'),
#  ('Q106547728',
#   'http://www.wikidata.org/entity/Q106547728',
#   'Alexandra Balashova'),
#  ('Q107379986', 'http://www.wikidata.org/entity/Q107379986', 'Maria Zamoyska'),
#  ('Q107380004',
#   'http://www.wikidata.org/entity/Q107380004',
#   'Maria Szweykowska'),
#  ('Q107380248', 'http://www.wikidata.org/entity/Q107380248', 'Teresa Sapieha'),
#  ('Q109127940',
#   'http://www.wikidata.org/entity/Q109127940',
#   'Anastasia Alekseeva Senjavina'),
#  ('Q114837271', 'http://www.wikidata.org/entity/Q114837271', 'Zoia Văcărescu'),
#  ('Q116247736',
#   'http://www.wikidata.org/entity/Q116247736',
#   'Maria Illarionovna Musina-Pushkina (nee Vorontsova-Dashkova)'),
#  ('Q116877323', 'http://www.wikidata.org/entity/Q116877323', 'Q116877323'),
#  ('Q6527', 'http://www.wikidata.org/entity/Q6527', 'Jean-Jacques Rousseau'),
#  ('Q9235',
#   'http://www.wikidata.org/entity/Q9235',
#   'Georg Wilhelm Friedrich Hegel'),
#  ('Q15975', 'http://www.wikidata.org/entity/Q15975', 'Montesquieu'),
#  ('Q35802', 'http://www.wikidata.org/entity/Q35802', 'Benedictus de Spinoza'),
#  ('Q41414', 'http://www.wikidata.org/entity/Q41414', 'Ludwik Tyszkiewicz'),
#  ('Q77711',
#   'http://www.wikidata.org/entity/Q77711',
#   'Antoni Wilhelm Radziwiłł'),
#  ('Q86130', 'http://www.wikidata.org/entity/Q86130', 'Karl Von Hegel'),
#  ('Q239260', 'http://www.wikidata.org/entity/Q239260', 'Pyotr Bagration'),
#  ('Q271809', 'http://www.wikidata.org/entity/Q271809', 'Proclus'),
#  ('Q349948',
#   'http://www.wikidata.org/entity/Q349948',
#   'Adam Kazimierz Czartoryski'),
#  ('Q540752', 'http://www.wikidata.org/entity/Q540752', 'Grigory Orlov'),
#  ('Q550652', 'http://www.wikidata.org/entity/Q550652', 'Seweryn Rzewuski'),
#  ('Q646034', 'http://www.wikidata.org/entity/Q646034', 'Adam Rzewuski'),
#  ('Q888263', 'http://www.wikidata.org/entity/Q888263', 'Wincenty Krasiński'),
#  ('Q1247154', 'http://www.wikidata.org/entity/Q1247154', 'Nikolay Yusupov'),
#  ('Q1439976',
#   'http://www.wikidata.org/entity/Q1439976',
#   'Illarion Vorontsov-Dashkov'),
#  ('Q1613305', 'http://www.wikidata.org/entity/Q1613305', 'Hermann Schelling'),
#  ('Q1977625',
#   'http://www.wikidata.org/entity/Q1977625',
#   'Iwan Osipowicz de Witt'),
#  ('Q2028738',
#   'http://www.wikidata.org/entity/Q2028738',
#   'Władysław Grzegorz Branicki'),
#  ('Q2063773', 'http://www.wikidata.org/entity/Q2063773', 'Pauline Gotter'),
#  ('Q2087955', 'http://www.wikidata.org/entity/Q2087955', 'Vasily Engelhardt'),
#  ('Q2506397', 'http://www.wikidata.org/entity/Q2506397', 'Stanisław Potocki'),
#  ('Q2607550',
#   'http://www.wikidata.org/entity/Q2607550',
#   'Aleksander Michał Sapieha'),
#  ('Q2713079', 'http://www.wikidata.org/entity/Q2713079', 'Mikhail Vorontsov'),
#  ('Q3919822',
#   'http://www.wikidata.org/entity/Q3919822',
#   'Stanisław Wilhelm Radziwiłł'),
#  ('Q3920403',
#   'http://www.wikidata.org/entity/Q3920403',
#   'Eustachy Kajetan Sapieha'),
#  ('Q4125787',
#   'http://www.wikidata.org/entity/Q4125787',
#   'Illarion Vorontsov-Dashkov'),
#  ('Q4141594', 'http://www.wikidata.org/entity/Q4141594', 'Fyodor Golitsyn'),
#  ('Q4264001',
#   'http://www.wikidata.org/entity/Q4264001',
#   'Giulio Renato de Litta Visconti Arese'),
#  ('Q4284126',
#   'http://www.wikidata.org/entity/Q4284126',
#   'Jerzy Friederich Radziwiłł'),
#  ('Q4375007',
#   'http://www.wikidata.org/entity/Q4375007',
#   'Mikhail Sergeevich Potemkin'),
#  ('Q4523074', 'http://www.wikidata.org/entity/Q4523074', 'Dmitry Sheremetev'),
#  ('Q4531778',
#   'http://www.wikidata.org/entity/Q4531778',
#   'Vasily Vasilyevich Engelhardt'),
#  ('Q4767640', 'http://www.wikidata.org/entity/Q4767640', 'Anna Zofia Sapieha'),
#  ('Q4801655', 'http://www.wikidata.org/entity/Q4801655', 'Artur Potocki'),
#  ('Q5341534',
#   'http://www.wikidata.org/entity/Q5341534',
#   'Edward Aleksander Raczyński'),
#  ('Q5368719',
#   'http://www.wikidata.org/entity/Q5368719',
#   'Elżbieta Lubomirska'),
#  ('Q6121572',
#   'http://www.wikidata.org/entity/Q6121572',
#   'Jadwiga Maria Potocka'),
#  ('Q6217401', 'http://www.wikidata.org/entity/Q6217401', 'John Byron'),
#  ('Q6420482',
#   'http://www.wikidata.org/entity/Q6420482',
#   'Klementyna Czartoryska'),
#  ('Q7327762',
#   'http://www.wikidata.org/entity/Q7327762',
#   'Richard Meade, 3rd Earl of Clanwilliam'),
#  ('Q7386594', 'http://www.wikidata.org/entity/Q7386594', 'Róża Maria Potocka'),
#  ('Q7599119',
#   'http://www.wikidata.org/entity/Q7599119',
#   'Stanisław Bohdan Grabiński'),
#  ('Q7606012',
#   'http://www.wikidata.org/entity/Q7606012',
#   'Stefan Adam Zamoyski'),
#  ('Q9139711', 'http://www.wikidata.org/entity/Q9139711', 'Adam Józef Potocki'),
#  ('Q9139852', 'http://www.wikidata.org/entity/Q9139852', 'Adam Krasiński'),
#  ('Q9255980',
#   'http://www.wikidata.org/entity/Q9255980',
#   'Eugeniusz Adolf Lubomirski'),
#  ('Q9259607',
#   'http://www.wikidata.org/entity/Q9259607',
#   'Filip Nereusz Raczyński'),
#  ('Q9345168', 'http://www.wikidata.org/entity/Q9345168', 'Stefan Lubomirski'),
#  ('Q10018149',
#   'http://www.wikidata.org/entity/Q10018149',
#   'Józef Felicjan Potocki'),
#  ('Q11686963', 'http://www.wikidata.org/entity/Q11686963', 'August Potocki'),
#  ('Q11718640',
#   'http://www.wikidata.org/entity/Q11718640',
#   'Prince Jan Pawel Alexander Sapieha-Rozanski'),
#  ('Q11731689', 'http://www.wikidata.org/entity/Q11731689', 'Józef de Witte'),
#  ('Q11733366',
#   'http://www.wikidata.org/entity/Q11733366',
#   'Kajetan Michał Sapieha'),
#  ('Q11735941',
#   'http://www.wikidata.org/entity/Q11735941',
#   'Karol Aleksander Krasicki'),
#  ('Q11736274',
#   'http://www.wikidata.org/entity/Q11736274',
#   'Karol Roger Raczyński'),
#  ('Q11749206',
#   'http://www.wikidata.org/entity/Q11749206',
#   'Krzysztof Franciszek Sapieha'),
#  ('Q15344816',
#   'http://www.wikidata.org/entity/Q15344816',
#   'Natalya Saltykova-Golovkina'),
#  ('Q17045211',
#   'http://www.wikidata.org/entity/Q17045211',
#   'Jan Wladyslaw Sanguszko'),
#  ('Q20028199',
#   'http://www.wikidata.org/entity/Q20028199',
#   'Aniela Mieczysławska'),
#  ('Q20165319', 'http://www.wikidata.org/entity/Q20165319', 'Olga Shuvalova'),
#  ('Q21438188',
#   'http://www.wikidata.org/entity/Q21438188',
#   'Harutyun Avgeryan'),
#  ('Q22230907',
#   'http://www.wikidata.org/entity/Q22230907',
#   'Charlotte Genevieve Charpentier'),
#  ('Q24263182',
#   'http://www.wikidata.org/entity/Q24263182',
#   'Piotr Wojciech Szembek'),
#  ('Q26882450',
#   'http://www.wikidata.org/entity/Q26882450',
#   'Waleria Melania Szembek'),
#  ('Q28500400',
#   'http://www.wikidata.org/entity/Q28500400',
#   'Yekaterina Ribeaupierre'),
#  ('Q28811997',
#   'http://www.wikidata.org/entity/Q28811997',
#   'Antonia Adela Potocka'),
#  ('Q28949767',
#   'http://www.wikidata.org/entity/Q28949767',
#   'Princess Helena Radziwill'),
#  ('Q29653042',
#   'http://www.wikidata.org/entity/Q29653042',
#   'Antonina Krasińska'),
#  ('Q50770127',
#   'http://www.wikidata.org/entity/Q50770127',
#   'Henriette Odescalchi'),
#  ('Q55104629', 'http://www.wikidata.org/entity/Q55104629', 'Boris Golitsyn'),
#  ('Q55127316', 'http://www.wikidata.org/entity/Q55127316', 'Ludwig Wihl'),
#  ('Q61716917',
#   'http://www.wikidata.org/entity/Q61716917',
#   'Sir Walter Scott, 2nd Baronet'),
#  ('Q63184580', 'http://www.wikidata.org/entity/Q63184580', 'Anna Krasicka'),
#  ('Q63184639', 'http://www.wikidata.org/entity/Q63184639', 'Anna Radziwiłł'),
#  ('Q64031190',
#   'http://www.wikidata.org/entity/Q64031190',
#   'Anna Barbara Kopać'),
#  ('Q65922309',
#   'http://www.wikidata.org/entity/Q65922309',
#   'Helena Sołomerecka'),
#  ('Q75251358',
#   'http://www.wikidata.org/entity/Q75251358',
#   'Elizabeth Beauclerk'),
#  ('Q75260050', 'http://www.wikidata.org/entity/Q75260050', 'Eustace Vesey'),
#  ('Q75281885',
#   'http://www.wikidata.org/entity/Q75281885',
#   'Lady Selina Catherine Meade'),
#  ('Q75318089', 'http://www.wikidata.org/entity/Q75318089', 'Mariya Komarova'),
#  ('Q75318111', 'http://www.wikidata.org/entity/Q75318111', 'Sofya Shuvalova'),
#  ('Q75330580',
#   'http://www.wikidata.org/entity/Q75330580',
#   'Prince Jerzy Mikolaj Radziwill, XIX Ordynat Nieswiez'),
#  ('Q75330678',
#   'http://www.wikidata.org/entity/Q75330678',
#   'Princess Teresa Radziwill'),
#  ('Q75330705',
#   'http://www.wikidata.org/entity/Q75330705',
#   'Prince Heraklius Lubomirski'),
#  ('Q75330712',
#   'http://www.wikidata.org/entity/Q75330712',
#   'Princess Anna Lubomirski'),
#  ('Q75391796', 'http://www.wikidata.org/entity/Q75391796', 'Irina Naryshkina'),
#  ('Q75396887',
#   'http://www.wikidata.org/entity/Q75396887',
#   'Franziska von Kolowrat-Krakowsky'),
#  ('Q75519364',
#   'http://www.wikidata.org/entity/Q75519364',
#   'León Kazimierz Sapieha, Prince Sapieha'),
#  ('Q75914101',
#   'http://www.wikidata.org/entity/Q75914101',
#   'Charlotte Sophia Lockhart'),
#  ('Q75960526', 'http://www.wikidata.org/entity/Q75960526', 'Charles Scott'),
#  ('Q75970455',
#   'http://www.wikidata.org/entity/Q75970455',
#   'Irina Sheremeteva'),
#  ('Q76071149', 'http://www.wikidata.org/entity/Q76071149', 'Joyous Markham'),
#  ('Q76352808',
#   'http://www.wikidata.org/entity/Q76352808',
#   'Ivan Vorontsov-Dashkov'),
#  ('Q97497657', 'http://www.wikidata.org/entity/Q97497657', 'Zofia Branicka'),
#  ('Q98593668',
#   'http://www.wikidata.org/entity/Q98593668',
#   'Cecylia Lubomirska-Zamoyska'),
#  ('Q101081838', 'http://www.wikidata.org/entity/Q101081838', 'Varvara Orlova'),
#  ('Q101208715',
#   'http://www.wikidata.org/entity/Q101208715',
#   'Sofya Ribeaupierre'),
#  ('Q101242405',
#   'http://www.wikidata.org/entity/Q101242405',
#   'Yelena Shuvalova'),
#  ('Q102515598',
#   'http://www.wikidata.org/entity/Q102515598',
#   'Georg Ludwig Christoph Hegel'),
#  ('Q104368599',
#   'http://www.wikidata.org/entity/Q104368599',
#   'Pyotr Shakhovskoy'),
#  ('Q109796556',
#   'http://www.wikidata.org/entity/Q109796556',
#   'Heinrich Niklas von Bradke'),
#  ('Q110394796',
#   'http://www.wikidata.org/entity/Q110394796',
#   'Antoine Louis Octave de Choiseul-Gouffier'),
#  ('Q111028469',
#   'http://www.wikidata.org/entity/Q111028469',
#   'Edward Oktawian de Choiseul-Gouffier')]

# %% [markdown]
# # Creating neo4j graph

# %% [markdown]
# ## connect to database

# %%
driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "password"))
driver.verify_connectivity()
session = driver.session(database="wikidatadev")

# %% [markdown]
# ## create Person nodes

# %%
all_humans_qcodes = []
for human in all_humans:
    qcode, wd_url, name = human
    all_humans_qcodes.append(qcode)
    try:
        cypher_query = f"""MERGE (:Person{{name: "{name}", wd_url: "{wd_url}"}})"""
        session.run(cypher_query)
    except CypherSyntaxError:  #  Karol Stanisław "Panie Kochanku" Radziwiłł (Q386484) 
        cypher_query = f"""MERGE (:Person{{name: '{name}', wd_url: '{wd_url}'}})"""
        session.run(cypher_query)
# ^ 2m16s dla len(all_humans) =~ 30_000 (powstałe z 399 osób z inputu)

# %%
cypher_query = f"""
CREATE INDEX person_wd_idx IF NOT EXISTS
FOR (n:Person)
ON (n.wd_url)
"""
session.run(cypher_query)

cypher_query = f"""
CREATE INDEX person_name_idx IF NOT EXISTS
FOR (n:Person)
ON (n.name)
"""
session.run(cypher_query)

# jak sprawdzić, czy indexy się założyły?

# %% [markdown]
# ## create other nodes, edges & connect to Person nodes

# %%
# # SLOW
# ERRORS = []
# length = len(rdf_info.keys())
# print("Creating edges & object nodes for: ")
# for i, qcode in enumerate(rdf_info.keys()):
#     print(f"{qcode} {i+1} / {length}")
#     for t in rdf_info[qcode]:
#         object_name, object_url = t[5].replace("'", "\\'"), t[2].replace("'", "\\'")

#         object_label = "wdLabel"
#         object_qcode = object_url[object_url.rfind("Q"):]
#         if object_qcode in all_humans_qcodes:
#             object_label = "Person"
#         else:
#             cypher_query = f"""MERGE (:{object_label}{{name: '{object_name}', wd_url: '{object_url}'}})"""
#             try:
#                 session.run(cypher_query)
#             except Exception as e:
#                 ERRORS.append(("MERGE NODE", object_url, cypher_query, e))

#         cypher_illegal_edgename_chars = ["'", ",", "(", ")", "-", ".", "/", "&", "’", "+", "+d'-", ":"]
#         edge_name = t[4].replace(' ', '_').replace("–", "_")
#         for c in cypher_illegal_edgename_chars:
#             edge_name = edge_name.replace(c, "")
#         edge_name = edge_name.upper()
#         edge_url = t[1]

#         subject_url = t[0].replace("'", "\\'")
#         person_name = t[3].replace("'", "\\'")
#         try:
#             s = f"""
#             MATCH (p:Person), (l:{object_label}) 
#             WHERE p.wd_url="{subject_url}" AND l.wd_url='{object_url}'
#             MERGE (p)-[:`{edge_name}` {{wd_url: '{edge_url}', source: 'wikidata'}}]->(l)
#             """
#             session.run(s)
#         except Exception as e:
#             ERRORS.append(("MERGE EDGE", object_url, s, e))

# %%
# ^ 9s dla len(rdf_info.keys()) = 35 len(all_humans) = 88
# ^ 45s dla len(rdf_info.keys()) = 36 len(all_humans) = 170
# ^ 936m 52s dla len(rdf_info.keys()) = 13171 len(all_humans) = 29966

# %%
# ERRORS
# ^ lista ERRORS była pusta dla 936m 52s dla len(rdf_info.keys()) = 13171 len(all_humans) = 29966. To pewnie jakiś błąd jupytera(?), może za długo komórka działała. Jakeiś errory musiały się pojawić....

# %%
# WORK IN PROGRESS 
edges_csv_fp = r"C:\GraphProject\Places_People_and_Events\Krzysztof\edges.csv"
wdLabel_nodes_csv_fp =  r"C:\GraphProject\Places_People_and_Events\Krzysztof\wdLabel_nodes.csv"

non_person_node_label = "wdLabel"
unique_edge_names = set()
with open(edges_csv_fp, "w", newline="") as f:
    with open(wdLabel_nodes_csv_fp, "w", newline="") as f2:
        writer = csv.writer(f, delimiter=";")
        fields = ["subject_url", "edge_url", "object_url", "subject_name", "edge_name", "object_name", "object_label"]
        writer.writerow(fields)

        writer2 = csv.writer(f2, delimiter=";")
        fields2 = ["object_name", "object_url"]
        writer2.writerow(fields2)

        length = len(rdf_info.keys())
        for i, qcode in enumerate(rdf_info.keys()):
            for t in rdf_info[qcode]:
                subject_url = t[0].replace("'", "\\'")
                subject_name = t[3].replace("'", "\\'")
                edge_url = t[1]
                edge_name = t[4].replace(' ', '_').replace("–", "_")
                cypher_illegal_edgename_chars = ["'", ",", "(", ")", "-", ".", "/", "&", "’", "+", "+d'-", ":", ";"]
                for c in cypher_illegal_edgename_chars:
                    edge_name = edge_name.replace(c, "")
                edge_name = edge_name.upper()
                unique_edge_names.add(edge_name)
                object_url = t[2].replace("'", "\\'")
                object_name = t[5].replace("'", "\\'")
                object_qcode = object_url[object_url.rfind("Q"):]
                if object_qcode in all_humans_qcodes:
                    object_label = "Person"
                else:
                    object_label = non_person_node_label

                    row2 = [object_name, object_url]
                    writer2.writerow(row2)
                
                row = [subject_url, edge_url, object_url, subject_name, edge_name, object_name, object_label]
                writer.writerow(row)

# %%
# https://neo4j.com/docs/cypher-manual/current/clauses/call-subquery/#subquery-call-in-transactions
# https://neo4j.com/docs/cypher-manual/current/clauses/load-csv/
# UWAGA: nie można przypisywać labelek z pliku csv jako np. line.label
# EHH: https://community.neo4j.com/t/create-edges-and-their-labels-from-load-csv/45325
# https://stackoverflow.com/questions/47938032/how-to-get-relation-from-csv-in-neo4j-cypher-using-csv-load
# possible rozwiązanie: zrobić milion plików .csv, każdy odpowiadający innej nazwie krawędzi... ale najpierw przetestować to komórkę niżej 

query = f"""
LOAD CSV WITH HEADERS FROM 'file:///{wdLabel_nodes_csv_fp}' AS line FIELDTERMINATOR ';'
CALL {{
  WITH line
  MERGE (:wdLabel {{ name: line.object_name, wd_url: line.object_url }})
}} IN TRANSACTIONS
"""
session.run(query)

# %%
# o_O coś w końcu działa... przetestować szybkość wykonywania TODO
for edge_name in unique_edge_names:
  query2 = f"""
  LOAD CSV WITH HEADERS FROM 'file:///{edges_csv_fp}' AS line FIELDTERMINATOR ';'
  CALL {{
    WITH line 
    MATCH (p:Person {{wd_url: line.subject_url}}), (o{{wd_url: line.object_url}})  
    WHERE line.edge_name = "{edge_name}"
    MERGE (p)-[:{edge_name} {{wd_url: line.edge_url, source: 'wikidata'}}]->(o)
  }} IN TRANSACTIONS
  """
  # print(query2) # HERE o:wdLabel
  session.run(query2)

# %% [markdown]
# ## delete all nodes

# %%
# # DELETE ALL
# s="""MATCH (n)
# CALL { WITH n
# DETACH DELETE n
# } IN TRANSACTIONS;"""
# session.run(s)

# %% [markdown]
# ## session close

# %%
# session.close()

# %% [markdown]
# # Komentarze
# Zbiór niezbyt dobrze uporządkowanych myśli i nieścisłych wyrażeń *(informacje dla mnie, po jakimś czasie i tak przestałem aktualizować tę sekcję)*

# %% [markdown]
# Co zrobiłem:
# * uporządkowałem kod
# * odrzuciłem pojedyncze nazwy z listy osób, np. "Pierre"
# * ```get_all_triples_and_qcodes()``` dodałem opcję zostawienia tych objects, które nie są Qcodami w wikidata (różne literały, często są to jakieś id w muzeach czy innych zbiorach danych, wcześniej to odrzuciłem bo wydało mi się nieprzydatne)
# * ^ ale wd_url będzie wtedy literałem, a nie urlem w grafie. Nie jest to chyba duży problem i może tak zostać.
# * dla krawędzi: uppercase nazw i dodanie atrybutu ```source: 'wikidata' ```
# * dla każdego subject z listy sprawdzenie wszystkich powiązanych objects i zapisanie qcodów tych obiektów, które są ```instance_of``` --> ```human```
# * ```scrape_qcodes(list, humans_only=False, first_only=False)``` dodałem sposób na dostanie Qcode tylko pierwszego znalezionego człowieka na wikidata
# * zrezygnowałem z atrybutu ```description``` dla scrapeowanych qcodów (w grafie)
# * rekurencyjne pobieranie info o ludziach połączonych z ludźmi z inputu
#
# Kilka problematycznych kwestii:
# * a może nie brać osób z listów Paderewskiego, a zostawić tylko osoby z listów Chopina?
# * osoba, o którą nam chodzi nie jest pierwszym wynikiem na liście wyszukiwania w wikidata
# * czy kontrolujemy manualnie poprawność osób dodanych z wikidata? (chodzi o osoby z input_list)
# * biblioteka SPARQLWrapper nie działa dobrze, zwraca często zmultiplikowane wyniki i spowalnia działanie programu
# * osoby, które są na najniższym poziome (liście drzewa) nie mają żadnych atrybutów (trójek rdf), bo kiedyś ten łańcuch trzeba skończyć. Pytanie w jaki sposób.
# * w grafie prawdopodobnie będą błędy, np. randomowe osoby nazywające się tak samo jak np. te wspomniane w listach, a tych wspomnianych nie będzie w grafie
# * będą sobie pływały randomowe węzły osób w tym grafie, np. Q383232 (Afiat Yuris Wirawan, gracz badmintona) bo np Rachmaninov ma "FactGrid item ID": Q383232
# * ^ EDIT:   naprawiłem to dla tego specyficznego przypadku krawędzi "FactGrid item ID", u nich wszystkie ID są postaci takiej jak Qcody na wikidata
# * ^         ale mogą się pojawić inne randomowe osoby i przez to nie będzie tworzony węzęł z obiektem o nazwie np. Q123 i nie będzie krawędzi między subjectem(osobą) a obiektem/randomową osobą
#
# ['Etienne',
#  'Perrichet',
#  'Pierre',
#  'Alexis',
#  'Grandville',
#  'Rafael',
#  'Voltaire']
#
# Granville https://www.wikidata.org/wiki/Q744442 ???
#
# Voltaire https://www.wikidata.org/wiki/Q9068 ???
#
# Pierre służący Fryderyka Chopina ???
#
#
# --- na razie robię sobie przerwę od tego projektu, muszę zacząć robić pracę inżynierską i mam też inny projekt
#
# -- https://query.wikidata.org/ do rozważenia jakby ktoś chciał się zająć pobieraniem innych danych (nie dotyczących osób)

# %% [markdown]
# # TODO

# %% [markdown]
# * Ctrl + f "TODO" w kodzie - things to work on first
# * Zbyt długo trwa robienie grafu. Może zrobienie csv i potem wczytywanie csv do neo4j będzie szybsze niż pojedyncze robienie węzłów i krawędzi. Zrobić indeksy, zwiększyć limity pamięci w neo4j desktop, zrobić CSV do krawędzi i LOAD CSV, CALL IN TRANSACTIONS. Do zrobienia.
# * Zbyt długo trwa recursive_get_rdf_info. Napisać szybszą funkcję, dającą ten sam wynik.
# * Może by tak oznaczać osoby (węzeł :Person), które nie mają atrybutów z wikidata (czyli w grafie powiązań z węzłami wdLabel) jakąś inną etykietą, lub jakimś atrybutem, np. "leaf"/"no_further_info"/"no_". Są to "osoby-liście", na których kończy się rekurencyjne pobieranie info o ludziach. ({all_humans} - {rdf_info.keys()}). A może nie trzeba i zostawić tak jak jest?
# * Biblioteka SPARQLWrapper nie działa dobrze, zwraca często zmultiplikowane wyniki i spowalnia działanie programu, można spróbować użyć innej biblioteki lub samemu napisać.
# * Może nie brać osób z listów Paderewskiego, a zostawić tylko osoby z listów Chopina?
# * [EDIT] [nieważne, neo4j browser nie wyświetla krawędzi czasami] czemu wielu kompozytorów nie ma OCCUPATION -> composer? np. Robert Schumann... Wygląda na to, że czasamiu niektóre krawędzie się nie tworzą, zbadać przyczynę i naprawić.
# * [DONE] Niektórych osób z input listy nie wyszukuje w wikdata. Jak się usunie dopiski w nawiasach, to już tak, np. dla "Józef Michał Poniatowski (książę)".
# * [DONE] w np. DATE_OF_BIRTH są jakieś śmieci czasami, np. http://www.wikidata.org/.well-known/genid/c9a8b2f22783c60e6bf383200d9285f7. Pewnie można by w "create other nodes, edges & connect to Person nodes" sprawdzać wartość dla qcodów dat np date_of_birth, date_of_costam.
#
#
# ** TYLKO POMYSŁ: sporo czasu by trzeba poświęcić na sprawdzanie czy pierszy scrape'owany human z wikidata search to osoba której chcemy (czyli w jakiś sposób powiązana z Chopinem/osobami na grafie).

# %% [markdown]
# ## sample cypher queries

# %%
# UWAGA: nie można traktować uzyskanych wyników jako prawdę odzwierdciedlającą rzeczywistość; dane są niekompletne i pewnie niektóre nawet są nieprawdziwe.

# MATCH (n) WHERE n.name =~ ".*Chopin.*" RETURN n

# match (n:Person)-[e:OCCUPATION]-(s) WHERE s.name CONTAINS "composer" return n,s

# MATCH (p:Person)-[l:residence]-(s)
# WHERE p.name=~'.*Chopin' or p.name=~'.*Liszt'
# RETURN p, s

# MATCH (p:Person)-[l:RESIDENCE]-(s)
# WHERE p.name=~'.*Chopin' or p.name=~'.*Beethoven.*'
# RETURN p, s

# MATCH (p:Person)-[l:STUDENT_OF]-(s)
# WHERE p.name=~'.*Frédéric Chopin.*' or p.name=~'.*Franz Liszt.*'
# RETURN p, s

# Match(p:Person)-[e:date_of_birth]-(l:Label) return p, l

# match (n:Person) WHERE n.name CONTAINS "Bee" return n

# MATCH (p:Person)-[e:OCCUPATION]-(s:wdLabel) WHERE s.name =~ ".*singer.*" RETURN p,s

# MATCH w=(p:Person)-[e:INSTRUMENT]-(s:wdLabel)
# WITH s, COLLECT(w) as test
# ORDER BY SIZE(test) DESC
# RETURN s.name, SIZE(test)

# MATCH (p:Person)-[e:DATE_OF_BIRTH]-(d:wdLabel)
# WHERE datetime({year: 1770, month:7}) <= datetime(d.name) < datetime({year: 1771})
# WITH p, d
# ORDER BY d.name DESC
# RETURN p, d, p.name, d.name

# MATCH (p:Person)-[e:HANDEDNESS]-(s:wdLabel), (p)-[i:INSTRUMENT]-(s2:wdLabel)
# WHERE s.name =~ '.*left.*' 
# RETURN *  

# MATCH (p:Person)-[e:HANDEDNESS]-(s:wdLabel)
# WHERE s.name =~ '.*left.*' 
# RETURN *  

# MATCH (p:Person)-[e:DIFFERENT_FROM]-(o)
# WHERE p.name =~ '.*.*'
# RETURN p, o limit 200
